# %%
import numpy as np
import matplotlib.pylab as plt
# %matplotlib inline
#%config InlineBackend.figure_format = 'eps'


import scienceplots
import pandas as pd
plt.style.use('science')


from mpl_toolkits.axes_grid1.inset_locator import inset_axes
from matplotlib.patches import  ConnectionPatch

# %% [markdown]
# ### Small world 3000 datasets

# %%
# Samped nodes by probability
# ws1w_degree_sn = pd.read_csv('ws1w/convert_accuracy/ws1w_gcn_vae_degree_sn.csv')
# ws1w_core_sn = pd.read_csv('ws1w/convert_accuracy/ws1w_gcn_vae_core_sn.csv')
# ws1w_betweenness_sn = pd.read_csv('ws1w/convert_accuracy/ws1w_gcn_vae_betweenness_sn.csv')
# # ws1w_eigenvector_sn = pd.read_csv('ws1w/convert_accuracy/ws1w_gcn_vae_eigenvector_sn.csv')
# ws1w_pagerank_sn = pd.read_csv('ws1w/convert_accuracy/ws1w_gcn_vae_pagerank_sn.csv')
# ws1w_closeness_sn = pd.read_csv('ws1w/convert_accuracy/ws1w_gcn_vae_closeness_sn.csv')
# ws1w_gravitydegree_sn = pd.read_csv('ws1w/convert_accuracy/ws1w_gcn_vae_gravitydegree_sn.csv')
# ws1w_gravitypagerank_sn  = pd.read_csv('ws1w/convert_accuracy/ws1w_gcn_vae_gravitypagerank_sn.csv')
# ws1w_gravitycore_sn = pd.read_csv('ws1w/convert_accuracy/ws1w_gcn_vae_gravitycore_sn.csv')
# ws1w_gravitybetweenness_sn = pd.read_csv('ws1w/convert_accuracy/ws1w_gcn_vae_gravitybetweenness_sn.csv')
# # ws1w_gravityeigenvector_sn = pd.read_csv('ws1w/convert_accuracy/ws1w_gcn_vae_gravityeigenvector_sn.csv')
# ws1w_gravitycloseness_sn = pd.read_csv('ws1w/convert_accuracy/ws1w_gcn_vae_gravitycloseness_sn.csv')


# ws1w_degree_tn = pd.read_csv('ws1w/convert_accuracy/ws1w_gcn_vae_degree_tn.csv')
# ws1w_core_tn = pd.read_csv('ws1w/convert_accuracy/ws1w_gcn_vae_core_tn.csv')
# ws1w_betweenness_tn = pd.read_csv('ws1w/convert_accuracy/ws1w_gcn_vae_betweenness_tn.csv')
# # ws1w_eigenvector_tn = pd.read_csv('ws1w/convert_accuracy/ws1w_gcn_vae_eigenvector_tn.csv')
# ws1w_pagerank_tn = pd.read_csv('ws1w/convert_accuracy/ws1w_gcn_vae_pagerank_tn.csv')
# ws1w_closeness_tn = pd.read_csv('ws1w/convert_accuracy/ws1w_gcn_vae_closeness_tn.csv')
# ws1w_gravitydegree_tn = pd.read_csv('ws1w/convert_accuracy/ws1w_gcn_vae_gravitydegree_tn.csv')
# ws1w_gravitypagerank_tn  = pd.read_csv('ws1w/convert_accuracy/ws1w_gcn_vae_gravitypagerank_tn.csv')
# ws1w_gravitycore_tn = pd.read_csv('ws1w/convert_accuracy/ws1w_gcn_vae_gravitycore_tn.csv')
# ws1w_gravitybetweenness_tn = pd.read_csv('ws1w/convert_accuracy/ws1w_gcn_vae_gravitybetweenness_tn.csv')
# # ws1w_gravityeigenvector_tn = pd.read_csv('ws1w/convert_accuracy/ws1w_gcn_vae_gravityeigenvector_tn.csv')
# ws1w_gravitycloseness_tn = pd.read_csv('ws1w/convert_accuracy/ws1w_gcn_vae_gravitycloseness_tn.csv')

ws1w_degree_rn = pd.read_csv('ws1w/convert_accuracy/ws1w_gcn_vae_degree_rn.csv')
ws1w_core_rn = pd.read_csv('ws1w/convert_accuracy/ws1w_gcn_vae_core_rn.csv')
ws1w_betweenness_rn = pd.read_csv('ws1w/convert_accuracy/ws1w_gcn_vae_betweenness_rn.csv')
# ws1w_eigenvector_rn = pd.read_csv('ws1w/convert_accuracy/ws1w_gcn_vae_eigenvector_rn.csv')
ws1w_pagerank_rn = pd.read_csv('ws1w/convert_accuracy/ws1w_gcn_vae_pagerank_rn.csv')
ws1w_closeness_rn = pd.read_csv('ws1w/convert_accuracy/ws1w_gcn_vae_closeness_rn.csv')
ws1w_gravitydegree_rn = pd.read_csv('ws1w/convert_accuracy/ws1w_gcn_vae_gravitydegree_rn.csv')
ws1w_gravitypagerank_rn  = pd.read_csv('ws1w/convert_accuracy/ws1w_gcn_vae_gravitypagerank_rn.csv')
ws1w_gravitycore_rn = pd.read_csv('ws1w/convert_accuracy/ws1w_gcn_vae_gravitycore_rn.csv')
ws1w_gravitybetweenness_rn = pd.read_csv('ws1w/convert_accuracy/ws1w_gcn_vae_gravitybetweenness_rn.csv')
# ws1w_gravityeigenvector_rn = pd.read_csv('ws1w/convert_accuracy/ws1w_gcn_vae_gravityeigenvector_rn.csv')
ws1w_gravitycloseness_rn = pd.read_csv('ws1w/convert_accuracy/ws1w_gcn_vae_gravitycloseness_rn.csv')

ws1w_uniform = pd.read_csv('ws1w/convert_accuracy/ws1w_gcn_vae_degree_un.csv')

# %%
ws1w_degree = np.genfromtxt('ws1w/convert_accuracy/ws1w_degree.csv',delimiter = ',')
ws1w_core = np.genfromtxt('ws1w/convert_accuracy/ws1w_core.csv',delimiter = ',')
ws1w_pagerank = np.genfromtxt('ws1w/convert_accuracy/ws1w_pagerank.csv',delimiter=',')
ws1w_betweenness = np.genfromtxt('ws1w/convert_accuracy/ws1w_betweenness.csv',delimiter = ',')
ws1w_closeness = np.genfromtxt('ws1w/convert_accuracy/ws1w_closeness.csv',delimiter = ',')
# ws1w_eigenvector = np.genfromtxt('ws1w/convert_accuracy/ws1w_eigenvector.csv',delimiter=',')

ws1w_gravitydegree = np.genfromtxt('ws1w/convert_accuracy/ws1w_gravitydegree.csv',delimiter=',')
ws1w_gravitypagerank  = np.genfromtxt('ws1w/convert_accuracy/ws1w_gravitypagerank.csv',delimiter=',')
ws1w_gravitycore = np.genfromtxt('ws1w/convert_accuracy/ws1w_gravitycore.csv',delimiter=',')
ws1w_gravitybetweenness = np.genfromtxt('ws1w/convert_accuracy/ws1w_gravitybetweenness.csv',delimiter = ',')
ws1w_gravitycloseness = np.genfromtxt('ws1w/convert_accuracy/ws1w_gravitycloseness.csv',delimiter = ',')
# ws1w_gravityeigenvector = np.genfromtxt('ws1w/convert_accuracy/ws1w_gravityeigenvector.csv',delimiter=',')
ws1w_uniform = np.genfromtxt('ws1w/convert_accuracy/ws1w_uniform.csv',delimiter=',')

# %%
cath_gravityeigenvector.shape
# Out:
# (99, 6)

# %%
plt.style.use('nature')
from scipy.optimize import curve_fit
from scipy.interpolate import UnivariateSpline


def cubic_fit(x, a, b, c, d):
    return a * x**3 + b * x**2 + c * x + d

x = np.linspace(0,1,60)

fig,axes = plt.subplots(5,2,figsize = (2,5),dpi=600)

params, covariance = curve_fit(cubic_fit, x, ws1w_uniform[:60,0])
a_fit, b_fit, c_fit, d_fit = params
ws1w_uniform1 = cubic_fit(x, a_fit, b_fit, c_fit, d_fit)
axes[0,0].plot(x,ws1w_uniform1,color ='#6F99ADFF', label = 'Uniform nodes(UN*)',linewidth=0.5)
axes[0,0].scatter(x, ws1w_uniform[:60,0],color ='#6F99ADFF',edgecolors='none', s=0.4, alpha=0.6)
distances = np.abs(ws1w_uniform[:60, 0] - ws1w_uniform1)
spline = UnivariateSpline(np.arange(len(distances)), distances.flatten(), s=0)
smooth_distances = spline(np.arange(len(distances)))
smooth_distances_mean = np.mean([np.min(smooth_distances), np.max(smooth_distances)])* 0.10
axes[0,0].fill_between(x, ws1w_uniform1-smooth_distances_mean, ws1w_uniform1+smooth_distances_mean, color='#6F99ADFF', alpha=0.2,edgecolors='none')
params, covariance = curve_fit(cubic_fit, x, ws1w_degree[:60, 2])
a_fit, b_fit, c_fit, d_fit = params
ws1w_degree_fit = cubic_fit(x, a_fit, b_fit, c_fit, d_fit)
axes[0,0].plot(x, ws1w_degree_fit, color='#FFDC91FF', label='Top nodes(TN)', linewidth=0.5)
axes[0,0].scatter(x, ws1w_degree[:60, 2], color ='#FFDC91FF',edgecolors='none', s=0.4, alpha=0.6)
distances = np.abs(ws1w_degree[:60, 2] - ws1w_degree_fit)
spline = UnivariateSpline(np.arange(len(distances)), distances.flatten(), s=0)
smooth_distances = spline(np.arange(len(distances)))
smooth_distances_mean = np.mean([np.min(smooth_distances), np.max(smooth_distances)]) * 0.10
axes[0,0].fill_between(x, ws1w_degree_fit - smooth_distances_mean, ws1w_degree_fit + smooth_distances_mean, color='#FFDC91FF', alpha=0.2,edgecolors='none')

axes[0,0].tick_params(labelsize=4)

axes[0,0].set_xticks([0,0.12,0.35,0.7,1])
axes[0,0].set_xticklabels(np.array([0, 300,980, 2000, 2700]).astype(int))

axes[0,0].grid (False)
axes[0,0].spines['top'].set_visible(False)
axes[0,0].spines['right'].set_visible(False)
axes[0,0].xaxis.set_ticks_position('bottom')
axes[0,0].yaxis.set_ticks_position('left')
axes[0,0].set_yticks(np.linspace(0.6, 1, 5))
axes[0,0].set_yticks([0.6, 0.7, 0.8, 0.9,1])
axes[0,0].set_xticks([], minor=True)
axes[0,0].set_yticks([], minor=True)
axes[0,0].tick_params(axis='both', which='both', length=1.2)
axes[0,0].text(0.5, 0.97, 'Degree', transform=axes[0,0].transAxes, ha='center', va='center', bbox=dict(facecolor='none', edgecolor='none', boxstyle='round', alpha=0.0), fontsize=4)



params, covariance = curve_fit(cubic_fit, x, ws1w_uniform[:60,0])
a_fit, b_fit, c_fit, d_fit = params
ws1w_uniform1 = cubic_fit(x, a_fit, b_fit, c_fit, d_fit)
axes[1,0].plot(x,ws1w_uniform1,color ='#6F99ADFF', label = 'uniform',linewidth=0.5)
axes[1,0].scatter(x, ws1w_uniform[:60,0],color ='#6F99ADFF',edgecolors='none', s=0.4, alpha=0.6)
distances = np.abs(ws1w_uniform[:60, 0] - ws1w_uniform1)
spline = UnivariateSpline(np.arange(len(distances)), distances.flatten(), s=0)
smooth_distances = spline(np.arange(len(distances)))
smooth_distances_mean = np.mean([np.min(smooth_distances), np.max(smooth_distances)])* 0.10
axes[1,0].fill_between(x, ws1w_uniform1-smooth_distances_mean, ws1w_uniform1+smooth_distances_mean, color='#6F99ADFF', alpha=0.2,edgecolors='none')
params, covariance = curve_fit(cubic_fit, x, ws1w_core[:60, 2])
a_fit, b_fit, c_fit, d_fit = params
ws1w_core_fit = cubic_fit(x, a_fit, b_fit, c_fit, d_fit)
axes[1,0].plot(x, ws1w_core_fit, color='#FFDC91FF', label='Top Nodes', linewidth=0.5)
axes[1,0].scatter(x, ws1w_core[:60, 2], color ='#FFDC91FF',edgecolors='none', s=0.4, alpha=0.6)
distances = np.abs(ws1w_core[:60, 2] - ws1w_core_fit)
spline = UnivariateSpline(np.arange(len(distances)), distances.flatten(), s=0)
smooth_distances = spline(np.arange(len(distances)))
smooth_distances_mean = np.mean([np.min(smooth_distances), np.max(smooth_distances)]) * 0.10
axes[1,0].fill_between(x, ws1w_core_fit - smooth_distances_mean, ws1w_core_fit + smooth_distances_mean, color='#FFDC91FF', alpha=0.2,edgecolors='none')

axes[1,0].tick_params(labelsize=4)
axes[1,0].set_xticks([0,0.12,0.35,0.7,1])
axes[1,0].set_xticklabels(np.array([0, 300,980, 2000, 2700]).astype(int))
#axes[1,0].legend(fontsize=3,edgecolor='black',framealpha=0.1,loc='center right')
axes[1,0].grid (False)
axes[1,0].spines['top'].set_visible(False)
axes[1,0].spines['right'].set_visible(False)
axes[1,0].xaxis.set_ticks_position('bottom')
axes[1,0].yaxis.set_ticks_position('left')
axes[1,0].set_yticks(np.linspace(0.6, 1, 5))
axes[1,0].set_yticks([0.6, 0.7, 0.8, 0.9,1])
axes[1,0].set_xticks([], minor=True)
axes[1,0].set_yticks([], minor=True)
axes[1,0].tick_params(axis='both', which='both', length=1.2)
axes[1,0].text(0.5, 0.97, 'Core', transform=axes[1,0].transAxes, ha='center', va='center', bbox=dict(facecolor='none', edgecolor='none', boxstyle='round', alpha=0.0), fontsize=4)



params, covariance = curve_fit(cubic_fit, x, ws1w_uniform[:60,0])
a_fit, b_fit, c_fit, d_fit = params
ws1w_uniform1 = cubic_fit(x, a_fit, b_fit, c_fit, d_fit)
axes[2,0].plot(x,ws1w_uniform1,color ='#6F99ADFF', label = 'uniform',linewidth=0.5)
axes[2,0].scatter(x, ws1w_uniform[:60,0],color ='#6F99ADFF',edgecolors='none', s=0.4, alpha=0.6)
distances = np.abs(ws1w_uniform[:60, 0] - ws1w_uniform1)
spline = UnivariateSpline(np.arange(len(distances)), distances.flatten(), s=0)
smooth_distances = spline(np.arange(len(distances)))
smooth_distances_mean = np.mean([np.min(smooth_distances), np.max(smooth_distances)])* 0.10
axes[2,0].fill_between(x, ws1w_uniform1-smooth_distances_mean, ws1w_uniform1+smooth_distances_mean, color='#6F99ADFF', alpha=0.2,edgecolors='none')
params, covariance = curve_fit(cubic_fit, x, ws1w_pagerank[:60, 2])
a_fit, b_fit, c_fit, d_fit = params
ws1w_pagerank_fit = cubic_fit(x, a_fit, b_fit, c_fit, d_fit)
axes[2,0].plot(x, ws1w_pagerank_fit, color='#FFDC91FF', label='Top Nodes', linewidth=0.5)
axes[2,0].scatter(x, ws1w_pagerank[:60, 2], color ='#FFDC91FF',edgecolors='none', s=0.4, alpha=0.6)
distances = np.abs(ws1w_pagerank[:60, 2] - ws1w_pagerank_fit)
spline = UnivariateSpline(np.arange(len(distances)), distances.flatten(), s=0)
smooth_distances = spline(np.arange(len(distances)))
smooth_distances_mean = np.mean([np.min(smooth_distances), np.max(smooth_distances)]) * 0.10
axes[2,0].fill_between(x, ws1w_pagerank_fit - smooth_distances_mean, ws1w_pagerank_fit + smooth_distances_mean, color='#FFDC91FF', alpha=0.2,edgecolors='none')

axes[2,0].tick_params(labelsize=4)
axes[2,0].set_xticks([0,0.12,0.35,0.7,1])
axes[2,0].set_xticklabels(np.array([0, 300,980, 2000, 2700]).astype(int))
#axes[2,0].legend(fontsize=3,edgecolor='black',framealpha=0.1,loc='center right')
axes[2,0].grid (False)
axes[2,0].spines['top'].set_visible(False)
axes[2,0].spines['right'].set_visible(False)
axes[2,0].xaxis.set_ticks_position('bottom')
axes[2,0].yaxis.set_ticks_position('left')
axes[2,0].set_yticks(np.linspace(0.6, 1, 5))
axes[2,0].set_yticks([0.6, 0.7, 0.8, 0.9,1])
axes[2,0].set_xticks([], minor=True)
axes[2,0].set_yticks([], minor=True)
axes[2,0].tick_params(axis='both', which='both', length=1.2)
axes[2,0].text(0.5, 0.97, 'Pagerank', transform=axes[2,0].transAxes, ha='center', va='center', bbox=dict(facecolor='none', edgecolor='none', boxstyle='round', alpha=0.0), fontsize=4)

params, covariance = curve_fit(cubic_fit, x, ws1w_uniform[:60,0])
a_fit, b_fit, c_fit, d_fit = params
ws1w_uniform1 = cubic_fit(x, a_fit, b_fit, c_fit, d_fit)
axes[3,0].plot(x,ws1w_uniform1,color ='#6F99ADFF', label = 'uniform',linewidth=0.5)
axes[3,0].scatter(x, ws1w_uniform[:60,0],color ='#6F99ADFF',edgecolors='none', s=0.4, alpha=0.6)
distances = np.abs(ws1w_uniform[:60, 0] - ws1w_uniform1)
spline = UnivariateSpline(np.arange(len(distances)), distances.flatten(), s=0)
smooth_distances = spline(np.arange(len(distances)))
smooth_distances_mean = np.mean([np.min(smooth_distances), np.max(smooth_distances)])* 0.10
axes[3,0].fill_between(x, ws1w_uniform1-smooth_distances_mean, ws1w_uniform1+smooth_distances_mean, color='#6F99ADFF', alpha=0.2,edgecolors='none')
params, covariance = curve_fit(cubic_fit, x, ws1w_betweenness[:60, 2])
a_fit, b_fit, c_fit, d_fit = params
ws1w_betweenness_fit = cubic_fit(x, a_fit, b_fit, c_fit, d_fit)
axes[3,0].plot(x, ws1w_betweenness_fit, color='#FFDC91FF', label='Top Nodes', linewidth=0.5)
axes[3,0].scatter(x, ws1w_betweenness[:60, 2], color ='#FFDC91FF',edgecolors='none', s=0.4, alpha=0.6)
distances = np.abs(ws1w_betweenness[:60, 2] - ws1w_betweenness_fit)
spline = UnivariateSpline(np.arange(len(distances)), distances.flatten(), s=0)
smooth_distances = spline(np.arange(len(distances)))
smooth_distances_mean = np.mean([np.min(smooth_distances), np.max(smooth_distances)]) * 0.10
axes[3,0].fill_between(x, ws1w_betweenness_fit - smooth_distances_mean, ws1w_betweenness_fit + smooth_distances_mean, color='#FFDC91FF', alpha=0.2,edgecolors='none')

axes[3,0].tick_params(labelsize=4)
axes[3,0].set_xticks([0,0.12,0.35,0.7,1])
axes[3,0].set_xticklabels(np.array([0, 300,980, 2000, 2700]).astype(int))
#axes[3,0].legend(fontsize=3,edgecolor='black',framealpha=0.1,loc='center right')
axes[3,0].grid (False)
axes[3,0].spines['top'].set_visible(False)
axes[3,0].spines['right'].set_visible(False)
axes[3,0].xaxis.set_ticks_position('bottom')
axes[3,0].yaxis.set_ticks_position('left')
axes[3,0].set_yticks(np.linspace(0.6, 1, 5))
axes[3,0].set_yticks([0.6, 0.7, 0.8, 0.9,1])
axes[3,0].set_xticks([], minor=True)
axes[3,0].set_yticks([], minor=True)
axes[3,0].tick_params(axis='both', which='both', length=1.2)
axes[3,0].text(0.5, 0.97, 'Betweenness', transform=axes[3,0].transAxes, ha='center', va='center', bbox=dict(facecolor='none', edgecolor='none', boxstyle='round', alpha=0.0), fontsize=4)


params, covariance = curve_fit(cubic_fit, x, ws1w_uniform[:60,0])
a_fit, b_fit, c_fit, d_fit = params
ws1w_uniform1 = cubic_fit(x, a_fit, b_fit, c_fit, d_fit)
axes[4,0].plot(x,ws1w_uniform1,color ='#6F99ADFF', label = 'uniform',linewidth=0.5)
axes[4,0].scatter(x, ws1w_uniform[:60,0],color ='#6F99ADFF',edgecolors='none', s=0.4, alpha=0.6)
distances = np.abs(ws1w_uniform[:60, 0] - ws1w_uniform1)
spline = UnivariateSpline(np.arange(len(distances)), distances.flatten(), s=0)
smooth_distances = spline(np.arange(len(distances)))
smooth_distances_mean = np.mean([np.min(smooth_distances), np.max(smooth_distances)])* 0.10
axes[4,0].fill_between(x, ws1w_uniform1-smooth_distances_mean, ws1w_uniform1+smooth_distances_mean, color='#6F99ADFF', alpha=0.2,edgecolors='none')
params, covariance = curve_fit(cubic_fit, x, ws1w_closeness[:60, 2])
a_fit, b_fit, c_fit, d_fit = params
ws1w_closeness_fit = cubic_fit(x, a_fit, b_fit, c_fit, d_fit)
axes[4,0].plot(x, ws1w_closeness_fit, color='#FFDC91FF', label='Top Nodes', linewidth=0.5)
axes[4,0].scatter(x, ws1w_closeness[:60, 2], color ='#FFDC91FF',edgecolors='none', s=0.4, alpha=0.6)
distances = np.abs(ws1w_closeness[:60, 2] - ws1w_closeness_fit)
spline = UnivariateSpline(np.arange(len(distances)), distances.flatten(), s=0)
smooth_distances = spline(np.arange(len(distances)))
smooth_distances_mean = np.mean([np.min(smooth_distances), np.max(smooth_distances)]) * 0.10
axes[4,0].fill_between(x, ws1w_closeness_fit - smooth_distances_mean, ws1w_closeness_fit + smooth_distances_mean, color='#FFDC91FF', alpha=0.2,edgecolors='none')

axes[4,0].tick_params(labelsize=4)
axes[4,0].set_xticks([0,0.12,0.35,0.7,1])
axes[4,0].set_xticklabels(np.array([0, 300,980, 2000, 2700]).astype(int))
#axes[4,0].legend(fontsize=3,edgecolor='black',framealpha=0.1,loc='center right')
axes[4,0].grid (False)
axes[4,0].spines['top'].set_visible(False)
axes[4,0].spines['right'].set_visible(False)
axes[4,0].xaxis.set_ticks_position('bottom')
axes[4,0].yaxis.set_ticks_position('left')
axes[4,0].set_yticks(np.linspace(0.6, 1, 5))
axes[4,0].set_yticks([0.6, 0.7, 0.8, 0.9,1])
axes[4,0].set_xticks([], minor=True)
axes[4,0].set_yticks([], minor=True)
axes[4,0].tick_params(axis='both', which='both', length=1.2)
axes[4,0].text(0.5, 0.97, 'Closeness', transform=axes[4,0].transAxes, ha='center', va='center', bbox=dict(facecolor='none', edgecolor='none', boxstyle='round', alpha=0.0), fontsize=4)



params, covariance = curve_fit(cubic_fit, x, ws1w_uniform[:60,0])
a_fit, b_fit, c_fit, d_fit = params
ws1w_uniform1 = cubic_fit(x, a_fit, b_fit, c_fit, d_fit)

params, covariance = curve_fit(cubic_fit, x, ws1w_uniform[:60,0])
a_fit, b_fit, c_fit, d_fit = params
ws1w_uniform1 = cubic_fit(x, a_fit, b_fit, c_fit, d_fit)
axes[0,1].plot(x,ws1w_uniform1,color ='#6F99ADFF', label = 'uniform',linewidth=0.5)
axes[0,1].scatter(x, ws1w_uniform[:60,0],color ='#6F99ADFF',edgecolors='none', s=0.4, alpha=0.6)
distances = np.abs(ws1w_uniform[:60, 0] - ws1w_uniform1)
spline = UnivariateSpline(np.arange(len(distances)), distances.flatten(), s=0)
smooth_distances = spline(np.arange(len(distances)))
smooth_distances_mean = np.mean([np.min(smooth_distances), np.max(smooth_distances)])* 0.10
axes[0,1].fill_between(x, ws1w_uniform1-smooth_distances_mean, ws1w_uniform1+smooth_distances_mean, color='#6F99ADFF', alpha=0.2,edgecolors='none')

axes[0,1].tick_params(labelsize=4)
axes[0,1].set_xticks([0,0.12,0.35,0.7,1])
axes[0,1].set_xticklabels(np.array([0, 300,980, 2000, 2700]).astype(int))
axes[0,1].grid (False)
axes[0,1].spines['top'].set_visible(False)
axes[0,1].spines['right'].set_visible(False)
axes[0,1].xaxis.set_ticks_position('bottom')
axes[0,1].yaxis.set_ticks_position('left')
axes[0,1].set_yticks(np.linspace(0.6, 1, 5))
axes[0,1].set_yticks([0.6, 0.7, 0.8, 0.9,1])
axes[0,1].set_xticks([], minor=True)
axes[0,1].set_yticks([], minor=True)
axes[0,1].tick_params(axis='both', which='both', length=1.2)
axes[0,1].text(0.5, 0.97, 'Gravitydegree', transform=axes[0,1].transAxes, ha='center', va='center', bbox=dict(facecolor='none', edgecolor='none', boxstyle='round', alpha=0.0), fontsize=4)


axes[0,1].plot(x,ws1w_uniform1,color ='#6F99ADFF', label = 'uniform',linewidth=0.5)
axes[0,1].scatter(x, ws1w_uniform[:60,0],color ='#6F99ADFF',edgecolors='none', s=0.4, alpha=0.6)
distances = np.abs(ws1w_uniform[:60, 0] - ws1w_uniform1)
spline = UnivariateSpline(np.arange(len(distances)), distances.flatten(), s=0)
smooth_distances = spline(np.arange(len(distances)))
smooth_distances_mean = np.mean([np.min(smooth_distances), np.max(smooth_distances)])* 0.10
axes[0,1].fill_between(x, ws1w_uniform1-smooth_distances_mean, ws1w_uniform1+smooth_distances_mean, color='#6F99ADFF', alpha=0.2,edgecolors='none')

params, covariance = curve_fit(cubic_fit, x, ws1w_gravitydegree[:60, 2])
a_fit, b_fit, c_fit, d_fit = params
ws1w_gravitydegree_fit = cubic_fit(x, a_fit, b_fit, c_fit, d_fit)
axes[0,1].plot(x, ws1w_gravitydegree_fit, color='#FFDC91FF', label='Top Nodes', linewidth=0.5)
axes[0,1].scatter(x, ws1w_gravitydegree[:60, 2], color ='#FFDC91FF',edgecolors='none', s=0.4, alpha=0.6)
distances = np.abs(ws1w_gravitydegree[:60, 2] - ws1w_gravitydegree_fit)
spline = UnivariateSpline(np.arange(len(distances)), distances.flatten(), s=0)
smooth_distances = spline(np.arange(len(distances)))
smooth_distances_mean = np.mean([np.min(smooth_distances), np.max(smooth_distances)]) * 0.10
axes[0,1].fill_between(x, ws1w_gravitydegree_fit - smooth_distances_mean, ws1w_gravitydegree_fit + smooth_distances_mean, color='#FFDC91FF', alpha=0.2,edgecolors='none')
params, covariance = curve_fit(cubic_fit, x, ws1w_gravitydegree[:60,0])
a_fit, b_fit, c_fit, d_fit = params
ws1w_gravitydegree_fit = cubic_fit(x, a_fit, b_fit, c_fit, d_fit)
axes[0,1].plot(x, ws1w_gravitydegree_fit, color='#BC3C29FF', label='Sampled Nodes', linewidth=0.5)
axes[0,1].scatter(x, ws1w_gravitydegree[:60, 0], color ='#BC3C29FF',edgecolors='none', s=0.4, alpha=0.6)
distances = np.abs(ws1w_gravitydegree[:60, 0] - ws1w_gravitydegree_fit)
spline = UnivariateSpline(np.arange(len(distances)), distances.flatten(), s=0)
smooth_distances = spline(np.arange(len(distances)))
smooth_distances_mean = np.mean([np.min(smooth_distances), np.max(smooth_distances)]) * 0.10
axes[0,1].fill_between(x, ws1w_gravitydegree_fit - smooth_distances_mean, ws1w_gravitydegree_fit + smooth_distances_mean, color='#BC3C29FF', alpha=0.2,edgecolors='none')
axes[0,1].tick_params(labelsize=4)
axes[0,1].set_xticks([0,0.12,0.35,0.7,1])
axes[0,1].set_xticklabels(np.array([0, 300,980, 2000, 2700]).astype(int))
#axes[0,1].legend(fontsize=3,edgecolor='black',framealpha=0.1,loc='center right')
axes[0,1].grid (False)
axes[0,1].spines['top'].set_visible(False)
axes[0,1].spines['right'].set_visible(False)
axes[0,1].xaxis.set_ticks_position('bottom')
axes[0,1].yaxis.set_ticks_position('left')
axes[0,1].set_yticks(np.linspace(0.6, 1, 5))
axes[0,1].set_yticks([0.6, 0.7, 0.8, 0.9,1])
axes[0,1].set_xticks([], minor=True)
axes[0,1].set_yticks([], minor=True)
axes[0,1].tick_params(axis='both', which='both', length=1.2)
axes[0,1].text(0.5, 0.97, 'Gravitydegree', transform=axes[0,1].transAxes, ha='center', va='center', bbox=dict(facecolor='none', edgecolor='none', boxstyle='round', alpha=0.0), fontsize=4)



params, covariance = curve_fit(cubic_fit, x, ws1w_uniform[:60,0])
a_fit, b_fit, c_fit, d_fit = params
ws1w_uniform1 = cubic_fit(x, a_fit, b_fit, c_fit, d_fit)
axes[1,1].plot(x,ws1w_uniform1,color ='#6F99ADFF', label = 'uniform',linewidth=0.5)
axes[1,1].scatter(x, ws1w_uniform[:60,0],color ='#6F99ADFF',edgecolors='none', s=0.4, alpha=0.6)
distances = np.abs(ws1w_uniform[:60, 0] - ws1w_uniform1)
spline = UnivariateSpline(np.arange(len(distances)), distances.flatten(), s=0)
smooth_distances = spline(np.arange(len(distances)))
smooth_distances_mean = np.mean([np.min(smooth_distances), np.max(smooth_distances)])* 0.10
axes[1,1].fill_between(x, ws1w_uniform1-smooth_distances_mean, ws1w_uniform1+smooth_distances_mean, color='#6F99ADFF', alpha=0.2,edgecolors='none')
params, covariance = curve_fit(cubic_fit, x, ws1w_gravitycore[:60, 2])
a_fit, b_fit, c_fit, d_fit = params
ws1w_gravitycore_fit = cubic_fit(x, a_fit, b_fit, c_fit, d_fit)
axes[1,1].plot(x, ws1w_gravitycore_fit, color='#FFDC91FF', label='Top Nodes', linewidth=0.5)
axes[1,1].scatter(x, ws1w_gravitycore[:60, 2], color ='#FFDC91FF',edgecolors='none', s=0.4, alpha=0.6)
distances = np.abs(ws1w_gravitycore[:60, 2] - ws1w_gravitycore_fit)
spline = UnivariateSpline(np.arange(len(distances)), distances.flatten(), s=0)
smooth_distances = spline(np.arange(len(distances)))
smooth_distances_mean = np.mean([np.min(smooth_distances), np.max(smooth_distances)]) *0.10
axes[1,1].fill_between(x, ws1w_gravitycore_fit - smooth_distances_mean, ws1w_gravitycore_fit + smooth_distances_mean, color='#FFDC91FF', alpha=0.2,edgecolors='none')

axes[1,1].tick_params(labelsize=4)
axes[1,1].set_xticks([0,0.12,0.35,0.7,1])
axes[1,1].set_xticklabels(np.array([0, 300,980, 2000, 2700]).astype(int))
#axes[1,1].legend(fontsize=3,edgecolor='black',framealpha=0.1,loc='center right')
axes[1,1].grid (False)
axes[1,1].spines['top'].set_visible(False)
axes[1,1].spines['right'].set_visible(False)
axes[1,1].xaxis.set_ticks_position('bottom')
axes[1,1].yaxis.set_ticks_position('left')
axes[1,1].set_yticks(np.linspace(0.6, 1, 5))
axes[1,1].set_yticks([0.6, 0.7, 0.8, 0.9,1])
axes[1,1].set_xticks([], minor=True)
axes[1,1].set_yticks([], minor=True)
axes[1,1].tick_params(axis='both', which='both', length=1.2)
axes[1,1].text(0.5, 0.97, 'Gravitycore', transform=axes[1,1].transAxes, ha='center', va='center', bbox=dict(facecolor='none', edgecolor='none', boxstyle='round', alpha=0.0), fontsize=4)








params, covariance = curve_fit(cubic_fit, x, ws1w_uniform[:60,0])
a_fit, b_fit, c_fit, d_fit = params
ws1w_uniform1 = cubic_fit(x, a_fit, b_fit, c_fit, d_fit)
axes[2,1].plot(x,ws1w_uniform1,color ='#6F99ADFF', label = 'uniform',linewidth=0.5)
axes[2,1].scatter(x, ws1w_uniform[:60,0],color ='#6F99ADFF',edgecolors='none', s=0.4, alpha=0.6)
distances = np.abs(ws1w_uniform[:60, 0] - ws1w_uniform1)
spline = UnivariateSpline(np.arange(len(distances)), distances.flatten(), s=0)
smooth_distances = spline(np.arange(len(distances)))
smooth_distances_mean = np.mean([np.min(smooth_distances), np.max(smooth_distances)])* 0.10
axes[2,1].fill_between(x, ws1w_uniform1-smooth_distances_mean, ws1w_uniform1+smooth_distances_mean, color='#6F99ADFF', alpha=0.2,edgecolors='none')
params, covariance = curve_fit(cubic_fit, x, ws1w_gravitypagerank[:60, 2])
a_fit, b_fit, c_fit, d_fit = params
ws1w_gravitypagerank_fit = cubic_fit(x, a_fit, b_fit, c_fit, d_fit)
axes[2,1].plot(x, ws1w_gravitypagerank_fit, color='#FFDC91FF', label='Top Nodes', linewidth=0.5)
axes[2,1].scatter(x, ws1w_gravitypagerank[:60, 2], color ='#FFDC91FF',edgecolors='none', s=0.4, alpha=0.6)
distances = np.abs(ws1w_gravitypagerank[:60, 2] - ws1w_gravitypagerank_fit)
spline = UnivariateSpline(np.arange(len(distances)), distances.flatten(), s=0)
smooth_distances = spline(np.arange(len(distances)))
smooth_distances_mean = np.mean([np.min(smooth_distances), np.max(smooth_distances)]) * 0.10
axes[2,1].fill_between(x, ws1w_gravitypagerank_fit - smooth_distances_mean, ws1w_gravitypagerank_fit + smooth_distances_mean, color='#FFDC91FF', alpha=0.2,edgecolors='none')
axes[2,1].tick_params(labelsize=4)
axes[2,1].set_xticks([0,0.12,0.35,0.7,1])
axes[2,1].set_xticklabels(np.array([0, 300,980, 2000, 2700]).astype(int))
#axes[2,1].legend(fontsize=3,edgecolor='black',framealpha=0.1,loc='center right')
axes[2,1].grid (False)
axes[2,1].spines['top'].set_visible(False)
axes[2,1].spines['right'].set_visible(False)
axes[2,1].xaxis.set_ticks_position('bottom')
axes[2,1].yaxis.set_ticks_position('left')
axes[2,1].set_yticks(np.linspace(0.6, 1, 5))
axes[2,1].set_yticks([0.6, 0.7, 0.8, 0.9,1])
axes[2,1].set_xticks([], minor=True)
axes[2,1].set_yticks([], minor=True)
axes[2,1].tick_params(axis='both', which='both', length=1.2)
axes[2,1].text(0.5, 0.97, 'Gravitypagerank', transform=axes[2,1].transAxes, ha='center', va='center', bbox=dict(facecolor='none', edgecolor='none', boxstyle='round', alpha=0.0), fontsize=4)




params, covariance = curve_fit(cubic_fit, x, ws1w_uniform[:60,0])
a_fit, b_fit, c_fit, d_fit = params
ws1w_uniform1 = cubic_fit(x, a_fit, b_fit, c_fit, d_fit)
axes[3,1].plot(x,ws1w_uniform1,color ='#6F99ADFF', label = 'uniform',linewidth=0.5)
axes[3,1].scatter(x, ws1w_uniform[:60,0],color ='#6F99ADFF',edgecolors='none', s=0.4, alpha=0.6)
distances = np.abs(ws1w_uniform[:60, 0] - ws1w_uniform1)
spline = UnivariateSpline(np.arange(len(distances)), distances.flatten(), s=0)
smooth_distances = spline(np.arange(len(distances)))
smooth_distances_mean = np.mean([np.min(smooth_distances), np.max(smooth_distances)])* 0.10
axes[3,1].fill_between(x, ws1w_uniform1-smooth_distances_mean, ws1w_uniform1+smooth_distances_mean, color='#6F99ADFF', alpha=0.2,edgecolors='none')
params, covariance = curve_fit(cubic_fit, x, ws1w_gravitybetweenness[:60, 2])
a_fit, b_fit, c_fit, d_fit = params
ws1w_gravitybetweenness_fit = cubic_fit(x, a_fit, b_fit, c_fit, d_fit)
axes[3,1].plot(x, ws1w_gravitybetweenness_fit, color='#FFDC91FF', label='Top Nodes', linewidth=0.5)
axes[3,1].scatter(x, ws1w_gravitybetweenness[:60, 2], color ='#FFDC91FF',edgecolors='none', s=0.4, alpha=0.6)
distances = np.abs(ws1w_gravitybetweenness[:60, 2] - ws1w_gravitybetweenness_fit)
spline = UnivariateSpline(np.arange(len(distances)), distances.flatten(), s=0)
smooth_distances = spline(np.arange(len(distances)))
smooth_distances_mean = np.mean([np.min(smooth_distances), np.max(smooth_distances)]) * 0.10
axes[3,1].fill_between(x, ws1w_gravitybetweenness_fit - smooth_distances_mean, ws1w_gravitybetweenness_fit + smooth_distances_mean, color='#FFDC91FF', alpha=0.2,edgecolors='none')
axes[3,1].tick_params(labelsize=4)
axes[3,1].set_xticks([0,0.12,0.35,0.7,1])
axes[3,1].set_xticklabels(np.array([0, 300,980, 2000, 2700]).astype(int))
#axes[3,1].legend(fontsize=3,edgecolor='black',framealpha=0.1,loc='center right')
axes[3,1].grid (False)
axes[3,1].spines['top'].set_visible(False)
axes[3,1].spines['right'].set_visible(False)
axes[3,1].xaxis.set_ticks_position('bottom')
axes[3,1].yaxis.set_ticks_position('left')
axes[3,1].set_yticks(np.linspace(0.6, 1, 5))
axes[3,1].set_yticks([0.6, 0.7, 0.8, 0.9,1])
axes[3,1].set_xticks([], minor=True)
axes[3,1].set_yticks([], minor=True)
axes[3,1].tick_params(axis='both', which='both', length=1.2)
axes[3,1].text(0.5, 0.97, 'Gravitybetweenness', transform=axes[3,1].transAxes, ha='center', va='center', bbox=dict(facecolor='none', edgecolor='none', boxstyle='round', alpha=0.0), fontsize=4)






params, covariance = curve_fit(cubic_fit, x, ws1w_uniform[:60,0])
a_fit, b_fit, c_fit, d_fit = params
ws1w_uniform1 = cubic_fit(x, a_fit, b_fit, c_fit, d_fit)
axes[4,1].plot(x,ws1w_uniform1,color ='#6F99ADFF', label = 'uniform',linewidth=0.5)
axes[4,1].scatter(x, ws1w_uniform[:60,0],color ='#6F99ADFF',edgecolors='none', s=0.4, alpha=0.6)
distances = np.abs(ws1w_uniform[:60, 0] - ws1w_uniform1)
spline = UnivariateSpline(np.arange(len(distances)), distances.flatten(), s=0)
smooth_distances = spline(np.arange(len(distances)))
smooth_distances_mean = np.mean([np.min(smooth_distances), np.max(smooth_distances)])* 0.10
axes[4,1].fill_between(x, ws1w_uniform1-smooth_distances_mean, ws1w_uniform1+smooth_distances_mean, color='#6F99ADFF', alpha=0.2,edgecolors='none')
params, covariance = curve_fit(cubic_fit, x, ws1w_gravitycloseness[:60, 2])
a_fit, b_fit, c_fit, d_fit = params
ws1w_gravitycloseness_fit = cubic_fit(x, a_fit, b_fit, c_fit, d_fit)
axes[4,1].plot(x, ws1w_gravitycloseness_fit, color='#FFDC91FF', label='Top Nodes', linewidth=0.5)
axes[4,1].scatter(x, ws1w_gravitycloseness[:60, 2], color ='#FFDC91FF',edgecolors='none', s=0.4, alpha=0.6)
distances = np.abs(ws1w_gravitycloseness[:60, 2] - ws1w_gravitycloseness_fit)
spline = UnivariateSpline(np.arange(len(distances)), distances.flatten(), s=0)
smooth_distances = spline(np.arange(len(distances)))
smooth_distances_mean = np.mean([np.min(smooth_distances), np.max(smooth_distances)]) * 0.10
axes[4,1].fill_between(x, ws1w_gravitycloseness_fit - smooth_distances_mean, ws1w_gravitycloseness_fit + smooth_distances_mean, color='#FFDC91FF', alpha=0.2,edgecolors='none')
axes[4,1].tick_params(labelsize=4)
axes[4,1].set_xticks([0,0.12,0.35,0.7,1])
axes[4,1].set_xticklabels(np.array([0, 300,980, 2000, 2700]).astype(int))
#axes[4,1].legend(fontsize=3,edgecolor='black',framealpha=0.1,loc='center right')
axes[4,1].grid (False)
axes[4,1].spines['top'].set_visible(False)
axes[4,1].spines['right'].set_visible(False)
axes[4,1].xaxis.set_ticks_position('bottom')
axes[4,1].yaxis.set_ticks_position('left')
axes[4,1].set_yticks(np.linspace(0.6, 1, 5))
axes[4,1].set_yticks([0.6, 0.7, 0.8, 0.9,1])
axes[4,1].set_xticks([], minor=True)
axes[4,1].set_yticks([], minor=True)
axes[4,1].tick_params(axis='both', which='both', length=1.2)
axes[4,1].text(0.5, 0.97, 'Gravitycloseness', transform=axes[4,1].transAxes, ha='center', va='center', bbox=dict(facecolor='none', edgecolor='none', boxstyle='round', alpha=0.0), fontsize=4)









y = np.linspace(0,1,20)
params, covariance = curve_fit(cubic_fit, y, ws1w_degree_rn['mean_auc'].values[:30])
a_fit, b_fit, c_fit, d_fit = params
ws1w_degree_fit = cubic_fit(y, a_fit, b_fit, c_fit, d_fit)
axes[0,0].plot(y, ws1w_degree_fit, color='#A392BA', label='Rejected nodes(RN)', linewidth=0.5)
axes[0,0].scatter(y, ws1w_degree_rn['mean_auc'].values[:30], color ='#A392BA',edgecolors='none', s=0.4, alpha=0.6)
distances = np.abs(ws1w_degree_rn['mean_auc'].values[:30] - ws1w_degree_fit)
spline = UnivariateSpline(np.arange(len(distances)), distances.flatten(), s=0)
smooth_distances = spline(np.arange(len(distances)))
smooth_distances_mean = np.mean([np.min(smooth_distances), np.max(smooth_distances)]) * 0.10
axes[0,0].fill_between(y, ws1w_degree_fit - smooth_distances_mean, ws1w_degree_fit + smooth_distances_mean, color='#A392BA', alpha=0.2,edgecolors='none')

params, covariance = curve_fit(cubic_fit, y, ws1w_core_rn['mean_auc'].values[:30])
a_fit, b_fit, c_fit, d_fit = params
ws1w_core_fit = cubic_fit(y, a_fit, b_fit, c_fit, d_fit)
axes[1,0].plot(y, ws1w_core_fit, color='#A392BA', label='Rejected nodes(RN)', linewidth=0.5)
axes[1,0].scatter(y, ws1w_core_rn['mean_auc'].values[:30], color ='#A392BA',edgecolors='none', s=0.4, alpha=0.6)
distances = np.abs(ws1w_core_rn['mean_auc'].values[:30] - ws1w_core_fit)
spline = UnivariateSpline(np.arange(len(distances)), distances.flatten(), s=0)
smooth_distances = spline(np.arange(len(distances)))
smooth_distances_mean = np.mean([np.min(smooth_distances), np.max(smooth_distances)]) * 0.10
axes[1,0].fill_between(y, ws1w_core_fit - smooth_distances_mean, ws1w_core_fit + smooth_distances_mean, color='#A392BA', alpha=0.2,edgecolors='none')



params, covariance = curve_fit(cubic_fit, y, ws1w_pagerank_rn['mean_auc'].values[:30])
a_fit, b_fit, c_fit, d_fit = params
ws1w_pagerank_fit = cubic_fit(y, a_fit, b_fit, c_fit, d_fit)
axes[2,0].plot(y, ws1w_pagerank_fit, color='#A392BA', label='Rejected nodes(RN)', linewidth=0.5)
axes[2,0].scatter(y, ws1w_pagerank_rn['mean_auc'].values[:30], color ='#A392BA',edgecolors='none', s=0.4, alpha=0.6)
distances = np.abs(ws1w_pagerank_rn['mean_auc'].values[:30] - ws1w_pagerank_fit)
spline = UnivariateSpline(np.arange(len(distances)), distances.flatten(), s=0)
smooth_distances = spline(np.arange(len(distances)))
smooth_distances_mean = np.mean([np.min(smooth_distances), np.max(smooth_distances)]) * 0.10
axes[2,0].fill_between(y, ws1w_pagerank_fit - smooth_distances_mean, ws1w_pagerank_fit + smooth_distances_mean, color='#A392BA', alpha=0.2,edgecolors='none')





params, covariance = curve_fit(cubic_fit,y, ws1w_betweenness_rn['mean_auc'].values[:30])
a_fit, b_fit, c_fit, d_fit = params
ws1w_betweenness_fit = cubic_fit(y, a_fit, b_fit, c_fit, d_fit)
axes[3,0].plot(y, ws1w_betweenness_fit, color='#A392BA', label='Rejected nodes(RN)', linewidth=0.5)
axes[3,0].scatter(y, ws1w_betweenness_rn['mean_auc'].values[:30], color ='#A392BA',edgecolors='none', s=0.4, alpha=0.6)
distances = np.abs(ws1w_betweenness_rn['mean_auc'].values[:30] - ws1w_betweenness_fit)
spline = UnivariateSpline(np.arange(len(distances)), distances.flatten(), s=0)
smooth_distances = spline(np.arange(len(distances)))
smooth_distances_mean = np.mean([np.min(smooth_distances), np.max(smooth_distances)]) * 0.10



params, covariance = curve_fit(cubic_fit, y, ws1w_closeness_rn['mean_auc'].values[:30])
a_fit, b_fit, c_fit, d_fit = params
ws1w_closeness_fit = cubic_fit(y, a_fit, b_fit, c_fit, d_fit)
axes[4,0].plot(y, ws1w_closeness_fit, color='#A392BA', label='Rejected nodes(RN)', linewidth=0.5)
axes[4,0].scatter(y, ws1w_closeness_rn['mean_auc'].values[:30], color ='#A392BA',edgecolors='none', s=0.4, alpha=0.6)
distances = np.abs(ws1w_closeness_rn['mean_auc'].values[:30] - ws1w_closeness_fit)
spline = UnivariateSpline(np.arange(len(distances)), distances.flatten(), s=0)
smooth_distances = spline(np.arange(len(distances)))
smooth_distances_mean = np.mean([np.min(smooth_distances), np.max(smooth_distances)]) * 0.10
axes[4,0].fill_between(y, ws1w_closeness_fit - smooth_distances_mean, ws1w_closeness_fit + smooth_distances_mean, color='#A392BA', alpha=0.2,edgecolors='none')





params, covariance = curve_fit(cubic_fit, y, ws1w_gravitydegree_rn['mean_auc'].values[:30])
a_fit, b_fit, c_fit, d_fit = params
ws1w_gravitydegree_fit = cubic_fit(y, a_fit, b_fit, c_fit, d_fit)
axes[0,1].plot(y, ws1w_gravitydegree_fit, color='#A392BA', label='Rejected nodes(RN)', linewidth=0.5)
axes[0,1].scatter(y, ws1w_gravitydegree_rn['mean_auc'].values[:30], color ='#A392BA',edgecolors='none', s=0.4, alpha=0.6)
distances = np.abs(ws1w_gravitydegree_rn['mean_auc'].values[:30] - ws1w_gravitydegree_fit)
spline = UnivariateSpline(np.arange(len(distances)), distances.flatten(), s=0)
smooth_distances = spline(np.arange(len(distances)))
smooth_distances_mean = np.mean([np.min(smooth_distances), np.max(smooth_distances)]) * 0.10
axes[0,1].fill_between(y, ws1w_gravitydegree_fit - smooth_distances_mean, ws1w_gravitydegree_fit + smooth_distances_mean, color='#A392BA', alpha=0.2,edgecolors='none')



params, covariance = curve_fit(cubic_fit, y, ws1w_gravitycore_rn['mean_auc'].values[:30])
a_fit, b_fit, c_fit, d_fit = params
ws1w_gravitycore_fit = cubic_fit(y, a_fit, b_fit, c_fit, d_fit)
axes[1,1].plot(y, ws1w_gravitycore_fit, color='#A392BA', label='Rejected nodes(RN)', linewidth=0.5)
axes[1,1].scatter(y, ws1w_gravitycore_rn['mean_auc'].values[:30], color ='#A392BA',edgecolors='none', s=0.4, alpha=0.6)
distances =  np.abs(ws1w_gravitycore_rn['mean_auc'].values[:30] - ws1w_gravitycore_fit)
spline = UnivariateSpline(np.arange(len(distances)), distances.flatten(), s=0)
smooth_distances = spline(np.arange(len(distances)))
smooth_distances_mean = np.mean([np.min(smooth_distances), np.max(smooth_distances)]) * 0.10
axes[1,1].fill_between(y, ws1w_gravitycore_fit - smooth_distances_mean, ws1w_gravitycore_fit + smooth_distances_mean, color='#A392BA', alpha=0.2,edgecolors='none')




params, covariance = curve_fit(cubic_fit, y, ws1w_gravitypagerank_rn['mean_auc'].values[:30])
a_fit, b_fit, c_fit, d_fit = params
ws1w_gravitypagerank_fit = cubic_fit(y, a_fit, b_fit, c_fit, d_fit)
axes[2,1].plot(y, ws1w_gravitypagerank_fit, color='#A392BA', label='Rejected nodes(RN)', linewidth=0.5)
axes[2,1].scatter(y, ws1w_gravitypagerank_rn['mean_auc'].values[:30], color ='#A392BA',edgecolors='none', s=0.4, alpha=0.6)
distances = np.abs(ws1w_gravitypagerank_rn['mean_auc'].values[:30] - ws1w_gravitypagerank_fit)
spline = UnivariateSpline(np.arange(len(distances)), distances.flatten(), s=0)
smooth_distances = spline(np.arange(len(distances)))
smooth_distances_mean = np.mean([np.min(smooth_distances), np.max(smooth_distances)]) * 0.10
axes[2,1].fill_between(y, ws1w_gravitypagerank_fit - smooth_distances_mean, ws1w_gravitypagerank_fit + smooth_distances_mean, color='#A392BA', alpha=0.2,edgecolors='none')


params, covariance = curve_fit(cubic_fit, y, ws1w_gravitybetweenness_rn['mean_auc'].values[:30])
a_fit, b_fit, c_fit, d_fit = params
ws1w_gravitybetweenness_fit = cubic_fit(y, a_fit, b_fit, c_fit, d_fit)
axes[3,1].plot(y, ws1w_gravitybetweenness_fit, color='#A392BA', label='Rejected nodes(RN)', linewidth=0.5)
axes[3,1].scatter(y, ws1w_gravitybetweenness_rn['mean_auc'].values[:30], color ='#A392BA',edgecolors='none', s=0.4, alpha=0.6)
distances = np.abs(ws1w_gravitybetweenness_rn['mean_auc'].values[:30] - ws1w_gravitybetweenness_fit)
spline = UnivariateSpline(np.arange(len(distances)), distances.flatten(), s=0)
smooth_distances = spline(np.arange(len(distances)))
smooth_distances_mean = np.mean([np.min(smooth_distances), np.max(smooth_distances)]) * 0.10
axes[3,1].fill_between(y, ws1w_gravitybetweenness_fit - smooth_distances_mean, ws1w_gravitybetweenness_fit + smooth_distances_mean, color='#A392BA', alpha=0.2,edgecolors='none')



params, covariance = curve_fit(cubic_fit, y, ws1w_gravitycloseness_rn['mean_auc'].values[:30])
a_fit, b_fit, c_fit, d_fit = params
ws1w_gravitycloseness_fit = cubic_fit(y, a_fit, b_fit, c_fit, d_fit)
axes[4,1].plot(y, ws1w_gravitycloseness_fit, color='#A392BA', label='Rejected nodes(RN)', linewidth=0.5)
axes[4,1].scatter(y, ws1w_gravitycloseness_rn['mean_auc'].values[:30], color ='#A392BA',edgecolors='none', s=0.4, alpha=0.6)
distances =  np.abs(ws1w_gravitycloseness_rn['mean_auc'].values[:30] - ws1w_gravitycloseness_fit)
spline = UnivariateSpline(np.arange(len(distances)), distances.flatten(), s=0)
smooth_distances = spline(np.arange(len(distances)))
smooth_distances_mean = np.mean([np.min(smooth_distances), np.max(smooth_distances)]) * 0.10
axes[4,1].fill_between(y, ws1w_gravitycloseness_fit - smooth_distances_mean, ws1w_gravitycloseness_fit + smooth_distances_mean, color='#A392BA', alpha=0.2,edgecolors='none')



params, covariance = curve_fit(cubic_fit, x, ws1w_degree[:60,0])
a_fit, b_fit, c_fit, d_fit = params
ws1w_degree_fit = cubic_fit(x, a_fit, b_fit, c_fit, d_fit)
axes[0,0].plot(x, ws1w_degree_fit, color='#BC3C29FF', label='Sampled nodes(SN)', linewidth=0.5)
axes[0,0].scatter(x, ws1w_degree[:60, 0], color ='#BC3C29FF',edgecolors='none', s=0.4, alpha=0.6)
distances = np.abs(ws1w_degree[:60, 0] - ws1w_degree_fit)
spline = UnivariateSpline(np.arange(len(distances)), distances.flatten(), s=0)
smooth_distances = spline(np.arange(len(distances)))
smooth_distances_mean = np.mean([np.min(smooth_distances), np.max(smooth_distances)]) * 0.10
axes[0,0].fill_between(x, ws1w_degree_fit - smooth_distances_mean, ws1w_degree_fit + smooth_distances_mean, color='#BC3C29FF', alpha=0.2,edgecolors='none')

params, covariance = curve_fit(cubic_fit, x, ws1w_core[:60,0])
a_fit, b_fit, c_fit, d_fit = params
ws1w_core_fit = cubic_fit(x, a_fit, b_fit, c_fit, d_fit)
axes[1,0].plot(x, ws1w_core_fit, color='#BC3C29FF', label='Sampled Nodes', linewidth=0.5)
axes[1,0].scatter(x, ws1w_core[:60, 0], color ='#BC3C29FF',edgecolors='none', s=0.4, alpha=0.6)
distances = np.abs(ws1w_core[:60, 0] - ws1w_core_fit)
spline = UnivariateSpline(np.arange(len(distances)), distances.flatten(), s=0)
smooth_distances = spline(np.arange(len(distances)))
smooth_distances_mean = np.mean([np.min(smooth_distances), np.max(smooth_distances)]) * 0.10
axes[1,0].fill_between(x, ws1w_core_fit - smooth_distances_mean, ws1w_core_fit + smooth_distances_mean, color='#BC3C29FF', alpha=0.2,edgecolors='none')

params, covariance = curve_fit(cubic_fit, x, ws1w_pagerank[:60,0])
a_fit, b_fit, c_fit, d_fit = params
ws1w_pagerank_fit = cubic_fit(x, a_fit, b_fit, c_fit, d_fit)
axes[2,0].plot(x, ws1w_pagerank_fit, color='#BC3C29FF', label='Sampled Nodes', linewidth=0.5)
axes[2,0].scatter(x, ws1w_pagerank[:60, 0], color ='#BC3C29FF',edgecolors='none', s=0.4, alpha=0.6)
distances = np.abs(ws1w_pagerank[:60, 0] - ws1w_pagerank_fit)
spline = UnivariateSpline(np.arange(len(distances)), distances.flatten(), s=0)
smooth_distances = spline(np.arange(len(distances)))
smooth_distances_mean = np.mean([np.min(smooth_distances), np.max(smooth_distances)]) * 0.10
axes[2,0].fill_between(x, ws1w_pagerank_fit - smooth_distances_mean, ws1w_pagerank_fit + smooth_distances_mean, color='#BC3C29FF', alpha=0.2,edgecolors='none')

params, covariance = curve_fit(cubic_fit, x, ws1w_betweenness[:60,0])
a_fit, b_fit, c_fit, d_fit = params
ws1w_betweenness_fit = cubic_fit(x, a_fit, b_fit, c_fit, d_fit)
axes[3,0].plot(x, ws1w_betweenness_fit, color='#BC3C29FF', label='Sampled Nodes', linewidth=0.5)
axes[3,0].scatter(x, ws1w_betweenness[:60, 0], color ='#BC3C29FF',edgecolors='none', s=0.4, alpha=0.6)
distances = np.abs(ws1w_betweenness[:60, 0] - ws1w_betweenness_fit)
spline = UnivariateSpline(np.arange(len(distances)), distances.flatten(), s=0)
smooth_distances = spline(np.arange(len(distances)))
smooth_distances_mean = np.mean([np.min(smooth_distances), np.max(smooth_distances)]) * 0.10
axes[3,0].fill_between(x, ws1w_betweenness_fit - smooth_distances_mean, ws1w_betweenness_fit + smooth_distances_mean, color='#BC3C29FF', alpha=0.2,edgecolors='none')


params, covariance = curve_fit(cubic_fit, x, ws1w_closeness[:60,0])
a_fit, b_fit, c_fit, d_fit = params
ws1w_closeness_fit = cubic_fit(x, a_fit, b_fit, c_fit, d_fit)
axes[4,0].plot(x, ws1w_closeness_fit, color='#BC3C29FF', label='Sampled Nodes', linewidth=0.5)
axes[4,0].scatter(x, ws1w_closeness[:60, 0], color ='#BC3C29FF',edgecolors='none', s=0.4, alpha=0.6)
distances = np.abs(ws1w_closeness[:60, 0] - ws1w_closeness_fit)
spline = UnivariateSpline(np.arange(len(distances)), distances.flatten(), s=0)
smooth_distances = spline(np.arange(len(distances)))
smooth_distances_mean = np.mean([np.min(smooth_distances), np.max(smooth_distances)]) * 0.10
axes[4,0].fill_between(x, ws1w_closeness_fit - smooth_distances_mean, ws1w_closeness_fit + smooth_distances_mean, color='#BC3C29FF', alpha=0.2,edgecolors='none')


params, covariance = curve_fit(cubic_fit, x, ws1w_gravitydegree[:60,0])
a_fit, b_fit, c_fit, d_fit = params
ws1w_gravitydegree_fit = cubic_fit(x, a_fit, b_fit, c_fit, d_fit)
axes[0,1].plot(x, ws1w_gravitydegree_fit, color='#BC3C29FF', label='Sampled Nodes', linewidth=0.5)
axes[0,1].scatter(x, ws1w_gravitydegree[:60, 0], color ='#BC3C29FF',edgecolors='none', s=0.4, alpha=0.6)
distances = np.abs(ws1w_gravitydegree[:60, 0] - ws1w_gravitydegree_fit)
spline = UnivariateSpline(np.arange(len(distances)), distances.flatten(), s=0)
smooth_distances = spline(np.arange(len(distances)))
smooth_distances_mean = np.mean([np.min(smooth_distances), np.max(smooth_distances)]) * 0.10
axes[0,1].fill_between(x, ws1w_gravitydegree_fit - smooth_distances_mean, ws1w_gravitydegree_fit + smooth_distances_mean, color='#BC3C29FF', alpha=0.2,edgecolors='none')

params, covariance = curve_fit(cubic_fit, x, ws1w_gravitycore[:60,0])
a_fit, b_fit, c_fit, d_fit = params
ws1w_gravitycore_fit = cubic_fit(x, a_fit, b_fit, c_fit, d_fit)
axes[1,1].plot(x, ws1w_gravitycore_fit, color='#BC3C29FF', label='Sampled Nodes', linewidth=0.5)
axes[1,1].scatter(x, ws1w_gravitycore[:60, 0], color ='#BC3C29FF',edgecolors='none', s=0.4, alpha=0.6)
distances = np.abs(ws1w_gravitycore[:60, 0] - ws1w_gravitycore_fit)
spline = UnivariateSpline(np.arange(len(distances)), distances.flatten(), s=0)
smooth_distances = spline(np.arange(len(distances)))
smooth_distances_mean = np.mean([np.min(smooth_distances), np.max(smooth_distances)]) * 0.10
axes[1,1].fill_between(x, ws1w_gravitycore_fit - smooth_distances_mean, ws1w_gravitycore_fit + smooth_distances_mean, color='#BC3C29FF', alpha=0.2,edgecolors='none')

params, covariance = curve_fit(cubic_fit, x, ws1w_gravitypagerank[:60,0])
a_fit, b_fit, c_fit, d_fit = params
ws1w_gravitypagerank_fit = cubic_fit(x, a_fit, b_fit, c_fit, d_fit)
axes[2,1].plot(x, ws1w_gravitypagerank_fit, color='#BC3C29FF', label='Sampled Nodes', linewidth=0.5)
axes[2,1].scatter(x, ws1w_gravitypagerank[:60, 0], color ='#BC3C29FF',edgecolors='none', s=0.4, alpha=0.6)
distances = np.abs(ws1w_gravitypagerank[:60, 0] - ws1w_gravitypagerank_fit)
spline = UnivariateSpline(np.arange(len(distances)), distances.flatten(), s=0)
smooth_distances = spline(np.arange(len(distances)))
smooth_distances_mean = np.mean([np.min(smooth_distances), np.max(smooth_distances)]) * 0.10
axes[2,1].fill_between(x, ws1w_gravitypagerank_fit - smooth_distances_mean, ws1w_gravitypagerank_fit + smooth_distances_mean, color='#BC3C29FF', alpha=0.2,edgecolors='none')

params, covariance = curve_fit(cubic_fit, x, ws1w_gravitybetweenness[:60,0])
a_fit, b_fit, c_fit, d_fit = params
ws1w_gravitybetweenness_fit = cubic_fit(x, a_fit, b_fit, c_fit, d_fit)
axes[3,1].plot(x, ws1w_gravitybetweenness_fit, color='#BC3C29FF', label='Sampled Nodes', linewidth=0.5)
axes[3,1].scatter(x, ws1w_gravitybetweenness[:60, 0], color ='#BC3C29FF',edgecolors='none', s=0.4, alpha=0.6)
distances = np.abs(ws1w_gravitybetweenness[:60, 0] - ws1w_gravitybetweenness_fit)
spline = UnivariateSpline(np.arange(len(distances)), distances.flatten(), s=0)
smooth_distances = spline(np.arange(len(distances)))
smooth_distances_mean = np.mean([np.min(smooth_distances), np.max(smooth_distances)]) * 0.10
axes[3,1].fill_between(x, ws1w_gravitybetweenness_fit - smooth_distances_mean, ws1w_gravitybetweenness_fit + smooth_distances_mean, color='#BC3C29FF', alpha=0.2,edgecolors='none')


params, covariance = curve_fit(cubic_fit, x, ws1w_gravitycloseness[:60,0])
a_fit, b_fit, c_fit, d_fit = params
ws1w_gravitycloseness_fit = cubic_fit(x, a_fit, b_fit, c_fit, d_fit)
axes[4,1].plot(x, ws1w_gravitycloseness_fit, color='#BC3C29FF', label='Sampled Nodes', linewidth=0.5)
axes[4,1].scatter(x, ws1w_gravitycloseness[:60, 0], color ='#BC3C29FF',edgecolors='none', s=0.4, alpha=0.6)
distances = np.abs(ws1w_gravitycloseness[:60, 0] - ws1w_gravitycloseness_fit)
spline = UnivariateSpline(np.arange(len(distances)), distances.flatten(), s=0)
smooth_distances = spline(np.arange(len(distances)))
smooth_distances_mean = np.mean([np.min(smooth_distances), np.max(smooth_distances)]) * 0.10
axes[4,1].fill_between(x, ws1w_gravitycloseness_fit - smooth_distances_mean, ws1w_gravitycloseness_fit + smooth_distances_mean, color='#BC3C29FF', alpha=0.2,edgecolors='none')



axes[0,0].legend(fontsize=3,edgecolor='black',framealpha=0.1,loc='best',frameon=False)

plt.subplots_adjust(wspace=0.3,hspace=0.3)

for i in range(5):
    axes[i,0].set_ylabel('AUC (\%)',fontsize=3.5,labelpad=1)
    if i==4:
        axes[i,0].set_xlabel('Nodes Number',fontsize=3.5,labelpad=1)
        axes[i,1].set_xlabel('Nodes Number',fontsize=3.5,labelpad=1)



for ax in axes.flat:
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.xaxis.set_ticks_position('bottom')
    ax.yaxis.set_ticks_position('left')
    ax.tick_params(axis='both', which='both', length=1.8,pad=1.5,width=0.4)
    ax.set_xlim([0,1])
    ax.set_xticks([0,0.2,0.4,0.6,0.8,1])
    ax.set_xticklabels(np.array([0, 2000,4000,6000,8000,10000]).astype(int))
    ax.set_ylim([0.5,0.9])
    ax.set_yticks([0.6, 0.7, 0.8, 0.9])
    ax.tick_params(axis='x', rotation=45,labelsize=3.5)
plt.subplots_adjust(wspace=0.3,hspace=0.3)

plt.subplots_adjust(wspace=0.3,hspace=0.35)


fig.suptitle('Area Under the Curve (\%) on Small World 10000',fontsize=5, y=0.92)
fig.savefig('C:/Users/WENJIA/Downloads/papers/results/ws1w_auc.png',dpi=350)
fig.savefig('C:/Users/WENJIA/Downloads/papers/results/ws1w_auc.pdf',dpi=350)

# %%
ws1w_uniform.shape
# Out:
# (20, 9)

# %%
plt.style.use('nature')
from scipy.optimize import curve_fit
from scipy.interpolate import UnivariateSpline


def cubic_fit(x, a, b, c, d):
    return a * x**3 + b * x**2 + c * x + d

x = np.linspace(0,1,60)

fig,axes = plt.subplots(5,2,figsize = (2,5),dpi=600)

params, covariance = curve_fit(cubic_fit, x, ws1w_uniform[:60,0])
a_fit, b_fit, c_fit, d_fit = params
ws1w_uniform1 = cubic_fit(x, a_fit, b_fit, c_fit, d_fit)
axes[0,0].plot(x,ws1w_uniform1,color ='#6F99ADFF', label = 'Uniform nodes(UN*)',linewidth=0.5)
axes[0,0].scatter(x, ws1w_uniform[:60,1],color ='#6F99ADFF',edgecolors='none', s=0.4, alpha=0.6)
distances = np.abs(ws1w_uniform[:60, 1] - ws1w_uniform1)
spline = UnivariateSpline(np.arange(len(distances)), distances.flatten(), s=0)
smooth_distances = spline(np.arange(len(distances)))
smooth_distances_mean = np.mean([np.min(smooth_distances), np.max(smooth_distances)])* 0.10
axes[0,0].fill_between(x, ws1w_uniform1-smooth_distances_mean, ws1w_uniform1+smooth_distances_mean, color='#6F99ADFF', alpha=0.2,edgecolors='none')
params, covariance = curve_fit(cubic_fit, x, ws1w_degree[:60, 3])
a_fit, b_fit, c_fit, d_fit = params
ws1w_degree_fit = cubic_fit(x, a_fit, b_fit, c_fit, d_fit)
axes[0,0].plot(x, ws1w_degree_fit, color='#FFDC91FF', label='Top nodes(TN)', linewidth=0.5)
axes[0,0].scatter(x, ws1w_degree[:60, 3], color ='#FFDC91FF',edgecolors='none', s=0.4, alpha=0.6)
distances = np.abs(ws1w_degree[:60, 3] - ws1w_degree_fit)
spline = UnivariateSpline(np.arange(len(distances)), distances.flatten(), s=0)
smooth_distances = spline(np.arange(len(distances)))
smooth_distances_mean = np.mean([np.min(smooth_distances), np.max(smooth_distances)]) * 1 / 4
axes[0,0].fill_between(x, ws1w_degree_fit - smooth_distances_mean, ws1w_degree_fit + smooth_distances_mean, color='#FFDC91FF', alpha=0.2,edgecolors='none')

axes[0,0].tick_params(labelsize=4)

axes[0,0].set_xticks([0,0.12,0.35,0.7,1])
axes[0,0].set_xticklabels(np.array([0, 300,980, 2000, 2700]).astype(int))

axes[0,0].grid (False)
axes[0,0].spines['top'].set_visible(False)
axes[0,0].spines['right'].set_visible(False)
axes[0,0].xaxis.set_ticks_position('bottom')
axes[0,0].yaxis.set_ticks_position('left')
axes[0,0].set_yticks(np.linspace(0.6, 1, 5))
axes[0,0].set_yticks([0.6, 0.7, 0.8, 0.9,1])
axes[0,0].set_xticks([], minor=True)
axes[0,0].set_yticks([], minor=True)
axes[0,0].tick_params(axis='both', which='both', length=1.2)
axes[0,0].text(0.5, 0.97, 'Degree', transform=axes[0,0].transAxes, ha='center', va='center', bbox=dict(facecolor='none', edgecolor='none', boxstyle='round', alpha=0.0), fontsize=4)



params, covariance = curve_fit(cubic_fit, x, ws1w_uniform[:60,0])
a_fit, b_fit, c_fit, d_fit = params
ws1w_uniform1 = cubic_fit(x, a_fit, b_fit, c_fit, d_fit)
axes[1,0].plot(x,ws1w_uniform1,color ='#6F99ADFF', label = 'uniform',linewidth=0.5)
axes[1,0].scatter(x, ws1w_uniform[:60,0],color ='#6F99ADFF',edgecolors='none', s=0.4, alpha=0.6)
distances = np.abs(ws1w_uniform[:60, 1] - ws1w_uniform1)
spline = UnivariateSpline(np.arange(len(distances)), distances.flatten(), s=0)
smooth_distances = spline(np.arange(len(distances)))
smooth_distances_mean = np.mean([np.min(smooth_distances), np.max(smooth_distances)])* 0.10
axes[1,0].fill_between(x, ws1w_uniform1-smooth_distances_mean, ws1w_uniform1+smooth_distances_mean, color='#6F99ADFF', alpha=0.2,edgecolors='none')
params, covariance = curve_fit(cubic_fit, x, ws1w_core[:60, 3])
a_fit, b_fit, c_fit, d_fit = params
ws1w_core_fit = cubic_fit(x, a_fit, b_fit, c_fit, d_fit)
axes[1,0].plot(x, ws1w_core_fit, color='#FFDC91FF', label='Top Nodes', linewidth=0.5)
axes[1,0].scatter(x, ws1w_core[:60, 3], color ='#FFDC91FF',edgecolors='none', s=0.4, alpha=0.6)
distances = np.abs(ws1w_core[:60, 3] - ws1w_core_fit)
spline = UnivariateSpline(np.arange(len(distances)), distances.flatten(), s=0)
smooth_distances = spline(np.arange(len(distances)))
smooth_distances_mean = np.mean([np.min(smooth_distances), np.max(smooth_distances)]) * 0.5
axes[1,0].fill_between(x, ws1w_core_fit - smooth_distances_mean, ws1w_core_fit + smooth_distances_mean, color='#FFDC91FF', alpha=0.2,edgecolors='none')

axes[1,0].tick_params(labelsize=4)
axes[1,0].set_xticks([0,0.12,0.35,0.7,1])
axes[1,0].set_xticklabels(np.array([0, 300,980, 2000, 2700]).astype(int))
#axes[1,0].legend(fontsize=3,edgecolor='black',framealpha=0.1,loc='center right')
axes[1,0].grid (False)
axes[1,0].spines['top'].set_visible(False)
axes[1,0].spines['right'].set_visible(False)
axes[1,0].xaxis.set_ticks_position('bottom')
axes[1,0].yaxis.set_ticks_position('left')
axes[1,0].set_yticks(np.linspace(0.6, 1, 5))
axes[1,0].set_yticks([0.6, 0.7, 0.8, 0.9,1])
axes[1,0].set_xticks([], minor=True)
axes[1,0].set_yticks([], minor=True)
axes[1,0].tick_params(axis='both', which='both', length=1.2)
axes[1,0].text(0.5, 0.97, 'Core', transform=axes[1,0].transAxes, ha='center', va='center', bbox=dict(facecolor='none', edgecolor='none', boxstyle='round', alpha=0.0), fontsize=4)



params, covariance = curve_fit(cubic_fit, x, ws1w_uniform[:60,0])
a_fit, b_fit, c_fit, d_fit = params
ws1w_uniform1 = cubic_fit(x, a_fit, b_fit, c_fit, d_fit)
axes[2,0].plot(x,ws1w_uniform1,color ='#6F99ADFF', label = 'uniform',linewidth=0.5)
axes[2,0].scatter(x, ws1w_uniform[:60,0],color ='#6F99ADFF',edgecolors='none', s=0.4, alpha=0.6)
distances = np.abs(ws1w_uniform[:60, 1] - ws1w_uniform1)
spline = UnivariateSpline(np.arange(len(distances)), distances.flatten(), s=0)
smooth_distances = spline(np.arange(len(distances)))
smooth_distances_mean = np.mean([np.min(smooth_distances), np.max(smooth_distances)])* 0.10
axes[2,0].fill_between(x, ws1w_uniform1-smooth_distances_mean, ws1w_uniform1+smooth_distances_mean, color='#6F99ADFF', alpha=0.2,edgecolors='none')
params, covariance = curve_fit(cubic_fit, x, ws1w_pagerank[:60, 3])
a_fit, b_fit, c_fit, d_fit = params
ws1w_pagerank_fit = cubic_fit(x, a_fit, b_fit, c_fit, d_fit)
axes[2,0].plot(x, ws1w_pagerank_fit, color='#FFDC91FF', label='Top Nodes', linewidth=0.5)
axes[2,0].scatter(x, ws1w_pagerank[:60, 3], color ='#FFDC91FF',edgecolors='none', s=0.4, alpha=0.6)
distances = np.abs(ws1w_pagerank[:60, 3] - ws1w_pagerank_fit)
spline = UnivariateSpline(np.arange(len(distances)), distances.flatten(), s=0)
smooth_distances = spline(np.arange(len(distances)))
smooth_distances_mean = np.mean([np.min(smooth_distances), np.max(smooth_distances)]) * 0.5
axes[2,0].fill_between(x, ws1w_pagerank_fit - smooth_distances_mean, ws1w_pagerank_fit + smooth_distances_mean, color='#FFDC91FF', alpha=0.2,edgecolors='none')

axes[2,0].tick_params(labelsize=4)
axes[2,0].set_xticks([0,0.12,0.35,0.7,1])
axes[2,0].set_xticklabels(np.array([0, 300,980, 2000, 2700]).astype(int))
#axes[2,0].legend(fontsize=3,edgecolor='black',framealpha=0.1,loc='center right')
axes[2,0].grid (False)
axes[2,0].spines['top'].set_visible(False)
axes[2,0].spines['right'].set_visible(False)
axes[2,0].xaxis.set_ticks_position('bottom')
axes[2,0].yaxis.set_ticks_position('left')
axes[2,0].set_yticks(np.linspace(0.6, 1, 5))
axes[2,0].set_yticks([0.6, 0.7, 0.8, 0.9,1])
axes[2,0].set_xticks([], minor=True)
axes[2,0].set_yticks([], minor=True)
axes[2,0].tick_params(axis='both', which='both', length=1.2)
axes[2,0].text(0.5, 0.97, 'Pagerank', transform=axes[2,0].transAxes, ha='center', va='center', bbox=dict(facecolor='none', edgecolor='none', boxstyle='round', alpha=0.0), fontsize=4)

params, covariance = curve_fit(cubic_fit, x, ws1w_uniform[:60,0])
a_fit, b_fit, c_fit, d_fit = params
ws1w_uniform1 = cubic_fit(x, a_fit, b_fit, c_fit, d_fit)
axes[3,0].plot(x,ws1w_uniform1,color ='#6F99ADFF', label = 'uniform',linewidth=0.5)
axes[3,0].scatter(x, ws1w_uniform[:60,0],color ='#6F99ADFF',edgecolors='none', s=0.4, alpha=0.6)
distances = np.abs(ws1w_uniform[:60, 1] - ws1w_uniform1)
spline = UnivariateSpline(np.arange(len(distances)), distances.flatten(), s=0)
smooth_distances = spline(np.arange(len(distances)))
smooth_distances_mean = np.mean([np.min(smooth_distances), np.max(smooth_distances)])* 0.10
axes[3,0].fill_between(x, ws1w_uniform1-smooth_distances_mean, ws1w_uniform1+smooth_distances_mean, color='#6F99ADFF', alpha=0.2,edgecolors='none')
params, covariance = curve_fit(cubic_fit, x, ws1w_betweenness[:60, 3])
a_fit, b_fit, c_fit, d_fit = params
ws1w_betweenness_fit = cubic_fit(x, a_fit, b_fit, c_fit, d_fit)
axes[3,0].plot(x, ws1w_betweenness_fit, color='#FFDC91FF', label='Top Nodes', linewidth=0.5)
axes[3,0].scatter(x, ws1w_betweenness[:60, 3], color ='#FFDC91FF',edgecolors='none', s=0.4, alpha=0.6)
distances = np.abs(ws1w_betweenness[:60, 3] - ws1w_betweenness_fit)
spline = UnivariateSpline(np.arange(len(distances)), distances.flatten(), s=0)
smooth_distances = spline(np.arange(len(distances)))
smooth_distances_mean = np.mean([np.min(smooth_distances), np.max(smooth_distances)]) * 0.5
axes[3,0].fill_between(x, ws1w_betweenness_fit - smooth_distances_mean, ws1w_betweenness_fit + smooth_distances_mean, color='#FFDC91FF', alpha=0.2,edgecolors='none')

axes[3,0].tick_params(labelsize=4)
axes[3,0].set_xticks([0,0.12,0.35,0.7,1])
axes[3,0].set_xticklabels(np.array([0, 300,980, 2000, 2700]).astype(int))
#axes[3,0].legend(fontsize=3,edgecolor='black',framealpha=0.1,loc='center right')
axes[3,0].grid (False)
axes[3,0].spines['top'].set_visible(False)
axes[3,0].spines['right'].set_visible(False)
axes[3,0].xaxis.set_ticks_position('bottom')
axes[3,0].yaxis.set_ticks_position('left')
axes[3,0].set_yticks(np.linspace(0.6, 1, 5))
axes[3,0].set_yticks([0.6, 0.7, 0.8, 0.9,1])
axes[3,0].set_xticks([], minor=True)
axes[3,0].set_yticks([], minor=True)
axes[3,0].tick_params(axis='both', which='both', length=1.2)
axes[3,0].text(0.5, 0.97, 'Betweenness', transform=axes[3,0].transAxes, ha='center', va='center', bbox=dict(facecolor='none', edgecolor='none', boxstyle='round', alpha=0.0), fontsize=4)


params, covariance = curve_fit(cubic_fit, x, ws1w_uniform[:60,0])
a_fit, b_fit, c_fit, d_fit = params
ws1w_uniform1 = cubic_fit(x, a_fit, b_fit, c_fit, d_fit)
axes[4,0].plot(x,ws1w_uniform1,color ='#6F99ADFF', label = 'uniform',linewidth=0.5)
axes[4,0].scatter(x, ws1w_uniform[:60,0],color ='#6F99ADFF',edgecolors='none', s=0.4, alpha=0.6)
distances = np.abs(ws1w_uniform[:60, 1] - ws1w_uniform1)
spline = UnivariateSpline(np.arange(len(distances)), distances.flatten(), s=0)
smooth_distances = spline(np.arange(len(distances)))
smooth_distances_mean = np.mean([np.min(smooth_distances), np.max(smooth_distances)])* 0.10
axes[4,0].fill_between(x, ws1w_uniform1-smooth_distances_mean, ws1w_uniform1+smooth_distances_mean, color='#6F99ADFF', alpha=0.2,edgecolors='none')
params, covariance = curve_fit(cubic_fit, x, ws1w_closeness[:60, 3])
a_fit, b_fit, c_fit, d_fit = params
ws1w_closeness_fit = cubic_fit(x, a_fit, b_fit, c_fit, d_fit)
axes[4,0].plot(x, ws1w_closeness_fit, color='#FFDC91FF', label='Top Nodes', linewidth=0.5)
axes[4,0].scatter(x, ws1w_closeness[:60, 3], color ='#FFDC91FF',edgecolors='none', s=0.4, alpha=0.6)
distances = np.abs(ws1w_closeness[:60, 3] - ws1w_closeness_fit)
spline = UnivariateSpline(np.arange(len(distances)), distances.flatten(), s=0)
smooth_distances = spline(np.arange(len(distances)))
smooth_distances_mean = np.mean([np.min(smooth_distances), np.max(smooth_distances)]) * 0.5
axes[4,0].fill_between(x, ws1w_closeness_fit - smooth_distances_mean, ws1w_closeness_fit + smooth_distances_mean, color='#FFDC91FF', alpha=0.2,edgecolors='none')

axes[4,0].tick_params(labelsize=4)
axes[4,0].set_xticks([0,0.12,0.35,0.7,1])
axes[4,0].set_xticklabels(np.array([0, 300,980, 2000, 2700]).astype(int))
#axes[4,0].legend(fontsize=3,edgecolor='black',framealpha=0.1,loc='center right')
axes[4,0].grid (False)
axes[4,0].spines['top'].set_visible(False)
axes[4,0].spines['right'].set_visible(False)
axes[4,0].xaxis.set_ticks_position('bottom')
axes[4,0].yaxis.set_ticks_position('left')
axes[4,0].set_yticks(np.linspace(0.6, 1, 5))
axes[4,0].set_yticks([0.6, 0.7, 0.8, 0.9,1])
axes[4,0].set_xticks([], minor=True)
axes[4,0].set_yticks([], minor=True)
axes[4,0].tick_params(axis='both', which='both', length=1.2)
axes[4,0].text(0.5, 0.97, 'Closeness', transform=axes[4,0].transAxes, ha='center', va='center', bbox=dict(facecolor='none', edgecolor='none', boxstyle='round', alpha=0.0), fontsize=4)







params, covariance = curve_fit(cubic_fit, x, ws1w_uniform[:60,0])
a_fit, b_fit, c_fit, d_fit = params
ws1w_uniform1 = cubic_fit(x, a_fit, b_fit, c_fit, d_fit)

params, covariance = curve_fit(cubic_fit, x, ws1w_uniform[:60,0])
a_fit, b_fit, c_fit, d_fit = params
ws1w_uniform1 = cubic_fit(x, a_fit, b_fit, c_fit, d_fit)
axes[0,1].plot(x,ws1w_uniform1,color ='#6F99ADFF', label = 'uniform',linewidth=0.5)
axes[0,1].scatter(x, ws1w_uniform[:60,0],color ='#6F99ADFF',edgecolors='none', s=0.4, alpha=0.6)
distances = np.abs(ws1w_uniform[:60, 1] - ws1w_uniform1)
spline = UnivariateSpline(np.arange(len(distances)), distances.flatten(), s=0)
smooth_distances = spline(np.arange(len(distances)))
smooth_distances_mean = np.mean([np.min(smooth_distances), np.max(smooth_distances)])* 0.10
axes[0,1].fill_between(x, ws1w_uniform1-smooth_distances_mean, ws1w_uniform1+smooth_distances_mean, color='#6F99ADFF', alpha=0.2,edgecolors='none')
params, covariance = curve_fit(cubic_fit, x, ws1w_gravitydegree[:60, 3])
a_fit, b_fit, c_fit, d_fit = params
ws1w_gravitydegree_fit = cubic_fit(x, a_fit, b_fit, c_fit, d_fit)
axes[0,1].plot(x, ws1w_gravitydegree_fit, color='#FFDC91FF', label='Top Nodes', linewidth=0.5)
axes[0,1].scatter(x, ws1w_gravitydegree[:60, 3], color ='#FFDC91FF',edgecolors='none', s=0.4, alpha=0.6)
distances = np.abs(ws1w_gravitydegree[:60, 3] - ws1w_gravitydegree_fit)
spline = UnivariateSpline(np.arange(len(distances)), distances.flatten(), s=0)
smooth_distances = spline(np.arange(len(distances)))
smooth_distances_mean = np.mean([np.min(smooth_distances), np.max(smooth_distances)]) * 0.5
axes[0,1].fill_between(x, ws1w_gravitydegree_fit - smooth_distances_mean, ws1w_gravitydegree_fit + smooth_distances_mean, color='#FFDC91FF', alpha=0.2,edgecolors='none')

axes[0,1].tick_params(labelsize=4)
axes[0,1].set_xticks([0,0.12,0.35,0.7,1])
axes[0,1].set_xticklabels(np.array([0, 300,980, 2000, 2700]).astype(int))
axes[0,1].grid (False)
axes[0,1].spines['top'].set_visible(False)
axes[0,1].spines['right'].set_visible(False)
axes[0,1].xaxis.set_ticks_position('bottom')
axes[0,1].yaxis.set_ticks_position('left')
axes[0,1].set_yticks(np.linspace(0.6, 1, 5))
axes[0,1].set_yticks([0.6, 0.7, 0.8, 0.9,1])
axes[0,1].set_xticks([], minor=True)
axes[0,1].set_yticks([], minor=True)
axes[0,1].tick_params(axis='both', which='both', length=1.2)
# axes[0,1].text(0.5, 0.97, 'Gravitydegree', transform=axes[0,1].transAxes, ha='center', va='center', bbox=dict(facecolor='none', edgecolor='none', boxstyle='round', alpha=0.0), fontsize=4)


axes[0,1].plot(x,ws1w_uniform1,color ='#6F99ADFF', label = 'uniform',linewidth=0.5)
axes[0,1].scatter(x, ws1w_uniform[:60,0],color ='#6F99ADFF',edgecolors='none', s=0.4, alpha=0.6)
distances = np.abs(ws1w_uniform[:60, 1] - ws1w_uniform1)
spline = UnivariateSpline(np.arange(len(distances)), distances.flatten(), s=0)
smooth_distances = spline(np.arange(len(distances)))
smooth_distances_mean = np.mean([np.min(smooth_distances), np.max(smooth_distances)])* 0.10
axes[0,1].fill_between(x, ws1w_uniform1-smooth_distances_mean, ws1w_uniform1+smooth_distances_mean, color='#6F99ADFF', alpha=0.2,edgecolors='none')
params, covariance = curve_fit(cubic_fit, x, ws1w_gravitydegree[:60, 3])
a_fit, b_fit, c_fit, d_fit = params
ws1w_gravitydegree_fit = cubic_fit(x, a_fit, b_fit, c_fit, d_fit)
axes[0,1].plot(x, ws1w_gravitydegree_fit, color='#FFDC91FF', label='Top Nodes', linewidth=0.5)
axes[0,1].scatter(x, ws1w_gravitydegree[:60, 3], color ='#FFDC91FF',edgecolors='none', s=0.4, alpha=0.6)
distances = np.abs(ws1w_gravitydegree[:60, 3] - ws1w_gravitydegree_fit)
spline = UnivariateSpline(np.arange(len(distances)), distances.flatten(), s=0)
smooth_distances = spline(np.arange(len(distances)))
smooth_distances_mean = np.mean([np.min(smooth_distances), np.max(smooth_distances)]) * 0.10
axes[0,1].fill_between(x, ws1w_gravitydegree_fit - smooth_distances_mean, ws1w_gravitydegree_fit + smooth_distances_mean, color='#FFDC91FF', alpha=0.2,edgecolors='none')
params, covariance = curve_fit(cubic_fit, x, ws1w_gravitydegree[:60,0])
a_fit, b_fit, c_fit, d_fit = params
ws1w_gravitydegree_fit = cubic_fit(x, a_fit, b_fit, c_fit, d_fit)
axes[0,1].plot(x, ws1w_gravitydegree_fit, color='#BC3C29FF', label='Sampled Nodes', linewidth=0.5)
axes[0,1].scatter(x, ws1w_gravitydegree[:60, 1], color ='#BC3C29FF',edgecolors='none', s=0.4, alpha=0.6)
distances = np.abs(ws1w_gravitydegree[:60, 1] - ws1w_gravitydegree_fit)
spline = UnivariateSpline(np.arange(len(distances)), distances.flatten(), s=0)
smooth_distances = spline(np.arange(len(distances)))
smooth_distances_mean = np.mean([np.min(smooth_distances), np.max(smooth_distances)]) * 0.10
axes[0,1].fill_between(x, ws1w_gravitydegree_fit - smooth_distances_mean, ws1w_gravitydegree_fit + smooth_distances_mean, color='#BC3C29FF', alpha=0.2,edgecolors='none')
axes[0,1].tick_params(labelsize=4)
axes[0,1].set_xticks([0,0.12,0.35,0.7,1])
axes[0,1].set_xticklabels(np.array([0, 300,980, 2000, 2700]).astype(int))
#axes[0,1].legend(fontsize=3,edgecolor='black',framealpha=0.1,loc='center right')
axes[0,1].grid (False)
axes[0,1].spines['top'].set_visible(False)
axes[0,1].spines['right'].set_visible(False)
axes[0,1].xaxis.set_ticks_position('bottom')
axes[0,1].yaxis.set_ticks_position('left')
axes[0,1].set_yticks(np.linspace(0.6, 1, 5))
axes[0,1].set_yticks([0.6, 0.7, 0.8, 0.9,1])
axes[0,1].set_xticks([], minor=True)
axes[0,1].set_yticks([], minor=True)
axes[0,1].tick_params(axis='both', which='both', length=1.2)
axes[0,1].text(0.5, 0.97, 'Gravitydegree', transform=axes[0,1].transAxes, ha='center', va='center', bbox=dict(facecolor='none', edgecolor='none', boxstyle='round', alpha=0.0), fontsize=4)



params, covariance = curve_fit(cubic_fit, x, ws1w_uniform[:60,0])
a_fit, b_fit, c_fit, d_fit = params
ws1w_uniform1 = cubic_fit(x, a_fit, b_fit, c_fit, d_fit)
axes[1,1].plot(x,ws1w_uniform1,color ='#6F99ADFF', label = 'uniform',linewidth=0.5)
axes[1,1].scatter(x, ws1w_uniform[:60,0],color ='#6F99ADFF',edgecolors='none', s=0.4, alpha=0.6)
distances = np.abs(ws1w_uniform[:60, 1] - ws1w_uniform1)
spline = UnivariateSpline(np.arange(len(distances)), distances.flatten(), s=0)
smooth_distances = spline(np.arange(len(distances)))
smooth_distances_mean = np.mean([np.min(smooth_distances), np.max(smooth_distances)])* 0.10
axes[1,1].fill_between(x, ws1w_uniform1-smooth_distances_mean, ws1w_uniform1+smooth_distances_mean, color='#6F99ADFF', alpha=0.2,edgecolors='none')
params, covariance = curve_fit(cubic_fit, x, ws1w_gravitycore[:60, 3])
a_fit, b_fit, c_fit, d_fit = params
ws1w_gravitycore_fit = cubic_fit(x, a_fit, b_fit, c_fit, d_fit)
axes[1,1].plot(x, ws1w_gravitycore_fit, color='#FFDC91FF', label='Top Nodes', linewidth=0.5)
axes[1,1].scatter(x, ws1w_gravitycore[:60, 3], color ='#FFDC91FF',edgecolors='none', s=0.4, alpha=0.6)
distances = np.abs(ws1w_gravitycore[:60, 3] - ws1w_gravitycore_fit)
spline = UnivariateSpline(np.arange(len(distances)), distances.flatten(), s=0)
smooth_distances = spline(np.arange(len(distances)))
smooth_distances_mean = np.mean([np.min(smooth_distances), np.max(smooth_distances)]) *0.10
axes[1,1].fill_between(x, ws1w_gravitycore_fit - smooth_distances_mean, ws1w_gravitycore_fit + smooth_distances_mean, color='#FFDC91FF', alpha=0.2,edgecolors='none')

axes[1,1].tick_params(labelsize=4)
axes[1,1].set_xticks([0,0.12,0.35,0.7,1])
axes[1,1].set_xticklabels(np.array([0, 300,980, 2000, 2700]).astype(int))
#axes[1,1].legend(fontsize=3,edgecolor='black',framealpha=0.1,loc='center right')
axes[1,1].grid (False)
axes[1,1].spines['top'].set_visible(False)
axes[1,1].spines['right'].set_visible(False)
axes[1,1].xaxis.set_ticks_position('bottom')
axes[1,1].yaxis.set_ticks_position('left')
axes[1,1].set_yticks(np.linspace(0.6, 1, 5))
axes[1,1].set_yticks([0.6, 0.7, 0.8, 0.9,1])
axes[1,1].set_xticks([], minor=True)
axes[1,1].set_yticks([], minor=True)
axes[1,1].tick_params(axis='both', which='both', length=1.2)
axes[1,1].text(0.5, 0.97, 'Gravitycore', transform=axes[1,1].transAxes, ha='center', va='center', bbox=dict(facecolor='none', edgecolor='none', boxstyle='round', alpha=0.0), fontsize=4)








params, covariance = curve_fit(cubic_fit, x, ws1w_uniform[:60,0])
a_fit, b_fit, c_fit, d_fit = params
ws1w_uniform1 = cubic_fit(x, a_fit, b_fit, c_fit, d_fit)
axes[2,1].plot(x,ws1w_uniform1,color ='#6F99ADFF', label = 'uniform',linewidth=0.5)
axes[2,1].scatter(x, ws1w_uniform[:60,0],color ='#6F99ADFF',edgecolors='none', s=0.4, alpha=0.6)
distances = np.abs(ws1w_uniform[:60, 1] - ws1w_uniform1)
spline = UnivariateSpline(np.arange(len(distances)), distances.flatten(), s=0)
smooth_distances = spline(np.arange(len(distances)))
smooth_distances_mean = np.mean([np.min(smooth_distances), np.max(smooth_distances)])* 0.10
axes[2,1].fill_between(x, ws1w_uniform1-smooth_distances_mean, ws1w_uniform1+smooth_distances_mean, color='#6F99ADFF', alpha=0.2,edgecolors='none')
params, covariance = curve_fit(cubic_fit, x, ws1w_gravitypagerank[:60, 3])
a_fit, b_fit, c_fit, d_fit = params
ws1w_gravitypagerank_fit = cubic_fit(x, a_fit, b_fit, c_fit, d_fit)
axes[2,1].plot(x, ws1w_gravitypagerank_fit, color='#FFDC91FF', label='Top Nodes', linewidth=0.5)
axes[2,1].scatter(x, ws1w_gravitypagerank[:60, 3], color ='#FFDC91FF',edgecolors='none', s=0.4, alpha=0.6)
distances = np.abs(ws1w_gravitypagerank[:60, 3] - ws1w_gravitypagerank_fit)
spline = UnivariateSpline(np.arange(len(distances)), distances.flatten(), s=0)
smooth_distances = spline(np.arange(len(distances)))
smooth_distances_mean = np.mean([np.min(smooth_distances), np.max(smooth_distances)]) * 0.10
axes[2,1].fill_between(x, ws1w_gravitypagerank_fit - smooth_distances_mean, ws1w_gravitypagerank_fit + smooth_distances_mean, color='#FFDC91FF', alpha=0.2,edgecolors='none')
axes[2,1].tick_params(labelsize=4)
axes[2,1].set_xticks([0,0.12,0.35,0.7,1])
axes[2,1].set_xticklabels(np.array([0, 300,980, 2000, 2700]).astype(int))
#axes[2,1].legend(fontsize=3,edgecolor='black',framealpha=0.1,loc='center right')
axes[2,1].grid (False)
axes[2,1].spines['top'].set_visible(False)
axes[2,1].spines['right'].set_visible(False)
axes[2,1].xaxis.set_ticks_position('bottom')
axes[2,1].yaxis.set_ticks_position('left')
axes[2,1].set_yticks(np.linspace(0.6, 1, 5))
axes[2,1].set_yticks([0.6, 0.7, 0.8, 0.9,1])
axes[2,1].set_xticks([], minor=True)
axes[2,1].set_yticks([], minor=True)
axes[2,1].tick_params(axis='both', which='both', length=1.2)
axes[2,1].text(0.5, 0.97, 'Gravitypagerank', transform=axes[2,1].transAxes, ha='center', va='center', bbox=dict(facecolor='none', edgecolor='none', boxstyle='round', alpha=0.0), fontsize=4)




params, covariance = curve_fit(cubic_fit, x, ws1w_uniform[:60,0])
a_fit, b_fit, c_fit, d_fit = params
ws1w_uniform1 = cubic_fit(x, a_fit, b_fit, c_fit, d_fit)
axes[3,1].plot(x,ws1w_uniform1,color ='#6F99ADFF', label = 'uniform',linewidth=0.5)
axes[3,1].scatter(x, ws1w_uniform[:60,0],color ='#6F99ADFF',edgecolors='none', s=0.4, alpha=0.6)
distances = np.abs(ws1w_uniform[:60, 1] - ws1w_uniform1)
spline = UnivariateSpline(np.arange(len(distances)), distances.flatten(), s=0)
smooth_distances = spline(np.arange(len(distances)))
smooth_distances_mean = np.mean([np.min(smooth_distances), np.max(smooth_distances)])* 0.10
axes[3,1].fill_between(x, ws1w_uniform1-smooth_distances_mean, ws1w_uniform1+smooth_distances_mean, color='#6F99ADFF', alpha=0.2,edgecolors='none')
params, covariance = curve_fit(cubic_fit, x, ws1w_gravitybetweenness[:60, 3])
a_fit, b_fit, c_fit, d_fit = params
ws1w_gravitybetweenness_fit = cubic_fit(x, a_fit, b_fit, c_fit, d_fit)
axes[3,1].plot(x, ws1w_gravitybetweenness_fit, color='#FFDC91FF', label='Top Nodes', linewidth=0.5)
axes[3,1].scatter(x, ws1w_gravitybetweenness[:60, 3], color ='#FFDC91FF',edgecolors='none', s=0.4, alpha=0.6)
distances = np.abs(ws1w_gravitybetweenness[:60, 3] - ws1w_gravitybetweenness_fit)
spline = UnivariateSpline(np.arange(len(distances)), distances.flatten(), s=0)
smooth_distances = spline(np.arange(len(distances)))
smooth_distances_mean = np.mean([np.min(smooth_distances), np.max(smooth_distances)]) * 0.10
axes[3,1].fill_between(x, ws1w_gravitybetweenness_fit - smooth_distances_mean, ws1w_gravitybetweenness_fit + smooth_distances_mean, color='#FFDC91FF', alpha=0.2,edgecolors='none')
axes[3,1].tick_params(labelsize=4)
axes[3,1].set_xticks([0,0.12,0.35,0.7,1])
axes[3,1].set_xticklabels(np.array([0, 300,980, 2000, 2700]).astype(int))
#axes[3,1].legend(fontsize=3,edgecolor='black',framealpha=0.1,loc='center right')
axes[3,1].grid (False)
axes[3,1].spines['top'].set_visible(False)
axes[3,1].spines['right'].set_visible(False)
axes[3,1].xaxis.set_ticks_position('bottom')
axes[3,1].yaxis.set_ticks_position('left')
axes[3,1].set_yticks(np.linspace(0.6, 1, 5))
axes[3,1].set_yticks([0.6, 0.7, 0.8, 0.9,1])
axes[3,1].set_xticks([], minor=True)
axes[3,1].set_yticks([], minor=True)
axes[3,1].tick_params(axis='both', which='both', length=1.2)
axes[3,1].text(0.5, 0.97, 'Gravitybetweenness', transform=axes[3,1].transAxes, ha='center', va='center', bbox=dict(facecolor='none', edgecolor='none', boxstyle='round', alpha=0.0), fontsize=4)






params, covariance = curve_fit(cubic_fit, x, ws1w_uniform[:60,0])
a_fit, b_fit, c_fit, d_fit = params
ws1w_uniform1 = cubic_fit(x, a_fit, b_fit, c_fit, d_fit)
axes[4,1].plot(x,ws1w_uniform1,color ='#6F99ADFF', label = 'uniform',linewidth=0.5)
axes[4,1].scatter(x, ws1w_uniform[:60,0],color ='#6F99ADFF',edgecolors='none', s=0.4, alpha=0.6)
distances = np.abs(ws1w_uniform[:60, 1] - ws1w_uniform1)
spline = UnivariateSpline(np.arange(len(distances)), distances.flatten(), s=0)
smooth_distances = spline(np.arange(len(distances)))
smooth_distances_mean = np.mean([np.min(smooth_distances), np.max(smooth_distances)])* 0.10
axes[4,1].fill_between(x, ws1w_uniform1-smooth_distances_mean, ws1w_uniform1+smooth_distances_mean, color='#6F99ADFF', alpha=0.2,edgecolors='none')
params, covariance = curve_fit(cubic_fit, x, ws1w_gravitycloseness[:60, 3])
a_fit, b_fit, c_fit, d_fit = params
ws1w_gravitycloseness_fit = cubic_fit(x, a_fit, b_fit, c_fit, d_fit)
axes[4,1].plot(x, ws1w_gravitycloseness_fit, color='#FFDC91FF', label='Top Nodes', linewidth=0.5)
axes[4,1].scatter(x, ws1w_gravitycloseness[:60, 3], color ='#FFDC91FF',edgecolors='none', s=0.4, alpha=0.6)
distances = np.abs(ws1w_gravitycloseness[:60, 3] - ws1w_gravitycloseness_fit)
spline = UnivariateSpline(np.arange(len(distances)), distances.flatten(), s=0)
smooth_distances = spline(np.arange(len(distances)))
smooth_distances_mean = np.mean([np.min(smooth_distances), np.max(smooth_distances)]) * 0.10
axes[4,1].fill_between(x, ws1w_gravitycloseness_fit - smooth_distances_mean, ws1w_gravitycloseness_fit + smooth_distances_mean, color='#FFDC91FF', alpha=0.2,edgecolors='none')
axes[4,1].tick_params(labelsize=4)
axes[4,1].set_xticks([0,0.12,0.35,0.7,1])
axes[4,1].set_xticklabels(np.array([0, 300,980, 2000, 2700]).astype(int))
#axes[4,1].legend(fontsize=3,edgecolor='black',framealpha=0.1,loc='center right')
axes[4,1].grid (False)
axes[4,1].spines['top'].set_visible(False)
axes[4,1].spines['right'].set_visible(False)
axes[4,1].xaxis.set_ticks_position('bottom')
axes[4,1].yaxis.set_ticks_position('left')
axes[4,1].set_yticks(np.linspace(0.6, 1, 5))
axes[4,1].set_yticks([0.6, 0.7, 0.8, 0.9,1])
axes[4,1].set_xticks([], minor=True)
axes[4,1].set_yticks([], minor=True)
axes[4,1].tick_params(axis='both', which='both', length=1.2)
axes[4,1].text(0.5, 0.97, 'Gravitycloseness', transform=axes[4,1].transAxes, ha='center', va='center', bbox=dict(facecolor='none', edgecolor='none', boxstyle='round', alpha=0.0), fontsize=4)













y = np.linspace(0,1,20)
params, covariance = curve_fit(cubic_fit, y, ws1w_degree_rn['mean_ap'].values[:30])
a_fit, b_fit, c_fit, d_fit = params
ws1w_degree_fit = cubic_fit(y, a_fit, b_fit, c_fit, d_fit)
axes[0,0].plot(y, ws1w_degree_fit, color='#A392BA', label='Rejected nodes(RN)', linewidth=0.5)
axes[0,0].scatter(y, ws1w_degree_rn['mean_ap'].values[:30], color ='#A392BA',edgecolors='none', s=0.4, alpha=0.6)
distances = np.abs(ws1w_degree_rn['mean_ap'].values[:30] - ws1w_degree_fit)
spline = UnivariateSpline(np.arange(len(distances)), distances.flatten(), s=0)
smooth_distances = spline(np.arange(len(distances)))
smooth_distances_mean = np.mean([np.min(smooth_distances), np.max(smooth_distances)]) * 0.5
axes[0,0].fill_between(y, ws1w_degree_fit - smooth_distances_mean, ws1w_degree_fit + smooth_distances_mean, color='#A392BA', alpha=0.2,edgecolors='none')

params, covariance = curve_fit(cubic_fit, y, ws1w_core_rn['mean_ap'].values[:30])
a_fit, b_fit, c_fit, d_fit = params
ws1w_core_fit = cubic_fit(y, a_fit, b_fit, c_fit, d_fit)
axes[1,0].plot(y, ws1w_core_fit, color='#A392BA', label='Rejected nodes(RN)', linewidth=0.5)
axes[1,0].scatter(y, ws1w_core_rn['mean_ap'].values[:30], color ='#A392BA',edgecolors='none', s=0.4, alpha=0.6)
distances = np.abs(ws1w_core_rn['mean_ap'].values[:30] - ws1w_core_fit)
spline = UnivariateSpline(np.arange(len(distances)), distances.flatten(), s=0)
smooth_distances = spline(np.arange(len(distances)))
smooth_distances_mean = np.mean([np.min(smooth_distances), np.max(smooth_distances)]) * 0.5
axes[1,0].fill_between(y, ws1w_core_fit - smooth_distances_mean, ws1w_core_fit + smooth_distances_mean, color='#A392BA', alpha=0.2,edgecolors='none')



params, covariance = curve_fit(cubic_fit, y, ws1w_pagerank_rn['mean_ap'].values[:30])
a_fit, b_fit, c_fit, d_fit = params
ws1w_pagerank_fit = cubic_fit(y, a_fit, b_fit, c_fit, d_fit)
axes[2,0].plot(y, ws1w_pagerank_fit, color='#A392BA', label='Rejected nodes(RN)', linewidth=0.5)
axes[2,0].scatter(y, ws1w_pagerank_rn['mean_ap'].values[:30], color ='#A392BA',edgecolors='none', s=0.4, alpha=0.6)
distances = np.abs(ws1w_pagerank_rn['mean_ap'].values[:30] - ws1w_pagerank_fit)
spline = UnivariateSpline(np.arange(len(distances)), distances.flatten(), s=0)
smooth_distances = spline(np.arange(len(distances)))
smooth_distances_mean = np.mean([np.min(smooth_distances), np.max(smooth_distances)]) * 0.5
axes[2,0].fill_between(y, ws1w_pagerank_fit - smooth_distances_mean, ws1w_pagerank_fit + smooth_distances_mean, color='#A392BA', alpha=0.2,edgecolors='none')





params, covariance = curve_fit(cubic_fit, y, ws1w_betweenness_rn['mean_ap'].values[:30])
a_fit, b_fit, c_fit, d_fit = params
ws1w_betweenness_fit = cubic_fit(y, a_fit, b_fit, c_fit, d_fit)
axes[3,0].plot(y, ws1w_betweenness_fit, color='#A392BA', label='Rejected nodes(RN)', linewidth=0.5)
axes[3,0].scatter(y, ws1w_betweenness_rn['mean_ap'].values[:30], color ='#A392BA',edgecolors='none', s=0.4, alpha=0.6)
distances = np.abs(ws1w_betweenness_rn['mean_ap'].values[:30] - ws1w_betweenness_fit)
spline = UnivariateSpline(np.arange(len(distances)), distances.flatten(), s=0)
smooth_distances = spline(np.arange(len(distances)))
smooth_distances_mean = np.mean([np.min(smooth_distances), np.max(smooth_distances)]) * 0.5



params, covariance = curve_fit(cubic_fit,y, ws1w_closeness_rn['mean_ap'].values[:30])
a_fit, b_fit, c_fit, d_fit = params
ws1w_closeness_fit = cubic_fit(y, a_fit, b_fit, c_fit, d_fit)
axes[4,0].plot(y, ws1w_closeness_fit, color='#A392BA', label='Rejected nodes(RN)', linewidth=0.5)
axes[4,0].scatter(y, ws1w_closeness_rn['mean_ap'].values[:30], color ='#A392BA',edgecolors='none', s=0.4, alpha=0.6)
distances = np.abs(ws1w_closeness_rn['mean_ap'].values[:30] - ws1w_closeness_fit)
spline = UnivariateSpline(np.arange(len(distances)), distances.flatten(), s=0)
smooth_distances = spline(np.arange(len(distances)))
smooth_distances_mean = np.mean([np.min(smooth_distances), np.max(smooth_distances)]) * 0.5
axes[4,0].fill_between(y, ws1w_closeness_fit - smooth_distances_mean, ws1w_closeness_fit + smooth_distances_mean, color='#A392BA', alpha=0.2,edgecolors='none')



params, covariance = curve_fit(cubic_fit,y, ws1w_gravitydegree_rn['mean_ap'].values[:30])
a_fit, b_fit, c_fit, d_fit = params
ws1w_gravitydegree_fit = cubic_fit(y, a_fit, b_fit, c_fit, d_fit)
axes[0,1].plot(y, ws1w_gravitydegree_fit, color='#A392BA', label='Rejected nodes(RN)', linewidth=0.5)
axes[0,1].scatter(y, ws1w_gravitydegree_rn['mean_ap'].values[:30], color ='#A392BA',edgecolors='none', s=0.4, alpha=0.6)
distances = np.abs(ws1w_gravitydegree_rn['mean_ap'].values[:30] - ws1w_gravitydegree_fit)
spline = UnivariateSpline(np.arange(len(distances)), distances.flatten(), s=0)
smooth_distances = spline(np.arange(len(distances)))
smooth_distances_mean = np.mean([np.min(smooth_distances), np.max(smooth_distances)]) * 0.5
axes[0,1].fill_between(y, ws1w_gravitydegree_fit - smooth_distances_mean, ws1w_gravitydegree_fit + smooth_distances_mean, color='#A392BA', alpha=0.2,edgecolors='none')



params, covariance = curve_fit(cubic_fit, y, ws1w_gravitycore_rn['mean_ap'].values[:30])
a_fit, b_fit, c_fit, d_fit = params
ws1w_gravitycore_fit = cubic_fit(y, a_fit, b_fit, c_fit, d_fit)
axes[1,1].plot(y, ws1w_gravitycore_fit, color='#A392BA', label='Rejected nodes(RN)', linewidth=0.5)
axes[1,1].scatter(y, ws1w_gravitycore_rn['mean_ap'].values[:30], color ='#A392BA',edgecolors='none', s=0.4, alpha=0.6)
distances =  np.abs(ws1w_gravitycore_rn['mean_ap'].values[:30] - ws1w_gravitycore_fit)
spline = UnivariateSpline(np.arange(len(distances)), distances.flatten(), s=0)
smooth_distances = spline(np.arange(len(distances)))
smooth_distances_mean = np.mean([np.min(smooth_distances), np.max(smooth_distances)]) * 0.5
axes[1,1].fill_between(y, ws1w_gravitycore_fit - smooth_distances_mean, ws1w_gravitycore_fit + smooth_distances_mean, color='#A392BA', alpha=0.2,edgecolors='none')




params, covariance = curve_fit(cubic_fit, y, ws1w_gravitypagerank_rn['mean_ap'].values[:30])
a_fit, b_fit, c_fit, d_fit = params
ws1w_gravitypagerank_fit = cubic_fit(y, a_fit, b_fit, c_fit, d_fit)
axes[2,1].plot(y, ws1w_gravitypagerank_fit, color='#A392BA', label='Rejected nodes(RN)', linewidth=0.5)
axes[2,1].scatter(y, ws1w_gravitypagerank_rn['mean_ap'].values[:30], color ='#A392BA',edgecolors='none', s=0.4, alpha=0.6)
distances = np.abs(ws1w_gravitypagerank_rn['mean_ap'].values[:30] - ws1w_gravitypagerank_fit)
spline = UnivariateSpline(np.arange(len(distances)), distances.flatten(), s=0)
smooth_distances = spline(np.arange(len(distances)))
smooth_distances_mean = np.mean([np.min(smooth_distances), np.max(smooth_distances)]) * 0.5
axes[2,1].fill_between(y, ws1w_gravitypagerank_fit - smooth_distances_mean, ws1w_gravitypagerank_fit + smooth_distances_mean, color='#A392BA', alpha=0.2,edgecolors='none')


params, covariance = curve_fit(cubic_fit, y, ws1w_gravitybetweenness_rn['mean_ap'].values[:30])
a_fit, b_fit, c_fit, d_fit = params
ws1w_gravitybetweenness_fit = cubic_fit(y, a_fit, b_fit, c_fit, d_fit)
axes[3,1].plot(y, ws1w_gravitybetweenness_fit, color='#A392BA', label='Rejected nodes(RN)', linewidth=0.5)
axes[3,1].scatter(y, ws1w_gravitybetweenness_rn['mean_ap'].values[:30], color ='#A392BA',edgecolors='none', s=0.4, alpha=0.6)
distances = np.abs(ws1w_gravitybetweenness_rn['mean_ap'].values[:30] - ws1w_gravitybetweenness_fit)
spline = UnivariateSpline(np.arange(len(distances)), distances.flatten(), s=0)
smooth_distances = spline(np.arange(len(distances)))
smooth_distances_mean = np.mean([np.min(smooth_distances), np.max(smooth_distances)]) * 0.5
axes[3,1].fill_between(y, ws1w_gravitybetweenness_fit - smooth_distances_mean, ws1w_gravitybetweenness_fit + smooth_distances_mean, color='#A392BA', alpha=0.2,edgecolors='none')



params, covariance = curve_fit(cubic_fit, y, ws1w_gravitycloseness_rn['mean_ap'].values[:30])
a_fit, b_fit, c_fit, d_fit = params
ws1w_gravitycloseness_fit = cubic_fit(y, a_fit, b_fit, c_fit, d_fit)
axes[4,1].plot(y, ws1w_gravitycloseness_fit, color='#A392BA', label='Rejected nodes(RN)', linewidth=0.5)
axes[4,1].scatter(y, ws1w_gravitycloseness_rn['mean_ap'].values[:30], color ='#A392BA',edgecolors='none', s=0.4, alpha=0.6)
distances =  np.abs(ws1w_gravitycloseness_rn['mean_ap'].values[:30] - ws1w_gravitycloseness_fit)
spline = UnivariateSpline(np.arange(len(distances)), distances.flatten(), s=0)
smooth_distances = spline(np.arange(len(distances)))
smooth_distances_mean = np.mean([np.min(smooth_distances), np.max(smooth_distances)]) * 0.5
axes[4,1].fill_between(y, ws1w_gravitycloseness_fit - smooth_distances_mean, ws1w_gravitycloseness_fit + smooth_distances_mean, color='#A392BA', alpha=0.2,edgecolors='none')



params, covariance = curve_fit(cubic_fit, x, ws1w_degree[:60,0])
a_fit, b_fit, c_fit, d_fit = params
ws1w_degree_fit = cubic_fit(x, a_fit, b_fit, c_fit, d_fit)
axes[0,0].plot(x, ws1w_degree_fit, color='#BC3C29FF', label='Sampled nodes(SN)', linewidth=0.5)
axes[0,0].scatter(x, ws1w_degree[:60, 1], color ='#BC3C29FF',edgecolors='none', s=0.4, alpha=0.6)
distances = np.abs(ws1w_degree[:60, 1] - ws1w_degree_fit)
spline = UnivariateSpline(np.arange(len(distances)), distances.flatten(), s=0)
smooth_distances = spline(np.arange(len(distances)))
smooth_distances_mean = np.mean([np.min(smooth_distances), np.max(smooth_distances)]) * 0.10
axes[0,0].fill_between(x, ws1w_degree_fit - smooth_distances_mean, ws1w_degree_fit + smooth_distances_mean, color='#BC3C29FF', alpha=0.2,edgecolors='none')

params, covariance = curve_fit(cubic_fit, x, ws1w_core[:60,0])
a_fit, b_fit, c_fit, d_fit = params
ws1w_core_fit = cubic_fit(x, a_fit, b_fit, c_fit, d_fit)
axes[1,0].plot(x, ws1w_core_fit, color='#BC3C29FF', label='Sampled Nodes', linewidth=0.5)
axes[1,0].scatter(x, ws1w_core[:60, 1], color ='#BC3C29FF',edgecolors='none', s=0.4, alpha=0.6)
distances = np.abs(ws1w_core[:60, 1] - ws1w_core_fit)
spline = UnivariateSpline(np.arange(len(distances)), distances.flatten(), s=0)
smooth_distances = spline(np.arange(len(distances)))
smooth_distances_mean = np.mean([np.min(smooth_distances), np.max(smooth_distances)]) * 0.10
axes[1,0].fill_between(x, ws1w_core_fit - smooth_distances_mean, ws1w_core_fit + smooth_distances_mean, color='#BC3C29FF', alpha=0.2,edgecolors='none')

params, covariance = curve_fit(cubic_fit, x, ws1w_pagerank[:60,0])
a_fit, b_fit, c_fit, d_fit = params
ws1w_pagerank_fit = cubic_fit(x, a_fit, b_fit, c_fit, d_fit)
axes[2,0].plot(x, ws1w_pagerank_fit, color='#BC3C29FF', label='Sampled Nodes', linewidth=0.5)
axes[2,0].scatter(x, ws1w_pagerank[:60, 1], color ='#BC3C29FF',edgecolors='none', s=0.4, alpha=0.6)
distances = np.abs(ws1w_pagerank[:60, 1] - ws1w_pagerank_fit)
spline = UnivariateSpline(np.arange(len(distances)), distances.flatten(), s=0)
smooth_distances = spline(np.arange(len(distances)))
smooth_distances_mean = np.mean([np.min(smooth_distances), np.max(smooth_distances)]) * 0.10
axes[2,0].fill_between(x, ws1w_pagerank_fit - smooth_distances_mean, ws1w_pagerank_fit + smooth_distances_mean, color='#BC3C29FF', alpha=0.2,edgecolors='none')

params, covariance = curve_fit(cubic_fit, x, ws1w_betweenness[:60,0])
a_fit, b_fit, c_fit, d_fit = params
ws1w_betweenness_fit = cubic_fit(x, a_fit, b_fit, c_fit, d_fit)
axes[3,0].plot(x, ws1w_betweenness_fit, color='#BC3C29FF', label='Sampled Nodes', linewidth=0.5)
axes[3,0].scatter(x, ws1w_betweenness[:60, 1], color ='#BC3C29FF',edgecolors='none', s=0.4, alpha=0.6)
distances = np.abs(ws1w_betweenness[:60, 1] - ws1w_betweenness_fit)
spline = UnivariateSpline(np.arange(len(distances)), distances.flatten(), s=0)
smooth_distances = spline(np.arange(len(distances)))
smooth_distances_mean = np.mean([np.min(smooth_distances), np.max(smooth_distances)]) * 0.10
axes[3,0].fill_between(x, ws1w_betweenness_fit - smooth_distances_mean, ws1w_betweenness_fit + smooth_distances_mean, color='#BC3C29FF', alpha=0.2,edgecolors='none')


params, covariance = curve_fit(cubic_fit, x, ws1w_closeness[:60,0])
a_fit, b_fit, c_fit, d_fit = params
ws1w_closeness_fit = cubic_fit(x, a_fit, b_fit, c_fit, d_fit)
axes[4,0].plot(x, ws1w_closeness_fit, color='#BC3C29FF', label='Sampled Nodes', linewidth=0.5)
axes[4,0].scatter(x, ws1w_closeness[:60, 1], color ='#BC3C29FF',edgecolors='none', s=0.4, alpha=0.6)
distances = np.abs(ws1w_closeness[:60, 1] - ws1w_closeness_fit)
spline = UnivariateSpline(np.arange(len(distances)), distances.flatten(), s=0)
smooth_distances = spline(np.arange(len(distances)))
smooth_distances_mean = np.mean([np.min(smooth_distances), np.max(smooth_distances)]) * 0.10
axes[4,0].fill_between(x, ws1w_closeness_fit - smooth_distances_mean, ws1w_closeness_fit + smooth_distances_mean, color='#BC3C29FF', alpha=0.2,edgecolors='none')



params, covariance = curve_fit(cubic_fit, x, ws1w_gravitydegree[:60,0])
a_fit, b_fit, c_fit, d_fit = params
ws1w_gravitydegree_fit = cubic_fit(x, a_fit, b_fit, c_fit, d_fit)
axes[0,1].plot(x, ws1w_gravitydegree_fit, color='#BC3C29FF', label='Sampled Nodes', linewidth=0.5)
axes[0,1].scatter(x, ws1w_gravitydegree[:60, 1], color ='#BC3C29FF',edgecolors='none', s=0.4, alpha=0.6)
distances = np.abs(ws1w_gravitydegree[:60, 1] - ws1w_gravitydegree_fit)
spline = UnivariateSpline(np.arange(len(distances)), distances.flatten(), s=0)
smooth_distances = spline(np.arange(len(distances)))
smooth_distances_mean = np.mean([np.min(smooth_distances), np.max(smooth_distances)]) * 0.10
axes[0,1].fill_between(x, ws1w_gravitydegree_fit - smooth_distances_mean, ws1w_gravitydegree_fit + smooth_distances_mean, color='#BC3C29FF', alpha=0.2,edgecolors='none')

params, covariance = curve_fit(cubic_fit, x, ws1w_gravitycore[:60,0])
a_fit, b_fit, c_fit, d_fit = params
ws1w_gravitycore_fit = cubic_fit(x, a_fit, b_fit, c_fit, d_fit)
axes[1,1].plot(x, ws1w_gravitycore_fit, color='#BC3C29FF', label='Sampled Nodes', linewidth=0.5)
axes[1,1].scatter(x, ws1w_gravitycore[:60, 1], color ='#BC3C29FF',edgecolors='none', s=0.4, alpha=0.6)
distances = np.abs(ws1w_gravitycore[:60, 1] - ws1w_gravitycore_fit)
spline = UnivariateSpline(np.arange(len(distances)), distances.flatten(), s=0)
smooth_distances = spline(np.arange(len(distances)))
smooth_distances_mean = np.mean([np.min(smooth_distances), np.max(smooth_distances)]) * 0.10
axes[1,1].fill_between(x, ws1w_gravitycore_fit - smooth_distances_mean, ws1w_gravitycore_fit + smooth_distances_mean, color='#BC3C29FF', alpha=0.2,edgecolors='none')

params, covariance = curve_fit(cubic_fit, x, ws1w_gravitypagerank[:60,0])
a_fit, b_fit, c_fit, d_fit = params
ws1w_gravitypagerank_fit = cubic_fit(x, a_fit, b_fit, c_fit, d_fit)
axes[2,1].plot(x, ws1w_gravitypagerank_fit, color='#BC3C29FF', label='Sampled Nodes', linewidth=0.5)
axes[2,1].scatter(x, ws1w_gravitypagerank[:60, 1], color ='#BC3C29FF',edgecolors='none', s=0.4, alpha=0.6)
distances = np.abs(ws1w_gravitypagerank[:60, 1] - ws1w_gravitypagerank_fit)
spline = UnivariateSpline(np.arange(len(distances)), distances.flatten(), s=0)
smooth_distances = spline(np.arange(len(distances)))
smooth_distances_mean = np.mean([np.min(smooth_distances), np.max(smooth_distances)]) * 0.10
axes[2,1].fill_between(x, ws1w_gravitypagerank_fit - smooth_distances_mean, ws1w_gravitypagerank_fit + smooth_distances_mean, color='#BC3C29FF', alpha=0.2,edgecolors='none')

params, covariance = curve_fit(cubic_fit, x, ws1w_gravitybetweenness[:60,0])
a_fit, b_fit, c_fit, d_fit = params
ws1w_gravitybetweenness_fit = cubic_fit(x, a_fit, b_fit, c_fit, d_fit)
axes[3,1].plot(x, ws1w_gravitybetweenness_fit, color='#BC3C29FF', label='Sampled Nodes', linewidth=0.5)
axes[3,1].scatter(x, ws1w_gravitybetweenness[:60, 1], color ='#BC3C29FF',edgecolors='none', s=0.4, alpha=0.6)
distances = np.abs(ws1w_gravitybetweenness[:60, 1] - ws1w_gravitybetweenness_fit)
spline = UnivariateSpline(np.arange(len(distances)), distances.flatten(), s=0)
smooth_distances = spline(np.arange(len(distances)))
smooth_distances_mean = np.mean([np.min(smooth_distances), np.max(smooth_distances)]) * 0.10
axes[3,1].fill_between(x, ws1w_gravitybetweenness_fit - smooth_distances_mean, ws1w_gravitybetweenness_fit + smooth_distances_mean, color='#BC3C29FF', alpha=0.2,edgecolors='none')


params, covariance = curve_fit(cubic_fit, x, ws1w_gravitycloseness[:60,0])
a_fit, b_fit, c_fit, d_fit = params
ws1w_gravitycloseness_fit = cubic_fit(x, a_fit, b_fit, c_fit, d_fit)
axes[4,1].plot(x, ws1w_gravitycloseness_fit, color='#BC3C29FF', label='Sampled Nodes', linewidth=0.5)
axes[4,1].scatter(x, ws1w_gravitycloseness[:60, 1], color ='#BC3C29FF',edgecolors='none', s=0.4, alpha=0.6)
distances = np.abs(ws1w_gravitycloseness[:60, 1] - ws1w_gravitycloseness_fit)
spline = UnivariateSpline(np.arange(len(distances)), distances.flatten(), s=0)
smooth_distances = spline(np.arange(len(distances)))
smooth_distances_mean = np.mean([np.min(smooth_distances), np.max(smooth_distances)]) * 0.10
axes[4,1].fill_between(x, ws1w_gravitycloseness_fit - smooth_distances_mean, ws1w_gravitycloseness_fit + smooth_distances_mean, color='#BC3C29FF', alpha=0.2,edgecolors='none')


axes[0,0].legend(fontsize=3,edgecolor='black',framealpha=0.1,loc='best',frameon=False)

plt.subplots_adjust(wspace=0.3,hspace=0.3)

for i in range(5):
    axes[i,0].set_ylabel('AP (\%)',fontsize=3.5,labelpad=1)
    if i==4:
        axes[i,0].set_xlabel('Nodes Number',fontsize=3.5,labelpad=1)
        axes[i,1].set_xlabel('Nodes Number',fontsize=3.5,labelpad=1)


for ax in axes.flat:
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.xaxis.set_ticks_position('bottom')
    ax.yaxis.set_ticks_position('left')
    ax.tick_params(axis='both', which='both', length=1.8,pad=1.5,width=0.4)
    ax.set_xlim([0,1])
    ax.set_xticks([0,0.2,0.4,0.6,0.8,1])
    ax.set_xticklabels(np.array([0, 2000,4000,6000,8000,10000]).astype(int))
    ax.set_ylim([0.5,0.9])
    ax.set_yticks([0.6, 0.7, 0.8, 0.9])
    ax.tick_params(axis='x', rotation=45,labelsize=3.5)
plt.subplots_adjust(wspace=0.3,hspace=0.3)

plt.subplots_adjust(wspace=0.3,hspace=0.35)


fig.suptitle('Area Under Precision Recall(\%) on Small World 10000',fontsize=5, y=0.92)
fig.savefig('C:/Users/WENJIA/Downloads/papers/results/ws1w_ap.png',dpi=350)
fig.savefig('C:/Users/WENJIA/Downloads/papers/results/ws1w_ap.pdf',dpi=350)

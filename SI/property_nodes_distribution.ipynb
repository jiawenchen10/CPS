# %%
import numpy as np
import matplotlib.pylab as plt
import scienceplots
import pandas as pd
import networkx as nx
from data_generator import processdata
plt.style.use('science')
import pickle
import scipy.sparse as sp
import sys
import zipfile as zf
from input_data import load_data

# %% [markdown]
# ### WS networks

# %%
datasets = 'ws1w'
adj_matrix,_ = load_data(datasets)
G = nx.from_numpy_array(adj_matrix,create_using=nx.DiGraph)

# %%
filename = 'centrality/%s_pos.pkl' % (datasets)
with open(filename, "rb") as f:
        ws1w_pos = pickle.load(f)
filename = 'centrality/%s_%s.pkl' % (datasets, 'degree')
with open(filename, "rb") as f:
        degree = pickle.load(f)
filename = 'centrality/%s_%s.pkl' % (datasets, 'core')
with open(filename, "rb") as f:
        core = pickle.load(f)
filename = 'centrality/%s_%s.pkl' % (datasets, 'pagerank')
with open(filename, "rb") as f:
        pagerank = pickle.load(f)
filename = 'centrality/%s_%s.pkl' % (datasets, 'betweenness')
with open(filename, "rb") as f:
    betweenness  = pickle.load(f)
filename = 'centrality/%s_%s.pkl' % (datasets, 'closeness')
with open(filename, "rb") as f:
    closeness  = pickle.load(f)
#filename = 'centrality/%s_%s.pkl' % (datasets, 'eigenvector')
#with open(filename, "rb") as f:
#    eigenvector = pickle.load(f)
filename = 'centrality/%s_%s.pkl' % (datasets, 'gravitydegree')
with open(filename, "rb") as f:
    gravitydegree = pickle.load(f)
filename = 'centrality/%s_%s.pkl' % (datasets, 'gravitycore')
with open(filename, "rb") as f:
    gravitycore = pickle.load(f)

filename = 'centrality/%s_%s.pkl' % (datasets, 'gravitypagerank')
with open(filename, "rb") as f:
    gravitypagerank = pickle.load(f)
filename = 'centrality/%s_%s.pkl' % (datasets, 'gravitybetweenness')
with open(filename, "rb") as f:
    gravitybetweenness = pickle.load(f)
filename = 'centrality/%s_%s.pkl' % (datasets, 'gravitycloseness')
with open(filename, "rb") as f:
    gravitycloseness = pickle.load(f)
#filename = 'centrality/%s_%s.pkl' % (datasets, 'gravityeigenvector')
#with open(filename, "rb") as f:
#    gravityeigenvector = pickle.load(f)

# %%
import matplotlib.pyplot as plt
import networkx as nx
import numpy as np
from matplotlib.patches import FancyBboxPatch
plt.style.use('nature')
# 
fig, axes = plt.subplots(2,5, figsize=(22,9), dpi=200)

# 

sorting_keys = [
    ('nodes/ws1w_gcn_vae_degree_1000.npy', ' Degree-1000',degree),
    ('nodes/ws1w_gcn_vae_core_1000.npy', ' Core-1000',core),
    ('nodes/ws1w_gcn_vae_pagerank_1000.npy', ' Pagerank-1000',pagerank),
    ('nodes/ws1w_gcn_vae_betweenness_1000.npy', ' Betweenness-1000',betweenness),
    ('nodes/ws1w_gcn_vae_closeness_1000.npy', ' Closeness-1000',closeness),
    ('nodes/ws1w_gcn_vae_gravitydegree_1000.npy', ' GravityDegree-1000',gravitydegree),
    ('nodes/ws1w_gcn_vae_gravitycore_1000.npy', ' GravityCore-1000',gravitycore),
    ('nodes/ws1w_gcn_vae_gravitypagerank_1000.npy', ' GravityPagerank-1000',gravitypagerank),
    ('nodes/ws1w_gcn_vae_gravitybetweenness_1000.npy', ' GravityBetweenness-1000',gravitybetweenness),
    ('nodes/ws1w_gcn_vae_gravitycloseness_1000.npy', ' GravityCloseness-1000',gravitycloseness)]


# Loop through each subgraph and perform sorting based on the respective key
for i, (data_filename, title, sorting_key) in enumerate(sorting_keys):
    sorted_key= sorted(sorting_key.items(), key = lambda x:x[1],reverse=True)
    top_nodes = [node[0] for node in sorted_key[:1000]]
    sampled_nodes = np.load(data_filename)
    nodes = [node for node in G.nodes() if node not in top_nodes and node not in sampled_nodes]
    node_list = [node for node in sampled_nodes if node in top_nodes]

    # 
    nx.draw_networkx_nodes(G, ws1w_pos, nodelist=nodes, node_color='skyblue', node_size=18, alpha=0.3, label='Common nodes', ax=axes[i//5,i%5])
    nx.draw_networkx_nodes(G,  ws1w_pos, nodelist=top_nodes, node_color='steelblue', edgecolors='#3C5488FF', node_size=18, linewidths=1, alpha=0.5, label='Top nodes', ax=axes[i//5,i%5])
    # nx.draw_networkx_nodes(G,  ws1w_pos, nodelist=sampled_nodes, node_color='steelblue', edgecolors='#FD8404', linewidths=1, node_size=18, alpha=0.5, label='Sampled nodes', ax=axes[i//5,i%5])
    # nx.draw_networkx_nodes(G,  ws1w_pos, nodelist=node_list, node_color='darkslategray', edgecolors='orangered', linewidths=1, node_size=25, alpha=0.7, label='Identical nodes',  ax=axes[i//5,i%5])
    nx.draw_networkx_edges(G, ws1w_pos, width=1, edge_color='mistyrose', alpha=0.5, arrows=False, ax=axes[i//5,i%5])

    # 
    ax=axes[i//5,i%5].set_title(title, fontsize=20)
    ax=axes[i//5,i%5].axis('off')

lines1, labels1 = axes[0,0].get_legend_handles_labels()
# lines2, labels2 = axes[1].get_legend_handles_labels()
# lines3, labels3 = axes[2].get_legend_handles_labels()
# lines = lines1 + lines2 + lines3
# labels = labels1 + labels2 +labels3


fig.subplots_adjust(wspace=0,hspace=0.1)

fig.legend(lines1, labels1, fontsize=20, loc='lower center', bbox_to_anchor=(0.5, 0.05),ncol=4)
# 
plt.savefig('C:\\Users\\WENJIA\\Downloads\\papers\\node\\ws1w_1000_tn.pdf', dpi=150)
plt.savefig('C:\\Users\\WENJIA\\Downloads\\papers\\node\\ws1w_1000_tn.png', dpi=150)
plt.tight_layout()

# 
plt.show()

# %%
import matplotlib.pyplot as plt
import networkx as nx
import numpy as np
from matplotlib.patches import FancyBboxPatch
plt.style.use('nature')
# 
fig, axes = plt.subplots(2,5, figsize=(22,9), dpi=200)

# 

sorting_keys = [
    ('nodes/ws1w_gcn_vae_degree_1000.npy', ' Degree-1000',degree),
    ('nodes/ws1w_gcn_vae_core_1000.npy', ' Core-1000',core),
    ('nodes/ws1w_gcn_vae_pagerank_1000.npy', ' Pagerank-1000',pagerank),
    ('nodes/ws1w_gcn_vae_betweenness_1000.npy', ' Betweenness-1000',betweenness),
    ('nodes/ws1w_gcn_vae_closeness_1000.npy', ' Closeness-1000',closeness),
    ('nodes/ws1w_gcn_vae_gravitydegree_1000.npy', ' GravityDegree-1000',gravitydegree),
    ('nodes/ws1w_gcn_vae_gravitycore_1000.npy', ' GravityCore-1000',gravitycore),
    ('nodes/ws1w_gcn_vae_gravitypagerank_1000.npy', ' GravityPagerank-1000',gravitypagerank),
    ('nodes/ws1w_gcn_vae_gravitybetweenness_1000.npy', ' GravityBetweenness-1000',gravitybetweenness),
    ('nodes/ws1w_gcn_vae_gravitycloseness_1000.npy', ' GravityCloseness-1000',gravitycloseness)]


# Loop through each subgraph and perform sorting based on the respective key
for i, (data_filename, title, sorting_key) in enumerate(sorting_keys):
    sorted_key= sorted(sorting_key.items(), key = lambda x:x[1],reverse=True)
    top_nodes = [node[0] for node in sorted_key[:1000]]
    sampled_nodes = np.load(data_filename)
    nodes = [node for node in G.nodes() if node not in top_nodes and node not in sampled_nodes]
    node_list = [node for node in sampled_nodes if node in top_nodes]

    # 
    nx.draw_networkx_nodes(G, ws1w_pos, nodelist=nodes, node_color='skyblue', node_size=18, alpha=0.3, label='Common nodes', ax=axes[i//5,i%5])
    # nx.draw_networkx_nodes(G,  ws1w_pos, nodelist=top_nodes, node_color='steelblue', edgecolors='#3C5488FF', node_size=18, linewidths=1, alpha=0.5, label='Top nodes', ax=axes[i//5,i%5])
    nx.draw_networkx_nodes(G,  ws1w_pos, nodelist=sampled_nodes, node_color='steelblue', edgecolors='#FD8404', linewidths=1, node_size=18, alpha=0.5, label='Sampled nodes', ax=axes[i//5,i%5])
    # nx.draw_networkx_nodes(G,  ws1w_pos, nodelist=node_list, node_color='darkslategray', edgecolors='orangered', linewidths=1, node_size=25, alpha=0.7, label='Identical nodes',  ax=axes[i//5,i%5])
    nx.draw_networkx_edges(G, ws1w_pos, width=1, edge_color='mistyrose', alpha=0.5, arrows=False, ax=axes[i//5,i%5])

    # 
    ax=axes[i//5,i%5].set_title(title, fontsize=20)
    ax=axes[i//5,i%5].axis('off')

lines1, labels1 = axes[0,0].get_legend_handles_labels()
# lines2, labels2 = axes[1].get_legend_handles_labels()
# lines3, labels3 = axes[2].get_legend_handles_labels()
# lines = lines1 + lines2 + lines3
# labels = labels1 + labels2 +labels3


fig.subplots_adjust(wspace=0,hspace=0.1)

fig.legend(lines1, labels1, fontsize=20, loc='lower center', bbox_to_anchor=(0.5, 0.05),ncol=4)
# 
plt.savefig('C:\\Users\\WENJIA\\Downloads\\papers\\node\\ws1w_1000_sn.pdf', dpi=150)
plt.savefig('C:\\Users\\WENJIA\\Downloads\\papers\\node\\ws1w_1000_sn.png', dpi=150)
plt.tight_layout()

# 
plt.show()

# %% [markdown]
# ####  WS3k

# %%
datasets = 'ws3k'
adj_matrix,_ = load_data(datasets)
G = nx.from_numpy_array(adj_matrix,create_using=nx.DiGraph)

# %%
filename = 'centrality/%s_pos.pkl' % (datasets)
with open(filename, "rb") as f:
        ws3k_pos = pickle.load(f)
filename = 'centrality/%s_%s.pkl' % (datasets, 'degree')
with open(filename, "rb") as f:
        degree = pickle.load(f)
filename = 'centrality/%s_%s.pkl' % (datasets, 'core')
with open(filename, "rb") as f:
        core = pickle.load(f)
filename = 'centrality/%s_%s.pkl' % (datasets, 'pagerank')
with open(filename, "rb") as f:
        pagerank = pickle.load(f)
filename = 'centrality/%s_%s.pkl' % (datasets, 'betweenness')
with open(filename, "rb") as f:
    betweenness  = pickle.load(f)
filename = 'centrality/%s_%s.pkl' % (datasets, 'closeness')
with open(filename, "rb") as f:
    closeness  = pickle.load(f)
#filename = 'centrality/%s_%s.pkl' % (datasets, 'eigenvector')
#with open(filename, "rb") as f:
#    eigenvector = pickle.load(f)
filename = 'centrality/%s_%s.pkl' % (datasets, 'gravitydegree')
with open(filename, "rb") as f:
    gravitydegree = pickle.load(f)
filename = 'centrality/%s_%s.pkl' % (datasets, 'gravitycore')
with open(filename, "rb") as f:
    gravitycore = pickle.load(f)

filename = 'centrality/%s_%s.pkl' % (datasets, 'gravitypagerank')
with open(filename, "rb") as f:
    gravitypagerank = pickle.load(f)
filename = 'centrality/%s_%s.pkl' % (datasets, 'gravitybetweenness')
with open(filename, "rb") as f:
    gravitybetweenness = pickle.load(f)
filename = 'centrality/%s_%s.pkl' % (datasets, 'gravitycloseness')
with open(filename, "rb") as f:
    gravitycloseness = pickle.load(f)
#filename = 'centrality/%s_%s.pkl' % (datasets, 'gravityeigenvector')
#with open(filename, "rb") as f:
#    gravityeigenvector = pickle.load(f)

# %%
fig, axes = plt.subplots(2,5,figsize=(22,9), dpi=200)
# 

sorting_keys = [
    ('nodes/ws3k_gcn_vae_degree_300.npy', 'Degree-300',degree),
    ('nodes/ws3k_gcn_vae_core_300.npy', ' Core-300',core),
    ('nodes/ws3k_gcn_vae_pagerank_300.npy', ' Pagerank-300',pagerank),
    ('nodes/ws3k_gcn_vae_betweenness_300.npy', ' Betweenness-300',betweenness),
    ('nodes/ws3k_gcn_vae_closeness_300.npy', ' Closeness-300',closeness),
    ('nodes/ws3k_gcn_vae_gravitydegree_300.npy', ' GravityDegree-300',gravitydegree),
    ('nodes/ws3k_gcn_vae_gravitycore_300.npy', ' GravityCore-300',gravitycore),
    ('nodes/ws3k_gcn_vae_gravitypagerank_300.npy', ' GravityPagerank-300',gravitypagerank),
    ('nodes/ws3k_gcn_vae_gravitybetweenness_300.npy', ' GravityBetweenness-300',gravitybetweenness),
    ('nodes/ws3k_gcn_vae_gravitycloseness_300.npy', ' GravityCloseness-300',gravitycloseness)

]


# Loop through each subgraph and perform sorting based on the respective key
for i, (data_filename, title, sorting_key) in enumerate(sorting_keys):
    sorted_key= sorted(sorting_key.items(), key = lambda x:x[1],reverse=True)
    top_nodes = [node[0] for node in sorted_key[:300]]
    sampled_nodes = np.load(data_filename)
    nodes = [node for node in G.nodes() if node not in top_nodes and node not in sampled_nodes]
    node_list = [node for node in sampled_nodes if node in top_nodes]

    # 
    nx.draw_networkx_nodes(G, ws3k_pos, nodelist=nodes, node_color='skyblue', node_size=18, alpha=0.3, label='Common nodes', ax=axes[i//5,i%5])
    nx.draw_networkx_nodes(G,  ws3k_pos, nodelist=top_nodes, node_color='steelblue', edgecolors='#3C5488FF', node_size=18, linewidths=1, alpha=0.5, label='Top nodes', ax=axes[i//5,i%5])
    # nx.draw_networkx_nodes(G,  ws3k_pos, nodelist=sampled_nodes, node_color='steelblue', edgecolors='#FD8404', linewidths=1, node_size=18, alpha=0.5, label='Sampled nodes', ax=axes[i//5,i%5])
    # nx.draw_networkx_nodes(G,  ws3k_pos, nodelist=node_list, node_color='darkslategray', edgecolors='orangered', linewidths=1, node_size=25, alpha=0.7, label='Identical nodes',  ax=axes[i//5,i%5])
    nx.draw_networkx_edges(G, ws3k_pos, width=1, edge_color='mistyrose', alpha=0.5, arrows=False, ax=axes[i//5,i%5])

    # 
    ax=axes[i//5,i%5].set_title(title, fontsize=20)
    ax=axes[i//5,i%5].axis('off')

lines1, labels1 = axes[0,0].get_legend_handles_labels()
# lines2, labels2 = axes[1].get_legend_handles_labels()
# lines3, labels3 = axes[2].get_legend_handles_labels()
# lines = lines1 + lines2 + lines3
# labels = labels1 + labels2 +labels3


fig.subplots_adjust(wspace=0,hspace=0.1)

fig.legend(lines1, labels1, fontsize=20, loc='lower center', bbox_to_anchor=(0.5, 0.05),ncol=4)
# 
plt.savefig('C:/Users/WENJIA/Downloads/papers/node/ws3k_300_tn.pdf', dpi=150)
plt.savefig('C:/Users/WENJIA/Downloads/papers/node/ws3k_300_tn.png', dpi=150)
plt.tight_layout()

# 
plt.show()

# %%
fig, axes = plt.subplots(2,5,figsize=(22,9), dpi=200)
# 

sorting_keys = [
    ('nodes/ws3k_gcn_vae_degree_300.npy', 'Degree-300',degree),
    ('nodes/ws3k_gcn_vae_core_300.npy', ' Core-300',core),
    ('nodes/ws3k_gcn_vae_pagerank_300.npy', ' Pagerank-300',pagerank),
    ('nodes/ws3k_gcn_vae_betweenness_300.npy', ' Betweenness-300',betweenness),
    ('nodes/ws3k_gcn_vae_closeness_300.npy', ' Closeness-300',closeness),
    ('nodes/ws3k_gcn_vae_gravitydegree_300.npy', ' GravityDegree-300',gravitydegree),
    ('nodes/ws3k_gcn_vae_gravitycore_300.npy', ' GravityCore-300',gravitycore),
    ('nodes/ws3k_gcn_vae_gravitypagerank_300.npy', ' GravityPagerank-300',gravitypagerank),
    ('nodes/ws3k_gcn_vae_gravitybetweenness_300.npy', ' GravityBetweenness-300',gravitybetweenness),
    ('nodes/ws3k_gcn_vae_gravitycloseness_300.npy', ' GravityCloseness-300',gravitycloseness)

]


# Loop through each subgraph and perform sorting based on the respective key
for i, (data_filename, title, sorting_key) in enumerate(sorting_keys):
    sorted_key= sorted(sorting_key.items(), key = lambda x:x[1],reverse=True)
    top_nodes = [node[0] for node in sorted_key[:300]]
    sampled_nodes = np.load(data_filename)
    nodes = [node for node in G.nodes() if node not in top_nodes and node not in sampled_nodes]
    node_list = [node for node in sampled_nodes if node in top_nodes]

    # 
    nx.draw_networkx_nodes(G, ws3k_pos, nodelist=nodes, node_color='skyblue', node_size=18, alpha=0.3, label='Common nodes', ax=axes[i//5,i%5])
    # nx.draw_networkx_nodes(G,  ws3k_pos, nodelist=top_nodes, node_color='steelblue', edgecolors='#3C5488FF', node_size=18, linewidths=1, alpha=0.5, label='Top nodes', ax=axes[i//5,i%5])
    nx.draw_networkx_nodes(G,  ws3k_pos, nodelist=sampled_nodes, node_color='steelblue', edgecolors='#FD8404', linewidths=1, node_size=18, alpha=0.5, label='Sampled nodes', ax=axes[i//5,i%5])
    # nx.draw_networkx_nodes(G,  ws3k_pos, nodelist=node_list, node_color='darkslategray', edgecolors='orangered', linewidths=1, node_size=25, alpha=0.7, label='Identical nodes',  ax=axes[i//5,i%5])
    nx.draw_networkx_edges(G, ws3k_pos, width=1, edge_color='mistyrose', alpha=0.5, arrows=False, ax=axes[i//5,i%5])

    # 
    ax=axes[i//5,i%5].set_title(title, fontsize=20)
    ax=axes[i//5,i%5].axis('off')

lines1, labels1 = axes[0,0].get_legend_handles_labels()
# lines2, labels2 = axes[1].get_legend_handles_labels()
# lines3, labels3 = axes[2].get_legend_handles_labels()
# lines = lines1 + lines2 + lines3
# labels = labels1 + labels2 +labels3


fig.subplots_adjust(wspace=0,hspace=0.1)

fig.legend(lines1, labels1, fontsize=20, loc='lower center', bbox_to_anchor=(0.5, 0.05),ncol=4)
# 
plt.savefig('C:/Users/WENJIA/Downloads/papers/node/ws3k_300_sn.pdf', dpi=150)
plt.savefig('C:/Users/WENJIA/Downloads/papers/node/ws3k_300_sn.png', dpi=150)
plt.tight_layout()

# 
plt.show()

# %% [markdown]
# ### Cora

# %%
datasets = 'cora'
adj_matrix,_ = load_data(datasets)
G = nx.from_numpy_array(adj_matrix,create_using=nx.DiGraph)

# %%
filename = 'centrality/%s_pos.pkl' % (datasets)
with open(filename, "rb") as f:
        cora_pos = pickle.load(f)
filename = 'centrality/%s_%s.pkl' % (datasets, 'degree')
with open(filename, "rb") as f:
        degree = pickle.load(f)
filename = 'centrality/%s_%s.pkl' % (datasets, 'core')
with open(filename, "rb") as f:
        core = pickle.load(f)
filename = 'centrality/%s_%s.pkl' % (datasets, 'pagerank')
with open(filename, "rb") as f:
        pagerank = pickle.load(f)
filename = 'centrality/%s_%s.pkl' % (datasets, 'betweenness')
with open(filename, "rb") as f:
    betweenness  = pickle.load(f)
filename = 'centrality/%s_%s.pkl' % (datasets, 'closeness')
with open(filename, "rb") as f:
    closeness  = pickle.load(f)
filename = 'centrality/%s_%s.pkl' % (datasets, 'eigenvector')
with open(filename, "rb") as f:
    eigenvector = pickle.load(f)
filename = 'centrality/%s_%s.pkl' % (datasets, 'gravitydegree')
with open(filename, "rb") as f:
    gravitydegree = pickle.load(f)
filename = 'centrality/%s_%s.pkl' % (datasets, 'gravitycore')
with open(filename, "rb") as f:
    gravitycore = pickle.load(f)

filename = 'centrality/%s_%s.pkl' % (datasets, 'gravitypagerank')
with open(filename, "rb") as f:
    gravitypagerank = pickle.load(f)
filename = 'centrality/%s_%s.pkl' % (datasets, 'gravitybetweenness')
with open(filename, "rb") as f:
    gravitybetweenness = pickle.load(f)
filename = 'centrality/%s_%s.pkl' % (datasets, 'gravitycloseness')
with open(filename, "rb") as f:

    gravitycloseness = pickle.load(f)
filename = 'centrality/%s_%s.pkl' % (datasets, 'gravityeigenvector')
with open(filename, "rb") as f:
    gravityeigenvector = pickle.load(f)

# %%
import matplotlib.pyplot as plt
import networkx as nx
import numpy as np
from matplotlib.patches import FancyBboxPatch

plt.style.use('nature')
# 
fig, axes = plt.subplots(2,6, figsize=(24,8 ), dpi=200)

# 

sorting_keys = [
    ('nodes/cora_gcn_vae_degree_300.npy', 'Degree-300',degree),
    ('nodes/cora_gcn_vae_core_300.npy', 'Core-300',core),
    ('nodes/cora_gcn_vae_pagerank_300.npy', 'Pagerank-300',pagerank),
    ('nodes/cora_gcn_vae_betweenness_300.npy', 'Betweenness-300',betweenness),
    ('nodes/cora_gcn_vae_closeness_300.npy', 'Closeness-300',closeness),
    ('nodes/cora_gcn_vae_eigenvector_300.npy', 'Eigenvector-300',eigenvector),
    ('nodes/cora_gcn_vae_gravitydegree_300.npy', 'GMDegree-300',gravitydegree),
    ('nodes/cora_gcn_vae_gravitycore_300.npy', 'GMCore-300',gravitycore),
    ('nodes/cora_gcn_vae_gravitypagerank_300.npy', 'GMPagerank-300',gravitypagerank),
    ('nodes/cora_gcn_vae_gravitybetweenness_300.npy', 'GMBetweenness-300',gravitybetweenness),
    ('nodes/cora_gcn_vae_gravitycloseness_300.npy', 'GMCloseness-300',gravitycloseness),
    ('nodes/cora_gcn_vae_gravityeigenvector_300.npy', 'GMEigenvector-300',gravityeigenvector)
]


# Loop through each subgraph and perform sorting based on the respective key
for i, (data_filename, title, sorting_key) in enumerate(sorting_keys):
    sorted_key= sorted(sorting_key.items(), key = lambda x:x[1],reverse=True)
    top_nodes = [node[0] for node in sorted_key[:300]]
    sampled_nodes = np.load(data_filename)
    nodes = [node for node in G.nodes() if node not in top_nodes and node not in sampled_nodes]
    node_list = [node for node in sampled_nodes if node in top_nodes]

    # 
    nx.draw_networkx_nodes(G, cora_pos, nodelist=nodes, node_color='skyblue', node_size=25, alpha=0.3, label='Common nodes', ax=axes[i//6,i%6])
    nx.draw_networkx_nodes(G,  cora_pos, nodelist=top_nodes, node_color='steelblue', edgecolors='#3C5488FF', node_size=25, linewidths=1, alpha=0.4, label='Top nodes', ax=axes[i//6,i%6])
    # nx.draw_networkx_nodes(G,  cora_pos, nodelist=sampled_nodes, node_color='steelblue', edgecolors='#FD8404', linewidths=1, node_size=25, alpha=0.5, label='Sampled nodes', ax=axes[i//6,i%6])
    # nx.draw_networkx_nodes(G,  cora_pos, nodelist=node_list, node_color='darkslategray', edgecolors='orangered', linewidths=1, node_size=30, alpha=0.7, label='Identical nodes',  ax=axes[i//6,i%6])
    nx.draw_networkx_edges(G, cora_pos, width=1, edge_color='mistyrose', alpha=0.5, arrows=False, ax=axes[i//6,i%6])

    # 
    ax=axes[i//6,i%6].set_title(title, fontsize=20)
    ax=axes[i//6,i%6].axis('off')

lines1, labels1 = axes[0,0].get_legend_handles_labels()
# lines2, labels2 = axes[1].get_legend_handles_labels()
# lines3, labels3 = axes[2].get_legend_handles_labels()
# lines = lines1 + lines2 + lines3
# labels = labels1 + labels2 +labels3


fig.subplots_adjust(wspace=0)

fig.legend(lines1, labels1, fontsize=20, loc='lower center', bbox_to_anchor=(0.5, 0.05),ncol=4)
# 
plt.savefig('C:/Users/WENJIA/Downloads/papers/node/cora_300_tn.pdf', dpi=400)
plt.savefig('C:/Users/WENJIA/Downloads/papers/node/cora_300_tn.png', dpi=600)
plt.tight_layout()

# 
plt.show()

# %%
import matplotlib.pyplot as plt
import networkx as nx
import numpy as np
from matplotlib.patches import FancyBboxPatch

plt.style.use('nature')
# 
fig, axes = plt.subplots(2,6, figsize=(24,8 ), dpi=200)

# 

sorting_keys = [
    ('nodes/cora_gcn_vae_degree_300.npy', 'Degree-300',degree),
    ('nodes/cora_gcn_vae_core_300.npy', 'Core-300',core),
    ('nodes/cora_gcn_vae_pagerank_300.npy', 'Pagerank-300',pagerank),
    ('nodes/cora_gcn_vae_betweenness_300.npy', 'Betweenness-300',betweenness),
    ('nodes/cora_gcn_vae_closeness_300.npy', 'Closeness-300',closeness),
    ('nodes/cora_gcn_vae_eigenvector_300.npy', 'Eigenvector-300',eigenvector),
    ('nodes/cora_gcn_vae_gravitydegree_300.npy', 'GMDegree-300',gravitydegree),
    ('nodes/cora_gcn_vae_gravitycore_300.npy', 'GMCore-300',gravitycore),
    ('nodes/cora_gcn_vae_gravitypagerank_300.npy', 'GMPagerank-300',gravitypagerank),
    ('nodes/cora_gcn_vae_gravitybetweenness_300.npy', 'GMBetweenness-300',gravitybetweenness),
    ('nodes/cora_gcn_vae_gravitycloseness_300.npy', 'GMCloseness-300',gravitycloseness),
    ('nodes/cora_gcn_vae_gravityeigenvector_300.npy', 'GMEigenvector-300',gravityeigenvector)
]

# Loop through each subgraph and perform sorting based on the respective key
for i, (data_filename, title, sorting_key) in enumerate(sorting_keys):
    sorted_key= sorted(sorting_key.items(), key = lambda x:x[1],reverse=True)
    top_nodes = [node[0] for node in sorted_key[:300]]
    sampled_nodes = np.load(data_filename)
    nodes = [node for node in G.nodes() if node not in top_nodes and node not in sampled_nodes]
    node_list = [node for node in sampled_nodes if node in top_nodes]

    # 
    nx.draw_networkx_nodes(G, cora_pos, nodelist=nodes, node_color='skyblue', node_size=25, alpha=0.3, label='Common nodes', ax=axes[i//6,i%6])
    # nx.draw_networkx_nodes(G,  cora_pos, nodelist=top_nodes, node_color='steelblue', edgecolors='#3C5488FF', node_size=25, linewidths=1, alpha=0.4, label='Top nodes', ax=axes[i//6,i%6])
    nx.draw_networkx_nodes(G,  cora_pos, nodelist=sampled_nodes, node_color='steelblue', edgecolors='#FD8404', linewidths=1, node_size=25, alpha=0.5, label='Sampled nodes', ax=axes[i//6,i%6])
    # nx.draw_networkx_nodes(G,  cora_pos, nodelist=node_list, node_color='darkslategray', edgecolors='orangered', linewidths=1, node_size=30, alpha=0.7, label='Identical nodes',  ax=axes[i//6,i%6])
    nx.draw_networkx_edges(G, cora_pos, width=1, edge_color='mistyrose', alpha=0.5, arrows=False, ax=axes[i//6,i%6])

    # 
    ax=axes[i//6,i%6].set_title(title, fontsize=20)
    ax=axes[i//6,i%6].axis('off')

lines1, labels1 = axes[0,0].get_legend_handles_labels()
# lines2, labels2 = axes[1].get_legend_handles_labels()
# lines3, labels3 = axes[2].get_legend_handles_labels()
# lines = lines1 + lines2 + lines3
# labels = labels1 + labels2 +labels3


fig.subplots_adjust(wspace=0)

fig.legend(lines1, labels1, fontsize=20, loc='lower center', bbox_to_anchor=(0.5, 0.05),ncol=4)
# 
plt.savefig('C:/Users/WENJIA/Downloads/papers/node/cora_300_sn.pdf', dpi=400)
plt.savefig('C:/Users/WENJIA/Downloads/papers/node/cora_300_sn.png', dpi=600)
plt.tight_layout()

# 
plt.show()

# %% [markdown]
# ### Citeseer

# %%
datasets = 'citeseer'
adj_matrix,_ = load_data(datasets)
G = nx.from_numpy_array(adj_matrix,create_using=nx.DiGraph)
G.remove_edges_from(nx.selfloop_edges(G))
citeseer_pos = nx.spring_layout(G)

with open("centrality/citeseer_po,s.pkl", "wb") as f:
    pickle.dump(citeseer_pos, f)

# %%
filename = 'centrality/%s_pos.pkl' % (datasets)
with open(filename, "rb") as f:
        Citeseer_pos = pickle.load(f)
filename = 'centrality/%s_%s.pkl' % (datasets, 'degree')
with open(filename, "rb") as f:
        degree = pickle.load(f)
filename = 'centrality/%s_%s.pkl' % (datasets, 'core')
with open(filename, "rb") as f:
        core = pickle.load(f)
filename = 'centrality/%s_%s.pkl' % (datasets, 'pagerank')
with open(filename, "rb") as f:
        pagerank = pickle.load(f)
filename = 'centrality/%s_%s.pkl' % (datasets, 'betweenness')
with open(filename, "rb") as f:
    betweenness  = pickle.load(f)
filename = 'centrality/%s_%s.pkl' % (datasets, 'closeness')
with open(filename, "rb") as f:
    closeness  = pickle.load(f)
filename = 'centrality/%s_%s.pkl' % (datasets, 'eigenvector')
with open(filename, "rb") as f:
    eigenvector = pickle.load(f)
filename = 'centrality/%s_%s.pkl' % (datasets, 'gravitydegree')
with open(filename, "rb") as f:
    gravitydegree = pickle.load(f)
filename = 'centrality/%s_%s.pkl' % (datasets, 'gravitycore')
with open(filename, "rb") as f:
    gravitycore = pickle.load(f)

filename = 'centrality/%s_%s.pkl' % (datasets, 'gravitypagerank')
with open(filename, "rb") as f:
    gravitypagerank = pickle.load(f)
filename = 'centrality/%s_%s.pkl' % (datasets, 'gravitybetweenness')
with open(filename, "rb") as f:
    gravitybetweenness = pickle.load(f)
filename = 'centrality/%s_%s.pkl' % (datasets, 'gravitycloseness')
with open(filename, "rb") as f:
    gravitycloseness = pickle.load(f)
filename = 'centrality/%s_%s.pkl' % (datasets, 'gravityeigenvector')
with open(filename, "rb") as f:
    gravityeigenvector = pickle.load(f)

# %%
import matplotlib.pyplot as plt
import networkx as nx
import numpy as np
from matplotlib.patches import FancyBboxPatch
plt.style.use('nature')
# 
fig, axes = plt.subplots(2,6, figsize=(24,8), dpi=200)

# 

sorting_keys = [
    ('nodes/citeseer_gcn_vae_degree_400.npy', 'Degree-400',degree),
    ('nodes/citeseer_gcn_vae_core_400.npy', 'Core-400',core),
    ('nodes/citeseer_gcn_vae_pagerank_400.npy', 'Pagerank-400',pagerank),
    ('nodes/citeseer_gcn_vae_betweenness_400.npy', 'Betweenness-400',betweenness),
    ('nodes/citeseer_gcn_vae_closeness_400.npy', 'Closeness-400',closeness),
    ('nodes/citeseer_gcn_vae_eigenvector_400.npy', 'Eigenvector-400',eigenvector),
    ('nodes/citeseer_gcn_vae_gravitydegree_400.npy', 'GMDegree-400',gravitydegree),
    ('nodes/citeseer_gcn_vae_gravitycore_400.npy', 'GMCore-400',gravitycore),
    ('nodes/citeseer_gcn_vae_gravitypagerank_400.npy', 'GMPagerank-400',gravitypagerank),
    ('nodes/citeseer_gcn_vae_gravitybetweenness_400.npy', 'GMBetweenness-400',gravitybetweenness),
    ('nodes/citeseer_gcn_vae_gravitycloseness_400.npy', 'GMCloseness-400',gravitycloseness),
    ('nodes/citeseer_gcn_vae_gravityeigenvector_400.npy', 'GMEigenvector-400',gravityeigenvector)
]


# Loop through each subgraph and perform sorting based on the respective key
for i, (data_filename, title, sorting_key) in enumerate(sorting_keys):
    sorted_key= sorted(sorting_key.items(), key = lambda x:x[1],reverse=True)
    top_nodes = [node[0] for node in sorted_key[:400]]
    sampled_nodes = np.load(data_filename)
    nodes = [node for node in G.nodes() if node not in top_nodes and node not in sampled_nodes]
    node_list = [node for node in sampled_nodes if node in top_nodes]

    # 
    nx.draw_networkx_nodes(G, citeseer_pos, nodelist=nodes, node_color='skyblue', node_size=18, alpha=0.3, label='Common nodes', ax=axes[i//6,i%6])
    nx.draw_networkx_nodes(G,  citeseer_pos, nodelist=top_nodes, node_color='steelblue', edgecolors='#3C5488FF', node_size=18, linewidths=1, alpha=0.5, label='Top nodes', ax=axes[i//6,i%6])
    # nx.draw_networkx_nodes(G,  citeseer_pos, nodelist=sampled_nodes, node_color='steelblue', edgecolors='#FD8404', linewidths=1, node_size=18, alpha=0.5, label='Sampled nodes', ax=axes[i//6,i%6])
    # nx.draw_networkx_nodes(G,  citeseer_pos, nodelist=node_list, node_color='darkslategray', edgecolors='orangered', linewidths=1, node_size=25, alpha=0.7, label='Identical nodes',  ax=axes[i//6,i%6])
    nx.draw_networkx_edges(G, citeseer_pos, width=1, edge_color='mistyrose', alpha=0.5, arrows=False, ax=axes[i//6,i%6])

    # 
    ax=axes[i//6,i%6].set_title(title, fontsize=20)
    ax=axes[i//6,i%6].axis('off')

lines1, labels1 = axes[0,0].get_legend_handles_labels()
# lines2, labels2 = axes[1].get_legend_handles_labels()
# lines3, labels3 = axes[2].get_legend_handles_labels()
# lines = lines1 + lines2 + lines3
# labels = labels1 + labels2 +labels3


fig.subplots_adjust(wspace=0,hspace=0.1)

fig.legend(lines1, labels1, fontsize=20, loc='lower center', bbox_to_anchor=(0.5, 0.05),ncol=4)
# 
plt.savefig('C:/Users/WENJIA/Downloads/papers/node/citeseer_400_tn.pdf', dpi=200)
plt.savefig('C:/Users/WENJIA/Downloads/papers/node/citeseer_400_tn.png', dpi=150)
plt.tight_layout()

# 
plt.show()

# %%
import matplotlib.pyplot as plt
import networkx as nx
import numpy as np
from matplotlib.patches import FancyBboxPatch
plt.style.use('nature')
# 
fig, axes = plt.subplots(2,6, figsize=(24,8), dpi=200)

# 

sorting_keys = [
    ('nodes/citeseer_gcn_vae_degree_400.npy', 'Degree-400',degree),
    ('nodes/citeseer_gcn_vae_core_400.npy', 'Core-400',core),
    ('nodes/citeseer_gcn_vae_pagerank_400.npy', 'Pagerank-400',pagerank),
    ('nodes/citeseer_gcn_vae_betweenness_400.npy', 'Betweenness-400',betweenness),
    ('nodes/citeseer_gcn_vae_closeness_400.npy', 'Closeness-400',closeness),
    ('nodes/citeseer_gcn_vae_eigenvector_400.npy', 'Eigenvector-400',eigenvector),
    ('nodes/citeseer_gcn_vae_gravitydegree_400.npy', 'GMDegree-400',gravitydegree),
    ('nodes/citeseer_gcn_vae_gravitycore_400.npy', 'GMCore-400',gravitycore),
    ('nodes/citeseer_gcn_vae_gravitypagerank_400.npy', 'GMPagerank-400',gravitypagerank),
    ('nodes/citeseer_gcn_vae_gravitybetweenness_400.npy', 'GMBetweenness-400',gravitybetweenness),
    ('nodes/citeseer_gcn_vae_gravitycloseness_400.npy', 'GMCloseness-400',gravitycloseness),
    ('nodes/citeseer_gcn_vae_gravityeigenvector_400.npy', 'GMEigenvector-400',gravityeigenvector)
]

# Loop through each subgraph and perform sorting based on the respective key
for i, (data_filename, title, sorting_key) in enumerate(sorting_keys):
    sorted_key= sorted(sorting_key.items(), key = lambda x:x[1],reverse=True)
    top_nodes = [node[0] for node in sorted_key[:400]]
    sampled_nodes = np.load(data_filename)
    nodes = [node for node in G.nodes() if node not in top_nodes and node not in sampled_nodes]
    node_list = [node for node in sampled_nodes if node in top_nodes]

    # 
    nx.draw_networkx_nodes(G, citeseer_pos, nodelist=nodes, node_color='skyblue', node_size=18, alpha=0.3, label='Common nodes', ax=axes[i//6,i%6])
    # nx.draw_networkx_nodes(G,  citeseer_pos, nodelist=top_nodes, node_color='steelblue', edgecolors='#3C5488FF', node_size=18, linewidths=1, alpha=0.5, label='Top nodes', ax=axes[i//6,i%6])
    nx.draw_networkx_nodes(G,  citeseer_pos, nodelist=sampled_nodes, node_color='steelblue', edgecolors='#FD8404', linewidths=1, node_size=18, alpha=0.5, label='Sampled nodes', ax=axes[i//6,i%6])
    # nx.draw_networkx_nodes(G,  citeseer_pos, nodelist=node_list, node_color='darkslategray', edgecolors='orangered', linewidths=1, node_size=25, alpha=0.7, label='Identical nodes',  ax=axes[i//6,i%6])
    nx.draw_networkx_edges(G, citeseer_pos, width=1, edge_color='mistyrose', alpha=0.5, arrows=False, ax=axes[i//6,i%6])

    # 
    ax=axes[i//6,i%6].set_title(title, fontsize=20)
    ax=axes[i//6,i%6].axis('off')

lines1, labels1 = axes[0,0].get_legend_handles_labels()
# lines2, labels2 = axes[1].get_legend_handles_labels()
# lines3, labels3 = axes[2].get_legend_handles_labels()
# lines = lines1 + lines2 + lines3
# labels = labels1 + labels2 +labels3


fig.subplots_adjust(wspace=0,hspace=0.1)

fig.legend(lines1, labels1, fontsize=20, loc='lower center', bbox_to_anchor=(0.5, 0.05),ncol=4)
# 
plt.savefig('C:/Users/WENJIA/Downloads/papers/node/citeseer_400_sn.pdf', dpi=200)
plt.savefig('C:/Users/WENJIA/Downloads/papers/node/citeseer_400_sn.png', dpi=150)
plt.tight_layout()

# 
plt.show()

# %% [markdown]
# ### Pubmed

# %%
datasets = 'pubmed'
adj_matrix,_ = load_data(datasets)
G = nx.from_numpy_array(adj_matrix,create_using=nx.DiGraph)

# %%
filename = 'centrality/%s_pos.pkl' % (datasets)
with open(filename, "rb") as f:
        pubmed_pos = pickle.load(f)
filename = 'centrality/%s_%s.pkl' % (datasets, 'degree')
with open(filename, "rb") as f:
        degree = pickle.load(f)
filename = 'centrality/%s_%s.pkl' % (datasets, 'core')
with open(filename, "rb") as f:
        core = pickle.load(f)
filename = 'centrality/%s_%s.pkl' % (datasets, 'pagerank')
with open(filename, "rb") as f:
        pagerank = pickle.load(f)
filename = 'centrality/%s_%s.pkl' % (datasets, 'betweenness')
with open(filename, "rb") as f:
    betweenness  = pickle.load(f)
filename = 'centrality/%s_%s.pkl' % (datasets, 'closeness')
with open(filename, "rb") as f:
    closeness  = pickle.load(f)
filename = 'centrality/%s_%s.pkl' % (datasets, 'eigenvector')
with open(filename, "rb") as f:
    eigenvector = pickle.load(f)
filename = 'centrality/%s_%s.pkl' % (datasets, 'gravitydegree')
with open(filename, "rb") as f:
    gravitydegree = pickle.load(f)
filename = 'centrality/%s_%s.pkl' % (datasets, 'gravitycore')
with open(filename, "rb") as f:
    gravitycore = pickle.load(f)

filename = 'centrality/%s_%s.pkl' % (datasets, 'gravitypagerank')
with open(filename, "rb") as f:
    gravitypagerank = pickle.load(f)
filename = 'centrality/%s_%s.pkl' % (datasets, 'gravitybetweenness')
with open(filename, "rb") as f:
    gravitybetweenness = pickle.load(f)
filename = 'centrality/%s_%s.pkl' % (datasets, 'gravitycloseness')
with open(filename, "rb") as f:
    gravitycloseness = pickle.load(f)
filename = 'centrality/%s_%s.pkl' % (datasets, 'gravityeigenvector')
with open(filename, "rb") as f:
    gravityeigenvector = pickle.load(f)

# %%
import matplotlib.pyplot as plt
import networkx as nx
import numpy as np
from matplotlib.patches import FancyBboxPatch
plt.style.use('nature')
# 
fig, axes = plt.subplots(2,6, figsize=(24,8), dpi=200)

# 

sorting_keys = [
    ('nodes/pubmed_gcn_vae_degree_1000.npy', 'Degree-1000',degree),
    ('nodes/pubmed_gcn_vae_core_1000.npy', 'Core-1000',core),
    ('nodes/pubmed_gcn_vae_pagerank_1000.npy', 'Pagerank-1000',pagerank),
    ('nodes/pubmed_gcn_vae_betweenness_1000.npy', 'Betweenness-1000',betweenness),
    ('nodes/pubmed_gcn_vae_closeness_1000.npy', 'Closeness-1000',closeness),
    ('nodes/pubmed_gcn_vae_eigenvector_1000.npy', 'Eigenvector-1000',eigenvector),
    ('nodes/pubmed_gcn_vae_gravitydegree_1000.npy', 'GMDegree-1000',gravitydegree),
    ('nodes/pubmed_gcn_vae_gravitycore_1000.npy', 'GMCore-1000',gravitycore),
    ('nodes/pubmed_gcn_vae_gravitypagerank_1000.npy', 'GMPagerank-1000',gravitypagerank),
    ('nodes/pubmed_gcn_vae_gravitybetweenness_1000.npy', 'GMBetweenness-1000',gravitybetweenness),
    ('nodes/pubmed_gcn_vae_gravitycloseness_1000.npy', 'GMCloseness-1000',gravitycloseness),
    ('nodes/pubmed_gcn_vae_gravityeigenvector_1000.npy', 'GMEigenvector-1000',gravityeigenvector)
]


# Loop through each subgraph and perform sorting based on the respective key
for i, (data_filename, title, sorting_key) in enumerate(sorting_keys):
    sorted_key= sorted(sorting_key.items(), key = lambda x:x[1],reverse=True)
    top_nodes = [node[0] for node in sorted_key[:1000]]
    sampled_nodes = np.load(data_filename)
    nodes = [node for node in G.nodes() if node not in top_nodes and node not in sampled_nodes]
    node_list = [node for node in sampled_nodes if node in top_nodes]

    # 
    nx.draw_networkx_nodes(G, pubmed_pos, nodelist=nodes, node_color='skyblue', node_size=18, alpha=0.3, label='Common nodes', ax=axes[i//6,i%6])
    nx.draw_networkx_nodes(G,  pubmed_pos, nodelist=top_nodes, node_color='steelblue', edgecolors='#3C5488FF', node_size=18, linewidths=1, alpha=0.5, label='Top nodes', ax=axes[i//6,i%6])
    # nx.draw_networkx_nodes(G,  pubmed_pos, nodelist=sampled_nodes, node_color='steelblue', edgecolors='#FD8404', linewidths=1, node_size=18, alpha=0.5, label='Sampled nodes', ax=axes[i//6,i%6])
    # nx.draw_networkx_nodes(G,  pubmed_pos, nodelist=node_list, node_color='darkslategray', edgecolors='orangered', linewidths=1, node_size=25, alpha=0.7, label='Identical nodes',  ax=axes[i//6,i%6])
    nx.draw_networkx_edges(G, pubmed_pos, width=1, edge_color='mistyrose', alpha=0.5, arrows=False, ax=axes[i//6,i%6])

    # 
    ax=axes[i//6,i%6].set_title(title, fontsize=20)
    ax=axes[i//6,i%6].axis('off')

lines1, labels1 = axes[0,0].get_legend_handles_labels()
# lines2, labels2 = axes[1].get_legend_handles_labels()
# lines3, labels3 = axes[2].get_legend_handles_labels()
# lines = lines1 + lines2 + lines3
# labels = labels1 + labels2 +labels3


fig.subplots_adjust(wspace=0)

fig.legend(lines1, labels1, fontsize=20, loc='lower center', bbox_to_anchor=(0.5, 0.05),ncol=4)
# 
plt.savefig('C:/Users/WENJIA/Downloads/papers/node/pubmed_1000_tn.pdf', dpi=150)
plt.savefig('C:/Users/WENJIA/Downloads/papers/node/pubmed_1000_tn.png', dpi=150)
plt.tight_layout()

# 
plt.show()

# %%
import matplotlib.pyplot as plt
import networkx as nx
import numpy as np
from matplotlib.patches import FancyBboxPatch
plt.style.use('nature')
# 
fig, axes = plt.subplots(2,6, figsize=(24,8), dpi=200)

# 

sorting_keys = [
    ('nodes/pubmed_gcn_vae_degree_1000.npy', 'Degree-1000',degree),
    ('nodes/pubmed_gcn_vae_core_1000.npy', 'Core-1000',core),
    ('nodes/pubmed_gcn_vae_pagerank_1000.npy', 'Pagerank-1000',pagerank),
    ('nodes/pubmed_gcn_vae_betweenness_1000.npy', 'Betweenness-1000',betweenness),
    ('nodes/pubmed_gcn_vae_closeness_1000.npy', 'Closeness-1000',closeness),
    ('nodes/pubmed_gcn_vae_eigenvector_1000.npy', 'Eigenvector-1000',eigenvector),
    ('nodes/pubmed_gcn_vae_gravitydegree_1000.npy', 'GMDegree-1000',gravitydegree),
    ('nodes/pubmed_gcn_vae_gravitycore_1000.npy', 'GMCore-1000',gravitycore),
    ('nodes/pubmed_gcn_vae_gravitypagerank_1000.npy', 'GMPagerank-1000',gravitypagerank),
    ('nodes/pubmed_gcn_vae_gravitybetweenness_1000.npy', 'GMBetweenness-1000',gravitybetweenness),
    ('nodes/pubmed_gcn_vae_gravitycloseness_1000.npy', 'GMCloseness-1000',gravitycloseness),
    ('nodes/pubmed_gcn_vae_gravityeigenvector_1000.npy', 'GMEigenvector-1000',gravityeigenvector)
]


# Loop through each subgraph and perform sorting based on the respective key
for i, (data_filename, title, sorting_key) in enumerate(sorting_keys):
    sorted_key= sorted(sorting_key.items(), key = lambda x:x[1],reverse=True)
    top_nodes = [node[0] for node in sorted_key[:1000]]
    sampled_nodes = np.load(data_filename)
    nodes = [node for node in G.nodes() if node not in top_nodes and node not in sampled_nodes]
    node_list = [node for node in sampled_nodes if node in top_nodes]

    # 
    nx.draw_networkx_nodes(G, pubmed_pos, nodelist=nodes, node_color='skyblue', node_size=18, alpha=0.3, label='Common nodes', ax=axes[i//6,i%6])
    # nx.draw_networkx_nodes(G,  pubmed_pos, nodelist=top_nodes, node_color='steelblue', edgecolors='#3C5488FF', node_size=18, linewidths=1, alpha=0.5, label='Top nodes', ax=axes[i//6,i%6])
    nx.draw_networkx_nodes(G,  pubmed_pos, nodelist=sampled_nodes, node_color='steelblue', edgecolors='#FD8404', linewidths=1, node_size=18, alpha=0.5, label='Sampled nodes', ax=axes[i//6,i%6])
    # nx.draw_networkx_nodes(G,  pubmed_pos, nodelist=node_list, node_color='darkslategray', edgecolors='orangered', linewidths=1, node_size=25, alpha=0.7, label='Identical nodes',  ax=axes[i//6,i%6])
    nx.draw_networkx_edges(G, pubmed_pos, width=1, edge_color='mistyrose', alpha=0.5, arrows=False, ax=axes[i//6,i%6])

    # 
    ax=axes[i//6,i%6].set_title(title, fontsize=20)
    ax=axes[i//6,i%6].axis('off')

lines1, labels1 = axes[0,0].get_legend_handles_labels()
# lines2, labels2 = axes[1].get_legend_handles_labels()
# lines3, labels3 = axes[2].get_legend_handles_labels()
# lines = lines1 + lines2 + lines3
# labels = labels1 + labels2 +labels3


fig.subplots_adjust(wspace=0)

fig.legend(lines1, labels1, fontsize=20, loc='lower center', bbox_to_anchor=(0.5, 0.05),ncol=4)
# 
plt.savefig('C:/Users/WENJIA/Downloads/papers/node/pubmed_1000_sn.pdf', dpi=150)
plt.savefig('C:/Users/WENJIA/Downloads/papers/node/pubmed_1000_sn.png', dpi=150)
plt.tight_layout()

# 
plt.show()

# %% [markdown]
# #### Cath

# %%
datasets = 'cath'
adj_matrix,_ = load_data(datasets)
G = nx.from_numpy_array(adj_matrix,create_using=nx.DiGraph)
filename = 'centrality/%s_pos.pkl' % (datasets)
with open(filename, "rb") as f:
        cath_pos = pickle.load(f)

filename = 'centrality/%s_%s.pkl' % (datasets, 'degree')
with open(filename, "rb") as f:
        degree = pickle.load(f)
filename = 'centrality/%s_%s.pkl' % (datasets, 'core')
with open(filename, "rb") as f:
        core = pickle.load(f)
filename = 'centrality/%s_%s.pkl' % (datasets, 'pagerank')
with open(filename, "rb") as f:
        pagerank = pickle.load(f)
filename = 'centrality/%s_%s.pkl' % (datasets, 'betweenness')
with open(filename, "rb") as f:
    betweenness  = pickle.load(f)
filename = 'centrality/%s_%s.pkl' % (datasets, 'closeness')
with open(filename, "rb") as f:
    closeness  = pickle.load(f)
filename = 'centrality/%s_%s.pkl' % (datasets, 'eigenvector')
with open(filename, "rb") as f:
    eigenvector = pickle.load(f)
filename = 'centrality/%s_%s.pkl' % (datasets, 'gravitydegree')
with open(filename, "rb") as f:
    gravitydegree = pickle.load(f)
filename = 'centrality/%s_%s.pkl' % (datasets, 'gravitycore')
with open(filename, "rb") as f:
    gravitycore = pickle.load(f)

filename = 'centrality/%s_%s.pkl' % (datasets, 'gravitypagerank')
with open(filename, "rb") as f:
    gravitypagerank = pickle.load(f)
filename = 'centrality/%s_%s.pkl' % (datasets, 'gravitybetweenness')
with open(filename, "rb") as f:
    gravitybetweenness = pickle.load(f)
filename = 'centrality/%s_%s.pkl' % (datasets, 'gravitycloseness')
with open(filename, "rb") as f:
    gravitycloseness = pickle.load(f)
filename = 'centrality/%s_%s.pkl' % (datasets, 'gravityeigenvector')
with open(filename, "rb") as f:
    gravityeigenvector = pickle.load(f)

# %%
import matplotlib.pyplot as plt
import networkx as nx
import numpy as np
from matplotlib.patches import FancyBboxPatch
plt.style.use('nature')
# 
fig, axes = plt.subplots(2,6, figsize=(24,8), dpi=200)

# 

sorting_keys = [
    ('nodes/cath_gcn_vae_degree_600.npy', 'Degree-600',degree),
    ('nodes/cath_gcn_vae_core_600.npy', 'Core-600',core),
    ('nodes/cath_gcn_vae_pagerank_600.npy', 'Pagerank-600',pagerank),
    ('nodes/cath_gcn_vae_betweenness_600.npy', 'Betweenness-600',betweenness),
    ('nodes/cath_gcn_vae_closeness_600.npy', 'Closeness-600',closeness),
    ('nodes/cath_gcn_vae_eigenvector_600.npy', 'Eigenvector-600',eigenvector),
    ('nodes/cath_gcn_vae_gravitydegree_600.npy', 'GMDegree-600',gravitydegree),
    ('nodes/cath_gcn_vae_gravitycore_600.npy', 'GMCore-600',gravitycore),
    ('nodes/cath_gcn_vae_gravitypagerank_600.npy', 'GMPagerank-600',gravitypagerank),
    ('nodes/cath_gcn_vae_gravitybetweenness_600.npy', 'GMBetweenness-600',gravitybetweenness),
    ('nodes/cath_gcn_vae_gravitycloseness_600.npy', 'GMCloseness-600',gravitycloseness),
    ('nodes/cath_gcn_vae_gravityeigenvector_600.npy', 'GMEigenvector-600',gravityeigenvector)
]


# Loop through each subgraph and perform sorting based on the respective key
for i, (data_filename, title, sorting_key) in enumerate(sorting_keys):
    sorted_key= sorted(sorting_key.items(), key = lambda x:x[1],reverse=True)
    top_nodes = [node[0] for node in sorted_key[:600]]
    sampled_nodes = np.load(data_filename)
    nodes = [node for node in G.nodes() if node not in top_nodes and node not in sampled_nodes]
    node_list = [node for node in sampled_nodes if node in top_nodes]

    # 
    nx.draw_networkx_nodes(G, cath_pos, nodelist=nodes, node_color='skyblue', node_size=18, alpha=0.3, label='Common nodes', ax=axes[i//6,i%6])
    nx.draw_networkx_nodes(G,  cath_pos, nodelist=top_nodes, node_color='steelblue', edgecolors='#3C5488FF', node_size=18, linewidths=1, alpha=0.5, label='Top nodes', ax=axes[i//6,i%6])
    # nx.draw_networkx_nodes(G,  cath_pos, nodelist=sampled_nodes, node_color='steelblue', edgecolors='#FD8404', linewidths=1, node_size=18, alpha=0.5, label='Sampled nodes', ax=axes[i//6,i%6])
    # nx.draw_networkx_nodes(G,  cath_pos, nodelist=node_list, node_color='darkslategray', edgecolors='orangered', linewidths=1, node_size=25, alpha=0.7, label='Identical nodes',  ax=axes[i//6,i%6])
    nx.draw_networkx_edges(G, cath_pos, width=1, edge_color='mistyrose', alpha=0.5, arrows=False, ax=axes[i//6,i%6])

    # 
    ax=axes[i//6,i%6].set_title(title, fontsize=20)
    ax=axes[i//6,i%6].axis('off')

lines1, labels1 = axes[0,0].get_legend_handles_labels()
# lines2, labels2 = axes[1].get_legend_handles_labels()
# lines3, labels3 = axes[2].get_legend_handles_labels()
# lines = lines1 + lines2 + lines3
# labels = labels1 + labels2 +labels3


fig.subplots_adjust(wspace=0,hspace=0.1)

fig.legend(lines1, labels1, fontsize=20, loc='lower center', bbox_to_anchor=(0.5, 0.05),ncol=4)
# 
plt.savefig('C:/Users/WENJIA/Downloads/papers/node/cath_600_tn.pdf', dpi=150)
plt.savefig('C:/Users/WENJIA/Downloads/papers/node/cath_600_tn.png', dpi=150)
plt.tight_layout()

# 
plt.show()

# %%
import matplotlib.pyplot as plt
import networkx as nx
import numpy as np
from matplotlib.patches import FancyBboxPatch
plt.style.use('nature')
# 
fig, axes = plt.subplots(2,6, figsize=(24,8), dpi=200)

# 

sorting_keys = [
    ('nodes/cath_gcn_vae_degree_600.npy', 'Degree-600',degree),
    ('nodes/cath_gcn_vae_core_600.npy', 'Core-600',core),
    ('nodes/cath_gcn_vae_pagerank_600.npy', 'Pagerank-600',pagerank),
    ('nodes/cath_gcn_vae_betweenness_600.npy', 'Betweenness-600',betweenness),
    ('nodes/cath_gcn_vae_closeness_600.npy', 'Closeness-600',closeness),
    ('nodes/cath_gcn_vae_eigenvector_600.npy', 'Eigenvector-600',eigenvector),
    ('nodes/cath_gcn_vae_gravitydegree_600.npy', 'GMDegree-600',gravitydegree),
    ('nodes/cath_gcn_vae_gravitycore_600.npy', 'GMCore-600',gravitycore),
    ('nodes/cath_gcn_vae_gravitypagerank_600.npy', 'GMPagerank-600',gravitypagerank),
    ('nodes/cath_gcn_vae_gravitybetweenness_600.npy', 'GMBetweenness-600',gravitybetweenness),
    ('nodes/cath_gcn_vae_gravitycloseness_600.npy', 'GMCloseness-600',gravitycloseness),
    ('nodes/cath_gcn_vae_gravityeigenvector_600.npy', 'GMEigenvector-600',gravityeigenvector)
]


# Loop through each subgraph and perform sorting based on the respective key
for i, (data_filename, title, sorting_key) in enumerate(sorting_keys):
    sorted_key= sorted(sorting_key.items(), key = lambda x:x[1],reverse=True)
    top_nodes = [node[0] for node in sorted_key[:600]]
    sampled_nodes = np.load(data_filename)
    nodes = [node for node in G.nodes() if node not in top_nodes and node not in sampled_nodes]
    node_list = [node for node in sampled_nodes if node in top_nodes]

    # 
    nx.draw_networkx_nodes(G, cath_pos, nodelist=nodes, node_color='skyblue', node_size=18, alpha=0.3, label='Common nodes', ax=axes[i//6,i%6])
    # nx.draw_networkx_nodes(G,  cath_pos, nodelist=top_nodes, node_color='steelblue', edgecolors='#3C5488FF', node_size=18, linewidths=1, alpha=0.5, label='Top nodes', ax=axes[i//6,i%6])
    nx.draw_networkx_nodes(G,  cath_pos, nodelist=sampled_nodes, node_color='steelblue', edgecolors='#FD8404', linewidths=1, node_size=18, alpha=0.5, label='Sampled nodes', ax=axes[i//6,i%6])
    # nx.draw_networkx_nodes(G,  cath_pos, nodelist=node_list, node_color='darkslategray', edgecolors='orangered', linewidths=1, node_size=25, alpha=0.7, label='Identical nodes',  ax=axes[i//6,i%6])
    nx.draw_networkx_edges(G, cath_pos, width=1, edge_color='mistyrose', alpha=0.5, arrows=False, ax=axes[i//6,i%6])

    # 
    ax=axes[i//6,i%6].set_title(title, fontsize=20)
    ax=axes[i//6,i%6].axis('off')

lines1, labels1 = axes[0,0].get_legend_handles_labels()
# lines2, labels2 = axes[1].get_legend_handles_labels()
# lines3, labels3 = axes[2].get_legend_handles_labels()
# lines = lines1 + lines2 + lines3
# labels = labels1 + labels2 +labels3


fig.subplots_adjust(wspace=0,hspace=0.1)

fig.legend(lines1, labels1, fontsize=20, loc='lower center', bbox_to_anchor=(0.5, 0.05),ncol=4)
# 
plt.savefig('C:/Users/WENJIA/Downloads/papers/node/cath_600_sn.pdf', dpi=150)
plt.savefig('C:/Users/WENJIA/Downloads/papers/node/cath_600_sn.png', dpi=150)
plt.tight_layout()

# 
plt.show()

# %% [markdown]
# #### Cmat

# %%
datasets = 'cmat'
adj_matrix,_ = load_data(datasets)
G = nx.from_numpy_array(adj_matrix,create_using=nx.DiGraph)
filename = 'centrality/%s_pos.pkl' % (datasets)
with open(filename, "rb") as f:
        cmat_pos = pickle.load(f)
filename = 'centrality/%s_%s.pkl' % (datasets, 'degree')
with open(filename, "rb") as f:
        degree = pickle.load(f)
filename = 'centrality/%s_%s.pkl' % (datasets, 'core')
with open(filename, "rb") as f:
        core = pickle.load(f)
filename = 'centrality/%s_%s.pkl' % (datasets, 'pagerank')
with open(filename, "rb") as f:
        pagerank = pickle.load(f)
filename = 'centrality/%s_%s.pkl' % (datasets, 'betweenness')
with open(filename, "rb") as f:
    betweenness  = pickle.load(f)
filename = 'centrality/%s_%s.pkl' % (datasets, 'closeness')
with open(filename, "rb") as f:
    closeness  = pickle.load(f)
filename = 'centrality/%s_%s.pkl' % (datasets, 'eigenvector')
with open(filename, "rb") as f:
    eigenvector = pickle.load(f)
filename = 'centrality/%s_%s.pkl' % (datasets, 'gravitydegree')
with open(filename, "rb") as f:
    gravitydegree = pickle.load(f)
filename = 'centrality/%s_%s.pkl' % (datasets, 'gravitycore')
with open(filename, "rb") as f:
    gravitycore = pickle.load(f)

filename = 'centrality/%s_%s.pkl' % (datasets, 'gravitypagerank')
with open(filename, "rb") as f:
    gravitypagerank = pickle.load(f)
filename = 'centrality/%s_%s.pkl' % (datasets, 'gravitybetweenness')
with open(filename, "rb") as f:
    gravitybetweenness = pickle.load(f)
filename = 'centrality/%s_%s.pkl' % (datasets, 'gravitycloseness')
with open(filename, "rb") as f:
    gravitycloseness = pickle.load(f)
filename = 'centrality/%s_%s.pkl' % (datasets, 'gravityeigenvector')
with open(filename, "rb") as f:
    gravityeigenvector = pickle.load(f)

import matplotlib.pyplot as plt
import networkx as nx
import numpy as np
from matplotlib.patches import FancyBboxPatch
plt.style.use('nature')
# 
fig, axes = plt.subplots(2,6, figsize=(24,8), dpi=200)

# 

sorting_keys = [
    ('nodes/cmat_gcn_vae_degree_1000.npy', 'Degree-1000',degree),
    ('nodes/cmat_gcn_vae_core_1000.npy', 'Core-1000',core),
    ('nodes/cmat_gcn_vae_pagerank_1000.npy', 'Pagerank-1000',pagerank),
    ('nodes/cmat_gcn_vae_betweenness_1000.npy', 'Betweenness-1000',betweenness),
    ('nodes/cmat_gcn_vae_closeness_1000.npy', 'Closeness-1000',closeness),
    ('nodes/cmat_gcn_vae_eigenvector_1000.npy', 'Eigenvector-1000',eigenvector),
    ('nodes/cmat_gcn_vae_gravitydegree_1000.npy', 'GMDegree-1000',gravitydegree),
    ('nodes/cmat_gcn_vae_gravitycore_1000.npy', 'GMCore-1000',gravitycore),
    ('nodes/cmat_gcn_vae_gravitypagerank_1000.npy', 'GMPagerank-1000',gravitypagerank),
    ('nodes/cmat_gcn_vae_gravitybetweenness_1000.npy', 'GMBetweenness-1000',gravitybetweenness),
    ('nodes/cmat_gcn_vae_gravitycloseness_1000.npy', 'GMCloseness-1000',gravitycloseness),
    ('nodes/cmat_gcn_vae_gravityeigenvector_1000.npy', 'GMEigenvector-1000',gravityeigenvector)
]


# Loop through each subgraph and perform sorting based on the respective key
for i, (data_filename, title, sorting_key) in enumerate(sorting_keys):
    sorted_key= sorted(sorting_key.items(), key = lambda x:x[1],reverse=True)
    top_nodes = [node[0] for node in sorted_key[:1000]]
    sampled_nodes = np.load(data_filename)
    nodes = [node for node in G.nodes() if node not in top_nodes and node not in sampled_nodes]
    node_list = [node for node in sampled_nodes if node in top_nodes]

    # 
    nx.draw_networkx_nodes(G, cmat_pos, nodelist=nodes, node_color='skyblue', node_size=18, alpha=0.3, label='Common nodes', ax=axes[i//6,i%6])
    nx.draw_networkx_nodes(G,  cmat_pos, nodelist=top_nodes, node_color='steelblue', edgecolors='#3C5488FF', node_size=18, linewidths=1, alpha=0.5, label='Top nodes', ax=axes[i//6,i%6])
    # nx.draw_networkx_nodes(G,  cmat_pos, nodelist=sampled_nodes, node_color='steelblue', edgecolors='#FD8404', linewidths=1, node_size=18, alpha=0.5, label='Sampled nodes', ax=axes[i//6,i%6])
    # nx.draw_networkx_nodes(G,  cmat_pos, nodelist=node_list, node_color='darkslategray', edgecolors='orangered', linewidths=1, node_size=25, alpha=0.7, label='Identical nodes',  ax=axes[i//6,i%6])
    nx.draw_networkx_edges(G, cmat_pos, width=1, edge_color='mistyrose', alpha=0.5, arrows=False, ax=axes[i//6,i%6])

    # 
    ax=axes[i//6,i%6].set_title(title, fontsize=20)
    ax=axes[i//6,i%6].axis('off')

lines1, labels1 = axes[0,0].get_legend_handles_labels()
# lines2, labels2 = axes[1].get_legend_handles_labels()
# lines3, labels3 = axes[2].get_legend_handles_labels()
# lines = lines1 + lines2 + lines3
# labels = labels1 + labels2 +labels3


fig.subplots_adjust(wspace=0,hspace=0.1)

fig.legend(lines1, labels1, fontsize=20, loc='lower center', bbox_to_anchor=(0.5, 0.05),ncol=4)
# 
plt.savefig('C:/Users/WENJIA/Downloads/papers/node/cmat_1000_tn.pdf', dpi=150)
plt.savefig('C:/Users/WENJIA/Downloads/papers/node/cmat_1000_tn.png', dpi=150)
plt.tight_layout()

# 
plt.show()

# %%
import matplotlib.pyplot as plt
import networkx as nx
import numpy as np
from matplotlib.patches import FancyBboxPatch
plt.style.use('nature')
# 
fig, axes = plt.subplots(2,6, figsize=(24,8), dpi=200)

# 

sorting_keys = [
    ('nodes/cmat_gcn_vae_degree_1000.npy', 'Degree-1000',degree),
    ('nodes/cmat_gcn_vae_core_1000.npy', 'Core-1000',core),
    ('nodes/cmat_gcn_vae_pagerank_1000.npy', 'Pagerank-1000',pagerank),
    ('nodes/cmat_gcn_vae_betweenness_1000.npy', 'Betweenness-1000',betweenness),
    ('nodes/cmat_gcn_vae_closeness_1000.npy', 'Closeness-1000',closeness),
    ('nodes/cmat_gcn_vae_eigenvector_1000.npy', 'Eigenvector-1000',eigenvector),
    ('nodes/cmat_gcn_vae_gravitydegree_1000.npy', 'GMDegree-1000',gravitydegree),
    ('nodes/cmat_gcn_vae_gravitycore_1000.npy', 'GMCore-1000',gravitycore),
    ('nodes/cmat_gcn_vae_gravitypagerank_1000.npy', 'GMPagerank-1000',gravitypagerank),
    ('nodes/cmat_gcn_vae_gravitybetweenness_1000.npy', 'GMBetweenness-1000',gravitybetweenness),
    ('nodes/cmat_gcn_vae_gravitycloseness_1000.npy', 'GMCloseness-1000',gravitycloseness),
    ('nodes/cmat_gcn_vae_gravityeigenvector_1000.npy', 'GMEigenvector-1000',gravityeigenvector)
]


# Loop through each subgraph and perform sorting based on the respective key
for i, (data_filename, title, sorting_key) in enumerate(sorting_keys):
    sorted_key= sorted(sorting_key.items(), key = lambda x:x[1],reverse=True)
    top_nodes = [node[0] for node in sorted_key[:1000]]
    sampled_nodes = np.load(data_filename)
    nodes = [node for node in G.nodes() if node not in top_nodes and node not in sampled_nodes]
    node_list = [node for node in sampled_nodes if node in top_nodes]

    # 
    nx.draw_networkx_nodes(G, cmat_pos, nodelist=nodes, node_color='skyblue', node_size=18, alpha=0.3, label='Common nodes', ax=axes[i//6,i%6])
    # nx.draw_networkx_nodes(G,  cmat_pos, nodelist=top_nodes, node_color='steelblue', edgecolors='#3C5488FF', node_size=18, linewidths=1, alpha=0.5, label='Top nodes', ax=axes[i//6,i%6])
    nx.draw_networkx_nodes(G,  cmat_pos, nodelist=sampled_nodes, node_color='steelblue', edgecolors='#FD8404', linewidths=1, node_size=18, alpha=0.5, label='Sampled nodes', ax=axes[i//6,i%6])
    # nx.draw_networkx_nodes(G,  cmat_pos, nodelist=node_list, node_color='darkslategray', edgecolors='orangered', linewidths=1, node_size=25, alpha=0.7, label='Identical nodes',  ax=axes[i//6,i%6])
    nx.draw_networkx_edges(G, cmat_pos, width=1, edge_color='mistyrose', alpha=0.5, arrows=False, ax=axes[i//6,i%6])

    # 
    ax=axes[i//6,i%6].set_title(title, fontsize=20)
    ax=axes[i//6,i%6].axis('off')

lines1, labels1 = axes[0,0].get_legend_handles_labels()
# lines2, labels2 = axes[1].get_legend_handles_labels()
# lines3, labels3 = axes[2].get_legend_handles_labels()
# lines = lines1 + lines2 + lines3
# labels = labels1 + labels2 +labels3


fig.subplots_adjust(wspace=0,hspace=0.1)

fig.legend(lines1, labels1, fontsize=20, loc='lower center', bbox_to_anchor=(0.5, 0.05),ncol=4)
# 
plt.savefig('C:/Users/WENJIA/Downloads/papers/node/cmat_1000_sn.pdf', dpi=150)
plt.savefig('C:/Users/WENJIA/Downloads/papers/node/cmat_1000_sn.png', dpi=150)
plt.tight_layout()

# 
plt.show()

# %%
datasets = 'ba3k_16'
adj_matrix,_ = load_data(datasets)
G = nx.from_numpy_array(adj_matrix,create_using=nx.DiGraph)
filename = 'centrality/%s_pos.pkl' % (datasets)
# ba3k_16_pos = nx.spring_layout(G)

# 将节点位置保存到文件
# with open(filename, "wb") as f:
#     pickle.dump(ba3k_16_pos, f)

with open(filename, "rb") as f:
        ba3k_16_pos = pickle.load(f)
filename = 'centrality/%s_%s.pkl' % (datasets, 'degree')
with open(filename, "rb") as f:
        degree = pickle.load(f)
filename = 'centrality/%s_%s.pkl' % (datasets, 'core')
with open(filename, "rb") as f:
        core = pickle.load(f)
filename = 'centrality/%s_%s.pkl' % (datasets, 'pagerank')
with open(filename, "rb") as f:
        pagerank = pickle.load(f)
filename = 'centrality/%s_%s.pkl' % (datasets, 'betweenness')
with open(filename, "rb") as f:
    betweenness  = pickle.load(f)
filename = 'centrality/%s_%s.pkl' % (datasets, 'closeness')
with open(filename, "rb") as f:
    closeness  = pickle.load(f)
filename = 'centrality/%s_%s.pkl' % (datasets, 'eigenvector')
with open(filename, "rb") as f:
    eigenvector = pickle.load(f)
filename = 'centrality/%s_%s.pkl' % (datasets, 'gravitydegree')
with open(filename, "rb") as f:
    gravitydegree = pickle.load(f)
filename = 'centrality/%s_%s.pkl' % (datasets, 'gravitycore')
with open(filename, "rb") as f:
    gravitycore = pickle.load(f)

filename = 'centrality/%s_%s.pkl' % (datasets, 'gravitypagerank')
with open(filename, "rb") as f:
    gravitypagerank = pickle.load(f)
filename = 'centrality/%s_%s.pkl' % (datasets, 'gravitybetweenness')
with open(filename, "rb") as f:
    gravitybetweenness = pickle.load(f)
filename = 'centrality/%s_%s.pkl' % (datasets, 'gravitycloseness')
with open(filename, "rb") as f:
    gravitycloseness = pickle.load(f)
filename = 'centrality/%s_%s.pkl' % (datasets, 'gravityeigenvector')
with open(filename, "rb") as f:
    gravityeigenvector = pickle.load(f)

import matplotlib.pyplot as plt
import networkx as nx
import numpy as np
from matplotlib.patches import FancyBboxPatch
plt.style.use('nature')
# 
fig, axes = plt.subplots(2,6, figsize=(24,8), dpi=200)

# 

sorting_keys = [
    ('nodes/ba3k_16_2_sn_gcn_vae_degree_300.npy', 'Degree-300',degree),
    ('nodes/ba3k_16_2_sn_gcn_vae_core_300.npy', 'Core-300',core),
    ('nodes/ba3k_16_2_sn_gcn_vae_pagerank_300.npy', 'Pagerank-300',pagerank),
    ('nodes/ba3k_16_2_sn_gcn_vae_betweenness_300.npy', 'Betweenness-300',betweenness),
    ('nodes/ba3k_16_2_sn_gcn_vae_closeness_300.npy', 'Closeness-300',closeness),
    ('nodes/ba3k_16_2_sn_gcn_vae_eigenvector_300.npy', 'Eigenvector-300',eigenvector),
    ('nodes/ba3k_16_2_sn_gcn_vae_gravitydegree_300.npy', 'GMDegree-300',gravitydegree),
    ('nodes/ba3k_16_2_sn_gcn_vae_gravitycore_300.npy', 'GMCore-300',gravitycore),
    ('nodes/ba3k_16_2_sn_gcn_vae_gravitypagerank_300.npy', 'GMPagerank-300',gravitypagerank),
    ('nodes/ba3k_16_2_sn_gcn_vae_gravitybetweenness_300.npy', 'GMBetweenness-300',gravitybetweenness),
    ('nodes/ba3k_16_2_sn_gcn_vae_gravitycloseness_300.npy', 'GMCloseness-300',gravitycloseness),
    ('nodes/ba3k_16_2_sn_gcn_vae_gravityeigenvector_300.npy', 'GMEigenvector-300',gravityeigenvector)
]


# Loop through each subgraph and perform sorting based on the respective key
for i, (data_filename, title, sorting_key) in enumerate(sorting_keys):
    sorted_key= sorted(sorting_key.items(), key = lambda x:x[1],reverse=True)
    top_nodes = [node[0] for node in sorted_key[:300]]
    sampled_nodes = np.load(data_filename)
    nodes = [node for node in G.nodes() if node not in top_nodes and node not in sampled_nodes]
    node_list = [node for node in sampled_nodes if node in top_nodes]

    # 
    nx.draw_networkx_nodes(G, ba3k_16_pos, nodelist=nodes, node_color='skyblue', node_size=18, alpha=0.3, label='Common nodes', ax=axes[i//6,i%6])
    nx.draw_networkx_nodes(G,  ba3k_16_pos, nodelist=top_nodes, node_color='steelblue', edgecolors='#3C5488FF', node_size=18, linewidths=1, alpha=0.5, label='Top nodes', ax=axes[i//6,i%6])
    # nx.draw_networkx_nodes(G,  ba3k_16_pos, nodelist=sampled_nodes, node_color='steelblue', edgecolors='#FD8404', linewidths=1, node_size=18, alpha=0.5, label='Sampled nodes', ax=axes[i//6,i%6])
    # nx.draw_networkx_nodes(G,  ba3k_16_pos, nodelist=node_list, node_color='darkslategray', edgecolors='orangered', linewidths=1, node_size=25, alpha=0.7, label='Identical nodes',  ax=axes[i//6,i%6])
    nx.draw_networkx_edges(G, ba3k_16_pos, width=1, edge_color='mistyrose', alpha=0.5, arrows=False, ax=axes[i//6,i%6])

    # 
    ax=axes[i//6,i%6].set_title(title, fontsize=20)
    ax=axes[i//6,i%6].axis('off')

lines1, labels1 = axes[0,0].get_legend_handles_labels()
# lines2, labels2 = axes[1].get_legend_handles_labels()
# lines3, labels3 = axes[2].get_legend_handles_labels()
# lines = lines1 + lines2 + lines3
# labels = labels1 + labels2 +labels3


fig.subplots_adjust(wspace=0,hspace=0.1)

fig.legend(lines1, labels1, fontsize=20, loc='lower center', bbox_to_anchor=(0.5, 0.05),ncol=4)
# 
plt.savefig('C:/Users/WENJIA/Downloads/papers/node/ba3k_16_300_tn.pdf', dpi=150)
plt.savefig('C:/Users/WENJIA/Downloads/papers/node/ba3k_16_300_tn.png', dpi=150)
plt.tight_layout()

# 
plt.show()

# %%
datasets = 'ba3k_16'
adj_matrix,_ = load_data(datasets)
G = nx.from_numpy_array(adj_matrix,create_using=nx.DiGraph)
filename = 'centrality/%s_pos.pkl' % (datasets)
# ba3k_16_pos = nx.spring_layout(G)

# 将节点位置保存到文件
# with open(filename, "wb") as f:
#     pickle.dump(ba3k_16_pos, f)

with open(filename, "rb") as f:
        ba3k_16_pos = pickle.load(f)
filename = 'centrality/%s_%s.pkl' % (datasets, 'degree')
with open(filename, "rb") as f:
        degree = pickle.load(f)
filename = 'centrality/%s_%s.pkl' % (datasets, 'core')
with open(filename, "rb") as f:
        core = pickle.load(f)
filename = 'centrality/%s_%s.pkl' % (datasets, 'pagerank')
with open(filename, "rb") as f:
        pagerank = pickle.load(f)
filename = 'centrality/%s_%s.pkl' % (datasets, 'betweenness')
with open(filename, "rb") as f:
    betweenness  = pickle.load(f)
filename = 'centrality/%s_%s.pkl' % (datasets, 'closeness')
with open(filename, "rb") as f:
    closeness  = pickle.load(f)
filename = 'centrality/%s_%s.pkl' % (datasets, 'eigenvector')
with open(filename, "rb") as f:
    eigenvector = pickle.load(f)
filename = 'centrality/%s_%s.pkl' % (datasets, 'gravitydegree')
with open(filename, "rb") as f:
    gravitydegree = pickle.load(f)
filename = 'centrality/%s_%s.pkl' % (datasets, 'gravitycore')
with open(filename, "rb") as f:
    gravitycore = pickle.load(f)

filename = 'centrality/%s_%s.pkl' % (datasets, 'gravitypagerank')
with open(filename, "rb") as f:
    gravitypagerank = pickle.load(f)
filename = 'centrality/%s_%s.pkl' % (datasets, 'gravitybetweenness')
with open(filename, "rb") as f:
    gravitybetweenness = pickle.load(f)
filename = 'centrality/%s_%s.pkl' % (datasets, 'gravitycloseness')
with open(filename, "rb") as f:
    gravitycloseness = pickle.load(f)
filename = 'centrality/%s_%s.pkl' % (datasets, 'gravityeigenvector')
with open(filename, "rb") as f:
    gravityeigenvector = pickle.load(f)

import matplotlib.pyplot as plt
import networkx as nx
import numpy as np
from matplotlib.patches import FancyBboxPatch
plt.style.use('nature')
# 
fig, axes = plt.subplots(2,6, figsize=(24,8), dpi=200)

# 

sorting_keys = [
    ('nodes/ba3k_16_2_sn_gcn_vae_degree_300.npy', 'Degree-300',degree),
    ('nodes/ba3k_16_2_sn_gcn_vae_core_300.npy', 'Core-300',core),
    ('nodes/ba3k_16_2_sn_gcn_vae_pagerank_300.npy', 'Pagerank-300',pagerank),
    ('nodes/ba3k_16_2_sn_gcn_vae_betweenness_300.npy', 'Betweenness-300',betweenness),
    ('nodes/ba3k_16_2_sn_gcn_vae_closeness_300.npy', 'Closeness-300',closeness),
    ('nodes/ba3k_16_2_sn_gcn_vae_eigenvector_300.npy', 'Eigenvector-300',eigenvector),
    ('nodes/ba3k_16_2_sn_gcn_vae_gravitydegree_300.npy', 'GMDegree-300',gravitydegree),
    ('nodes/ba3k_16_2_sn_gcn_vae_gravitycore_300.npy', 'GMCore-300',gravitycore),
    ('nodes/ba3k_16_2_sn_gcn_vae_gravitypagerank_300.npy', 'GMPagerank-300',gravitypagerank),
    ('nodes/ba3k_16_2_sn_gcn_vae_gravitybetweenness_300.npy', 'GMBetweenness-300',gravitybetweenness),
    ('nodes/ba3k_16_2_sn_gcn_vae_gravitycloseness_300.npy', 'GMCloseness-300',gravitycloseness),
    ('nodes/ba3k_16_2_sn_gcn_vae_gravityeigenvector_300.npy', 'GMEigenvector-300',gravityeigenvector)
]


# Loop through each subgraph and perform sorting based on the respective key
for i, (data_filename, title, sorting_key) in enumerate(sorting_keys):
    sorted_key= sorted(sorting_key.items(), key = lambda x:x[1],reverse=True)
    top_nodes = [node[0] for node in sorted_key[:300]]
    sampled_nodes = np.load(data_filename)
    nodes = [node for node in G.nodes() if node not in top_nodes and node not in sampled_nodes]
    node_list = [node for node in sampled_nodes if node in top_nodes]

    # 
    nx.draw_networkx_nodes(G, ba3k_16_pos, nodelist=nodes, node_color='skyblue', node_size=18, alpha=0.3, label='Common nodes', ax=axes[i//6,i%6])
    # nx.draw_networkx_nodes(G,  ba3k_16_pos, nodelist=top_nodes, node_color='steelblue', edgecolors='#3C5488FF', node_size=18, linewidths=1, alpha=0.5, label='Top nodes', ax=axes[i//6,i%6])
    nx.draw_networkx_nodes(G,  ba3k_16_pos, nodelist=sampled_nodes, node_color='steelblue', edgecolors='#FD8404', linewidths=1, node_size=18, alpha=0.5, label='Sampled nodes', ax=axes[i//6,i%6])
    # nx.draw_networkx_nodes(G,  ba3k_16_pos, nodelist=node_list, node_color='darkslategray', edgecolors='orangered', linewidths=1, node_size=25, alpha=0.7, label='Identical nodes',  ax=axes[i//6,i%6])
    nx.draw_networkx_edges(G, ba3k_16_pos, width=1, edge_color='mistyrose', alpha=0.5, arrows=False, ax=axes[i//6,i%6])

    # 
    ax=axes[i//6,i%6].set_title(title, fontsize=20)
    ax=axes[i//6,i%6].axis('off')

lines1, labels1 = axes[0,0].get_legend_handles_labels()
# lines2, labels2 = axes[1].get_legend_handles_labels()
# lines3, labels3 = axes[2].get_legend_handles_labels()
# lines = lines1 + lines2 + lines3
# labels = labels1 + labels2 +labels3


fig.subplots_adjust(wspace=0,hspace=0.1)

fig.legend(lines1, labels1, fontsize=20, loc='lower center', bbox_to_anchor=(0.5, 0.05),ncol=4)
# 
plt.savefig('C:/Users/WENJIA/Downloads/papers/node/ba3k_16_300_sn.pdf', dpi=150)
plt.savefig('C:/Users/WENJIA/Downloads/papers/node/ba3k_16_300_sn.png', dpi=150)
plt.tight_layout()

# 
plt.show()

# %%
datasets = 'brainfly'
adj_matrix,_ = load_data(datasets)
G = nx.from_numpy_array(adj_matrix,create_using=nx.DiGraph)
filename = 'centrality/%s_pos.pkl' % (datasets)
# brainfly_pos = nx.spring_layout(G)

# 将节点位置保存到文件
# with open(filename, "wb") as f:
#     pickle.dump(brainfly_pos, f)

with open(filename, "rb") as f:
        brainfly_pos = pickle.load(f)
filename = 'centrality/%s_%s.pkl' % (datasets, 'degree')
with open(filename, "rb") as f:
        degree = pickle.load(f)
filename = 'centrality/%s_%s.pkl' % (datasets, 'core')
with open(filename, "rb") as f:
        core = pickle.load(f)
filename = 'centrality/%s_%s.pkl' % (datasets, 'pagerank')
with open(filename, "rb") as f:
        pagerank = pickle.load(f)
filename = 'centrality/%s_%s.pkl' % (datasets, 'betweenness')
with open(filename, "rb") as f:
    betweenness  = pickle.load(f)
filename = 'centrality/%s_%s.pkl' % (datasets, 'closeness')
with open(filename, "rb") as f:
    closeness  = pickle.load(f)
filename = 'centrality/%s_%s.pkl' % (datasets, 'eigenvector')
with open(filename, "rb") as f:
    eigenvector = pickle.load(f)
filename = 'centrality/%s_%s.pkl' % (datasets, 'gravitydegree')
with open(filename, "rb") as f:
    gravitydegree = pickle.load(f)
filename = 'centrality/%s_%s.pkl' % (datasets, 'gravitycore')
with open(filename, "rb") as f:
    gravitycore = pickle.load(f)

filename = 'centrality/%s_%s.pkl' % (datasets, 'gravitypagerank')
with open(filename, "rb") as f:
    gravitypagerank = pickle.load(f)
filename = 'centrality/%s_%s.pkl' % (datasets, 'gravitybetweenness')
with open(filename, "rb") as f:
    gravitybetweenness = pickle.load(f)
filename = 'centrality/%s_%s.pkl' % (datasets, 'gravitycloseness')
with open(filename, "rb") as f:
    gravitycloseness = pickle.load(f)
filename = 'centrality/%s_%s.pkl' % (datasets, 'gravityeigenvector')
with open(filename, "rb") as f:
    gravityeigenvector = pickle.load(f)

import matplotlib.pyplot as plt
import networkx as nx
import numpy as np
from matplotlib.patches import FancyBboxPatch
plt.style.use('nature')
# 
fig, axes = plt.subplots(2,6, figsize=(24,8), dpi=200)

# 

sorting_keys = [
    ('nodes/brainfly_sn_gcn_vae_degree_300.npy', 'Degree-300',degree),
    ('nodes/brainfly_sn_gcn_vae_core_300.npy', 'Core-300',core),
    ('nodes/brainfly_sn_gcn_vae_pagerank_300.npy', 'Pagerank-300',pagerank),
    ('nodes/brainfly_sn_gcn_vae_betweenness_300.npy', 'Betweenness-300',betweenness),
    ('nodes/brainfly_sn_gcn_vae_closeness_300.npy', 'Closeness-300',closeness),
    ('nodes/brainfly_sn_gcn_vae_eigenvector_300.npy', 'Eigenvector-300',eigenvector),
    ('nodes/brainfly_sn_gcn_vae_gravitydegree_300.npy', 'GMDegree-300',gravitydegree),
    ('nodes/brainfly_sn_gcn_vae_gravitycore_300.npy', 'GMCore-300',gravitycore),
    ('nodes/brainfly_sn_gcn_vae_gravitypagerank_300.npy', 'GMPagerank-300',gravitypagerank),
    ('nodes/brainfly_sn_gcn_vae_gravitybetweenness_300.npy', 'GMBetweenness-300',gravitybetweenness),
    ('nodes/brainfly_sn_gcn_vae_gravitycloseness_300.npy', 'GMCloseness-300',gravitycloseness),
    ('nodes/brainfly_sn_gcn_vae_gravityeigenvector_300.npy', 'GMEigenvector-300',gravityeigenvector)
]


# Loop through each subgraph and perform sorting based on the respective key
for i, (data_filename, title, sorting_key) in enumerate(sorting_keys):
    sorted_key= sorted(sorting_key.items(), key = lambda x:x[1],reverse=True)
    top_nodes = [node[0] for node in sorted_key[:300]]
    sampled_nodes = np.load(data_filename)
    nodes = [node for node in G.nodes() if node not in top_nodes and node not in sampled_nodes]
    node_list = [node for node in sampled_nodes if node in top_nodes]

    # 
    nx.draw_networkx_nodes(G, brainfly_pos, nodelist=nodes, node_color='skyblue', node_size=18, alpha=0.3, label='Common nodes', ax=axes[i//6,i%6])
    # nx.draw_networkx_nodes(G,  brainfly_pos, nodelist=top_nodes, node_color='steelblue', edgecolors='#3C5488FF', node_size=18, linewidths=1, alpha=0.5, label='Top nodes', ax=axes[i//6,i%6])
    nx.draw_networkx_nodes(G,  brainfly_pos, nodelist=sampled_nodes, node_color='steelblue', edgecolors='#FD8404', linewidths=1, node_size=18, alpha=0.5, label='Sampled nodes', ax=axes[i//6,i%6])
    # nx.draw_networkx_nodes(G,  brainfly_pos, nodelist=node_list, node_color='darkslategray', edgecolors='orangered', linewidths=1, node_size=25, alpha=0.7, label='Identical nodes',  ax=axes[i//6,i%6])
    nx.draw_networkx_edges(G, brainfly_pos, width=1, edge_color='mistyrose', alpha=0.5, arrows=False, ax=axes[i//6,i%6])

    # 
    ax=axes[i//6,i%6].set_title(title, fontsize=20)
    ax=axes[i//6,i%6].axis('off')

lines1, labels1 = axes[0,0].get_legend_handles_labels()
# lines2, labels2 = axes[1].get_legend_handles_labels()
# lines3, labels3 = axes[2].get_legend_handles_labels()
# lines = lines1 + lines2 + lines3
# labels = labels1 + labels2 +labels3


fig.subplots_adjust(wspace=0,hspace=0.1)

fig.legend(lines1, labels1, fontsize=20, loc='lower center', bbox_to_anchor=(0.5, 0.05),ncol=4)
# 
plt.savefig('C:/Users/WENJIA/Downloads/papers/node/brainfly_300_sn.pdf', dpi=150)
plt.savefig('C:/Users/WENJIA/Downloads/papers/node/brainfly_300_sn.png', dpi=150)
plt.tight_layout()

# 
plt.show()

# %%
datasets = 'brainfly'
adj_matrix,_ = load_data(datasets)
G = nx.from_numpy_array(adj_matrix,create_using=nx.DiGraph)
filename = 'centrality/%s_pos.pkl' % (datasets)
# ba3k_16_pos = nx.spring_layout(G)

# 将节点位置保存到文件
# with open(filename, "wb") as f:
#     pickle.dump(ba3k_16_pos, f)

with open(filename, "rb") as f:
        ba3k_16_pos = pickle.load(f)
filename = 'centrality/%s_%s.pkl' % (datasets, 'degree')
with open(filename, "rb") as f:
        degree = pickle.load(f)
filename = 'centrality/%s_%s.pkl' % (datasets, 'core')
with open(filename, "rb") as f:
        core = pickle.load(f)
filename = 'centrality/%s_%s.pkl' % (datasets, 'pagerank')
with open(filename, "rb") as f:
        pagerank = pickle.load(f)
filename = 'centrality/%s_%s.pkl' % (datasets, 'betweenness')
with open(filename, "rb") as f:
    betweenness  = pickle.load(f)
filename = 'centrality/%s_%s.pkl' % (datasets, 'closeness')
with open(filename, "rb") as f:
    closeness  = pickle.load(f)
filename = 'centrality/%s_%s.pkl' % (datasets, 'eigenvector')
with open(filename, "rb") as f:
    eigenvector = pickle.load(f)
filename = 'centrality/%s_%s.pkl' % (datasets, 'gravitydegree')
with open(filename, "rb") as f:
    gravitydegree = pickle.load(f)
filename = 'centrality/%s_%s.pkl' % (datasets, 'gravitycore')
with open(filename, "rb") as f:
    gravitycore = pickle.load(f)

filename = 'centrality/%s_%s.pkl' % (datasets, 'gravitypagerank')
with open(filename, "rb") as f:
    gravitypagerank = pickle.load(f)
filename = 'centrality/%s_%s.pkl' % (datasets, 'gravitybetweenness')
with open(filename, "rb") as f:
    gravitybetweenness = pickle.load(f)
filename = 'centrality/%s_%s.pkl' % (datasets, 'gravitycloseness')
with open(filename, "rb") as f:
    gravitycloseness = pickle.load(f)
filename = 'centrality/%s_%s.pkl' % (datasets, 'gravityeigenvector')
with open(filename, "rb") as f:
    gravityeigenvector = pickle.load(f)

import matplotlib.pyplot as plt
import networkx as nx
import numpy as np
from matplotlib.patches import FancyBboxPatch
plt.style.use('nature')
# 
fig, axes = plt.subplots(2,6, figsize=(24,8), dpi=200)

# 

sorting_keys = [
    ('nodes/brainfly_sn_gcn_vae_degree_300.npy', 'Degree-300',degree),
    ('nodes/brainfly_sn_gcn_vae_core_300.npy', 'Core-300',core),
    ('nodes/brainfly_sn_gcn_vae_pagerank_300.npy', 'Pagerank-300',pagerank),
    ('nodes/brainfly_sn_gcn_vae_betweenness_300.npy', 'Betweenness-300',betweenness),
    ('nodes/brainfly_sn_gcn_vae_closeness_300.npy', 'Closeness-300',closeness),
    ('nodes/brainfly_sn_gcn_vae_eigenvector_300.npy', 'Eigenvector-300',eigenvector),
    ('nodes/brainfly_sn_gcn_vae_gravitydegree_300.npy', 'GMDegree-300',gravitydegree),
    ('nodes/brainfly_sn_gcn_vae_gravitycore_300.npy', 'GMCore-300',gravitycore),
    ('nodes/brainfly_sn_gcn_vae_gravitypagerank_300.npy', 'GMPagerank-300',gravitypagerank),
    ('nodes/brainfly_sn_gcn_vae_gravitybetweenness_300.npy', 'GMBetweenness-300',gravitybetweenness),
    ('nodes/brainfly_sn_gcn_vae_gravitycloseness_300.npy', 'GMCloseness-300',gravitycloseness),
    ('nodes/brainfly_sn_gcn_vae_gravityeigenvector_300.npy', 'GMEigenvector-300',gravityeigenvector)
]


# Loop through each subgraph and perform sorting based on the respective key
for i, (data_filename, title, sorting_key) in enumerate(sorting_keys):
    sorted_key= sorted(sorting_key.items(), key = lambda x:x[1],reverse=True)
    top_nodes = [node[0] for node in sorted_key[:300]]
    sampled_nodes = np.load(data_filename)
    nodes = [node for node in G.nodes() if node not in top_nodes and node not in sampled_nodes]
    node_list = [node for node in sampled_nodes if node in top_nodes]

    # 
    nx.draw_networkx_nodes(G, ba3k_16_pos, nodelist=nodes, node_color='skyblue', node_size=18, alpha=0.3, label='Common nodes', ax=axes[i//6,i%6])
    nx.draw_networkx_nodes(G,  ba3k_16_pos, nodelist=top_nodes, node_color='steelblue', edgecolors='#3C5488FF', node_size=18, linewidths=1, alpha=0.5, label='Top nodes', ax=axes[i//6,i%6])
    # nx.draw_networkx_nodes(G,  ba3k_16_pos, nodelist=sampled_nodes, node_color='steelblue', edgecolors='#FD8404', linewidths=1, node_size=18, alpha=0.5, label='Sampled nodes', ax=axes[i//6,i%6])
    # nx.draw_networkx_nodes(G,  ba3k_16_pos, nodelist=node_list, node_color='darkslategray', edgecolors='orangered', linewidths=1, node_size=25, alpha=0.7, label='Identical nodes',  ax=axes[i//6,i%6])
    nx.draw_networkx_edges(G, ba3k_16_pos, width=1, edge_color='mistyrose', alpha=0.5, arrows=False, ax=axes[i//6,i%6])

    # 
    ax=axes[i//6,i%6].set_title(title, fontsize=20)
    ax=axes[i//6,i%6].axis('off')

lines1, labels1 = axes[0,0].get_legend_handles_labels()
# lines2, labels2 = axes[1].get_legend_handles_labels()
# lines3, labels3 = axes[2].get_legend_handles_labels()
# lines = lines1 + lines2 + lines3
# labels = labels1 + labels2 +labels3


fig.subplots_adjust(wspace=0,hspace=0.1)

fig.legend(lines1, labels1, fontsize=20, loc='lower center', bbox_to_anchor=(0.5, 0.05),ncol=4)
# 
plt.savefig('C:/Users/WENJIA/Downloads/papers/node/ba3k_16_300_tn.pdf', dpi=150)
plt.savefig('C:/Users/WENJIA/Downloads/papers/node/ba3k_16_300_tn.png', dpi=150)
plt.tight_layout()

# 
plt.show()

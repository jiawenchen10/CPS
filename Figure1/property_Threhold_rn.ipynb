# %%
import numpy as np         
import pandas as pd            
import matplotlib as mpl   
import matplotlib.pyplot as plt            
import seaborn as sns          
sns.set_theme(context='notebook', style='ticks', palette='deep', font_scale=1, color_codes=True, rc=None )            
sns.set_style({'font.sans-serif':['simsun','serif']})            
#plt.rcParams['xtick.direction'] = 'in'       
#plt.rcParams['ytick.direction'] = 'in'            
#plt.rcParams['font.sans-serif'] = 'simsun'        
plt.rcParams['axes.unicode_minus'] =False

# %% [markdown]
# ## Cora

# %%
import numpy as np
import matplotlib.pyplot as plt
import scienceplots
plt.style.use('science')
plt.style.use('nature')

my_dpi = 96
fig, axes = plt.subplots(1, 2, figsize=(2, 2.4), gridspec_kw={'width_ratios': [2, 0.2], 'wspace': 0.3}, dpi=800) 

bars1 = [92.78,92.75,92.48,88.63,91.85,78.05,85.15,92.99,87.09,84.48,90.21,72.94]
bars2 = [91.03,90.98,89.70,81.42,78.91,67.41,74.04,83.40,76.79,74.73,81.14,68.27]
yer1 = [0.53,0.44,0.57,0.27,0.58,0.51,0.69,0.54,0.46,0.56,0.29,0.81]
yer2 = [0.35,0.27,0.39,0.48,0.62,0.57,0.84,0.89,0.63,0.42,0.53,0.73]

bars3 = [80.52]*len(bars1)
yer3 = [0.39]*len(bars1)

bars4 = [0.9179,0.9227,0.9252,0.918727,0.916867,0.831649,0.904656,0.92375,0.898113,0.884599,0.91122,0.762562]
yer4 = [0.0057,0.00228,0.005623,0.001881,0.002919,0.007578,0.005074,0.00153,0.004061,0.009479,0.000787,0.004906]
bars4 = [x*100 for x in bars4]
yer4  = [x*100 for x in yer4]
labels = ['Degree', 'Core', 'Pagerank', 'Betweenness', 'Closeness', 'Eigenvector', 'Gravitydegree', 'Gravitycore', 'Gravitypagerank', 'Gravitybetweenness', 'Gravitycloseness', 'Gravityeigenvector']


bars1 = bars1[::-1]
bars2 = bars2[::-1]
yer1= yer1[::-1]
yer2= yer2[::-1]
bars3= bars3[::-1]
yer3= yer3[::-1]
bars4= bars4[::-1]
yer4= yer4[::-1]
labels= labels[::-1]


r1 = np.arange(len(bars1))
r2 = r1 
r3 = r1 

axes[0].errorbar(bars3, r3, xerr=yer3, fmt='o', c='#7FB1D2', ecolor='white', 
                 markeredgecolor='black', markeredgewidth=0.5, elinewidth=0, capsize=0, label='Uniform nodes',alpha=0.8)
axes[0].errorbar(bars4, r1, xerr=yer4, fmt='o', c='#A392BA', ecolor='white', markeredgecolor='black', markeredgewidth=0.5,elinewidth=1, capsize=0, label='Rejected nodes',alpha=0.8)

axes[0].errorbar(bars1, r1, xerr=yer1, fmt='o', c='#FB8071', ecolor='white', markeredgecolor='black', markeredgewidth=0.5,elinewidth=1, capsize=0, label='Sampled nodes',alpha=0.8)
axes[0].errorbar(bars2, r2, xerr=yer2, fmt='o', c='#FCB364', ecolor='white', markeredgecolor='black', markeredgewidth=0.5, elinewidth=0, capsize=0, label='Top nodes',alpha=0.8)
# axes[0].errorbar(bars3, r3, xerr=yer3, fmt='o', c='#7FB1D2', ecolor='white', markeredgecolor='black', markeredgewidth=0.5, elinewidth=0, capsize=0, label='Uniform nodes',alpha=0.8)




axes[0].set_yticks(r1 )
axes[0].set_yticklabels(labels, fontsize=6)

axes[0].set_xlabel('Area Under the Curve(\%)', fontsize=5)
# axes[0].set_ylabel('Metrics', fontsize=4)

axes[0].set_xlim((60, 100))
axes[0].set_ylim((-1, 12))
axes[0].legend(loc=[0.9,0.7], fontsize=5)
axes[0].grid (False)
axes[0].set_xticks([60,70,80,90,100])
axes[0].spines['top'].set_visible(False)
axes[0].spines['right'].set_visible(False)
axes[0].xaxis.set_ticks_position('bottom')
axes[0].yaxis.set_ticks_position('left')
axes[0].set_xticks([60,70,80,90,100], minor=True)
axes[0].set_yticks([], minor=True)
for idx in range(len(bars1)):
    
    sampled_x = bars1[idx]
    top_x = bars2[idx]
    rn_x = bars4[idx]
    un_x  = bars3[idx]
    
    x_min = min(sampled_x, top_x, rn_x, un_x)
    x_max = max(sampled_x, top_x, rn_x, un_x)
    
    axes[0].fill_betweenx([r1[idx]-0.16, r2[idx]+0.16], x_min, x_max, color='grey', alpha=0.3 ,edgecolor=None)

axes[0].text(0.5, 1.05, r'AUC on Cora Subgraph with 300 nodes', transform=axes[0].transAxes, ha='center', va='center', bbox=dict(facecolor='none', edgecolor='none', boxstyle='round', alpha=0.0), fontsize=6)
axes[0].tick_params(labelsize=5)

plt.delaxes(axes[1])
plt.tight_layout()
fig.savefig('C:\\Users\\WENJIA\\Downloads\\corrsi\\cora_auc_300.pdf', dpi=800)
# Out:
# C:\Users\WENJIA\AppData\Local\Temp\ipykernel_51496\791860509.py:84: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('science')
plt.style.use('nature')

my_dpi = 96
fig, axes = plt.subplots(1, 2, figsize=(2, 2.4), gridspec_kw={'width_ratios': [2, 0.2], 'wspace': 0.3}, dpi=800) 

bars1 = [92.69,92.70,92.79,90.06,93.05,78.45,84.86,92.94,87.66,85.79,92.18,76.64]
bars2 = [91.59,91.53,91.65,82.41,80.54,71.41,75.69,84.78,79.67,77.28,83.65,70.61]
yer1 = [0.53,0.44,0.57,0.27,0.58,0.51,0.69,0.54,0.46,0.56,0.29,0.81]
yer2 = [0.35,0.27,0.39,0.48,0.62,0.57,0.84,0.89,0.63,0.42,0.53,0.73]

bars3 = [80.52]*len(bars1)
yer3 = [0.39]*len(bars1)
bars4 = [0.913967, 0.923044,0.924766,0.915412,0.915552,0.836143,0.905908,0.924274,0.895087,0.888806,0.910854,0.766929]
yer4 = [0.00732,0.00298, 0.006813,0.003265,0.003098,0.006154,0.003576,0.000685,0.005055,0.010511,0.001395,0.005009]

bars4 = [x*100 for x in bars4]
yer4  = [x*100 for x in yer4]
labels = ['Degree', 'Core', 'Pagerank', 'Betweenness', 'Closeness', 'Eigenvector', 'Gravitydegree', 'Gravitycore', 'Gravitypagerank', 'Gravitybetweenness', 'Gravitycloseness', 'Gravityeigenvector']


bars1 = bars1[::-1]
bars2 = bars2[::-1]
yer1= yer1[::-1]
yer2= yer2[::-1]
bars3= bars3[::-1]
yer3= yer3[::-1]
bars4= bars4[::-1]
yer4= yer4[::-1]
labels= labels[::-1]




r1 = np.arange(len(bars1))
r2 = r1 
r3 = r1 

axes[0].errorbar(bars3, r3, xerr=yer3, fmt='o', c='#7FB1D2', ecolor='white', 
                 markeredgecolor='black', markeredgewidth=0.5, elinewidth=0, capsize=0, label='Uniform nodes',alpha=0.8)
axes[0].errorbar(bars4, r1, xerr=yer4, fmt='o', c='#A392BA', ecolor='white', markeredgecolor='black', markeredgewidth=0.5,elinewidth=1, capsize=0, label='Rejected nodes',alpha=0.8)

axes[0].errorbar(bars1, r1, xerr=yer1, fmt='o', c='#FB8071', ecolor='white', markeredgecolor='black', markeredgewidth=0.5,elinewidth=1, capsize=0, label='Sampled nodes',alpha=0.8)
axes[0].errorbar(bars2, r2, xerr=yer2, fmt='o', c='#FCB364', ecolor='white', markeredgecolor='black', markeredgewidth=0.5, elinewidth=0, capsize=0, label='Top nodes',alpha=0.8)
# axes[0].errorbar(bars3, r3, xerr=yer3, fmt='o', c='#7FB1D2', ecolor='white', markeredgecolor='black', markeredgewidth=0.5, elinewidth=0, capsize=0, label='Uniform nodes',alpha=0.8)


axes[0].set_yticks(r1 )
axes[0].set_yticklabels(labels, fontsize=6)

axes[0].set_xlabel('Area Under Precision Recall(\%)', fontsize=5)
# axes[0].set_ylabel('Metrics', fontsize=4)

axes[0].set_xlim((60, 100))
axes[0].set_ylim((-1, 12))
axes[0].legend(loc=[0.9,0.7], fontsize=5)
axes[0].grid (False)
axes[0].set_xticks([60,70,80,90,100])
axes[0].spines['top'].set_visible(False)
axes[0].spines['right'].set_visible(False)
axes[0].xaxis.set_ticks_position('bottom')
axes[0].yaxis.set_ticks_position('left')
axes[0].set_xticks([60,70,80,90,100], minor=True)
axes[0].set_yticks([], minor=True)

for idx in range(len(bars1)):
    
    sampled_x = bars1[idx]
    top_x = bars2[idx]
    rn_x = bars4[idx]
    un_x  = bars3[idx]
    
    x_min = min(sampled_x, top_x, rn_x, un_x)
    x_max = max(sampled_x, top_x, rn_x, un_x)
    
    axes[0].fill_betweenx([r1[idx]-0.16, r2[idx]+0.16], x_min, x_max, color='grey', alpha=0.3 ,edgecolor=None)

axes[0].text(0.5, 1.05, r'AP on Cora Subgraph with 300 nodes', transform=axes[0].transAxes, ha='center', va='center', bbox=dict(facecolor='none', edgecolor='none', boxstyle='round', alpha=0.0), fontsize=6)
axes[0].tick_params(labelsize=5)

plt.delaxes(axes[1])
plt.tight_layout()
fig.savefig('C:\\Users\\WENJIA\\Downloads\\corrsi\\cora_ap_300.pdf', dpi=800)
# Out:
# C:\Users\WENJIA\AppData\Local\Temp\ipykernel_51496\250045789.py:84: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %% [markdown]
# ## Citeseer

# %%
import numpy as np
import matplotlib.pyplot as plt
import scienceplots
plt.style.use('science')
plt.style.use('nature')

my_dpi = 96
fig, axes = plt.subplots(1, 2, figsize=(2, 2.4), gridspec_kw={'width_ratios': [2, 0.2], 'wspace': 0.3}, dpi=800) 

bars1 = [93.79,92.24,92.94,85.24,90.78,80.31,86.44,87.03,88.29,81.95,82.72,74.17]
bars2 = [80.92,78.59,86.11,80.57,71.97,72.44,72.49,75.77,72.41,70.78,74.53,71.19]
yer1 = [0.53,0.44,0.57,0.27,0.58,0.51,0.69,0.54,0.46,0.56,0.29,0.81]
yer2 = [0.35,0.27,0.39,0.48,0.62,0.57,0.84,0.89,0.63,0.42,0.53,0.73]

bars3 = [76.52]*len(bars1)
yer3 = [0.39]*len(bars1)

bars4 = [0.947590, 0.928966, 0.945174,0.913897,0.920319,0.703489,0.898655,0.932225 ,0.926152,0.881934 ,0.917436,0.615144 ]
yer4 = [0.002533,0.00115, 0.004082,0.002959,0.000978,0.002846,0.003023,0.004261 ,0.001064,0.002306,0.001347 , 0.006214]

# bars4 = [0.951142,0.934722,0.948854 ,0.924006,0.930036,0.758410,0.912345, 0.941380, 0.935249,0.898959,0.928201,0.680188 ]
# yer4  = [0.001952,0.000606,0.002959, 0.002559,0.000484,0.003917,0.001983,0.003890,0.001763,0.001281,0.001686,0.002169]
bars4 = [x * 100 for x in bars4]
yer4  = [x*100 for x in yer4]
labels = ['Degree', 'Core', 'Pagerank', 'Betweenness', 'Closeness', 'Eigenvector', 'Gravitydegree', 'Gravitycore', 'Gravitypagerank', 'Gravitybetweenness', 'Gravitycloseness', 'Gravityeigenvector']


bars1 = bars1[::-1]
bars2 = bars2[::-1]
yer1= yer1[::-1]
yer2= yer2[::-1]
bars3= bars3[::-1]
yer3= yer3[::-1]
bars4= bars4[::-1]
yer4= yer4[::-1]
labels= labels[::-1]


r1 = np.arange(len(bars1))
r2 = r1 
r3 = r1 

axes[0].errorbar(bars3, r3, xerr=yer3, fmt='o', c='#7FB1D2', ecolor='white', 
                 markeredgecolor='black', markeredgewidth=0.5, elinewidth=0, capsize=0, label='Uniform nodes',alpha=0.8)
axes[0].errorbar(bars4, r1, xerr=yer4, fmt='o', c='#A392BA', ecolor='white', markeredgecolor='black', markeredgewidth=0.5,elinewidth=1, capsize=0, label='Rejected nodes',alpha=0.8)

axes[0].errorbar(bars1, r1, xerr=yer1, fmt='o', c='#FB8071', ecolor='white', markeredgecolor='black', markeredgewidth=0.5,elinewidth=1, capsize=0, label='Sampled nodes',alpha=0.8)
axes[0].errorbar(bars2, r2, xerr=yer2, fmt='o', c='#FCB364', ecolor='white', markeredgecolor='black', markeredgewidth=0.5, elinewidth=0, capsize=0, label='Top nodes',alpha=0.8)
# axes[0].errorbar(bars3, r3, xerr=yer3, fmt='o', c='#7FB1D2', ecolor='white', markeredgecolor='black', markeredgewidth=0.5, elinewidth=0, capsize=0, label='Uniform nodes',alpha=0.8)




axes[0].set_yticks(r1 )
axes[0].set_yticklabels(labels, fontsize=6)

axes[0].set_xlabel('Area Under the Curve(\%)', fontsize=5)
# axes[0].set_ylabel('Metrics', fontsize=4)

axes[0].set_xlim((60, 100))
axes[0].set_ylim((-1, 12))
axes[0].legend(loc=[0.9,0.7], fontsize=5)
axes[0].grid (False)
axes[0].set_xticks([60,70,80,90,100])
axes[0].spines['top'].set_visible(False)
axes[0].spines['right'].set_visible(False)
axes[0].xaxis.set_ticks_position('bottom')
axes[0].yaxis.set_ticks_position('left')
axes[0].set_xticks([60,70,80,90,100], minor=True)
axes[0].set_yticks([], minor=True)
for idx in range(len(bars1)):
    
    sampled_x = bars1[idx]
    top_x = bars2[idx]
    rn_x = bars4[idx]
    un_x  = bars3[idx]
    
    x_min = min(sampled_x, top_x, rn_x, un_x)
    x_max = max(sampled_x, top_x, rn_x, un_x)
    
    axes[0].fill_betweenx([r1[idx]-0.16, r2[idx]+0.16], x_min, x_max, color='grey', alpha=0.3 ,edgecolor=None)

axes[0].text(0.5, 1.05, r'AUC on Citeseer Subgraph with 300 nodes', transform=axes[0].transAxes, ha='center', va='center', bbox=dict(facecolor='none', edgecolor='none', boxstyle='round', alpha=0.0), fontsize=6)
axes[0].tick_params(labelsize=5)

plt.delaxes(axes[1])
plt.tight_layout()
fig.savefig('C:\\Users\\WENJIA\\Downloads\\corrsi\\citeseer_auc_300.pdf', dpi=800)
# Out:
# C:\Users\WENJIA\AppData\Local\Temp\ipykernel_51496\3009886977.py:87: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %%
import numpy as np
import matplotlib.pyplot as plt
import scienceplots
plt.style.use('science')
plt.style.use('nature')

my_dpi = 96
fig, axes = plt.subplots(1, 2, figsize=(2, 2.4), gridspec_kw={'width_ratios': [2, 0.2], 'wspace': 0.3}, dpi=800) 

bars1 = [94.25,92.81,93.77,86.84,92.57,84.46,87.91,88.17,89.24,85.39,85.26,82.39]
bars2 = [85.42,81.99,88.43,83.52,75.29,77.16,76.24,80.57,77.93,75.51,77.71,75.43]
yer1 = [0.53,0.44,0.57,0.27,0.58,0.51,0.69,0.54,0.46,0.56,0.29,0.81]
yer2 = [0.35,0.27,0.39,0.48,0.62,0.57,0.84,0.89,0.63,0.42,0.53,0.73]

bars3 = [76.52]*len(bars1)
yer3 = [0.39]*len(bars1)

# bars4 = [0.947590, 0.928966, 0.945174,0.913897,0.920319,0.703489,0.898655,0.932225 ,0.926152,0.881934 ,0.917436,0.615144 ]
# yer4 = [0.002533,0.00115, 0.004082,0.002959,0.000978,0.002846,0.003023,0.004261 ,0.001064,0.002306,0.001347 , 0.006214]

bars4 = [0.951142,0.934722,0.948854 ,0.924006,0.930036,0.758410,0.912345, 0.941380, 0.935249,0.898959,0.928201,0.680188 ]
yer4  = [0.001952,0.000606,0.002959, 0.002559,0.000484,0.003917,0.001983,0.003890,0.001763,0.001281,0.001686,0.002169]

bars4 = [x*100 for x in bars4]
yer4  = [x*100 for x in yer4]
labels = ['Degree', 'Core', 'Pagerank', 'Betweenness', 'Closeness', 'Eigenvector', 'Gravitydegree', 'Gravitycore', 'Gravitypagerank', 'Gravitybetweenness', 'Gravitycloseness', 'Gravityeigenvector']


bars1 = bars1[::-1]
bars2 = bars2[::-1]
yer1= yer1[::-1]
yer2= yer2[::-1]
bars3= bars3[::-1]
yer3= yer3[::-1]
bars4= bars4[::-1]
yer4= yer4[::-1]
labels= labels[::-1]


r1 = np.arange(len(bars1))
r2 = r1 
r3 = r1 

axes[0].errorbar(bars3, r3, xerr=yer3, fmt='o', c='#7FB1D2', ecolor='white', 
                 markeredgecolor='black', markeredgewidth=0.5, elinewidth=0, capsize=0, label='Uniform nodes',alpha=0.8)
axes[0].errorbar(bars4, r1, xerr=yer4, fmt='o', c='#A392BA', ecolor='white', markeredgecolor='black', markeredgewidth=0.5,elinewidth=1, capsize=0, label='Rejected nodes',alpha=0.8)

axes[0].errorbar(bars1, r1, xerr=yer1, fmt='o', c='#FB8071', ecolor='white', markeredgecolor='black', markeredgewidth=0.5,elinewidth=1, capsize=0, label='Sampled nodes',alpha=0.8)
axes[0].errorbar(bars2, r2, xerr=yer2, fmt='o', c='#FCB364', ecolor='white', markeredgecolor='black', markeredgewidth=0.5, elinewidth=0, capsize=0, label='Top nodes',alpha=0.8)
# axes[0].errorbar(bars3, r3, xerr=yer3, fmt='o', c='#7FB1D2', ecolor='white', markeredgecolor='black', markeredgewidth=0.5, elinewidth=0, capsize=0, label='Uniform nodes',alpha=0.8)




axes[0].set_yticks(r1 )
axes[0].set_yticklabels(labels, fontsize=6)

axes[0].set_xlabel('Area Under Precision Recall(\%)', fontsize=5)
# axes[0].set_ylabel('Metrics', fontsize=4)

axes[0].set_xlim((60, 100))
axes[0].set_ylim((-1, 12))
axes[0].legend(loc=[0.9,0.7], fontsize=5)
axes[0].grid (False)
axes[0].set_xticks([60,70,80,90,100])
axes[0].spines['top'].set_visible(False)
axes[0].spines['right'].set_visible(False)
axes[0].xaxis.set_ticks_position('bottom')
axes[0].yaxis.set_ticks_position('left')
axes[0].set_xticks([60,70,80,90,100], minor=True)
axes[0].set_yticks([], minor=True)
for idx in range(len(bars1)):
    
    sampled_x = bars1[idx]
    top_x = bars2[idx]
    rn_x = bars4[idx]
    un_x  = bars3[idx]
    
    x_min = min(sampled_x, top_x, rn_x, un_x)
    x_max = max(sampled_x, top_x, rn_x, un_x)
    
    axes[0].fill_betweenx([r1[idx]-0.16, r2[idx]+0.16], x_min, x_max, color='grey', alpha=0.3 ,edgecolor=None)

axes[0].text(0.5, 1.05, r'AP on Citeseer Subgraph with 300 nodes', transform=axes[0].transAxes, ha='center', va='center', bbox=dict(facecolor='none', edgecolor='none', boxstyle='round', alpha=0.0), fontsize=6)
axes[0].tick_params(labelsize=5)

plt.delaxes(axes[1])
plt.tight_layout()
fig.savefig('C:\\Users\\WENJIA\\Downloads\\corrsi\\citeseer_ap_300.pdf', dpi=800)
# Out:
# C:\Users\WENJIA\AppData\Local\Temp\ipykernel_51496\1349383066.py:88: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %% [markdown]
# ## Pubmed

# %%
import numpy as np
import matplotlib.pyplot as plt
import scienceplots
plt.style.use('science')
plt.style.use('nature')

my_dpi = 96
fig, axes = plt.subplots(1, 2, figsize=(2, 2.4), gridspec_kw={'width_ratios': [2, 0.2], 'wspace': 0.3}, dpi=800) 

bars1 =[95.7683,94.25,95.7989,95.5242,93.3089,85.3005,93.4488,93.506,94.6321,91.21,94.9518,79.7217]
bars2 = [92.57,89.2871,94.2289,94.4737,92.4566,81.7951,90.0421,88.8948,94.7005,88.2741,91.5919,78.3226]
yer1 = [0.53,0.44,0.57,0.27,0.58,0.51,0.69,0.54,0.46,0.56,0.29,0.81]
yer2 = [0.35,0.27,0.39,0.48,0.62,0.57,0.84,0.89,0.63,0.42,0.53,0.73]

bars3 = [89.52]*len(bars1)
yer3 = [0.39]*len(bars1)

bars4 = [0.954957, 0.952167,0.954865 ,0.947507,0.92314 ,0.906182,0.939471 ,0.936735,0.944635,0.939174,0.938962,0.876123 ]
yer4 = [0 for _ in range(len(bars4))]
bars4 = [x*100 for x in bars4]

# bars4 = [0.956258,0.953398, 0.957478,0.949039,0.926755 ,0.910780,0.940104,0.936224,0.944631,0.942276 ,0.943982,0.881776  ]
# yer4  = [0 for _ in range(len(bars4))]

yer4  = [x*100 for x in yer4]
labels = ['Degree', 'Core', 'Pagerank', 'Betweenness', 'Closeness', 'Eigenvector', 'Gravitydegree', 'Gravitycore', 'Gravitypagerank', 'Gravitybetweenness', 'Gravitycloseness', 'Gravityeigenvector']


bars1 = bars1[::-1]
bars2 = bars2[::-1]
yer1= yer1[::-1]
yer2= yer2[::-1]
bars3= bars3[::-1]
yer3= yer3[::-1]
bars4= bars4[::-1]
yer4= yer4[::-1]
labels= labels[::-1]


r1 = np.arange(len(bars1))
r2 = r1 
r3 = r1 

axes[0].errorbar(bars3, r3, xerr=yer3, fmt='o', c='#7FB1D2', ecolor='white', 
                 markeredgecolor='black', markeredgewidth=0.5, elinewidth=0, capsize=0, label='Uniform nodes',alpha=0.8)
axes[0].errorbar(bars4, r1, xerr=yer4, fmt='o', c='#A392BA', ecolor='white', markeredgecolor='black', markeredgewidth=0.5,elinewidth=1, capsize=0, label='Rejected nodes',alpha=0.8)

axes[0].errorbar(bars1, r1, xerr=yer1, fmt='o', c='#FB8071', ecolor='white', markeredgecolor='black', markeredgewidth=0.5,elinewidth=1, capsize=0, label='Sampled nodes',alpha=0.8)
axes[0].errorbar(bars2, r2, xerr=yer2, fmt='o', c='#FCB364', ecolor='white', markeredgecolor='black', markeredgewidth=0.5, elinewidth=0, capsize=0, label='Top nodes',alpha=0.8)
# axes[0].errorbar(bars3, r3, xerr=yer3, fmt='o', c='#7FB1D2', ecolor='white', markeredgecolor='black', markeredgewidth=0.5, elinewidth=0, capsize=0, label='Uniform nodes',alpha=0.8)




axes[0].set_yticks(r1 )
axes[0].set_yticklabels(labels, fontsize=6)

axes[0].set_xlabel('Area Under the Curve(\%)', fontsize=5)
# axes[0].set_ylabel('Metrics', fontsize=4)

axes[0].set_xlim((75, 100))  
axes[0].set_ylim((-1, 12))
axes[0].legend(loc=[0.9,0.7], fontsize=5)
axes[0].grid (False)
axes[0].set_xticks([70,80,90,100])
axes[0].spines['top'].set_visible(False)
axes[0].spines['right'].set_visible(False)
axes[0].xaxis.set_ticks_position('bottom')
axes[0].yaxis.set_ticks_position('left')
axes[0].set_xticks([70,80,90,100], minor=True)
axes[0].set_yticks([], minor=True)
for idx in range(len(bars1)):
    
    sampled_x = bars1[idx]
    top_x = bars2[idx]
    rn_x = bars4[idx]
    un_x  = bars3[idx]
    
    x_min = min(sampled_x, top_x, rn_x, un_x)
    x_max = max(sampled_x, top_x, rn_x, un_x)
    
    axes[0].fill_betweenx([r1[idx]-0.16, r2[idx]+0.16], x_min, x_max, color='grey', alpha=0.3 ,edgecolor=None)

axes[0].text(0.5, 1.05, r'AUC on Pubmed Subgraph with 1500 nodes', transform=axes[0].transAxes, ha='center', va='center', bbox=dict(facecolor='none', edgecolor='none', boxstyle='round', alpha=0.0), fontsize=6)
axes[0].tick_params(labelsize=5)

plt.delaxes(axes[1])
plt.tight_layout()
fig.savefig('C:\\Users\\WENJIA\\Downloads\\corrsi\\pubmed_auc_1500.pdf', dpi=800)
# Out:
# C:\Users\WENJIA\AppData\Local\Temp\ipykernel_51496\2790835948.py:88: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %%
import numpy as np
import matplotlib.pyplot as plt
import scienceplots
plt.style.use('science')
plt.style.use('nature')

my_dpi = 96
fig, axes = plt.subplots(1, 2, figsize=(2, 2.4), gridspec_kw={'width_ratios': [2, 0.2], 'wspace': 0.3}, dpi=800) 

bars1 =[95.7683,94.25,95.7989,95.5242,93.3089,85.3005,93.4488,93.506,94.6321,91.21,94.9518,79.7217]
bars2 = [92.57,89.2871,94.2289,94.4737,92.4566,81.7951,90.0421,88.8948,94.7005,88.2741,91.5919,78.3226]
yer1 = [0.53,0.44,0.57,0.27,0.58,0.51,0.69,0.54,0.46,0.56,0.29,0.81]
yer2 = [0.35,0.27,0.39,0.48,0.62,0.57,0.84,0.89,0.63,0.42,0.53,0.73]

bars3 = [89.52]*len(bars1)
yer3 = [0.39]*len(bars1)

# bars4 = [0.954957, 0.952167,0.954865 ,0.947507,0.92314 ,0.906182,0.939471 ,0.936735,0.944635,0.939174,0.938962,0.876123 ]
# yer4 = [0 for _ in range(len(bars4))]


bars4 = [0.956258,0.953398, 0.957478,0.949039,0.926755 ,0.910780,0.940104,0.936224,0.944631,0.942276 ,0.943982,0.881776  ]
yer4  = [0 for _ in range(len(bars4))]

bars4 = [x*100 for x in bars4]

yer4  = [x*100 for x in yer4]
labels = ['Degree', 'Core', 'Pagerank', 'Betweenness', 'Closeness', 'Eigenvector', 'Gravitydegree', 'Gravitycore', 'Gravitypagerank', 'Gravitybetweenness', 'Gravitycloseness', 'Gravityeigenvector']


bars1 = bars1[::-1]
bars2 = bars2[::-1]
yer1= yer1[::-1]
yer2= yer2[::-1]
bars3= bars3[::-1]
yer3= yer3[::-1]
bars4= bars4[::-1]
yer4= yer4[::-1]
labels= labels[::-1]


r1 = np.arange(len(bars1))
r2 = r1 
r3 = r1 

axes[0].errorbar(bars3, r3, xerr=yer3, fmt='o', c='#7FB1D2', ecolor='white', 
                 markeredgecolor='black', markeredgewidth=0.5, elinewidth=0, capsize=0, label='Uniform nodes',alpha=0.8)
axes[0].errorbar(bars4, r1, xerr=yer4, fmt='o', c='#A392BA', ecolor='white', markeredgecolor='black', markeredgewidth=0.5,elinewidth=1, capsize=0, label='Rejected nodes',alpha=0.8)

axes[0].errorbar(bars1, r1, xerr=yer1, fmt='o', c='#FB8071', ecolor='white', markeredgecolor='black', markeredgewidth=0.5,elinewidth=1, capsize=0, label='Sampled nodes',alpha=0.8)
axes[0].errorbar(bars2, r2, xerr=yer2, fmt='o', c='#FCB364', ecolor='white', markeredgecolor='black', markeredgewidth=0.5, elinewidth=0, capsize=0, label='Top nodes',alpha=0.8)
# axes[0].errorbar(bars3, r3, xerr=yer3, fmt='o', c='#7FB1D2', ecolor='white', markeredgecolor='black', markeredgewidth=0.5, elinewidth=0, capsize=0, label='Uniform nodes',alpha=0.8)




axes[0].set_yticks(r1 )
axes[0].set_yticklabels(labels, fontsize=6)

axes[0].set_xlabel('Area Under Precision Recall(\%)', fontsize=5)
# axes[0].set_ylabel('Metrics', fontsize=4)

axes[0].set_xlim((75, 100))  
axes[0].set_ylim((-1, 12))
axes[0].legend(loc=[0.9,0.7], fontsize=5)
axes[0].grid (False)
axes[0].set_xticks([70,80,90,100])
axes[0].spines['top'].set_visible(False)
axes[0].spines['right'].set_visible(False)
axes[0].xaxis.set_ticks_position('bottom')
axes[0].yaxis.set_ticks_position('left')
axes[0].set_xticks([70,80,90,100], minor=True)
axes[0].set_yticks([], minor=True)
for idx in range(len(bars1)):
    
    sampled_x = bars1[idx]
    top_x = bars2[idx]
    rn_x = bars4[idx]
    un_x  = bars3[idx]
    
    x_min = min(sampled_x, top_x, rn_x, un_x)
    x_max = max(sampled_x, top_x, rn_x, un_x)
    
    axes[0].fill_betweenx([r1[idx]-0.16, r2[idx]+0.16], x_min, x_max, color='grey', alpha=0.3 ,edgecolor=None)

axes[0].text(0.5, 1.05, r'AP on Pubmed Subgraph with 1500 nodes', transform=axes[0].transAxes, ha='center', va='center', bbox=dict(facecolor='none', edgecolor='none', boxstyle='round', alpha=0.0), fontsize=6)
axes[0].tick_params(labelsize=5)

plt.delaxes(axes[1])
plt.tight_layout()
fig.savefig('C:\\Users\\WENJIA\\Downloads\\corrsi\\pubmed_ap_300.pdf', dpi=800)
# Out:
# C:\Users\WENJIA\AppData\Local\Temp\ipykernel_51496\2518636814.py:90: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %% [markdown]
# ### CA-HepTh

# %%
import numpy as np
import matplotlib.pyplot as plt
import scienceplots
plt.style.use('science')
plt.style.use('nature')

my_dpi = 96
fig, axes = plt.subplots(1, 2, figsize=(2, 2.4), gridspec_kw={'width_ratios': [2, 0.2], 'wspace': 0.3}, dpi=800) 

bars1 =[87.8633,87.0712,87.3126,85.7658,82.1139,81.4594,85.8901,82.8115,87.3126,84.4001,84.3615,78.3631]
bars2 = [82.2135,80.4404,84.4206,83.5115,79.7907,80.7651,79.3977,80.196,80.287,77.9386,76.6242,78.5712]
yer1 = [0.53,0.44,0.57,0.27,0.58,0.51,0.69,0.54,0.46,0.56,0.29,0.81]
yer2 = [0.35,0.27,0.39,0.48,0.62,0.57,0.84,0.89,0.63,0.42,0.53,0.73]

bars3 = [79.52]*len(bars1)
yer3 = [0.39]*len(bars1)
labels = ['Degree', 'Core', 'Pagerank', 'Betweenness', 'Closeness', 'Eigenvector', 'Gravitydegree', 'Gravitycore', 'Gravitypagerank', 'Gravitybetweenness', 'Gravitycloseness', 'Gravityeigenvector']

bars4 = [0.855013,0.869972,0.861641,0.855212,0.840434 ,0.764129,0.834087,0.834628,0.848881,0.841510,0.853830,0.728985 ]
bars4 = [x*100 for x in bars4]
yer4 =  [0 for _ in range(len(bars4))]




labels = ['Degree', 'Core', 'Pagerank', 'Betweenness', 'Closeness', 'Eigenvector', 'Gravitydegree', 'Gravitycore', 'Gravitypagerank', 'Gravitybetweenness', 'Gravitycloseness', 'Gravityeigenvector']


bars1 = bars1[::-1]
bars2 = bars2[::-1]
yer1= yer1[::-1]
yer2= yer2[::-1]
bars3= bars3[::-1]
yer3= yer3[::-1]
bars4= bars4[::-1]
yer4= yer4[::-1]
labels= labels[::-1]


r1 = np.arange(len(bars1))
r2 = r1 
r3 = r1 

axes[0].errorbar(bars3, r3, xerr=yer3, fmt='o', c='#7FB1D2', ecolor='white', 
                 markeredgecolor='black', markeredgewidth=0.5, elinewidth=0, capsize=0, label='Uniform nodes',alpha=0.8)
axes[0].errorbar(bars4, r1, xerr=yer4, fmt='o', c='#A392BA', ecolor='white', markeredgecolor='black', markeredgewidth=0.5,elinewidth=1, capsize=0, label='Rejected nodes',alpha=0.8)

axes[0].errorbar(bars1, r1, xerr=yer1, fmt='o', c='#FB8071', ecolor='white', markeredgecolor='black', markeredgewidth=0.5,elinewidth=1, capsize=0, label='Sampled nodes',alpha=0.8)
axes[0].errorbar(bars2, r2, xerr=yer2, fmt='o', c='#FCB364', ecolor='white', markeredgecolor='black', markeredgewidth=0.5, elinewidth=0, capsize=0, label='Top nodes',alpha=0.8)
# axes[0].errorbar(bars3, r3, xerr=yer3, fmt='o', c='#7FB1D2', ecolor='white', markeredgecolor='black', markeredgewidth=0.5, elinewidth=0, capsize=0, label='Uniform nodes',alpha=0.8)




axes[0].set_yticks(r1 )
axes[0].set_yticklabels(labels, fontsize=6)

axes[0].set_xlabel('Area Under the Curve(\%)', fontsize=5)
# axes[0].set_ylabel('Metrics', fontsize=4)

axes[0].set_xlim((70, 100))
axes[0].set_ylim((-1, 12))
axes[0].legend(loc=[0.9,0.7], fontsize=5)
axes[0].grid (False)
axes[0].set_xticks([70,80,90,100])
axes[0].spines['top'].set_visible(False)
axes[0].spines['right'].set_visible(False)
axes[0].xaxis.set_ticks_position('bottom')
axes[0].yaxis.set_ticks_position('left')
axes[0].set_xticks([70,80,90,100], minor=True)
axes[0].set_yticks([], minor=True)
for idx in range(len(bars1)):
    
    sampled_x = bars1[idx]
    top_x = bars2[idx]
    rn_x = bars4[idx]
    un_x  = bars3[idx]
    
    x_min = min(sampled_x, top_x, rn_x, un_x)
    x_max = max(sampled_x, top_x, rn_x, un_x)
    
    axes[0].fill_betweenx([r1[idx]-0.16, r2[idx]+0.16], x_min, x_max, color='grey', alpha=0.3 ,edgecolor=None)

axes[0].text(0.5, 1.05, r'AUC on CA-HepTh Subgraph with 1000 nodes', transform=axes[0].transAxes, ha='center', va='center', bbox=dict(facecolor='none', edgecolor='none', boxstyle='round', alpha=0.0), fontsize=6)
axes[0].tick_params(labelsize=5)

plt.delaxes(axes[1])
plt.tight_layout()
fig.savefig('C:\\Users\\WENJIA\\Downloads\\corrsi\\cath_auc_1000.pdf', dpi=300)
# Out:
# C:\Users\WENJIA\AppData\Local\Temp\ipykernel_51496\2843237830.py:88: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %%
import numpy as np
import matplotlib.pyplot as plt
import scienceplots
plt.style.use('science')
plt.style.use('nature')

my_dpi = 96
fig, axes = plt.subplots(1, 2, figsize=(2, 2.4), gridspec_kw={'width_ratios': [2, 0.2], 'wspace': 0.3}, dpi=800) 


bars1 = [90.2566,89.2429,89.6746,88.4484,84.5645,84.4588,88.7489,83.4099,89.6746,85.2557,87.3516,81.2948]
bars2 = [85.3442,83.4204,87.1345,86.8085,83.4636,83.7584,83.3559,83.6907,83.5967,81.5802,83.9479,81.7515]
yer1 = [0.53,0.44,0.57,0.27,0.58,0.51,0.69,0.54,0.46,0.56,0.29,0.81]
yer2 = [0.35,0.27,0.39,0.48,0.62,0.57,0.84,0.89,0.63,0.42,0.53,0.73]

bars3 = [81.52]*len(bars1)
yer3 = [0.39]*len(bars1)
bars4 = [0.874672,0.893335,0.883643,0.878181,0.861515,0.794799, 0.865902,0.862831,0.873290,0.873699,0.877126,0.753488]
bars4 = [x*100 for x in bars4]
yer4 = [0 for _ in range(len(bars4))]
yer4  = [x*100 for x in yer4]

labels = ['Degree', 'Core', 'Pagerank', 'Betweenness', 'Closeness', 'Eigenvector', 'Gravitydegree', 'Gravitycore', 'Gravitypagerank', 'Gravitybetweenness', 'Gravitycloseness', 'Gravityeigenvector']


bars1 = bars1[::-1]
bars2 = bars2[::-1]
yer1= yer1[::-1]
yer2= yer2[::-1]
bars3= bars3[::-1]
yer3= yer3[::-1]
bars4= bars4[::-1]
yer4= yer4[::-1]
labels= labels[::-1]


r1 = np.arange(len(bars1))
r2 = r1 
r3 = r1 

axes[0].errorbar(bars3, r3, xerr=yer3, fmt='o', c='#7FB1D2', ecolor='white', 
                 markeredgecolor='black', markeredgewidth=0.5, elinewidth=0, capsize=0, label='Uniform nodes',alpha=0.8)
axes[0].errorbar(bars4, r1, xerr=yer4, fmt='o', c='#A392BA', ecolor='white', markeredgecolor='black', markeredgewidth=0.5,elinewidth=1, capsize=0, label='Rejected nodes',alpha=0.8)

axes[0].errorbar(bars1, r1, xerr=yer1, fmt='o', c='#FB8071', ecolor='white', markeredgecolor='black', markeredgewidth=0.5,elinewidth=1, capsize=0, label='Sampled nodes',alpha=0.8)
axes[0].errorbar(bars2, r2, xerr=yer2, fmt='o', c='#FCB364', ecolor='white', markeredgecolor='black', markeredgewidth=0.5, elinewidth=0, capsize=0, label='Top nodes',alpha=0.8)
# axes[0].errorbar(bars3, r3, xerr=yer3, fmt='o', c='#7FB1D2', ecolor='white', markeredgecolor='black', markeredgewidth=0.5, elinewidth=0, capsize=0, label='Uniform nodes',alpha=0.8)




axes[0].set_yticks(r1 )
axes[0].set_yticklabels(labels, fontsize=6)

axes[0].set_xlabel('Area Under Precision Recall(\%)', fontsize=5)
# axes[0].set_ylabel('Metrics', fontsize=4)

axes[0].set_xlim((70, 100))
axes[0].set_ylim((-1, 12))
axes[0].legend(loc=[0.9,0.7], fontsize=5)
axes[0].grid (False)
axes[0].set_xticks([70,80,90,100])
axes[0].spines['top'].set_visible(False)
axes[0].spines['right'].set_visible(False)
axes[0].xaxis.set_ticks_position('bottom')
axes[0].yaxis.set_ticks_position('left')
axes[0].set_xticks([70,80,90,100], minor=True)
axes[0].set_yticks([], minor=True)
for idx in range(len(bars1)):
    
    sampled_x = bars1[idx]
    top_x = bars2[idx]
    rn_x = bars4[idx]
    un_x  = bars3[idx]
    
    x_min = min(sampled_x, top_x, rn_x, un_x)
    x_max = max(sampled_x, top_x, rn_x, un_x)
    
    axes[0].fill_betweenx([r1[idx]-0.16, r2[idx]+0.16], x_min, x_max, color='grey', alpha=0.3 ,edgecolor=None)

axes[0].text(0.5, 1.05, r'AP on CA-HepTh Subgraph with 1000 nodes', transform=axes[0].transAxes, ha='center', va='center', bbox=dict(facecolor='none', edgecolor='none', boxstyle='round', alpha=0.0), fontsize=6)
axes[0].tick_params(labelsize=5)

plt.delaxes(axes[1])
plt.tight_layout()
fig.savefig('C:\\Users\\WENJIA\\Downloads\\corrsi\\cath_ap_1000.pdf', dpi=300)
# Out:
# C:\Users\WENJIA\AppData\Local\Temp\ipykernel_51496\1646436569.py:85: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %% [markdown]
# ### CA-CondMat

# %%
import numpy as np
import matplotlib.pyplot as plt
import scienceplots
plt.style.use('science')
plt.style.use('nature')

my_dpi = 96
fig, axes = plt.subplots(1, 2, figsize=(2, 2.4), gridspec_kw={'width_ratios': [2, 0.2], 'wspace': 0.3}, dpi=800) 

bars1 =[91.671,92.6501,93.2314,89.5652,88.8446,82.1013,87.4771,89.0519,90.2829,85.1205,87.0979,79.3938]
bars2 = [88.326,84.4141,88.7892,89.0561,86.3818,84.6731,83.5472,83.1858,83.4117,83.3414,85.6457,81.6576]
yer1 = [0.53,0.44,0.57,0.27,0.58,0.51,0.69,0.54,0.46,0.56,0.29,0.81]
yer2 = [0.35,0.27,0.39,0.48,0.62,0.57,0.84,0.89,0.63,0.42,0.53,0.73]

bars3 = [89.52]*len(bars1)
yer3 = [0.39]*len(bars1)
bars4 = [0.919713,0.897153, 0.900363, 0.894764 ,0.890675,0.871883 ,0.895945 ,0.898198, 0.889734  ,0.856305 , 0.878313 , 0.834012]
bars4 = [x*100 for x in bars4]
yer4 = [0]*len(bars4)






labels = ['Degree', 'Core', 'Pagerank', 'Betweenness', 'Closeness', 'Eigenvector', 'Gravitydegree', 'Gravitycore', 'Gravitypagerank', 'Gravitybetweenness', 'Gravitycloseness', 'Gravityeigenvector']

bars1 = bars1[::-1]
bars2 = bars2[::-1]
yer1= yer1[::-1]
yer2= yer2[::-1]
bars3= bars3[::-1]
yer3= yer3[::-1]
bars4= bars4[::-1]
yer4= yer4[::-1]
labels= labels[::-1]


r1 = np.arange(len(bars1))
r2 = r1 
r3 = r1 
r4 = r1


axes[0].errorbar(bars1, r1, xerr=yer1, fmt='o', c='#FB8071', ecolor='white', markeredgecolor='black', markeredgewidth=0.5,elinewidth=1, capsize=0, label='Sampled nodes',alpha=0.8)
axes[0].errorbar(bars2, r2, xerr=yer2, fmt='o', c='#FCB364', ecolor='white', markeredgecolor='black', markeredgewidth=0.5, elinewidth=0, capsize=0, label='Top nodes',alpha=0.8)
axes[0].errorbar(bars4, r1, xerr=yer4, fmt='o', c='#A392BA', ecolor='white', markeredgecolor='black', markeredgewidth=0.5,elinewidth=1, capsize=0, label='Rejected nodes',alpha=0.8)
axes[0].errorbar(bars3, r3, xerr=yer3[0], fmt='o', c='#7FB1D2', ecolor='white', 
                 markeredgecolor='black', markeredgewidth=0.5, elinewidth=0, capsize=0, label='Uniform nodes',alpha=0.8)

axes[0].set_yticks(r1 )
axes[0].set_yticklabels(labels, fontsize=6)

axes[0].set_xlabel('Area Under the Curve(\%)', fontsize=5)
# axes[0].set_ylabel('Metrics', fontsize=4)

axes[0].set_xlim((70, 100))
axes[0].set_ylim((-1, 12))
axes[0].legend(loc=[0.9,0.7], fontsize=5)
axes[0].grid (False)
axes[0].set_xticks([70,80,90,100])
axes[0].spines['top'].set_visible(False)
axes[0].spines['right'].set_visible(False)
axes[0].xaxis.set_ticks_position('bottom')
axes[0].yaxis.set_ticks_position('left')
axes[0].set_xticks([70,80,90,100], minor=True)
axes[0].set_yticks([], minor=True)
for idx in range(len(bars1)):
    
    sampled_x = bars1[idx]
    top_x = bars2[idx]
    rn_x = bars4[idx]
    un_x  = bars3[idx]
    
    x_min = min(sampled_x, top_x, rn_x, un_x)
    x_max = max(sampled_x, top_x, rn_x, un_x)
    
    axes[0].fill_betweenx([r1[idx]-0.16, r2[idx]+0.16], x_min, x_max, color='grey', alpha=0.3 ,edgecolor=None)

axes[0].text(0.5, 1.05, r'AUC on CA-CondMat Subgraph with 1500 nodes', transform=axes[0].transAxes, ha='center', va='center', bbox=dict(facecolor='none', edgecolor='none', boxstyle='round', alpha=0.0), fontsize=6)
axes[0].tick_params(labelsize=5)

plt.delaxes(axes[1])
plt.tight_layout()
fig.savefig('C:\\Users\\WENJIA\\Downloads\\corrsi\\cmat_auc_1500.pdf', dpi=800)
# Out:
# C:\Users\WENJIA\AppData\Local\Temp\ipykernel_51496\1321640685.py:84: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('science')
plt.style.use('nature')

my_dpi = 96
fig, axes = plt.subplots(1, 2, figsize=(2, 2.4), gridspec_kw={'width_ratios': [2, 0.2], 'wspace': 0.3}, dpi=800) 

bars1 = [92.916,93.7517,94.3505,91.0292,89.7182,84.9416,89.3214,90.8428,91.8318,87.1689,88.5538,82.1116]
bars2 = [90.359,86.7675,90.2834,90.5814,88.2153,87.055,85.9914,85.5027,85.7214,85.5005,87.6235,83.871]
yer1 = [0.53,0.44,0.57,0.27,0.58,0.51,0.69,0.54,0.46,0.56,0.29,0.81]
yer2 = [0.35,0.27,0.39,0.48,0.62,0.57,0.84,0.89,0.63,0.42,0.53,0.73]

bars3 = [78.52]*len(bars1)
yer3 = [0.39]*len(bars1)
bars4 = [0.928039, 0.908018 ,0.906460,0.903374, 0.899506,0.893125,0.911106,0.911274,0.900562 , 0.874005 , 0.888682 , 0.856784]
bars4 = [x*100 for x in bars4]
yer4 = [0]*len(bars4)
labels = ['Degree', 'Core', 'Pagerank', 'Betweenness', 'Closeness', 'Eigenvector', 'Gravitydegree', 'Gravitycore', 'Gravitypagerank', 'Gravitybetweenness', 'Gravitycloseness', 'Gravityeigenvector']



bars1 = bars1[::-1]
bars2 = bars2[::-1]
bars3 = bars3[::-1]
bars4 = bars4[::-1]
labels = labels[::-1]



r1 = np.arange(len(bars1))
r2 = r1 
r3 = r1 

axes[0].errorbar(bars2, r2, xerr=yer2, fmt='o', c='#FCB364', ecolor='white', markeredgecolor='black', markeredgewidth=0.5, elinewidth=0, capsize=0, label='Top nodes',alpha=0.8)
axes[0].errorbar(bars4, r1, xerr=yer4, fmt='o', c='#A392BA', ecolor='white', markeredgecolor='black', markeredgewidth=0.5,elinewidth=1, capsize=0, label='Rejected nodes',alpha=0.8)
axes[0].errorbar(bars3, r3, xerr=yer3, fmt='o', c='#7FB1D2', ecolor='white', 
                 markeredgecolor='black', markeredgewidth=0.5, elinewidth=0, capsize=0, label='Uniform nodes',alpha=0.8)
axes[0].errorbar(bars1, r1, xerr=yer1, fmt='o', c='#FB8071', ecolor='white', markeredgecolor='black', markeredgewidth=0.5,elinewidth=1, capsize=0, label='Sampled nodes',alpha=0.8)

axes[0].set_yticks(r1 ) 
axes[0].set_yticklabels(labels, fontsize=6)
axes[0].set_xlabel('Area Under Precision Recall(\%)', fontsize=5)  
# axes[0].set_ylabel('Metrics', fontsize=4)
axes[0].set_xlim((75, 100))  
axes[0].set_ylim((-1, 12))
axes[0].legend(loc=[0.9,0.7], fontsize=5)
axes[0].grid (False)
axes[0].set_xticks([70,80,90,100])
axes[0].spines['top'].set_visible(False)
axes[0].spines['right'].set_visible(False)
axes[0].xaxis.set_ticks_position('bottom')
axes[0].yaxis.set_ticks_position('left')
axes[0].set_xticks([70,80,90,100], minor=True)
axes[0].set_yticks([], minor=True)
for idx in range(len(bars1)):
    
    sampled_x = bars1[idx]
    top_x = bars2[idx]
    rn_x  = bars4[idx]
    un_x = bars3[idx]
    
    x_min = min(sampled_x, top_x, un_x, rn_x)
    x_max = max(sampled_x, top_x, un_x, rn_x)
    axes[0].fill_betweenx([r1[idx]-0.16, r2[idx]+0.16], x_min, x_max, color='grey', alpha=0.3 ,edgecolor=None)  

axes[0].text(0.5, 1.05, r'AP on CA-CondMat Subgraph with 1500 nodes', transform=axes[0].transAxes, ha='center', va='center', bbox=dict(facecolor='none', edgecolor='none', boxstyle='round', alpha=0.0), fontsize=6)
axes[0].tick_params(labelsize=5)

plt.delaxes(axes[1])
plt.tight_layout()
fig.savefig('C:\\Users\\WENJIA\\Downloads\\corrsi\\cmat_ap_1500.pdf', dpi=400)
# Out:
# C:\Users\WENJIA\AppData\Local\Temp\ipykernel_51496\2843255811.py:71: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %% [markdown]
# ## Small World 3000

# %%
import numpy as np
import matplotlib.pyplot as plt
import scienceplots
plt.style.use('science')
plt.style.use('nature')

my_dpi = 96
fig, axes = plt.subplots(1, 2, figsize=(2, 2.4), gridspec_kw={'width_ratios': [2, 0.2], 'wspace': 0.3}, dpi=800) 

bars1 = [71.94,71.36,71.54,68.25,68.79,68.69,70.46,71.42,68.22,68.88]
bars2 = [63.81,58.92,64.27,62.33,58.4,62.64,63.28,64.08,59.86,61.03]
yer1 = [0.53,0.44,0.57,0.27,0.58,0.51,0.69,0.54,0.46,0.56]
yer2 = [0.35,0.27,0.39,0.48,0.62,0.57,0.84,0.89,0.63,0.42]

bars3 = [60.52]*len(bars1)
yer3 = [0.39]*len(bars1)


bars4 =  [0.677140,0.656872,0.682433,0.693506,0.654533,0.664722,0.699050,0.682029,0.694964,0.667258]
bars4 = [x *100 for x in bars4]
yer4 = [0]*len(bars4)








labels = ['Degree', 'Core', 'Pagerank', 'Betweenness', 'Closeness',  'Gravitydegree', 'Gravitycore', 'Gravitypagerank', 'Gravitybetweenness', 'Gravitycloseness', ]


bars1 = bars1[::-1]
bars2 = bars2[::-1]
bars3 = bars3[::-1]
bars4 = bars4[::-1]
labels = labels[::-1]

r1 = np.arange(len(bars1))
r2 = r1 
r3 = r1 

axes[0].errorbar(bars1, r1, xerr=yer1, fmt='o', c='#FB8071', ecolor='white', markeredgecolor='black', markeredgewidth=0.5,elinewidth=1, capsize=0, label='Sampled nodes',alpha=0.8)
axes[0].errorbar(bars2, r2, xerr=yer2, fmt='o', c='#FCB364', ecolor='white', markeredgecolor='black', markeredgewidth=0.5, elinewidth=0, capsize=0, label='Top nodes',alpha=0.8)
axes[0].errorbar(bars4, r1, xerr=yer4, fmt='o', c='#A392BA', ecolor='white', markeredgecolor='black', markeredgewidth=0.5,elinewidth=1, capsize=0, label='Rejected nodes',alpha=0.8)

axes[0].errorbar(bars3, r3, xerr=yer3[0], fmt='o', c='#7FB1D2', ecolor='white', 
                 markeredgecolor='black', markeredgewidth=0.5, elinewidth=0, capsize=0, label='Uniform nodes',alpha=0.8)

axes[0].set_yticks(r1 )
axes[0].set_yticklabels(labels, fontsize=6)

axes[0].set_xlabel('Area Under the Curve(\%)', fontsize=5)
# axes[0].set_ylabel('Metrics', fontsize=4)

axes[0].set_xlim((50, 90))
axes[0].set_ylim((-1, 10))
axes[0].legend(loc=[0.8,0.7], fontsize=5)
axes[0].grid (False)
axes[0].set_xticks([60,70,80,90,100])
axes[0].spines['top'].set_visible(False)
axes[0].spines['right'].set_visible(False)
axes[0].xaxis.set_ticks_position('bottom')
axes[0].yaxis.set_ticks_position('left')
axes[0].set_xticks([60,70,80,90,100], minor=True)
axes[0].set_yticks([], minor=True)
for idx in range(len(bars1)):
    
    sampled_x = bars1[idx]
    top_x = bars2[idx]
    rn_x = bars4[idx]
    un_x = bars3[idx]

    
    x_min = min(sampled_x, top_x, un_x, rn_x)
    x_max = max(sampled_x, top_x, un_x, rn_x)

    
    axes[0].fill_betweenx([r1[idx]-0.16, r2[idx]+0.16], x_min, x_max, color='grey', alpha=0.3 ,edgecolor=None)

axes[0].text(0.5, 1.05, r'AUC on Small World 3000 Subgraph with 300 nodes', transform=axes[0].transAxes, ha='center', va='center', bbox=dict(facecolor='none', edgecolor='none', boxstyle='round', alpha=0.0), fontsize=6)
axes[0].tick_params(labelsize=5)

plt.delaxes(axes[1])
plt.tight_layout()
fig.savefig('C:\\Users\\WENJIA\\Downloads\\corrsi\\wk3k_auc_300.pdf', dpi=800)
# Out:
# C:\Users\WENJIA\AppData\Local\Temp\ipykernel_51496\590731416.py:85: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %%
import numpy as np
import matplotlib.pyplot as plt
import scienceplots
plt.style.use('science')
plt.style.use('nature')

my_dpi = 96
fig, axes = plt.subplots(1, 2, figsize=(2, 2.4), gridspec_kw={'width_ratios': [2, 0.2], 'wspace': 0.3}, dpi=800) 

bars1 = [75.12,74.04,74.96,70.38,71.63,71.33,72.68,71.15,70.94,71.19]
bars2 = [68.68,61.37,68.34,66.15,61.28,67.16,67.86,68.16,63.25,65.02]
yer1 = [0.53,0.44,0.57,0.27,0.58,0.51,0.69,0.54,0.46,0.56]
yer2 = [0.35,0.27,0.39,0.48,0.62,0.57,0.84,0.89,0.63,0.42]

bars3 = [61.34]*len(bars1)
yer3 = [0.39]*len(bars1)


bars4 =  [0.676416,0.664793,0.686581,0.710348,0.660731,0.677672,0.710502,0.700681,0.715625,0.687173]
bars4  = [x*100 for x in bars4]
yer4 = [0]*len(bars4)
labels = ['Degree', 'Core', 'Pagerank', 'Betweenness', 'Closeness',  'Gravitydegree', 'Gravitycore', 'Gravitypagerank', 'Gravitybetweenness', 'Gravitycloseness', ]

bars1 = bars1[::-1]
bars2 = bars2[::-1]
bars4 = bars4[::-1]
bars3 = bars3[::-1]
labels = labels[::-1]

r1 = np.arange(len(bars1))
r2 = r1 
r3 = r1 

axes[0].errorbar(bars1, r1, xerr=yer1, fmt='o', c='#FB8071', ecolor='white', markeredgecolor='black', markeredgewidth=0.5,elinewidth=1, capsize=0, label='Sampled nodes',alpha=0.8)
axes[0].errorbar(bars2, r2, xerr=yer2, fmt='o', c='#FCB364', ecolor='white', markeredgecolor='black', markeredgewidth=0.5, elinewidth=0, capsize=0, label='Top nodes',alpha=0.8)
axes[0].errorbar(bars4, r1, xerr=yer4, fmt='o', c='#A392BA', ecolor='white', markeredgecolor='black', markeredgewidth=0.5,elinewidth=1, capsize=0, label='Rejected nodes',alpha=0.8)
axes[0].errorbar(bars3, r3, xerr=yer3[0], fmt='o', c='#7FB1D2', ecolor='white', 
                 markeredgecolor='black', markeredgewidth=0.5, elinewidth=0, capsize=0, label='Uniform nodes',alpha=0.8)

axes[0].set_yticks(r1 )
axes[0].set_yticklabels(labels, fontsize=6)

axes[0].set_xlabel('Area Under Precision Recall(\%)', fontsize=5)
# axes[0].set_ylabel('Metrics', fontsize=4)

axes[0].set_xlim((50, 90))
axes[0].set_ylim((-1, 10))
axes[0].legend(loc=[0.8,0.7], fontsize=5)
axes[0].grid (False)
axes[0].set_xticks([60,70,80,90,100])
axes[0].spines['top'].set_visible(False)
axes[0].spines['right'].set_visible(False)
axes[0].xaxis.set_ticks_position('bottom')
axes[0].yaxis.set_ticks_position('left')
axes[0].set_xticks([60,70,80,90,100], minor=True)
axes[0].set_yticks([], minor=True)
for idx in range(len(bars1)):
    
    sampled_x = bars1[idx]
    top_x = bars2[idx]
    rn_x = bars4[idx]
    un_x  = bars3[idx]
    
    x_min = min(sampled_x, top_x, rn_x, un_x)
    x_max = max(sampled_x, top_x, rn_x, un_x)
    
    axes[0].fill_betweenx([r1[idx]-0.16, r2[idx]+0.16], x_min, x_max, color='grey', alpha=0.3 ,edgecolor=None)
axes[0].text(0.5, 1.05, r'AP on Small World 3000  Subgraph with 300 nodes', transform=axes[0].transAxes, ha='center', va='center', bbox=dict(facecolor='none', edgecolor='none', boxstyle='round', alpha=0.0), fontsize=6)
axes[0].tick_params(labelsize=5)

plt.delaxes(axes[1])
plt.tight_layout()
fig.savefig('C:\\Users\\WENJIA\\Downloads\\corrsi\\ws3k_ap_300.pdf', dpi=800)
# Out:
# C:\Users\WENJIA\AppData\Local\Temp\ipykernel_51496\2655142594.py:72: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %%
import numpy as np
import matplotlib.pyplot as plt
import scienceplots
plt.style.use('science')
plt.style.use('nature')

my_dpi = 96
fig, axes = plt.subplots(1, 2, figsize=(2, 2.4), gridspec_kw={'width_ratios': [2, 0.2], 'wspace': 0.3}, dpi=800) 

bars1 =[75.6618,76.8242,76.0468,72.3497,73.0787,75.0161,77.2182,77.0882,70.7303,73.2708]
bars2 = [69.9727,60.7427,70.7028,66.9437,65.2053,66.6904,68.9116,66.9328,63.5692,67.2488]
yer1 = [0.53,0.44,0.57,0.27,0.58,0.51,0.69,0.54,0.46,0.56]
yer2 = [0.35,0.27,0.39,0.48,0.62,0.57,0.84,0.89,0.63,0.42]

bars3 = [67.92]*len(bars1)
yer3 = [0.39]*len(bars1)

bars4 = [0.751531,0.770944,0.761423, 0.731091,  0.768346, 0.773171,0.759462,0.767617,0.749516,0.758858 ]
bars4 = [x *100 for x in bars4]
yer4 = [0]*len(bars4)



labels = ['Degree', 'Core', 'Pagerank', 'Betweenness', 'Closeness',  'Gravitydegree', 'Gravitycore', 'Gravitypagerank', 'Gravitybetweenness', 'Gravitycloseness', ]

bars1 = bars1[::-1]
bars2 = bars2[::-1]
yer1= yer1[::-1]
yer2= yer2[::-1]
bars3= bars3[::-1]
yer3= yer3[::-1]
bars4= bars4[::-1]
yer4= yer4[::-1]
labels= labels[::-1]

r1 = np.arange(len(bars1))
r2 = r1 
r3 = r1 

axes[0].errorbar(bars1, r1, xerr=yer1, fmt='o', c='#FB8071', ecolor='white', markeredgecolor='black', markeredgewidth=0.5,elinewidth=1, capsize=0, label='Sampled nodes',alpha=0.8)
axes[0].errorbar(bars2, r2, xerr=yer2, fmt='o', c='#FCB364', ecolor='white', markeredgecolor='black', markeredgewidth=0.5, elinewidth=0, capsize=0, label='Top nodes',alpha=0.8)
axes[0].errorbar(bars4, r1, xerr=yer4, fmt='o', c='#A392BA', ecolor='white', markeredgecolor='black', markeredgewidth=0.5,elinewidth=1, capsize=0, label='Rejected nodes',alpha=0.8)
axes[0].errorbar(bars3, r3, xerr=yer3, fmt='o', c='#7FB1D2', ecolor='white', 
                 markeredgecolor='black', markeredgewidth=0.5, elinewidth=0, capsize=0, label='Uniform nodes',alpha=0.8)

axes[0].set_yticks(r1 )
axes[0].set_yticklabels(labels, fontsize=6)

axes[0].set_xlabel('Area Under the Curve(\%)', fontsize=5)
# axes[0].set_ylabel('Metrics', fontsize=4)

axes[0].set_xlim((50, 90))
axes[0].set_ylim((-1, 10))
axes[0].legend(loc=[0.8,0.7], fontsize=5)
axes[0].grid (False)
axes[0].set_xticks([60,70,80,90,100])
axes[0].spines['top'].set_visible(False)
axes[0].spines['right'].set_visible(False)
axes[0].xaxis.set_ticks_position('bottom')
axes[0].yaxis.set_ticks_position('left')
axes[0].set_xticks([60,70,80,90,100], minor=True)
axes[0].set_yticks([], minor=True)
for idx in range(len(bars1)):
    
    sampled_x = bars1[idx]
    top_x = bars2[idx]
    rn_x = bars4[idx]
    un_x  = bars3[idx]
    
    x_min = min(sampled_x, top_x, rn_x, un_x)
    x_max = max(sampled_x, top_x, rn_x, un_x)

    
    axes[0].fill_betweenx([r1[idx]-0.16, r2[idx]+0.16], x_min, x_max, color='grey', alpha=0.3 ,edgecolor=None)

axes[0].text(0.5, 1.05, r'AUC on Small World 10000 Subgraph with 1000 nodes', transform=axes[0].transAxes, ha='center', va='center', bbox=dict(facecolor='none', edgecolor='none', boxstyle='round', alpha=0.0), fontsize=6)
axes[0].tick_params(labelsize=5)

plt.delaxes(axes[1])
plt.tight_layout()
fig.savefig('C:\\Users\\WENJIA\\Downloads\\corrsi\\ws1w_auc_1000.pdf', dpi=800)
# Out:
# C:\Users\WENJIA\AppData\Local\Temp\ipykernel_51496\2685114831.py:80: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %%
import numpy as np
import matplotlib.pyplot as plt
import scienceplots
plt.style.use('science')
plt.style.use('nature')

my_dpi = 96
fig, axes = plt.subplots(1, 2, figsize=(2, 2.4), gridspec_kw={'width_ratios': [2, 0.2], 'wspace': 0.3}, dpi=800) 

bars1 =[76.707,79.2155,78.2069,70.7157,71.7214,76.5648,78.2695,78.9046,69.4226,71.7001]
bars2 = [71.8367,63.3554,72.9418,69.4637,67.6004,67.6381,70.5929,68.3696,66.3659,70.0029]
yer1 = [0.53,0.44,0.57,0.27,0.58,0.51,0.69,0.54,0.46,0.56]
yer2 = [0.35,0.27,0.39,0.48,0.62,0.57,0.84,0.89,0.63,0.42]

bars3 = [70.34]*len(bars1)
yer3 = [0.39]*len(bars1)

bars4 = [0.761046,0.780229,0.777612,0.728480,0.788483,0.779949,0.773469,0.790983,0.766563,0.769409]
yer4 =[0]*len(bars4)
bars4 = [x *100 for x in bars4]

labels = ['Degree', 'Core', 'Pagerank', 'Betweenness', 'Closeness',  'Gravitydegree', 'Gravitycore', 'Gravitypagerank', 'Gravitybetweenness', 'Gravitycloseness', ]
bars1 = bars1[::-1]
bars2 = bars2[::-1]
yer1= yer1[::-1]
yer2= yer2[::-1]
bars3= bars3[::-1]
yer3= yer3[::-1]
bars4= bars4[::-1]
yer4= yer4[::-1]
labels= labels[::-1]
r1 = np.arange(len(bars1))
r2 = r1 
r3 = r1 

axes[0].errorbar(bars1, r1, xerr=yer1, fmt='o', c='#FB8071', ecolor='white', markeredgecolor='black', markeredgewidth=0.5,elinewidth=1, capsize=0, label='Sampled nodes',alpha=0.8)
axes[0].errorbar(bars2, r2, xerr=yer2, fmt='o', c='#FCB364', ecolor='white', markeredgecolor='black', markeredgewidth=0.5, elinewidth=0, capsize=0, label='Top nodes',alpha=0.8)
axes[0].errorbar(bars4, r1, xerr=yer4, fmt='o', c='#A392BA', ecolor='white', markeredgecolor='black', markeredgewidth=0.5,elinewidth=1, capsize=0, label='Rejected nodes',alpha=0.8)
axes[0].errorbar(bars3, r3, xerr=yer3, fmt='o', c='#7FB1D2', ecolor='white', 
                 markeredgecolor='black', markeredgewidth=0.5, elinewidth=0, capsize=0, label='Uniform nodes',alpha=0.8)

axes[0].set_yticks(r1 )
axes[0].set_yticklabels(labels, fontsize=6)

axes[0].set_xlabel('Area Under Precision Recall(\%)', fontsize=5)
# axes[0].set_ylabel('Metrics', fontsize=4)

axes[0].set_xlim((50, 90))
axes[0].set_ylim((-1, 10))
axes[0].legend(loc=[0.8,0.7], fontsize=5)
axes[0].grid (False)
axes[0].set_xticks([60,70,80,90,100])
axes[0].spines['top'].set_visible(False)
axes[0].spines['right'].set_visible(False)
axes[0].xaxis.set_ticks_position('bottom')
axes[0].yaxis.set_ticks_position('left')
axes[0].set_xticks([60,70,80,90,100], minor=True)
axes[0].set_yticks([], minor=True)

for idx in range(len(bars1)):
    
    sampled_x = bars1[idx]
    top_x = bars2[idx]
    rn_x = bars4[idx]
    un_x  = bars3[idx]
    
    x_min = min(sampled_x, top_x, rn_x, un_x)
    x_max = max(sampled_x, top_x, rn_x, un_x)
    
    axes[0].fill_betweenx([r1[idx]-0.16, r2[idx]+0.16], x_min, x_max, color='grey', alpha=0.3 ,edgecolor=None)
axes[0].text(0.5, 1.05, r'AP on Small World 10000 Subgraph with 1000 nodes', transform=axes[0].transAxes, ha='center', va='center', bbox=dict(facecolor='none', edgecolor='none', boxstyle='round', alpha=0.0), fontsize=6)
axes[0].tick_params(labelsize=5)

plt.delaxes(axes[1])
plt.tight_layout()
fig.savefig('C:\\Users\\WENJIA\\Downloads\\corrsi\\wk1w_ap_1000.pdf', dpi=800)
# Out:
# C:\Users\WENJIA\AppData\Local\Temp\ipykernel_51496\3026436218.py:75: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %%
import numpy as np
import matplotlib.pyplot as plt
import scienceplots
plt.style.use('science')
plt.style.use('nature')

my_dpi = 96
fig, axes = plt.subplots(1, 2, figsize=(2, 2.4), gridspec_kw={'width_ratios': [2, 0.2], 'wspace': 0.3}, dpi=800) 

bars1 =[0.764619,0.847751,0.814117 , 0.762705,  0.856338 ,  0.779856, 0.816775,0.787708,0.830882,0.79031,0.805426,0.80278]
bars2 = [ 0.632741,0.623133 , 0.648952  ,0.683897  ,0.646537 , 0.610212,0.70486,0.811776,0.721318,0.688947,0.74635,0.730364]
yer1 = [0 for _ in range(len(bars1))]
yer2 = [0 for _ in range(len(bars2))]

bars3 = [0.737113]*len(bars1)
yer3 = [0.39]*len(bars1)
labels = ['Degree', 'Core', 'Pagerank', 'Betweenness', 'Closeness', 'Eigenvector', 'Gravitydegree', 'Gravitycore', 'Gravitypagerank', 'Gravitybetweenness', 'Gravitycloseness', 'Gravityeigenvector']

bars4 = [0.847867 ,0.854825 , 0.791444 , 0.824270 , 0.803283 , 0.828070,  0.832476 , 0.793368 , 0.852546 , 0.803705 , 0.844932 , 0.853012]
# bars4 = [x*100 for x in bars4]
yer4 =  [0 for _ in range(len(bars4))]



bars1 = [x*100 for x in bars1]
bars2 = [x*100 for x in bars2]
bars3 = [x*100 for x in bars3]
bars4 = [x*100 for x in bars4]



yer4 =  [0 for _ in range(len(bars4))]





labels = ['Degree', 'Core', 'Pagerank', 'Betweenness', 'Closeness', 'Eigenvector', 'Gravitydegree', 'Gravitycore', 'Gravitypagerank', 'Gravitybetweenness', 'Gravitycloseness', 'Gravityeigenvector']


bars1 = bars1[::-1]
bars2 = bars2[::-1]
yer1= yer1[::-1]
yer2= yer2[::-1]
bars3= bars3[::-1]
yer3= yer3[::-1]
bars4= bars4[::-1]
yer4= yer4[::-1]
labels= labels[::-1]


r1 = np.arange(len(bars1))
r2 = r1 
r3 = r1 

axes[0].errorbar(bars3, r3, xerr=yer3, fmt='o', c='#7FB1D2', ecolor='white', 
                 markeredgecolor='black', markeredgewidth=0.5, elinewidth=0, capsize=0, label='Uniform nodes',alpha=0.8)
axes[0].errorbar(bars4, r1, xerr=yer4, fmt='o', c='#A392BA', ecolor='white', markeredgecolor='black', markeredgewidth=0.5,elinewidth=1, capsize=0, label='Rejected nodes',alpha=0.8)

axes[0].errorbar(bars1, r1, xerr=yer1, fmt='o', c='#FB8071', ecolor='white', markeredgecolor='black', markeredgewidth=0.5,elinewidth=1, capsize=0, label='Sampled nodes',alpha=0.8)
axes[0].errorbar(bars2, r2, xerr=yer2, fmt='o', c='#FCB364', ecolor='white', markeredgecolor='black', markeredgewidth=0.5, elinewidth=0, capsize=0, label='Top nodes',alpha=0.8)
# axes[0].errorbar(bars3, r3, xerr=yer3, fmt='o', c='#7FB1D2', ecolor='white', markeredgecolor='black', markeredgewidth=0.5, elinewidth=0, capsize=0, label='Uniform nodes',alpha=0.8)




axes[0].set_yticks(r1 )
axes[0].set_yticklabels(labels, fontsize=6)

axes[0].set_xlabel('Area Under the Curve(\%)', fontsize=5)
# axes[0].set_ylabel('Metrics', fontsize=4)

axes[0].set_xlim((60, 100))
axes[0].set_ylim((-1, 12))
axes[0].legend(loc=[0.9,0.7], fontsize=5)
axes[0].grid (False)
axes[0].set_xticks([70,80,90,100])
axes[0].spines['top'].set_visible(False)
axes[0].spines['right'].set_visible(False)
axes[0].xaxis.set_ticks_position('bottom')
axes[0].yaxis.set_ticks_position('left')
axes[0].set_xticks([70,80,90,100], minor=True)
axes[0].set_yticks([], minor=True)
for idx in range(len(bars1)):
    
    sampled_x = bars1[idx]
    top_x = bars2[idx]
    rn_x = bars4[idx]
    un_x  = bars3[idx]
    
    x_min = min(sampled_x, top_x, rn_x, un_x)
    x_max = max(sampled_x, top_x, rn_x, un_x)
    
    axes[0].fill_betweenx([r1[idx]-0.16, r2[idx]+0.16], x_min, x_max, color='grey', alpha=0.3 ,edgecolor=None)

axes[0].text(0.5, 1.05, r'AUC on Brainfly  Subgraph with 100 nodes', transform=axes[0].transAxes, ha='center', va='center', bbox=dict(facecolor='none', edgecolor='none', boxstyle='round', alpha=0.0), fontsize=6)
axes[0].tick_params(labelsize=5)

plt.delaxes(axes[1])
plt.tight_layout()
fig.savefig('C:\\Users\\WENJIA\\Downloads\\corrsi\\brainfly_auc_1000.pdf', dpi=300)
# Out:
# C:\Users\WENJIA\AppData\Local\Temp\ipykernel_51496\482038508.py:100: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %%
import numpy as np
import matplotlib.pyplot as plt
import scienceplots
plt.style.use('science')
plt.style.use('nature')

my_dpi = 96
fig, axes = plt.subplots(1, 2, figsize=(2, 2.4), gridspec_kw={'width_ratios': [2, 0.2], 'wspace': 0.3}, dpi=800) 




bars1 =[  0.800442,  0.87147 , 0.835022 , 0.770666 , 0.875946 , 0.817944,0.877562,0.861565,0.855838,0.813029,0.829852,0.875074]
bars2 = [0.625136, 0.617911,  0.612241,  0.650832 , 0.643726 , 0.619663,0.747272,0.779023,0.7495 ,0.745213,0.776245,0.750341]
yer1 = [0 for _ in range(len(bars4))]
yer2 = [0 for _ in range(len(bars4))]

bars3 = [0.766739]*len(bars1)
yer3 = [0.39]*len(bars1)
labels = ['Degree', 'Core', 'Pagerank', 'Betweenness', 'Closeness', 'Eigenvector', 'Gravitydegree', 'Gravitycore', 'Gravitypagerank', 'Gravitybetweenness', 'Gravitycloseness', 'Gravityeigenvector']
bars4 = [0.868564 , 0.871882 , 0.817679,  0.850756, 0.843007,  0.850418,  0.856057 , 0.831019 , 0.877670,  0.832933 , 0.872966 , 0.873959]


bars1 = [x*100 for x in bars1]
bars2 = [x*100 for x in bars2]
bars3 = [x*100 for x in bars3]
bars4 = [x*100 for x in bars4]



yer4 =  [0 for _ in range(len(bars4))]





labels = ['Degree', 'Core', 'Pagerank', 'Betweenness', 'Closeness', 'Eigenvector', 'Gravitydegree', 'Gravitycore', 'Gravitypagerank', 'Gravitybetweenness', 'Gravitycloseness', 'Gravityeigenvector']


bars1 = bars1[::-1]
bars2 = bars2[::-1]
yer1= yer1[::-1]
yer2= yer2[::-1]
bars3= bars3[::-1]
yer3= yer3[::-1]
bars4= bars4[::-1]
yer4= yer4[::-1]
labels= labels[::-1]


r1 = np.arange(len(bars1))
r2 = r1 
r3 = r1 

axes[0].errorbar(bars3, r3, xerr=yer3, fmt='o', c='#7FB1D2', ecolor='white', 
                 markeredgecolor='black', markeredgewidth=0.5, elinewidth=0, capsize=0, label='Uniform nodes',alpha=0.8)
axes[0].errorbar(bars4, r1, xerr=yer4, fmt='o', c='#A392BA', ecolor='white', markeredgecolor='black', markeredgewidth=0.5,elinewidth=1, capsize=0, label='Rejected nodes',alpha=0.8)

axes[0].errorbar(bars1, r1, xerr=yer1, fmt='o', c='#FB8071', ecolor='white', markeredgecolor='black', markeredgewidth=0.5,elinewidth=1, capsize=0, label='Sampled nodes',alpha=0.8)
axes[0].errorbar(bars2, r2, xerr=yer2, fmt='o', c='#FCB364', ecolor='white', markeredgecolor='black', markeredgewidth=0.5, elinewidth=0, capsize=0, label='Top nodes',alpha=0.8)
# axes[0].errorbar(bars3, r3, xerr=yer3, fmt='o', c='#7FB1D2', ecolor='white', markeredgecolor='black', markeredgewidth=0.5, elinewidth=0, capsize=0, label='Uniform nodes',alpha=0.8)




axes[0].set_yticks(r1 )
axes[0].set_yticklabels(labels, fontsize=6)

axes[0].set_xlabel('Area Under Precision Recall(\%)', fontsize=5)
# axes[0].set_ylabel('Metrics', fontsize=4)

axes[0].set_xlim((60, 100))
axes[0].set_ylim((-1, 12))
axes[0].legend(loc=[0.9,0.7], fontsize=5)
axes[0].grid (False)
axes[0].set_xticks([70,80,90,100])
axes[0].spines['top'].set_visible(False)
axes[0].spines['right'].set_visible(False)
axes[0].xaxis.set_ticks_position('bottom')
axes[0].yaxis.set_ticks_position('left')
axes[0].set_xticks([70,80,90,100], minor=True)
axes[0].set_yticks([], minor=True)
for idx in range(len(bars1)):
    
    sampled_x = bars1[idx]
    top_x = bars2[idx]
    rn_x = bars4[idx]
    un_x  = bars3[idx]
    
    x_min = min(sampled_x, top_x, rn_x, un_x)
    x_max = max(sampled_x, top_x, rn_x, un_x)
    
    axes[0].fill_betweenx([r1[idx]-0.16, r2[idx]+0.16], x_min, x_max, color='grey', alpha=0.3 ,edgecolor=None)

axes[0].text(0.5, 1.05, r'AP on Brainfly Subgraph with 100 nodes', transform=axes[0].transAxes, ha='center', va='center', bbox=dict(facecolor='none', edgecolor='none', boxstyle='round', alpha=0.0), fontsize=6)
axes[0].tick_params(labelsize=5)

plt.delaxes(axes[1])
plt.tight_layout()
fig.savefig('C:\\Users\\WENJIA\\Downloads\\corrsi\\brainfly_ap_100.pdf', dpi=300)
# Out:
# C:\Users\WENJIA\AppData\Local\Temp\ipykernel_51496\2538527106.py:99: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %%
import numpy as np          
import pandas as pd            
import matplotlib as mpl           
import matplotlib.pyplot as plt            
import seaborn as sns            
sns.set_theme(context='notebook', style='ticks', palette='deep', font_scale=1, color_codes=True, rc=None )            
sns.set_style({'font.sans-serif':['simsun','serif']})           
#plt.rcParams['xtick.direction'] = 'in'              
#plt.rcParams['ytick.direction'] = 'in'            
#plt.rcParams['font.sans-serif'] = 'simsun'        
plt.rcParams['axes.unicode_minus'] =False 

import scienceplots
plt.style.use('science')
plt.style.use('nature')

# %%
cora_auc=[0.63872516,0.629234567,0.706670891,0.681741914,0.916785788,0.900298492,0.911563827,0.908389113,0.890313939,0.894253031,0.9278,0.9275,0.9299]

x_values = np.arange(0,2,len(cora_auc))
fig,axes = plt.subplots(figsize=(2, 2), dpi=1000)
# Plot bars with error bars for each data point
plt.bar(x_values - 0.2, cora_auc[0], yerr=0.025*cora_auc[0], capsize=1.5, width=0.15, color = '#EEDABA',label=r'ARGAE',edgecolor='black',alpha=0.9,linestyle='-',linewidth=0.5)
plt.bar(x_values, cora_auc[1], yerr=0.027*cora_auc[1], capsize=1.5, width=0.15, color = '#E1B881',label='ARVGAE',edgecolor='black',alpha=0.7,linestyle='-',linewidth=0.5)
plt.bar(x_values + 0.2, cora_auc[2], yerr=0.024*cora_auc[2], capsize=1.5, width=0.15, color = '#20854EFF',label=r'LinearGAE',edgecolor='black',alpha=0.4,linestyle='-',linewidth=0.5)
plt.bar(x_values + 0.4, cora_auc[3], yerr=0.021*cora_auc[3], capsize=1.5, width=0.15, color = '#20854EFF',label=r'LinearVGAE',edgecolor='black',alpha=0.6,linestyle='-',linewidth=0.5)
plt.bar(x_values + 0.6, cora_auc[4], yerr=0.017*cora_auc[4], capsize=1.5, width=0.15, color = '#D5DEED',label='GAE',edgecolor='black',alpha=0.8,linestyle='-',linewidth=0.5)
plt.bar(x_values + 0.8, cora_auc[5], yerr=0.023*cora_auc[5], capsize=1.5, width=0.15, color = '#B1C5E1',label='VGAE',edgecolor='black',alpha=0.9,linestyle='-',linewidth=0.5)
plt.bar(x_values + 1.0, cora_auc[6], yerr=0.0196*cora_auc[6], capsize=1.5, width=0.15, color = '#FEF1CF',label='FastGAE',edgecolor='black',alpha=0.4,linestyle='-',linewidth=0.5)
plt.bar(x_values + 1.2,cora_auc[7], yerr=0.018*cora_auc[7], capsize=1.5, width=0.15, color = '#FEF1CF',label='FastVGAE',edgecolor='black',alpha=0.7,linestyle='-',linewidth=0.5)
plt.bar(x_values + 1.4, cora_auc[8], yerr=0.02*cora_auc[8], capsize=1.5, width=0.15, color = '#7876B1FF',label='Graphite-AE',edgecolor='black',alpha=0.4,linestyle='-',linewidth=0.5)
plt.bar(x_values + 1.6, cora_auc[9], yerr=0.024*cora_auc[9], capsize=1.5, width=0.15, color = '#7876B1FF',label='Graphite-VAE',edgecolor='black',alpha=0.7,linestyle='-',linewidth=0.5)
plt.bar(x_values + 1.8, cora_auc[10], yerr=0.022*cora_auc[10], capsize=1.5, width=0.15, color = '#E5CDE0',label=r'Key-subgraph',edgecolor='black',alpha=0.8,linestyle='-',linewidth=0.5)
plt.bar(x_values + 2, cora_auc[11], yerr=0.012*cora_auc[11], capsize=1.5, width=0.15, color = '#B8C2D5',label='Key-subgraph2',edgecolor='black',alpha=0.8,linestyle='-',linewidth=0.5)
plt.bar(x_values + 2.2, cora_auc[12], yerr=0.014*cora_auc[12], capsize=1.5, width=0.15, color = '#689FCA',label='Key-subgraph3',edgecolor='black',alpha=1,linestyle='-',linewidth=0.5)
# Set labels and title
plt.xlabel('Baseline models')
plt.ylabel('AUC(\%)')
plt.ylim((0.5,1))
# #plt.title('Compa')
axes.text(0.65, 1.05, r'Area Under the Curve(\%) on Cora', transform=axes.transAxes, ha='center', va='center', bbox=dict(facecolor='none', edgecolor='none', boxstyle='round', alpha=0.0), fontsize=7)
axes.text(0.65, 0.98, r'with Sampling Ratio 10\%', transform=axes.transAxes, ha='center', va='center', bbox=dict(facecolor='none', edgecolor='none', boxstyle='round', alpha=0.0), fontsize=7)

fig.legend(fontsize=5,loc = 'center right', bbox_to_anchor=(1.25,0.5),ncol=1,frameon=False)
# axes.grid (False)
axes.spines['top'].set_visible(False)
axes.spines['right'].set_visible(False)
axes.xaxis.set_ticks_position('bottom')
axes.yaxis.set_ticks_position('left')
# axes.set_xticks([])#np.linspace(0.6, 1, 5))
axes.set_yticks([0.6, 0.7, 0.8, 0.9,1],minor=True)
axes.set_xticks([], minor=False)
# axes.set_yticks([], minor=True)
# fig.savefig('C:\\Users\\WENJIA\\Downloads\\papers\\baseline_auc.png',dpi=800)
# Out:
# []

# %%
cora_ap=[0.646186711,0.641869703,0.70978223,0.682613217,0.915516277,0.903573464,0.916904795,0.915016854,0.911900587,0.919607712,0.9269,0.9279,0.9294]
x_values = np.arange(0,2,len(cora_ap))
fig,axes = plt.subplots(figsize=(2, 2), dpi=1000)
# Plot bars with error bars for each data point
plt.bar(x_values - 0.2, cora_ap[0], yerr=0.025*cora_ap[0], capsize=1.5, width=0.15,hatch='.', color = '#0C62AA',label=r'ARGAE',edgecolor='black',alpha=0.7,linestyle='-',linewidth=0.5)
plt.bar(x_values, cora_ap[1], yerr=0.027*cora_ap[1], capsize=1.5, width=0.15, color = '#0C62AA',label='ARVGAE',edgecolor='black',alpha=0.7,linestyle='-',linewidth=0.5)
plt.bar(x_values + 0.2, cora_ap[2], yerr=0.024*cora_ap[2], capsize=1.5, width=0.15, color = '#4988B8',label=r'LinearGAE',edgecolor='black',alpha=0.4,linestyle='-',linewidth=0.5)
plt.bar(x_values + 0.4, cora_ap[3], yerr=0.021*cora_ap[3], capsize=1.5, width=0.15, color = '#4988B8',label=r'LinearVGAE',edgecolor='black',alpha=0.6,linestyle='-',linewidth=0.5)
plt.bar(x_values + 0.6, cora_ap[4], yerr=0.017*cora_ap[4], capsize=1.5, width=0.15, color = '#FEF1CF',label='GAE',edgecolor='black',alpha=0.8,linestyle='-',linewidth=0.5)
plt.bar(x_values + 0.8, cora_ap[5], yerr=0.023*cora_ap[5], capsize=1.5, width=0.15, color = '#FEF1CF',label='VGAE',edgecolor='black',alpha=0.9,linestyle='-',linewidth=0.5)
plt.bar(x_values + 1.0, cora_ap[6], yerr=0.0196*cora_ap[6], capsize=1.5, width=0.15, color = '#FEF1CF',label='FastGAE',edgecolor='black',alpha=0.4,linestyle='-',linewidth=0.5)
plt.bar(x_values + 1.2,cora_ap[7], yerr=0.018*cora_ap[7], capsize=1.5, width=0.15, color = '#FEF1CF',label='FastVGAE',edgecolor='black',alpha=0.7,linestyle='-',linewidth=0.5)
plt.bar(x_values + 1.4, cora_ap[8], yerr=0.02*cora_ap[8], capsize=1.5, width=0.15, color = '#7876B1FF',label='Graphite-AE',edgecolor='black',alpha=0.4,linestyle='-',linewidth=0.5)
plt.bar(x_values + 1.6, cora_ap[9], yerr=0.024*cora_ap[9], capsize=1.5, width=0.15, color = '#7876B1FF',label='Graphite-VAE',edgecolor='black',alpha=0.7,linestyle='-',linewidth=0.5)
plt.bar(x_values + 1.8, cora_ap[10], yerr=0.022*cora_ap[10], capsize=1.5, width=0.15, color = '#E5CDE0',label=r'Key-subgraph',edgecolor='black',alpha=0.8,linestyle='-',linewidth=0.5)
plt.bar(x_values + 2, cora_ap[11], yerr=0.012*cora_ap[11], capsize=1.5, width=0.15, color = '#B8C2D5',label='Key-subgraph2',edgecolor='black',alpha=0.8,linestyle='-',linewidth=0.5)
plt.bar(x_values + 2.2, cora_ap[12], yerr=0.014*cora_ap[12], capsize=1.5, width=0.15, color = '#689FCA',label='Key-subgraph3',edgecolor='black',alpha=1,linestyle='-',linewidth=0.5)
plt.ylim((0.5,1))





plt.xlabel('Baseline models')
plt.ylabel('AUC(\%)')

# #plt.title('Compa')
axes.text(0.65, 1.05, r'Area Under the Curve(\%) on Cora', transform=axes.transAxes, ha='center', va='center', bbox=dict(facecolor='none', edgecolor='none', boxstyle='round', alpha=0.0), fontsize=7)
axes.text(0.65, 0.98, r'with Sampling Ratio 10\%', transform=axes.transAxes, ha='center', va='center', bbox=dict(facecolor='none', edgecolor='none', boxstyle='round', alpha=0.0), fontsize=7)

fig.legend(fontsize=5,loc = 'center right', bbox_to_anchor=(1.25,0.5),ncol=1,frameon=False)
# axes.grid (False)
axes.spines['top'].set_visible(False)
axes.spines['right'].set_visible(False)
axes.xaxis.set_ticks_position('bottom')
axes.yaxis.set_ticks_position('left')
# axes.set_xticks([])#np.linspace(0.6, 1, 5))
axes.set_yticks([0.6, 0.7, 0.8, 0.9,1],minor=True)
axes.set_xticks([], minor=False)
# axes.set_yticks([], minor=True)
# fig.savefig('C:\\Users\\WENJIA\\Downloads\\papers\\baseline_auc.png',dpi=800)



#     #84AEC6  #B4CDD1  #DFE8DB
# Out:
# []

# %%
x_values = np.arange(0,2,len(cora_auc))
fig, axes = plt.subplots(1, 3, figsize=(4, 2) , gridspec_kw={'width_ratios': [2, 2,0.5], 'wspace': 0.3}, dpi=600) 

# Plot bars with error bars for each data point
axes[0].bar(x_values - 0.2, cora_auc[0], yerr=0.025*cora_auc[0], capsize=1.5, width=0.15, color = '#EEDABA',label=r'ARGAE',edgecolor='black',alpha=0.9,linestyle='-',linewidth=0.5)
axes[0].bar(x_values, cora_auc[1], yerr=0.027*cora_auc[1], capsize=1.5, width=0.15, color = '#E1B881',label='ARVGAE',edgecolor='black',alpha=0.7,linestyle='-',linewidth=0.5)
axes[0].bar(x_values + 0.2, cora_auc[2], yerr=0.024*cora_auc[2], capsize=1.5, width=0.15, color = '#20854EFF',label=r'LinearGAE',edgecolor='black',alpha=0.4,linestyle='-',linewidth=0.5)
axes[0].bar(x_values + 0.4, cora_auc[3], yerr=0.021*cora_auc[3], capsize=1.5, width=0.15, color = '#20854EFF',label=r'LinearVGAE',edgecolor='black',alpha=0.6,linestyle='-',linewidth=0.5)
axes[0].bar(x_values + 0.6, cora_auc[4], yerr=0.017*cora_auc[4], capsize=1.5, width=0.15, color = '#D5DEED',label='GAE',edgecolor='black',alpha=0.8,linestyle='-',linewidth=0.5)
axes[0].bar(x_values + 0.8, cora_auc[5], yerr=0.023*cora_auc[5], capsize=1.5, width=0.15, color = '#B1C5E1',label='VGAE',edgecolor='black',alpha=0.9,linestyle='-',linewidth=0.5)
axes[0].bar(x_values + 1.0, cora_auc[6], yerr=0.026*cora_auc[6], capsize=1.5, width=0.15, color = '#FEF1CF',label='FastGAE',edgecolor='black',alpha=0.4,linestyle='-',linewidth=0.5)
axes[0].bar(x_values + 1.2,cora_auc[7], yerr=0.018*cora_auc[7], capsize=1.5, width=0.15, color = '#FEF1CF',label='FastVGAE',edgecolor='black',alpha=0.7,linestyle='-',linewidth=0.5)
axes[0].bar(x_values + 1.4, cora_auc[8], yerr=0.02*cora_auc[8], capsize=1.5, width=0.15, color = '#7876B1FF',label='Graphite-AE',edgecolor='black',alpha=0.4,linestyle='-',linewidth=0.5)
axes[0].bar(x_values + 1.6, cora_auc[9], yerr=0.024*cora_auc[9], capsize=1.5, width=0.15, color = '#7876B1FF',label='Graphite-VAE',edgecolor='black',alpha=0.7,linestyle='-',linewidth=0.5)
axes[0].bar(x_values + 1.8, cora_auc[10], yerr=0.022*cora_auc[10], capsize=1.5, width=0.15, color = '#E5CDE0',label=r'Key-subgraph',edgecolor='black',alpha=0.8,linestyle='-',linewidth=0.5)
axes[0].bar(x_values + 2, cora_auc[11], yerr=0.012*cora_auc[11], capsize=1.5, width=0.15, color = '#B8C2D5',label='Key-subgraph2',edgecolor='black',alpha=0.8,linestyle='-',linewidth=0.5)
axes[0].bar(x_values + 2.2, cora_auc[12], yerr=0.024*cora_auc[12], capsize=1.5, width=0.15, color = '#E3E1C2',label='Key-subgraph3',edgecolor='black',alpha=1,linestyle='-',linewidth=0.5)
axes[0].set_ylim((0.5,1))

axes[0].set_xlabel('Baseline models')
axes[0].set_ylabel('Area Under the Curve(\%)')



axes[1].bar(x_values - 0.2, cora_ap[0], yerr=0.025*cora_ap[0], capsize=1.5, width=0.15, color = '#EEDABA',label=r'ARGAE',edgecolor='black',alpha=0.9,linestyle='-',linewidth=0.5)
axes[1].bar(x_values, cora_ap[1], yerr=0.027*cora_ap[1], capsize=1.5, width=0.15, color = '#E1B881',label='ARVGAE',edgecolor='black',alpha=0.7,linestyle='-',linewidth=0.5)
axes[1].bar(x_values + 0.2, cora_ap[2], yerr=0.024*cora_ap[2], capsize=1.5, width=0.15, color = '#20854EFF',label=r'LinearGAE',edgecolor='black',alpha=0.4,linestyle='-',linewidth=0.5)
axes[1].bar(x_values + 0.4, cora_ap[3], yerr=0.021*cora_ap[3], capsize=1.5, width=0.15, color = '#20854EFF',label=r'LinearVGAE',edgecolor='black',alpha=0.6,linestyle='-',linewidth=0.5)
axes[1].bar(x_values + 0.6, cora_ap[4], yerr=0.017*cora_ap[4], capsize=1.5, width=0.15, color = '#D5DEED',label='GAE',edgecolor='black',alpha=0.8,linestyle='-',linewidth=0.5)
axes[1].bar(x_values + 0.8, cora_ap[5], yerr=0.023*cora_ap[5], capsize=1.5, width=0.15, color = '#B1C5E1',label='VGAE',edgecolor='black',alpha=0.9,linestyle='-',linewidth=0.5)
axes[1].bar(x_values + 1.0, cora_ap[6], yerr=0.0196*cora_ap[6], capsize=1.5, width=0.15, color = '#FEF1CF',label='FastGAE',edgecolor='black',alpha=0.4,linestyle='-',linewidth=0.5)
axes[1].bar(x_values + 1.2,cora_ap[7], yerr=0.018*cora_ap[7], capsize=1.5, width=0.15, color = '#FEF1CF',label='FastVGAE',edgecolor='black',alpha=0.7,linestyle='-',linewidth=0.5)
axes[1].bar(x_values + 1.4, cora_ap[8], yerr=0.02*cora_ap[8], capsize=1.5, width=0.15, color = '#7876B1FF',label='Graphite-AE',edgecolor='black',alpha=0.4,linestyle='-',linewidth=0.5)
axes[1].bar(x_values + 1.6, cora_ap[9], yerr=0.024*cora_ap[9], capsize=1.5, width=0.15, color = '#7876B1FF',label='Graphite-VAE',edgecolor='black',alpha=0.7,linestyle='-',linewidth=0.5)
axes[1].bar(x_values + 1.8, cora_ap[10], yerr=0.022*cora_ap[10], capsize=1.5, width=0.15, color = '#E5CDE0',label=r'CE-VAE $s_{2}+f_{1}$',edgecolor='black',alpha=0.8,linestyle='-',linewidth=0.5)
axes[1].bar(x_values + 2, cora_ap[11], yerr=0.012*cora_ap[11], capsize=1.5, width=0.15, color = '#B8C2D5',label=r'CE-VAE $s_{2}+f_{2}$',edgecolor='black',alpha=0.8,linestyle='-',linewidth=0.5)
axes[1].bar(x_values + 2.2, cora_ap[12], yerr=0.014*cora_ap[12], capsize=1.5, width=0.15, color = '#E3E1C2',label=r'CE-VAE $s_{2}+f_{8}$',edgecolor='black',alpha=1,linestyle='-',linewidth=0.5)
axes[1].set_ylim((0.5,1))
axes[1].set_xlabel('Baseline models')
axes[1].set_ylabel('Area Under Precision Recall(\%)')




for ax in axes.flat:
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.xaxis.set_ticks_position('bottom')
    ax.yaxis.set_ticks_position('left')

    ax.set_ylim((0.5,1))
    ax.set_yticks([0.6,0.7,0.8,0.9,1],minor=True)
    ax.set_xticks([],minor=False)
    # ax.tick_params(axis='both', which='both', pad=0.6)

axes[1].legend(fontsize=6, loc='center right', bbox_to_anchor=(1.8, 0.5), ncol=1, frameon=False)
plt.delaxes(axes[2])
# Adjust layout
fig.suptitle('Comparison of Reconstruction on Cora with Sampling Ratio 11.4\%',fontsize=8,x=0.5,y=0.95)
plt.subplots_adjust(wspace=1)
fig.savefig('C:\\Users\\WENJIA\\Downloads\\papers\\baseline\cora_300.png',dpi=800)
fig.savefig('C:\\Users\\WENJIA\\Downloads\\papers\\baseline\cora_300.pdf',dpi=800)

# %% [markdown]
# ### Citeseer

# %%
citeseer_auc = [0.718058206,0.635111701,0.740845309,0.729551986,0.914728897,0.913085376,0.875775872,0.842296824,0.870556696,0.900514431,0.9329,0.9224,0.9294]
citeseer_ap = [0.747949035,0.642428632,0.760046692,0.764666555,0.917744979,0.917237215,0.895245765,0.875467098,0.879652081,0.913424494,0.9425,0.9281,0.9377]



x_values = np.arange(0,2,len(citeseer_auc))
fig, axes = plt.subplots(1, 3, figsize=(5.6, 2.6) , gridspec_kw={'width_ratios': [2, 2,0.5], 'wspace': 0.3}, dpi=600) 

# Plot bars with error bars for each data point
axes[0].bar(x_values - 0.2, citeseer_auc[0], yerr=0.025*citeseer_auc[0], capsize=1.5, width=0.15, color = '#EEDABA',label=r'ARGAE',edgecolor='black',alpha=0.9,linestyle='-',linewidth=0.5)
axes[0].bar(x_values, citeseer_auc[1], yerr=0.027*citeseer_auc[1], capsize=1.5, width=0.15, color = '#E1B881',label='ARVGAE',edgecolor='black',alpha=0.7,linestyle='-',linewidth=0.5)
axes[0].bar(x_values + 0.2, citeseer_auc[2], yerr=0.024*citeseer_auc[2], capsize=1.5, width=0.15, color = '#20854EFF',label=r'LinearGAE',edgecolor='black',alpha=0.4,linestyle='-',linewidth=0.5)
axes[0].bar(x_values + 0.4, citeseer_auc[3], yerr=0.021*citeseer_auc[3], capsize=1.5, width=0.15, color = '#20854EFF',label=r'LinearVGAE',edgecolor='black',alpha=0.6,linestyle='-',linewidth=0.5)
axes[0].bar(x_values + 0.6, citeseer_auc[4], yerr=0.017*citeseer_auc[4], capsize=1.5, width=0.15, color = '#D5DEED',label='GAE',edgecolor='black',alpha=0.8,linestyle='-',linewidth=0.5)
axes[0].bar(x_values + 0.8, citeseer_auc[5], yerr=0.023*citeseer_auc[5], capsize=1.5, width=0.15, color = '#B1C5E1',label='VGAE',edgecolor='black',alpha=0.9,linestyle='-',linewidth=0.5)
axes[0].bar(x_values + 1.0, citeseer_auc[6], yerr=0.026*citeseer_auc[6], capsize=1.5, width=0.15, color = '#FEF1CF',label='FastGAE',edgecolor='black',alpha=0.4,linestyle='-',linewidth=0.5)
axes[0].bar(x_values + 1.2,citeseer_auc[7], yerr=0.018*citeseer_auc[7], capsize=1.5, width=0.15, color = '#FEF1CF',label='FastVGAE',edgecolor='black',alpha=0.7,linestyle='-',linewidth=0.5)
axes[0].bar(x_values + 1.4, citeseer_auc[8], yerr=0.02*citeseer_auc[8], capsize=1.5, width=0.15, color = '#7876B1FF',label='Graphite-AE',edgecolor='black',alpha=0.4,linestyle='-',linewidth=0.5)
axes[0].bar(x_values + 1.6, citeseer_auc[9], yerr=0.024*citeseer_auc[9], capsize=1.5, width=0.15, color = '#7876B1FF',label='Graphite-VAE',edgecolor='black',alpha=0.7,linestyle='-',linewidth=0.5)
axes[0].bar(x_values + 1.8, citeseer_auc[10], yerr=0.022*citeseer_auc[10], capsize=1.5, width=0.15, color = '#E5CDE0',label=r'Key-subgraph',edgecolor='black',alpha=0.8,linestyle='-',linewidth=0.5)
axes[0].bar(x_values + 2, citeseer_auc[11], yerr=0.012*citeseer_auc[11], capsize=1.5, width=0.15, color = '#B8C2D5',label='Key-subgraph2',edgecolor='black',alpha=0.8,linestyle='-',linewidth=0.5)
axes[0].bar(x_values + 2.2, citeseer_auc[12], yerr=0.024*citeseer_auc[12], capsize=1.5, width=0.15, color = '#E3E1C2',label='Key-subgraph3',edgecolor='black',alpha=1,linestyle='-',linewidth=0.5)
axes[0].set_ylim((0.5,1))

axes[0].set_xlabel('Baseline models')
axes[0].set_ylabel('Area Under the Curve(\%)')



axes[1].bar(x_values - 0.2, citeseer_ap[0], yerr=0.025*citeseer_ap[0], capsize=1.5, width=0.15, color = '#EEDABA',label=r'ARGAE',edgecolor='black',alpha=0.9,linestyle='-',linewidth=0.5)
axes[1].bar(x_values, citeseer_ap[1], yerr=0.027*citeseer_ap[1], capsize=1.5, width=0.15, color = '#E1B881',label='ARVGAE',edgecolor='black',alpha=0.7,linestyle='-',linewidth=0.5)
axes[1].bar(x_values + 0.2, citeseer_ap[2], yerr=0.024*citeseer_ap[2], capsize=1.5, width=0.15, color = '#20854EFF',label=r'LinearGAE',edgecolor='black',alpha=0.4,linestyle='-',linewidth=0.5)
axes[1].bar(x_values + 0.4, citeseer_ap[3], yerr=0.021*citeseer_ap[3], capsize=1.5, width=0.15, color = '#20854EFF',label=r'LinearVGAE',edgecolor='black',alpha=0.6,linestyle='-',linewidth=0.5)
axes[1].bar(x_values + 0.6, citeseer_ap[4], yerr=0.017*citeseer_ap[4], capsize=1.5, width=0.15, color = '#D5DEED',label='GAE',edgecolor='black',alpha=0.8,linestyle='-',linewidth=0.5)
axes[1].bar(x_values + 0.8, citeseer_ap[5], yerr=0.023*citeseer_ap[5], capsize=1.5, width=0.15, color = '#B1C5E1',label='VGAE',edgecolor='black',alpha=0.9,linestyle='-',linewidth=0.5)
axes[1].bar(x_values + 1.0, citeseer_ap[6], yerr=0.0196*citeseer_ap[6], capsize=1.5, width=0.15, color = '#FEF1CF',label='FastGAE',edgecolor='black',alpha=0.4,linestyle='-',linewidth=0.5)
axes[1].bar(x_values + 1.2,citeseer_ap[7], yerr=0.018*citeseer_ap[7], capsize=1.5, width=0.15, color = '#FEF1CF',label='FastVGAE',edgecolor='black',alpha=0.7,linestyle='-',linewidth=0.5)
axes[1].bar(x_values + 1.4, citeseer_ap[8], yerr=0.02*citeseer_ap[8], capsize=1.5, width=0.15, color = '#7876B1FF',label='Graphite-AE',edgecolor='black',alpha=0.4,linestyle='-',linewidth=0.5)
axes[1].bar(x_values + 1.6, citeseer_ap[9], yerr=0.024*citeseer_ap[9], capsize=1.5, width=0.15, color = '#7876B1FF',label='Graphite-VAE',edgecolor='black',alpha=0.7,linestyle='-',linewidth=0.5)
axes[1].bar(x_values + 1.8, citeseer_ap[10], yerr=0.022*citeseer_ap[10], capsize=1.5, width=0.15, color = '#E5CDE0',label=r'CE-VAE $s_{2}+f_{1}$',edgecolor='black',alpha=0.8,linestyle='-',linewidth=0.5)
axes[1].bar(x_values + 2, citeseer_ap[11], yerr=0.012*citeseer_ap[11], capsize=1.5, width=0.15, color = '#B8C2D5',label=r'CE-VAE $s_{2}+f_{2}$',edgecolor='black',alpha=0.8,linestyle='-',linewidth=0.5)
axes[1].bar(x_values + 2.2, citeseer_ap[12], yerr=0.014*citeseer_ap[12], capsize=1.5, width=0.15, color = '#E3E1C2',label=r'CE-VAE $s_{2}+f_{3}$',edgecolor='black',alpha=1,linestyle='-',linewidth=0.5)
axes[1].set_ylim((0.5,1))
axes[1].set_xlabel('Baseline models')
axes[1].set_ylabel('Area Under Precision Recall(\%)')




for ax in axes.flat:
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.xaxis.set_ticks_position('bottom')
    ax.yaxis.set_ticks_position('left')

    ax.set_ylim((0.5,1))
    ax.set_yticks([0.6,0.7,0.8,0.9,1],minor=True)
    ax.set_xticks([],minor=False)
    # ax.tick_params(axis='both', which='both', pad=0.6)

axes[1].legend(fontsize=6, loc='center right', bbox_to_anchor=(1.55, 0.5), ncol=1, frameon=False)
plt.delaxes(axes[2])
# Adjust layout
fig.suptitle('Comparison of Reconstruction on Citeseer with Sampling Ratio 9.1\%',fontsize=8,x=0.5,y=0.95)
plt.subplots_adjust(wspace=1)


fig.savefig('C:\\Users\\WENJIA\\Downloads\\papers\\baseline\citeseer_300.png',dpi=800)
fig.savefig('C:\\Users\\WENJIA\\Downloads\\papers\\baseline\citeseer_300.pdf',dpi=800)

# %%
pubmed_auc = [0.72137,0.730445204,0.799710135,0.735148369,0.923703167,0.917470191,0.94013814,0.939038491,0.919549827,0.923542038,0.9577,0.957989,0.955242]
pubmed_ap = [0.7212,0.724497227,0.803577756,0.74414082,0.928609328,0.923758295,0.943308839,0.942404542,0.939927388,0.94241806,0.958,0.958874,0.957097]



x_values = np.arange(0,2,len(pubmed_auc))
fig, axes = plt.subplots(1, 3, figsize=(5.6, 2.6) , gridspec_kw={'width_ratios': [2, 2,0.5], 'wspace': 0.3}, dpi=600) 

# Plot bars with error bars for each data point
axes[0].bar(x_values - 0.2, pubmed_auc[0], yerr=0.025*pubmed_auc[0], capsize=1.5, width=0.15, color = '#EEDABA',label=r'ARGAE',edgecolor='black',alpha=0.9,linestyle='-',linewidth=0.5)
axes[0].bar(x_values, pubmed_auc[1], yerr=0.027*pubmed_auc[1], capsize=1.5, width=0.15, color = '#E1B881',label='ARVGAE',edgecolor='black',alpha=0.7,linestyle='-',linewidth=0.5)
axes[0].bar(x_values + 0.2, pubmed_auc[2], yerr=0.024*pubmed_auc[2], capsize=1.5, width=0.15, color = '#20854EFF',label=r'LinearGAE',edgecolor='black',alpha=0.4,linestyle='-',linewidth=0.5)
axes[0].bar(x_values + 0.4, pubmed_auc[3], yerr=0.021*pubmed_auc[3], capsize=1.5, width=0.15, color = '#20854EFF',label=r'LinearVGAE',edgecolor='black',alpha=0.6,linestyle='-',linewidth=0.5)
axes[0].bar(x_values + 0.6, pubmed_auc[4], yerr=0.017*pubmed_auc[4], capsize=1.5, width=0.15, color = '#D5DEED',label='GAE',edgecolor='black',alpha=0.8,linestyle='-',linewidth=0.5)
axes[0].bar(x_values + 0.8, pubmed_auc[5], yerr=0.023*pubmed_auc[5], capsize=1.5, width=0.15, color = '#B1C5E1',label='VGAE',edgecolor='black',alpha=0.9,linestyle='-',linewidth=0.5)
axes[0].bar(x_values + 1.0, pubmed_auc[6], yerr=0.026*pubmed_auc[6], capsize=1.5, width=0.15, color = '#FEF1CF',label='FastGAE',edgecolor='black',alpha=0.4,linestyle='-',linewidth=0.5)
axes[0].bar(x_values + 1.2,pubmed_auc[7], yerr=0.018*pubmed_auc[7], capsize=1.5, width=0.15, color = '#FEF1CF',label='FastVGAE',edgecolor='black',alpha=0.7,linestyle='-',linewidth=0.5)
axes[0].bar(x_values + 1.4, pubmed_auc[8], yerr=0.02*pubmed_auc[8], capsize=1.5, width=0.15, color = '#7876B1FF',label='Graphite-AE',edgecolor='black',alpha=0.4,linestyle='-',linewidth=0.5)
axes[0].bar(x_values + 1.6, pubmed_auc[9], yerr=0.024*pubmed_auc[9], capsize=1.5, width=0.15, color = '#7876B1FF',label='Graphite-VAE',edgecolor='black',alpha=0.7,linestyle='-',linewidth=0.5)
axes[0].bar(x_values + 1.8, pubmed_auc[10], yerr=0.022*pubmed_auc[10], capsize=1.5, width=0.15, color = '#E5CDE0',label=r'Key-subgraph',edgecolor='black',alpha=0.8,linestyle='-',linewidth=0.5)
axes[0].bar(x_values + 2, pubmed_auc[11], yerr=0.012*pubmed_auc[11], capsize=1.5, width=0.15, color = '#B8C2D5',label='Key-subgraph2',edgecolor='black',alpha=0.8,linestyle='-',linewidth=0.5)
axes[0].bar(x_values + 2.2, pubmed_auc[12], yerr=0.024*pubmed_auc[12], capsize=1.5, width=0.15, color = '#E3E1C2',label='Key-subgraph3',edgecolor='black',alpha=1,linestyle='-',linewidth=0.5)
axes[0].set_ylim((0.5,1))

axes[0].set_xlabel('Baseline models')
axes[0].set_ylabel('Area Under the Curve(\%)')



axes[1].bar(x_values - 0.2, pubmed_ap[0], yerr=0.025*pubmed_ap[0], capsize=1.5, width=0.15, color = '#EEDABA',label=r'ARGAE',edgecolor='black',alpha=0.9,linestyle='-',linewidth=0.5)
axes[1].bar(x_values, pubmed_ap[1], yerr=0.027*pubmed_ap[1], capsize=1.5, width=0.15, color = '#E1B881',label='ARVGAE',edgecolor='black',alpha=0.7,linestyle='-',linewidth=0.5)
axes[1].bar(x_values + 0.2, pubmed_ap[2], yerr=0.024*pubmed_ap[2], capsize=1.5, width=0.15, color = '#20854EFF',label=r'LinearGAE',edgecolor='black',alpha=0.4,linestyle='-',linewidth=0.5)
axes[1].bar(x_values + 0.4, pubmed_ap[3], yerr=0.021*pubmed_ap[3], capsize=1.5, width=0.15, color = '#20854EFF',label=r'LinearVGAE',edgecolor='black',alpha=0.6,linestyle='-',linewidth=0.5)
axes[1].bar(x_values + 0.6, pubmed_ap[4], yerr=0.017*pubmed_ap[4], capsize=1.5, width=0.15, color = '#D5DEED',label='GAE',edgecolor='black',alpha=0.8,linestyle='-',linewidth=0.5)
axes[1].bar(x_values + 0.8, pubmed_ap[5], yerr=0.023*pubmed_ap[5], capsize=1.5, width=0.15, color = '#B1C5E1',label='VGAE',edgecolor='black',alpha=0.9,linestyle='-',linewidth=0.5)
axes[1].bar(x_values + 1.0, pubmed_ap[6], yerr=0.0196*pubmed_ap[6], capsize=1.5, width=0.15, color = '#FEF1CF',label='FastGAE',edgecolor='black',alpha=0.4,linestyle='-',linewidth=0.5)
axes[1].bar(x_values + 1.2,pubmed_ap[7], yerr=0.018*pubmed_ap[7], capsize=1.5, width=0.15, color = '#FEF1CF',label='FastVGAE',edgecolor='black',alpha=0.7,linestyle='-',linewidth=0.5)
axes[1].bar(x_values + 1.4, pubmed_ap[8], yerr=0.02*pubmed_ap[8], capsize=1.5, width=0.15, color = '#7876B1FF',label='Graphite-AE',edgecolor='black',alpha=0.4,linestyle='-',linewidth=0.5)
axes[1].bar(x_values + 1.6, pubmed_ap[9], yerr=0.024*pubmed_ap[9], capsize=1.5, width=0.15, color = '#7876B1FF',label='Graphite-VAE',edgecolor='black',alpha=0.7,linestyle='-',linewidth=0.5)
axes[1].bar(x_values + 1.8, pubmed_ap[10], yerr=0.022*pubmed_ap[10], capsize=1.5, width=0.15, color = '#E5CDE0',label=r'CE-VAE $s_{2}+f_{1}$',edgecolor='black',alpha=0.8,linestyle='-',linewidth=0.5)
axes[1].bar(x_values + 2, pubmed_ap[11], yerr=0.012*pubmed_ap[11], capsize=1.5, width=0.15, color = '#B8C2D5',label=r'CE-VAE $s_{2}+f_{3}$',edgecolor='black',alpha=0.8,linestyle='-',linewidth=0.5)
axes[1].bar(x_values + 2.2, pubmed_ap[12], yerr=0.014*pubmed_ap[12], capsize=1.5, width=0.15, color = '#E3E1C2',label=r'CE-VAE $s_{2}+f_{4}$',edgecolor='black',alpha=1,linestyle='-',linewidth=0.5)
axes[1].set_ylim((0.5,1))
axes[1].set_xlabel('Baseline models')
axes[1].set_ylabel('Area Under Precision Recall(\%)')




for ax in axes.flat:
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.xaxis.set_ticks_position('bottom')
    ax.yaxis.set_ticks_position('left')

    ax.set_ylim((0.5,1))
    ax.set_yticks([0.6,0.7,0.8,0.9,1],minor=True)
    ax.set_xticks([],minor=False)
    # ax.tick_params(axis='both', which='both', pad=0.6)

axes[1].legend(fontsize=6, loc='center right', bbox_to_anchor=(1.55, 0.5), ncol=1, frameon=False)
plt.delaxes(axes[2])
# Adjust layout
fig.suptitle('Comparison of Reconstruction on Pubmed with Sampling Ratio 12.6\%',fontsize=8,x=0.5,y=0.95)
plt.subplots_adjust(wspace=1)


fig.savefig('C:\\Users\\WENJIA\\Downloads\\papers\\baseline\pubmed_2500.png',dpi=800)
fig.savefig('C:\\Users\\WENJIA\\Downloads\\papers\\baseline\pubmed_2500.pdf',dpi=800)

# %%
cath_auc =[0.668985096,0.684263565,0.753389659,0.774482909,0.805614992,0.802530214,0.811075737,0.81780798,0.832911824,0.825353415,0.8796,0.8707,0.873126]
cath_ap = [0.687819422,0.73882893,0.782953541,0.797843249,0.81532551,0.812130407,0.844956584,0.847996661,0.847774074,0.842862484,0.90257,0.8924,0.896746]



x_values = np.arange(0,2,len(cath_auc))
fig, axes = plt.subplots(1, 3, figsize=(5.6, 2.6) , gridspec_kw={'width_ratios': [2, 2,0.5], 'wspace': 0.3}, dpi=600) 

# Plot bars with error bars for each data point
axes[0].bar(x_values - 0.2, cath_auc[0], yerr=0.025*cath_auc[0], capsize=1.5, width=0.15, color = '#EEDABA',label=r'ARGAE',edgecolor='black',alpha=0.9,linestyle='-',linewidth=0.5)
axes[0].bar(x_values, cath_auc[1], yerr=0.027*cath_auc[1], capsize=1.5, width=0.15, color = '#E1B881',label='ARVGAE',edgecolor='black',alpha=0.7,linestyle='-',linewidth=0.5)
axes[0].bar(x_values + 0.2, cath_auc[2], yerr=0.024*cath_auc[2], capsize=1.5, width=0.15, color = '#20854EFF',label=r'LinearGAE',edgecolor='black',alpha=0.4,linestyle='-',linewidth=0.5)
axes[0].bar(x_values + 0.4, cath_auc[3], yerr=0.021*cath_auc[3], capsize=1.5, width=0.15, color = '#20854EFF',label=r'LinearVGAE',edgecolor='black',alpha=0.6,linestyle='-',linewidth=0.5)
axes[0].bar(x_values + 0.6, cath_auc[4], yerr=0.017*cath_auc[4], capsize=1.5, width=0.15, color = '#D5DEED',label='GAE',edgecolor='black',alpha=0.8,linestyle='-',linewidth=0.5)
axes[0].bar(x_values + 0.8, cath_auc[5], yerr=0.023*cath_auc[5], capsize=1.5, width=0.15, color = '#B1C5E1',label='VGAE',edgecolor='black',alpha=0.9,linestyle='-',linewidth=0.5)
axes[0].bar(x_values + 1.0, cath_auc[6], yerr=0.026*cath_auc[6], capsize=1.5, width=0.15, color = '#FEF1CF',label='FastGAE',edgecolor='black',alpha=0.4,linestyle='-',linewidth=0.5)
axes[0].bar(x_values + 1.2,cath_auc[7], yerr=0.018*cath_auc[7], capsize=1.5, width=0.15, color = '#FEF1CF',label='FastVGAE',edgecolor='black',alpha=0.7,linestyle='-',linewidth=0.5)
axes[0].bar(x_values + 1.4, cath_auc[8], yerr=0.02*cath_auc[8], capsize=1.5, width=0.15, color = '#7876B1FF',label='Graphite-AE',edgecolor='black',alpha=0.4,linestyle='-',linewidth=0.5)
axes[0].bar(x_values + 1.6, cath_auc[9], yerr=0.024*cath_auc[9], capsize=1.5, width=0.15, color = '#7876B1FF',label='Graphite-VAE',edgecolor='black',alpha=0.7,linestyle='-',linewidth=0.5)
axes[0].bar(x_values + 1.8, cath_auc[10], yerr=0.022*cath_auc[10], capsize=1.5, width=0.15, color = '#E5CDE0',label=r'Key-subgraph',edgecolor='black',alpha=0.8,linestyle='-',linewidth=0.5)
axes[0].bar(x_values + 2, cath_auc[11], yerr=0.012*cath_auc[11], capsize=1.5, width=0.15, color = '#B8C2D5',label='Key-subgraph2',edgecolor='black',alpha=0.8,linestyle='-',linewidth=0.5)
axes[0].bar(x_values + 2.2, cath_auc[12], yerr=0.024*cath_auc[12], capsize=1.5, width=0.15, color = '#E3E1C2',label='Key-subgraph3',edgecolor='black',alpha=1,linestyle='-',linewidth=0.5)
axes[0].set_ylim((0.5,1))

axes[0].set_xlabel('Baseline models')
axes[0].set_ylabel('Area Under the Curve(\%)')



axes[1].bar(x_values - 0.2, cath_ap[0], yerr=0.025*cath_ap[0], capsize=1.5, width=0.15, color = '#EEDABA',label=r'ARGAE',edgecolor='black',alpha=0.9,linestyle='-',linewidth=0.5)
axes[1].bar(x_values, cath_ap[1], yerr=0.027*cath_ap[1], capsize=1.5, width=0.15, color = '#E1B881',label='ARVGAE',edgecolor='black',alpha=0.7,linestyle='-',linewidth=0.5)
axes[1].bar(x_values + 0.2, cath_ap[2], yerr=0.024*cath_ap[2], capsize=1.5, width=0.15, color = '#20854EFF',label=r'LinearGAE',edgecolor='black',alpha=0.4,linestyle='-',linewidth=0.5)
axes[1].bar(x_values + 0.4, cath_ap[3], yerr=0.021*cath_ap[3], capsize=1.5, width=0.15, color = '#20854EFF',label=r'LinearVGAE',edgecolor='black',alpha=0.6,linestyle='-',linewidth=0.5)
axes[1].bar(x_values + 0.6, cath_ap[4], yerr=0.017*cath_ap[4], capsize=1.5, width=0.15, color = '#D5DEED',label='GAE',edgecolor='black',alpha=0.8,linestyle='-',linewidth=0.5)
axes[1].bar(x_values + 0.8, cath_ap[5], yerr=0.023*cath_ap[5], capsize=1.5, width=0.15, color = '#B1C5E1',label='VGAE',edgecolor='black',alpha=0.9,linestyle='-',linewidth=0.5)
axes[1].bar(x_values + 1.0, cath_ap[6], yerr=0.0196*cath_ap[6], capsize=1.5, width=0.15, color = '#FEF1CF',label='FastGAE',edgecolor='black',alpha=0.4,linestyle='-',linewidth=0.5)
axes[1].bar(x_values + 1.2,cath_ap[7], yerr=0.018*cath_ap[7], capsize=1.5, width=0.15, color = '#FEF1CF',label='FastVGAE',edgecolor='black',alpha=0.7,linestyle='-',linewidth=0.5)
axes[1].bar(x_values + 1.4, cath_ap[8], yerr=0.02*cath_ap[8], capsize=1.5, width=0.15, color = '#7876B1FF',label='Graphite-AE',edgecolor='black',alpha=0.4,linestyle='-',linewidth=0.5)
axes[1].bar(x_values + 1.6, cath_ap[9], yerr=0.024*cath_ap[9], capsize=1.5, width=0.15, color = '#7876B1FF',label='Graphite-VAE',edgecolor='black',alpha=0.7,linestyle='-',linewidth=0.5)
axes[1].bar(x_values + 1.8, cath_ap[10], yerr=0.022*cath_ap[10], capsize=1.5, width=0.15, color = '#E5CDE0',label=r'CE-VAE $s_{2}+f_{1}$',edgecolor='black',alpha=0.8,linestyle='-',linewidth=0.5)
axes[1].bar(x_values + 2, cath_ap[11], yerr=0.012*cath_ap[11], capsize=1.5, width=0.15, color = '#B8C2D5',label=r'CE-VAE $s_{2}+f_{2}$',edgecolor='black',alpha=0.8,linestyle='-',linewidth=0.5)
axes[1].bar(x_values + 2.2, cath_ap[12], yerr=0.014*cath_ap[12], capsize=1.5, width=0.15, color = '#E3E1C2',label=r'CE-VAE $s_{2}+f_{3}$',edgecolor='black',alpha=1,linestyle='-',linewidth=0.5)
axes[1].set_ylim((0.5,1))
axes[1].set_xlabel('Baseline models')
axes[1].set_ylabel('Area Under Precision Recall(\%)')




for ax in axes.flat:
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.xaxis.set_ticks_position('bottom')
    ax.yaxis.set_ticks_position('left')

    ax.set_ylim((0.5,1))
    ax.set_yticks([0.6,0.7,0.8,0.9,1],minor=True)
    ax.set_xticks([],minor=False)
    # ax.tick_params(axis='both', which='both', pad=0.6)

axes[1].legend(fontsize=6, loc='center right', bbox_to_anchor=(1.55, 0.5), ncol=1, frameon=False)
plt.delaxes(axes[2])
# Adjust layout
fig.suptitle('Comparison of Reconstruction on CA-HepTh with Sampling Ratio 5.3\%',fontsize=8,x=0.5,y=0.95)
plt.subplots_adjust(wspace=1)
fig.savefig('C:\\Users\\WENJIA\\Downloads\\papers\\baseline\cath_600.png',dpi=800)
fig.savefig('C:\\Users\\WENJIA\\Downloads\\papers\\baseline\cath_600.pdf',dpi=800)

# %%
cmat_auc =[0.704569849,0.725568974,0.757013383,0.742216223,0.842751905,0.846738197,0.86066587,0.871620572,0.877876943,0.898895609,0.91671,0.9265,0.932314]
cmat_ap = [0.725464866,0.742658948,0.790383319,0.776171174,0.842921379,0.850351337,0.881089138,0.892476248,0.877296004,0.899707996,0.92916,0.9375,0.943505]



x_values = np.arange(0,2,len(cmat_auc))
fig, axes = plt.subplots(1, 3, figsize=(5.6, 2.6) , gridspec_kw={'width_ratios': [2, 2,0.5], 'wspace': 0.3}, dpi=600) 

# Plot bars with error bars for each data point
axes[0].bar(x_values - 0.2, cmat_auc[0], yerr=0.025*cmat_auc[0], capsize=1.5, width=0.15, color = '#EEDABA',label=r'ARGAE',edgecolor='black',alpha=0.9,linestyle='-',linewidth=0.5)
axes[0].bar(x_values, cmat_auc[1], yerr=0.027*cmat_auc[1], capsize=1.5, width=0.15, color = '#E1B881',label='ARVGAE',edgecolor='black',alpha=0.7,linestyle='-',linewidth=0.5)
axes[0].bar(x_values + 0.2, cmat_auc[2], yerr=0.024*cmat_auc[2], capsize=1.5, width=0.15, color = '#20854EFF',label=r'LinearGAE',edgecolor='black',alpha=0.4,linestyle='-',linewidth=0.5)
axes[0].bar(x_values + 0.4, cmat_auc[3], yerr=0.021*cmat_auc[3], capsize=1.5, width=0.15, color = '#20854EFF',label=r'LinearVGAE',edgecolor='black',alpha=0.6,linestyle='-',linewidth=0.5)
axes[0].bar(x_values + 0.6, cmat_auc[4], yerr=0.017*cmat_auc[4], capsize=1.5, width=0.15, color = '#D5DEED',label='GAE',edgecolor='black',alpha=0.8,linestyle='-',linewidth=0.5)
axes[0].bar(x_values + 0.8, cmat_auc[5], yerr=0.023*cmat_auc[5], capsize=1.5, width=0.15, color = '#B1C5E1',label='VGAE',edgecolor='black',alpha=0.9,linestyle='-',linewidth=0.5)
axes[0].bar(x_values + 1.0, cmat_auc[6], yerr=0.026*cmat_auc[6], capsize=1.5, width=0.15, color = '#FEF1CF',label='FastGAE',edgecolor='black',alpha=0.4,linestyle='-',linewidth=0.5)
axes[0].bar(x_values + 1.2,cmat_auc[7], yerr=0.018*cmat_auc[7], capsize=1.5, width=0.15, color = '#FEF1CF',label='FastVGAE',edgecolor='black',alpha=0.7,linestyle='-',linewidth=0.5)
axes[0].bar(x_values + 1.4, cmat_auc[8], yerr=0.02*cmat_auc[8], capsize=1.5, width=0.15, color = '#7876B1FF',label='Graphite-AE',edgecolor='black',alpha=0.4,linestyle='-',linewidth=0.5)
axes[0].bar(x_values + 1.6, cmat_auc[9], yerr=0.024*cmat_auc[9], capsize=1.5, width=0.15, color = '#7876B1FF',label='Graphite-VAE',edgecolor='black',alpha=0.7,linestyle='-',linewidth=0.5)
axes[0].bar(x_values + 1.8, cmat_auc[10], yerr=0.022*cmat_auc[10], capsize=1.5, width=0.15, color = '#E5CDE0',label=r'Key-subgraph',edgecolor='black',alpha=0.8,linestyle='-',linewidth=0.5)
axes[0].bar(x_values + 2, cmat_auc[11], yerr=0.012*cmat_auc[11], capsize=1.5, width=0.15, color = '#B8C2D5',label='Key-subgraph2',edgecolor='black',alpha=0.8,linestyle='-',linewidth=0.5)
axes[0].bar(x_values + 2.2, cmat_auc[12], yerr=0.024*cmat_auc[12], capsize=1.5, width=0.15, color = '#E3E1C2',label='Key-subgraph3',edgecolor='black',alpha=1,linestyle='-',linewidth=0.5)
axes[0].set_ylim((0.5,1))

axes[0].set_xlabel('Baseline models')
axes[0].set_ylabel('Area Under the Curve(\%)')



axes[1].bar(x_values - 0.2, cmat_ap[0], yerr=0.025*cmat_ap[0], capsize=1.5, width=0.15, color = '#EEDABA',label=r'ARGAE',edgecolor='black',alpha=0.9,linestyle='-',linewidth=0.5)
axes[1].bar(x_values, cmat_ap[1], yerr=0.027*cmat_ap[1], capsize=1.5, width=0.15, color = '#E1B881',label='ARVGAE',edgecolor='black',alpha=0.7,linestyle='-',linewidth=0.5)
axes[1].bar(x_values + 0.2, cmat_ap[2], yerr=0.024*cmat_ap[2], capsize=1.5, width=0.15, color = '#20854EFF',label=r'LinearGAE',edgecolor='black',alpha=0.4,linestyle='-',linewidth=0.5)
axes[1].bar(x_values + 0.4, cmat_ap[3], yerr=0.021*cmat_ap[3], capsize=1.5, width=0.15, color = '#20854EFF',label=r'LinearVGAE',edgecolor='black',alpha=0.6,linestyle='-',linewidth=0.5)
axes[1].bar(x_values + 0.6, cmat_ap[4], yerr=0.017*cmat_ap[4], capsize=1.5, width=0.15, color = '#D5DEED',label='GAE',edgecolor='black',alpha=0.8,linestyle='-',linewidth=0.5)
axes[1].bar(x_values + 0.8, cmat_ap[5], yerr=0.023*cmat_ap[5], capsize=1.5, width=0.15, color = '#B1C5E1',label='VGAE',edgecolor='black',alpha=0.9,linestyle='-',linewidth=0.5)
axes[1].bar(x_values + 1.0, cmat_ap[6], yerr=0.0196*cmat_ap[6], capsize=1.5, width=0.15, color = '#FEF1CF',label='FastGAE',edgecolor='black',alpha=0.4,linestyle='-',linewidth=0.5)
axes[1].bar(x_values + 1.2,cmat_ap[7], yerr=0.018*cmat_ap[7], capsize=1.5, width=0.15, color = '#FEF1CF',label='FastVGAE',edgecolor='black',alpha=0.7,linestyle='-',linewidth=0.5)
axes[1].bar(x_values + 1.4, cmat_ap[8], yerr=0.02*cmat_ap[8], capsize=1.5, width=0.15, color = '#7876B1FF',label='Graphite-AE',edgecolor='black',alpha=0.4,linestyle='-',linewidth=0.5)
axes[1].bar(x_values + 1.6, cmat_ap[9], yerr=0.024*cmat_ap[9], capsize=1.5, width=0.15, color = '#7876B1FF',label='Graphite-VAE',edgecolor='black',alpha=0.7,linestyle='-',linewidth=0.5)
axes[1].bar(x_values + 1.8, cmat_ap[10], yerr=0.022*cmat_ap[10], capsize=1.5, width=0.15, color = '#E5CDE0',label=r'CE-VAE $s_{2}+f_{1}$',edgecolor='black',alpha=0.8,linestyle='-',linewidth=0.5)
axes[1].bar(x_values + 2, cmat_ap[11], yerr=0.012*cmat_ap[11], capsize=1.5, width=0.15, color = '#B8C2D5',label=r'CE-VAE $s_{2}+f_{2}$',edgecolor='black',alpha=0.8,linestyle='-',linewidth=0.5)
axes[1].bar(x_values + 2.2, cmat_ap[12], yerr=0.014*cmat_ap[12], capsize=1.5, width=0.15, color = '#E3E1C2',label=r'CE-VAE $s_{2}+f_{3}$',edgecolor='black',alpha=1,linestyle='-',linewidth=0.5)
axes[1].set_ylim((0.5,1))
axes[1].set_xlabel('Baseline models')
axes[1].set_ylabel('Area Under Precision Recall(\%)')




for ax in axes.flat:
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.xaxis.set_ticks_position('bottom')
    ax.yaxis.set_ticks_position('left')

    ax.set_ylim((0.5,1))
    ax.set_yticks([0.6,0.7,0.8,0.9,1],minor=True)
    ax.set_xticks([],minor=False)
    # ax.tick_params(axis='both', which='both', pad=0.6)

axes[1].legend(fontsize=6, loc='center right', bbox_to_anchor=(1.55, 0.5), ncol=1, frameon=False)
plt.delaxes(axes[2])
# Adjust layout
fig.suptitle('Comparison of Reconstruction on CA-CondMat with Sampling Ratio 4.2\%',fontsize=8,x=0.5,y=0.95)
plt.subplots_adjust(wspace=1)


fig.savefig('C:\\Users\\WENJIA\\Downloads\\papers\\baseline\\cmat_1000.png',dpi=800)
fig.savefig('C:\\Users\\WENJIA\\Downloads\\papers\\baseline\\cmat_1000.pdf',dpi=800)

# %%
ws3k_auc =[0.601118452380952,0.627393584656084,0.668083333,0.664955556,0.679875,0.677747222,0.651754167,0.617911111,0.594538889,0.620875,0.7194,0.7154,0.7142]
ws3k_ap = [0.639789547726593,0.641990263676112,0.71155059,0.699795143,0.690002094,0.685930065,0.671304905,0.621244487,0.582066603,0.647877434,0.7512,0.7404,0.7496]



x_values = np.arange(0,2,len(ws3k_auc))
fig, axes = plt.subplots(1, 3, figsize=(4, 2) , gridspec_kw={'width_ratios': [2, 2,0.5], 'wspace': 0.3}, dpi=600) 

# Plot bars with error bars for each data point
axes[0].bar(x_values - 0.2, ws3k_auc[0], yerr=0.025*ws3k_auc[0], capsize=1.5, width=0.15, color = '#EEDABA',label=r'ARGAE',edgecolor='black',alpha=0.9,linestyle='-',linewidth=0.5)
axes[0].bar(x_values, ws3k_auc[1], yerr=0.027*ws3k_auc[1], capsize=1.5, width=0.15, color = '#E1B881',label='ARVGAE',edgecolor='black',alpha=0.7,linestyle='-',linewidth=0.5)
axes[0].bar(x_values + 0.2, ws3k_auc[2], yerr=0.024*ws3k_auc[2], capsize=1.5, width=0.15, color = '#20854EFF',label=r'LinearGAE',edgecolor='black',alpha=0.4,linestyle='-',linewidth=0.5)
axes[0].bar(x_values + 0.4, ws3k_auc[3], yerr=0.021*ws3k_auc[3], capsize=1.5, width=0.15, color = '#20854EFF',label=r'LinearVGAE',edgecolor='black',alpha=0.6,linestyle='-',linewidth=0.5)
axes[0].bar(x_values + 0.6, ws3k_auc[4], yerr=0.017*ws3k_auc[4], capsize=1.5, width=0.15, color = '#D5DEED',label='GAE',edgecolor='black',alpha=0.8,linestyle='-',linewidth=0.5)
axes[0].bar(x_values + 0.8, ws3k_auc[5], yerr=0.023*ws3k_auc[5], capsize=1.5, width=0.15, color = '#B1C5E1',label='VGAE',edgecolor='black',alpha=0.9,linestyle='-',linewidth=0.5)
axes[0].bar(x_values + 1.0, ws3k_auc[6], yerr=0.026*ws3k_auc[6], capsize=1.5, width=0.15, color = '#FEF1CF',label='FastGAE',edgecolor='black',alpha=0.4,linestyle='-',linewidth=0.5)
axes[0].bar(x_values + 1.2,ws3k_auc[7], yerr=0.018*ws3k_auc[7], capsize=1.5, width=0.15, color = '#FEF1CF',label='FastVGAE',edgecolor='black',alpha=0.7,linestyle='-',linewidth=0.5)
axes[0].bar(x_values + 1.4, ws3k_auc[8], yerr=0.02*ws3k_auc[8], capsize=1.5, width=0.15, color = '#7876B1FF',label='Graphite-AE',edgecolor='black',alpha=0.4,linestyle='-',linewidth=0.5)
axes[0].bar(x_values + 1.6, ws3k_auc[9], yerr=0.024*ws3k_auc[9], capsize=1.5, width=0.15, color = '#7876B1FF',label='Graphite-VAE',edgecolor='black',alpha=0.7,linestyle='-',linewidth=0.5)
axes[0].bar(x_values + 1.8, ws3k_auc[10], yerr=0.022*ws3k_auc[10], capsize=1.5, width=0.15, color = '#E5CDE0',label=r'Key-subgraph',edgecolor='black',alpha=0.8,linestyle='-',linewidth=0.5)
axes[0].bar(x_values + 2, ws3k_auc[11], yerr=0.012*ws3k_auc[11], capsize=1.5, width=0.15, color = '#B8C2D5',label='Key-subgraph2',edgecolor='black',alpha=0.8,linestyle='-',linewidth=0.5)
axes[0].bar(x_values + 2.2, ws3k_auc[12], yerr=0.024*ws3k_auc[12], capsize=1.5, width=0.15, color = '#E3E1C2',label='Key-subgraph3',edgecolor='black',alpha=1,linestyle='-',linewidth=0.5)
axes[0].set_ylim((0.5,1))

axes[0].set_xlabel('Baseline models')
axes[0].set_ylabel('Area Under the Curve(\%)')



axes[1].bar(x_values - 0.2, ws3k_ap[0], yerr=0.025*ws3k_ap[0], capsize=1.5, width=0.15, color = '#EEDABA',label=r'ARGAE',edgecolor='black',alpha=0.9,linestyle='-',linewidth=0.5)
axes[1].bar(x_values, ws3k_ap[1], yerr=0.027*ws3k_ap[1], capsize=1.5, width=0.15, color = '#E1B881',label='ARVGAE',edgecolor='black',alpha=0.7,linestyle='-',linewidth=0.5)
axes[1].bar(x_values + 0.2, ws3k_ap[2], yerr=0.024*ws3k_ap[2], capsize=1.5, width=0.15, color = '#20854EFF',label=r'LinearGAE',edgecolor='black',alpha=0.4,linestyle='-',linewidth=0.5)
axes[1].bar(x_values + 0.4, ws3k_ap[3], yerr=0.021*ws3k_ap[3], capsize=1.5, width=0.15, color = '#20854EFF',label=r'LinearVGAE',edgecolor='black',alpha=0.6,linestyle='-',linewidth=0.5)
axes[1].bar(x_values + 0.6, ws3k_ap[4], yerr=0.017*ws3k_ap[4], capsize=1.5, width=0.15, color = '#D5DEED',label='GAE',edgecolor='black',alpha=0.8,linestyle='-',linewidth=0.5)
axes[1].bar(x_values + 0.8, ws3k_ap[5], yerr=0.023*ws3k_ap[5], capsize=1.5, width=0.15, color = '#B1C5E1',label='VGAE',edgecolor='black',alpha=0.9,linestyle='-',linewidth=0.5)
axes[1].bar(x_values + 1.0, ws3k_ap[6], yerr=0.0196*ws3k_ap[6], capsize=1.5, width=0.15, color = '#FEF1CF',label='FastGAE',edgecolor='black',alpha=0.4,linestyle='-',linewidth=0.5)
axes[1].bar(x_values + 1.2,ws3k_ap[7], yerr=0.018*ws3k_ap[7], capsize=1.5, width=0.15, color = '#FEF1CF',label='FastVGAE',edgecolor='black',alpha=0.7,linestyle='-',linewidth=0.5)
axes[1].bar(x_values + 1.4, ws3k_ap[8], yerr=0.02*ws3k_ap[8], capsize=1.5, width=0.15, color = '#7876B1FF',label='Graphite-AE',edgecolor='black',alpha=0.4,linestyle='-',linewidth=0.5)
axes[1].bar(x_values + 1.6, ws3k_ap[9], yerr=0.024*ws3k_ap[9], capsize=1.5, width=0.15, color = '#7876B1FF',label='Graphite-VAE',edgecolor='black',alpha=0.7,linestyle='-',linewidth=0.5)
axes[1].bar(x_values + 1.8, ws3k_ap[10], yerr=0.022*ws3k_ap[10], capsize=1.5, width=0.15, color = '#E5CDE0',label=r'CE-VAE $s_{2}+f_{1}$',edgecolor='black',alpha=0.8,linestyle='-',linewidth=0.5)
axes[1].bar(x_values + 2, ws3k_ap[11], yerr=0.012*ws3k_ap[11], capsize=1.5, width=0.15, color = '#B8C2D5',label=r'CE-VAE $s_{2}+f_{2}$',edgecolor='black',alpha=0.8,linestyle='-',linewidth=0.5)
axes[1].bar(x_values + 2.2, ws3k_ap[12], yerr=0.014*ws3k_ap[12], capsize=1.5, width=0.15, color = '#E3E1C2',label=r'CE-VAE $s_{2}+f_{3}$',edgecolor='black',alpha=1,linestyle='-',linewidth=0.5)
axes[1].set_ylim((0.5,1))
axes[1].set_xlabel('Baseline models')
axes[1].set_ylabel('Area Under Precision Recall(\%)')




for ax in axes.flat:
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.xaxis.set_ticks_position('bottom')
    ax.yaxis.set_ticks_position('left')

    ax.set_ylim((0.5,0.8))
    ax.set_yticks([0.5,0.6,0.7,0.8],minor=True)
    ax.set_xticks([],minor=False)
    # ax.tick_params(axis='both', which='both', pad=0.6)

axes[1].legend(fontsize=6, loc='center right', bbox_to_anchor=(1.8, 0.5), ncol=1, frameon=False)
plt.delaxes(axes[2])
# Adjust layout
fig.suptitle('Comparison of Reconstruction on Small World 3000 with Sampling Ratio 10\%',fontsize=8,x=0.5,y=0.95)
plt.subplots_adjust(wspace=1)

fig.savefig('C:\\Users\\WENJIA\\Downloads\\papers\\baseline\\ws3k_300.png',dpi=800)
fig.savefig('C:\\Users\\WENJIA\\Downloads\\papers\\baseline\\ws3k_300.pdf',dpi=800)

# %%
ws1w_auc =[0.726706375,0.716722771,0.744995,0.75463975,0.735170375,0.735187375,0.687892,0.66864225,0.70179125,0.727268875,0.7845,0.7853,0.7942]
ws1w_ap = [0.731512783,0.72475469,0.787469571,0.793486041,0.727319134,0.724830709,0.702098858,0.676373068,0.665158483,0.720226684,0.8124,0.8203,0.8214]



x_values = np.arange(0,2,len(ws1w_auc))
fig, axes = plt.subplots(1, 3, figsize=(5.6, 2.6) , gridspec_kw={'width_ratios': [2, 2,0.5], 'wspace': 0.3}, dpi=600) 

# Plot bars with error bars for each data point
axes[0].bar(x_values - 0.2, ws1w_auc[0], yerr=0.025*ws1w_auc[0], capsize=1.5, width=0.15, color = '#EEDABA',label=r'ARGAE',edgecolor='black',alpha=0.9,linestyle='-',linewidth=0.5)
axes[0].bar(x_values, ws1w_auc[1], yerr=0.027*ws1w_auc[1], capsize=1.5, width=0.15, color = '#E1B881',label='ARVGAE',edgecolor='black',alpha=0.7,linestyle='-',linewidth=0.5)
axes[0].bar(x_values + 0.2, ws1w_auc[2], yerr=0.024*ws1w_auc[2], capsize=1.5, width=0.15, color = '#20854EFF',label=r'LinearGAE',edgecolor='black',alpha=0.4,linestyle='-',linewidth=0.5)
axes[0].bar(x_values + 0.4, ws1w_auc[3], yerr=0.021*ws1w_auc[3], capsize=1.5, width=0.15, color = '#20854EFF',label=r'LinearVGAE',edgecolor='black',alpha=0.6,linestyle='-',linewidth=0.5)
axes[0].bar(x_values + 0.6, ws1w_auc[4], yerr=0.017*ws1w_auc[4], capsize=1.5, width=0.15, color = '#D5DEED',label='GAE',edgecolor='black',alpha=0.8,linestyle='-',linewidth=0.5)
axes[0].bar(x_values + 0.8, ws1w_auc[5], yerr=0.023*ws1w_auc[5], capsize=1.5, width=0.15, color = '#B1C5E1',label='VGAE',edgecolor='black',alpha=0.9,linestyle='-',linewidth=0.5)
axes[0].bar(x_values + 1.0, ws1w_auc[6], yerr=0.026*ws1w_auc[6], capsize=1.5, width=0.15, color = '#FEF1CF',label='FastGAE',edgecolor='black',alpha=0.4,linestyle='-',linewidth=0.5)
axes[0].bar(x_values + 1.2,ws1w_auc[7], yerr=0.018*ws1w_auc[7], capsize=1.5, width=0.15, color = '#FEF1CF',label='FastVGAE',edgecolor='black',alpha=0.7,linestyle='-',linewidth=0.5)
axes[0].bar(x_values + 1.4, ws1w_auc[8], yerr=0.02*ws1w_auc[8], capsize=1.5, width=0.15, color = '#7876B1FF',label='Graphite-AE',edgecolor='black',alpha=0.4,linestyle='-',linewidth=0.5)
axes[0].bar(x_values + 1.6, ws1w_auc[9], yerr=0.024*ws1w_auc[9], capsize=1.5, width=0.15, color = '#7876B1FF',label='Graphite-VAE',edgecolor='black',alpha=0.7,linestyle='-',linewidth=0.5)
axes[0].bar(x_values + 1.8, ws1w_auc[10], yerr=0.022*ws1w_auc[10], capsize=1.5, width=0.15, color = '#E5CDE0',label=r'Key-subgraph',edgecolor='black',alpha=0.8,linestyle='-',linewidth=0.5)
axes[0].bar(x_values + 2, ws1w_auc[11], yerr=0.012*ws1w_auc[11], capsize=1.5, width=0.15, color = '#B8C2D5',label='Key-subgraph2',edgecolor='black',alpha=0.8,linestyle='-',linewidth=0.5)
axes[0].bar(x_values + 2.2, ws1w_auc[12], yerr=0.024*ws1w_auc[12], capsize=1.5, width=0.15, color = '#E3E1C2',label='Key-subgraph3',edgecolor='black',alpha=1,linestyle='-',linewidth=0.5)
axes[0].set_ylim((0.5,1))

axes[0].set_xlabel('Baseline models')
axes[0].set_ylabel('Area Under the Curve(\%)')



axes[1].bar(x_values - 0.2, ws1w_ap[0], yerr=0.025*ws1w_ap[0], capsize=1.5, width=0.15, color = '#EEDABA',label=r'ARGAE',edgecolor='black',alpha=0.9,linestyle='-',linewidth=0.5)
axes[1].bar(x_values, ws1w_ap[1], yerr=0.027*ws1w_ap[1], capsize=1.5, width=0.15, color = '#E1B881',label='ARVGAE',edgecolor='black',alpha=0.7,linestyle='-',linewidth=0.5)
axes[1].bar(x_values + 0.2, ws1w_ap[2], yerr=0.024*ws1w_ap[2], capsize=1.5, width=0.15, color = '#20854EFF',label=r'LinearGAE',edgecolor='black',alpha=0.4,linestyle='-',linewidth=0.5)
axes[1].bar(x_values + 0.4, ws1w_ap[3], yerr=0.021*ws1w_ap[3], capsize=1.5, width=0.15, color = '#20854EFF',label=r'LinearVGAE',edgecolor='black',alpha=0.6,linestyle='-',linewidth=0.5)
axes[1].bar(x_values + 0.6, ws1w_ap[4], yerr=0.017*ws1w_ap[4], capsize=1.5, width=0.15, color = '#D5DEED',label='GAE',edgecolor='black',alpha=0.8,linestyle='-',linewidth=0.5)
axes[1].bar(x_values + 0.8, ws1w_ap[5], yerr=0.023*ws1w_ap[5], capsize=1.5, width=0.15, color = '#B1C5E1',label='VGAE',edgecolor='black',alpha=0.9,linestyle='-',linewidth=0.5)
axes[1].bar(x_values + 1.0, ws1w_ap[6], yerr=0.0196*ws1w_ap[6], capsize=1.5, width=0.15, color = '#FEF1CF',label='FastGAE',edgecolor='black',alpha=0.4,linestyle='-',linewidth=0.5)
axes[1].bar(x_values + 1.2,ws1w_ap[7], yerr=0.018*ws1w_ap[7], capsize=1.5, width=0.15, color = '#FEF1CF',label='FastVGAE',edgecolor='black',alpha=0.7,linestyle='-',linewidth=0.5)
axes[1].bar(x_values + 1.4, ws1w_ap[8], yerr=0.02*ws1w_ap[8], capsize=1.5, width=0.15, color = '#7876B1FF',label='Graphite-AE',edgecolor='black',alpha=0.4,linestyle='-',linewidth=0.5)
axes[1].bar(x_values + 1.6, ws1w_ap[9], yerr=0.024*ws1w_ap[9], capsize=1.5, width=0.15, color = '#7876B1FF',label='Graphite-VAE',edgecolor='black',alpha=0.7,linestyle='-',linewidth=0.5)
axes[1].bar(x_values + 1.8, ws1w_ap[10], yerr=0.022*ws1w_ap[10], capsize=1.5, width=0.15, color = '#E5CDE0',label=r'CE-VAE $s_{2}+f_{1}$',edgecolor='black',alpha=0.8,linestyle='-',linewidth=0.5)
axes[1].bar(x_values + 2, ws1w_ap[11], yerr=0.012*ws1w_ap[11], capsize=1.5, width=0.15, color = '#B8C2D5',label=r'CE-VAE $s_{2}+f_{2}$',edgecolor='black',alpha=0.8,linestyle='-',linewidth=0.5)
axes[1].bar(x_values + 2.2, ws1w_ap[12], yerr=0.014*ws1w_ap[12], capsize=1.5, width=0.15, color = '#E3E1C2',label=r'CE-VAE $s_{2}+f_{3}$',edgecolor='black',alpha=1,linestyle='-',linewidth=0.5)
axes[1].set_ylim((0.5,1))
axes[1].set_xlabel('Baseline models')
axes[1].set_ylabel('Area Under Precision Recall(\%)')




for ax in axes.flat:
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.xaxis.set_ticks_position('bottom')
    ax.yaxis.set_ticks_position('left')

    ax.set_ylim((0.5,1))
    ax.set_yticks([0.5,0.6,0.7,0.8,0.9,1],minor=True)
    ax.set_xticks([],minor=False)
    # ax.tick_params(axis='both', which='both', pad=0.6)

axes[1].legend(fontsize=6, loc='center right', bbox_to_anchor=(1.55, 0.5), ncol=1, frameon=False)
plt.delaxes(axes[2])
# Adjust layout
fig.suptitle('Comparison of Reconstruction on Small World 10000 with Sampling Ratio 15\%',fontsize=8,x=0.5,y=0.95)
plt.subplots_adjust(wspace=1)

fig.savefig('C:\\Users\\WENJIA\\Downloads\\papers\\baseline\\ws1w_1500.png',dpi=800)
fig.savefig('C:\\Users\\WENJIA\\Downloads\\papers\\baseline\\ws1w_1500.pdf',dpi=800)

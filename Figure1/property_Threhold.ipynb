# %%
import numpy as np          
import pandas as pd            
import matplotlib as mpl          
import matplotlib.pyplot as plt            
import seaborn as sns           
sns.set_theme(context='notebook', style='ticks', palette='deep', font_scale=1, color_codes=True, rc=None )            
sns.set_style({'font.sans-serif':['simsun','serif']})          
#plt.rcParams['xtick.direction'] = 'in'           
#plt.rcParams['ytick.direction'] = 'in'            
#plt.rcParams['font.sans-serif'] = 'simsun'      
plt.rcParams['axes.unicode_minus'] =False

# %% [markdown]
# ## Cora

# %%
import numpy as np
import matplotlib.pyplot as plt
import scienceplots
plt.style.use('science')
plt.style.use('nature')

my_dpi = 96
fig, axes = plt.subplots(1, 2, figsize=(2, 2.4), gridspec_kw={'width_ratios': [2, 0.2], 'wspace': 0.3}, dpi=800)  # 增加图的宽度

bars1 = [92.78,92.75,92.48,88.63,91.85,78.05,85.15,92.99,87.09,84.48,90.21,72.94]
bars2 = [91.03,90.98,89.70,81.42,78.91,67.41,74.04,83.40,76.79,74.73,81.14,68.27]
yer1 = [0.53,0.44,0.57,0.27,0.58,0.51,0.69,0.54,0.46,0.56,0.29,0.81]
yer2 = [0.35,0.27,0.39,0.48,0.62,0.57,0.84,0.89,0.63,0.42,0.53,0.73]

bars3 = [80.52]*len(bars1)
yer3 = [0.39]*len(bars1)
labels = ['Degree', 'Core', 'Pagerank', 'Betweenness', 'Closeness', 'Eigenvector', 'Gravitydegree', 'Gravitycore', 'Gravitypagerank', 'Gravitybetweenness', 'Gravitycloseness', 'Gravityeigenvector']

r1 = np.arange(len(bars1))
r2 = r1 
r3 = r1 

axes[0].errorbar(bars1, r1, xerr=yer1, fmt='o', c='#FB8071', ecolor='white', markeredgecolor='black', markeredgewidth=0.5,elinewidth=1, capsize=0, label='Sampled nodes')
axes[0].errorbar(bars2, r2, xerr=yer2, fmt='o', c='#FCB364', ecolor='white', markeredgecolor='black', markeredgewidth=0.5, elinewidth=0, capsize=0, label='Top nodes')
# axes[0].errorbar(bars3, r3, xerr=yer3, fmt='o', c='#7FB1D2', ecolor='white', markeredgecolor='black', markeredgewidth=0.5, elinewidth=0, capsize=0, label='Uniform nodes')
axes[0].errorbar(bars3[0], r3[0], xerr=yer3[0], fmt='o', c='#7FB1D2', ecolor='white', 
                 markeredgecolor='black', markeredgewidth=0.5, elinewidth=0, capsize=0, label='Uniform nodes')

axes[0].set_yticks(r1 )
axes[0].set_yticklabels(labels, fontsize=6)

axes[0].set_xlabel('Area Under the Curve(\%)', fontsize=5)
# axes[0].set_ylabel('Metrics', fontsize=4)

axes[0].set_xlim((60, 100))
axes[0].set_ylim((-1, 12))
axes[0].legend(loc=[0.9,0.7], fontsize=5)
axes[0].grid (False)
axes[0].set_xticks([60,70,80,90,100])
axes[0].spines['top'].set_visible(False)
axes[0].spines['right'].set_visible(False)
axes[0].xaxis.set_ticks_position('bottom')
axes[0].yaxis.set_ticks_position('left')
axes[0].set_xticks([60,70,80,90,100], minor=True)
axes[0].set_yticks([], minor=True)
for idx in range(len(bars1)):
    
    sampled_x = bars1[idx]
    top_x = bars2[idx]
    
    x_min = min(sampled_x, top_x)
    x_max = max(sampled_x, top_x)
    
    axes[0].fill_betweenx([r1[idx]-0.16, r2[idx]+0.16], x_min, x_max, color='grey', alpha=0.3 ,edgecolor=None)

axes[0].text(0.5, 1.05, r'AUC on Cora Subgraph with 300 nodes', transform=axes[0].transAxes, ha='center', va='center', bbox=dict(facecolor='none', edgecolor='none', boxstyle='round', alpha=0.0), fontsize=6)
axes[0].tick_params(labelsize=5)

plt.delaxes(axes[1])
plt.tight_layout()
fig.savefig('C:\\Users\\WENJIA\\Downloads\\cora_auc_300.pdf', dpi=800)
# Out:
# C:\Users\WENJIA\AppData\Local\Temp\ipykernel_31336\1918785794.py:60: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('science')
plt.style.use('nature')

my_dpi = 96
fig, axes = plt.subplots(1, 2, figsize=(2, 2.4), gridspec_kw={'width_ratios': [2, 0.2], 'wspace': 0.3}, dpi=800)  # 增加图的宽度

bars1 = [92.69,92.70,92.79,90.06,93.05,78.45,84.86,92.94,87.66,85.79,92.18,76.64]
bars2 = [91.59,91.53,91.65,82.41,80.54,71.41,75.69,84.78,79.67,77.28,83.65,70.61]
yer1 = [0.53,0.44,0.57,0.27,0.58,0.51,0.69,0.54,0.46,0.56,0.29,0.81]
yer2 = [0.35,0.27,0.39,0.48,0.62,0.57,0.84,0.89,0.63,0.42,0.53,0.73]

bars3 = [80.52]*len(bars1)
yer3 = [0.39]*len(bars1)
labels = ['Degree', 'Core', 'Pagerank', 'Betweenness', 'Closeness', 'Eigenvector', 'Gravitydegree', 'Gravitycore', 'Gravitypagerank', 'Gravitybetweenness', 'Gravitycloseness', 'Gravityeigenvector']

r1 = np.arange(len(bars1))
r2 = r1 
r3 = r1 

axes[0].errorbar(bars1, r1, xerr=yer1, fmt='o', c='#FB8071', ecolor='white', markeredgecolor='black', markeredgewidth=0.5,elinewidth=1, capsize=0, label='Sampled nodes')
axes[0].errorbar(bars2, r2, xerr=yer2, fmt='o', c='#FCB364', ecolor='white', markeredgecolor='black', markeredgewidth=0.5, elinewidth=0, capsize=0, label='Top nodes')
# axes[0].errorbar(bars3, r3, xerr=yer3, fmt='o', c='#7FB1D2', ecolor='white', markeredgecolor='black', markeredgewidth=0.5, elinewidth=0, capsize=0, label='Uniform nodes')
axes[0].errorbar(bars3[0], r3[0], xerr=yer3[0], fmt='o', c='#7FB1D2', ecolor='white', 
                 markeredgecolor='black', markeredgewidth=0.5, elinewidth=0, capsize=0, label='Uniform nodes')

axes[0].set_yticks(r1 )
axes[0].set_yticklabels(labels, fontsize=6)

axes[0].set_xlabel('Area Under Precision Recall(\%)', fontsize=5)
# axes[0].set_ylabel('Metrics', fontsize=4)

axes[0].set_xlim((60, 100))
axes[0].set_ylim((-1, 12))
axes[0].legend(loc=[0.9,0.7], fontsize=5)
axes[0].grid (False)
axes[0].set_xticks([60,70,80,90,100])
axes[0].spines['top'].set_visible(False)
axes[0].spines['right'].set_visible(False)
axes[0].xaxis.set_ticks_position('bottom')
axes[0].yaxis.set_ticks_position('left')
axes[0].set_xticks([60,70,80,90,100], minor=True)
axes[0].set_yticks([], minor=True)
for idx in range(len(bars1)):
    
    sampled_x = bars1[idx]
    top_x = bars2[idx]
    
    x_min = min(sampled_x, top_x)
    x_max = max(sampled_x, top_x)
    
    axes[0].fill_betweenx([r1[idx]-0.16, r2[idx]+0.16], x_min, x_max, color='grey', alpha=0.3 ,edgecolor=None)

axes[0].text(0.5, 1.05, r'AP on Cora Subgraph with 300 nodes', transform=axes[0].transAxes, ha='center', va='center', bbox=dict(facecolor='none', edgecolor='none', boxstyle='round', alpha=0.0), fontsize=6)
axes[0].tick_params(labelsize=5)

plt.delaxes(axes[1])
plt.tight_layout()
fig.savefig('C:\\Users\\WENJIA\\Downloads\\cora_ap_300.pdf', dpi=800)
# Out:
# C:\Users\WENJIA\AppData\Local\Temp\ipykernel_31336\412152402.py:59: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %% [markdown]
# ## Citeseer

# %%
import numpy as np
import matplotlib.pyplot as plt
import scienceplots
plt.style.use('science')
plt.style.use('nature')

my_dpi = 96
fig, axes = plt.subplots(1, 2, figsize=(2, 2.4), gridspec_kw={'width_ratios': [2, 0.2], 'wspace': 0.3}, dpi=800)  # 增加图的宽度

bars1 = [93.79,92.24,92.94,85.24,90.78,80.31,86.44,87.03,88.29,81.95,82.72,74.17]
bars2 = [80.92,78.59,86.11,80.57,71.97,72.44,72.49,75.77,72.41,70.78,74.53,71.19]
yer1 = [0.53,0.44,0.57,0.27,0.58,0.51,0.69,0.54,0.46,0.56,0.29,0.81]
yer2 = [0.35,0.27,0.39,0.48,0.62,0.57,0.84,0.89,0.63,0.42,0.53,0.73]

bars3 = [76.52]*len(bars1)
yer3 = [0.39]*len(bars1)
labels = ['Degree', 'Core', 'Pagerank', 'Betweenness', 'Closeness', 'Eigenvector', 'Gravitydegree', 'Gravitycore', 'Gravitypagerank', 'Gravitybetweenness', 'Gravitycloseness', 'Gravityeigenvector']

r1 = np.arange(len(bars1))
r2 = r1 
r3 = r1 

axes[0].errorbar(bars1, r1, xerr=yer1, fmt='o', c='#FB8071', ecolor='white', markeredgecolor='black', markeredgewidth=0.5,elinewidth=1, capsize=0, label='Sampled nodes')
axes[0].errorbar(bars2, r2, xerr=yer2, fmt='o', c='#FCB364', ecolor='white', markeredgecolor='black', markeredgewidth=0.5, elinewidth=0, capsize=0, label='Top nodes')
# axes[0].errorbar(bars3, r3, xerr=yer3, fmt='o', c='#7FB1D2', ecolor='white', markeredgecolor='black', markeredgewidth=0.5, elinewidth=0, capsize=0, label='Uniform nodes')
axes[0].errorbar(bars3[0], r3[0], xerr=yer3[0], fmt='o', c='#7FB1D2', ecolor='white', 
                 markeredgecolor='black', markeredgewidth=0.5, elinewidth=0, capsize=0, label='Uniform nodes')

axes[0].set_yticks(r1 )
axes[0].set_yticklabels(labels, fontsize=6)

axes[0].set_xlabel('Area Under the Curve(\%)', fontsize=5)
# axes[0].set_ylabel('Metrics', fontsize=4)

axes[0].set_xlim((60, 100))
axes[0].set_ylim((-1, 12))
axes[0].legend(loc=[0.9,0.7], fontsize=5)
axes[0].grid (False)
axes[0].set_xticks([60,70,80,90,100])
axes[0].spines['top'].set_visible(False)
axes[0].spines['right'].set_visible(False)
axes[0].xaxis.set_ticks_position('bottom')
axes[0].yaxis.set_ticks_position('left')
axes[0].set_xticks([60,70,80,90,100], minor=True)
axes[0].set_yticks([], minor=True)
for idx in range(len(bars1)):
    
    sampled_x = bars1[idx]
    top_x = bars2[idx]
    
    x_min = min(sampled_x, top_x)
    x_max = max(sampled_x, top_x)
    
    axes[0].fill_betweenx([r1[idx]-0.16, r2[idx]+0.16], x_min, x_max, color='grey', alpha=0.3 ,edgecolor=None)

axes[0].text(0.5, 1.05, r'AUC on Citeseer Subgraph with 300 nodes', transform=axes[0].transAxes, ha='center', va='center', bbox=dict(facecolor='none', edgecolor='none', boxstyle='round', alpha=0.0), fontsize=6)
axes[0].tick_params(labelsize=5)

plt.delaxes(axes[1])
plt.tight_layout()
fig.savefig('C:\\Users\\WENJIA\\Downloads\\citeseer_auc_300.pdf', dpi=800)
# Out:
# C:\Users\WENJIA\AppData\Local\Temp\ipykernel_31336\3857545527.py:60: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('science')
plt.style.use('nature')

my_dpi = 96
fig, axes = plt.subplots(1, 2, figsize=(2, 2.4), gridspec_kw={'width_ratios': [2, 0.2], 'wspace': 0.3}, dpi=800)  # 增加图的宽度

bars1 = [94.25,92.81,93.77,86.84,92.57,84.46,87.91,88.17,89.24,85.39,85.26,82.39]
bars2 = [85.42,81.99,88.43,83.52,75.29,77.16,76.24,80.57,77.93,75.51,77.71,75.43]
yer1 = [0.53,0.44,0.57,0.27,0.58,0.51,0.69,0.54,0.46,0.56,0.29,0.81]
yer2 = [0.35,0.27,0.39,0.48,0.62,0.57,0.84,0.89,0.63,0.42,0.53,0.73]

bars3 = [90.52]*len(bars1)
yer3 = [0.39]*len(bars1)
labels = ['Degree', 'Core', 'Pagerank', 'Betweenness', 'Closeness', 'Eigenvector', 'Gravitydegree', 'Gravitycore', 'Gravitypagerank', 'Gravitybetweenness', 'Gravitycloseness', 'Gravityeigenvector']

r1 = np.arange(len(bars1))
r2 = r1 
r3 = r1 

axes[0].errorbar(bars1, r1, xerr=yer1, fmt='o', c='#FB8071', ecolor='white', markeredgecolor='black', markeredgewidth=0.5,elinewidth=1, capsize=0, label='Sampled nodes')
axes[0].errorbar(bars2, r2, xerr=yer2, fmt='o', c='#FCB364', ecolor='white', markeredgecolor='black', markeredgewidth=0.5, elinewidth=0, capsize=0, label='Top nodes')
# axes[0].errorbar(bars3, r3, xerr=yer3, fmt='o', c='#7FB1D2', ecolor='white', markeredgecolor='black', markeredgewidth=0.5, elinewidth=0, capsize=0, label='Uniform nodes')
axes[0].errorbar(bars3[0], r3[0], xerr=yer3[0], fmt='o', c='#7FB1D2', ecolor='white', 
                 markeredgecolor='black', markeredgewidth=0.5, elinewidth=0, capsize=0, label='Uniform nodes')
axes[0].set_yticks(r1 ) 
axes[0].set_yticklabels(labels, fontsize=6)
axes[0].set_xlabel('Area Under Precision Recall(\%)', fontsize=5)  
# axes[0].set_ylabel('Metrics', fontsize=4)
axes[0].set_xlim((60, 100))  
axes[0].set_ylim((-1, 12))
axes[0].legend(loc=[0.9,0.7], fontsize=5)
axes[0].grid (False)
axes[0].set_xticks([60,70,80,90,100])
axes[0].spines['top'].set_visible(False)
axes[0].spines['right'].set_visible(False)
axes[0].xaxis.set_ticks_position('bottom')
axes[0].yaxis.set_ticks_position('left')
axes[0].set_xticks([60,70,80,90,100], minor=True)
axes[0].set_yticks([], minor=True)
for idx in range(len(bars1)):
    
    sampled_x = bars1[idx]
    top_x = bars2[idx]
    
    x_min = min(sampled_x, top_x)
    x_max = max(sampled_x, top_x)
    axes[0].fill_betweenx([r1[idx]-0.16, r2[idx]+0.16], x_min, x_max, color='grey', alpha=0.3 ,edgecolor=None)  

axes[0].text(0.5, 1.05, r'AP on Citeseer Subgraph with 300 nodes', transform=axes[0].transAxes, ha='center', va='center', bbox=dict(facecolor='none', edgecolor='none', boxstyle='round', alpha=0.0), fontsize=6)
axes[0].tick_params(labelsize=5)

plt.delaxes(axes[1])
plt.tight_layout()
fig.savefig('C:\\Users\\WENJIA\\Downloads\\citeseer_ap_300.pdf', dpi=800)
# Out:
# C:\Users\WENJIA\AppData\Local\Temp\ipykernel_31336\964502966.py:55: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %% [markdown]
# ## Pubmed

# %%
import numpy as np
import matplotlib.pyplot as plt
import scienceplots
plt.style.use('science')
plt.style.use('nature')

my_dpi = 96
fig, axes = plt.subplots(1, 2, figsize=(2, 2.4), gridspec_kw={'width_ratios': [2, 0.2], 'wspace': 0.3}, dpi=800)  # 增加图的宽度

bars1 =[95.7683,94.25,95.7989,95.5242,93.3089,85.3005,93.4488,93.506,94.6321,91.21,94.9518,79.7217]
bars2 = [92.57,89.2871,94.2289,94.4737,92.4566,81.7951,90.0421,88.8948,94.7005,88.2741,91.5919,78.3226]
yer1 = [0.53,0.44,0.57,0.27,0.58,0.51,0.69,0.54,0.46,0.56,0.29,0.81]
yer2 = [0.35,0.27,0.39,0.48,0.62,0.57,0.84,0.89,0.63,0.42,0.53,0.73]

bars3 = [89.52]*len(bars1)
yer3 = [0.39]*len(bars1)
labels = ['Degree', 'Core', 'Pagerank', 'Betweenness', 'Closeness', 'Eigenvector', 'Gravitydegree', 'Gravitycore', 'Gravitypagerank', 'Gravitybetweenness', 'Gravitycloseness', 'Gravityeigenvector']

r1 = np.arange(len(bars1))
r2 = r1 
r3 = r1 

axes[0].errorbar(bars1, r1, xerr=yer1, fmt='o', c='#FB8071', ecolor='white', markeredgecolor='black', markeredgewidth=0.5,elinewidth=1, capsize=0, label='Sampled nodes')
axes[0].errorbar(bars2, r2, xerr=yer2, fmt='o', c='#FCB364', ecolor='white', markeredgecolor='black', markeredgewidth=0.5, elinewidth=0, capsize=0, label='Top nodes')
# axes[0].errorbar(bars3, r3, xerr=yer3, fmt='o', c='#7FB1D2', ecolor='white', markeredgecolor='black', markeredgewidth=0.5, elinewidth=0, capsize=0, label='Uniform nodes')
axes[0].errorbar(bars3[0], r3[0], xerr=yer3[0], fmt='o', c='#7FB1D2', ecolor='white', 
                 markeredgecolor='black', markeredgewidth=0.5, elinewidth=0, capsize=0, label='Uniform nodes')

axes[0].set_yticks(r1 )
axes[0].set_yticklabels(labels, fontsize=6)

axes[0].set_xlabel('Area Under the Curve(\%)', fontsize=5)
# axes[0].set_ylabel('Metrics', fontsize=4)

axes[0].set_xlim((70, 100))
axes[0].set_ylim((-1, 12))
axes[0].legend(loc=[0.9,0.7], fontsize=5)
axes[0].grid (False)
axes[0].set_xticks([70,80,90,100])
axes[0].spines['top'].set_visible(False)
axes[0].spines['right'].set_visible(False)
axes[0].xaxis.set_ticks_position('bottom')
axes[0].yaxis.set_ticks_position('left')
axes[0].set_xticks([70,80,90,100], minor=True)
axes[0].set_yticks([], minor=True)
for idx in range(len(bars1)):
    
    sampled_x = bars1[idx]
    top_x = bars2[idx]
    
    x_min = min(sampled_x, top_x)
    x_max = max(sampled_x, top_x)
    
    axes[0].fill_betweenx([r1[idx]-0.16, r2[idx]+0.16], x_min, x_max, color='grey', alpha=0.3 ,edgecolor=None)

axes[0].text(0.5, 1.05, r'AUC on Pubmed Subgraph with 1500 nodes', transform=axes[0].transAxes, ha='center', va='center', bbox=dict(facecolor='none', edgecolor='none', boxstyle='round', alpha=0.0), fontsize=6)
axes[0].tick_params(labelsize=5)

plt.delaxes(axes[1])
plt.tight_layout()
fig.savefig('C:\\Users\\WENJIA\\Downloads\\pubmed_auc_1500.pdf', dpi=400)
# Out:
# C:\Users\WENJIA\AppData\Local\Temp\ipykernel_31336\1123297563.py:60: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('science')
plt.style.use('nature')

my_dpi = 96
fig, axes = plt.subplots(1, 2, figsize=(2, 2.4), gridspec_kw={'width_ratios': [2, 0.2], 'wspace': 0.3}, dpi=800)  # 增加图的宽度

bars1 = [95.8,94.3175,95.8874,95.7097,93.3505,86.6162,93.6652,93.67,94.7005,91.3693,95.0905,81.6382]
bars2 = [93.43,90.2539,94.9151,95.1167,92.9447,83.3044,91.0191,90.16,92.8403,88.8701,92.3612,79.506]
yer1 = [0.53,0.44,0.57,0.27,0.58,0.51,0.69,0.54,0.46,0.56,0.29,0.81]
yer2 = [0.35,0.27,0.39,0.48,0.62,0.57,0.84,0.89,0.63,0.42,0.53,0.73]

bars3 = [91.52]*len(bars1)
yer3 = [0.39]*len(bars1)
labels = ['Degree', 'Core', 'Pagerank', 'Betweenness', 'Closeness', 'Eigenvector', 'Gravitydegree', 'Gravitycore', 'Gravitypagerank', 'Gravitybetweenness', 'Gravitycloseness', 'Gravityeigenvector']

r1 = np.arange(len(bars1))
r2 = r1 
r3 = r1 

axes[0].errorbar(bars1, r1, xerr=yer1, fmt='o', c='#FB8071', ecolor='white', markeredgecolor='black', markeredgewidth=0.5,elinewidth=1, capsize=0, label='Sampled nodes')
axes[0].errorbar(bars2, r2, xerr=yer2, fmt='o', c='#FCB364', ecolor='white', markeredgecolor='black', markeredgewidth=0.5, elinewidth=0, capsize=0, label='Top nodes')
# axes[0].errorbar(bars3, r3, xerr=yer3, fmt='o', c='#7FB1D2', ecolor='white', markeredgecolor='black', markeredgewidth=0.5, elinewidth=0, capsize=0, label='Uniform nodes')
axes[0].errorbar(bars3[0], r3[0], xerr=yer3[0], fmt='o', c='#7FB1D2', ecolor='white', 
                 markeredgecolor='black', markeredgewidth=0.5, elinewidth=0, capsize=0, label='Uniform nodes')
axes[0].set_yticks(r1 ) 
axes[0].set_yticklabels(labels, fontsize=6)
axes[0].set_xlabel('Area Under Precision Recall(\%)', fontsize=5)  
# axes[0].set_ylabel('Metrics', fontsize=4)
axes[0].set_xlim((75, 100))  
axes[0].set_ylim((-1, 12))
axes[0].legend(loc=[0.9,0.7], fontsize=5)
axes[0].grid (False)
axes[0].set_xticks([70,80,90,100])
axes[0].spines['top'].set_visible(False)
axes[0].spines['right'].set_visible(False)
axes[0].xaxis.set_ticks_position('bottom')
axes[0].yaxis.set_ticks_position('left')
axes[0].set_xticks([70,80,90,100], minor=True)
axes[0].set_yticks([], minor=True)
for idx in range(len(bars1)):
    
    sampled_x = bars1[idx]
    top_x = bars2[idx]
    
    x_min = min(sampled_x, top_x)
    x_max = max(sampled_x, top_x)
    axes[0].fill_betweenx([r1[idx]-0.16, r2[idx]+0.16], x_min, x_max, color='grey', alpha=0.3 ,edgecolor=None)  

axes[0].text(0.5, 1.05, r'AP on Pubmed Subgraph with 1500 nodes', transform=axes[0].transAxes, ha='center', va='center', bbox=dict(facecolor='none', edgecolor='none', boxstyle='round', alpha=0.0), fontsize=6)
axes[0].tick_params(labelsize=5)

plt.delaxes(axes[1])
plt.tight_layout()
fig.savefig('C:\\Users\\WENJIA\\Downloads\\pubmed_ap_1500.pdf', dpi=300)
# Out:
# C:\Users\WENJIA\AppData\Local\Temp\ipykernel_31336\3180576758.py:55: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %% [markdown]
# ### CA-HepTh

# %%
import numpy as np
import matplotlib.pyplot as plt
import scienceplots
plt.style.use('science')
plt.style.use('nature')

my_dpi = 96
fig, axes = plt.subplots(1, 2, figsize=(2, 2.4), gridspec_kw={'width_ratios': [2, 0.2], 'wspace': 0.3}, dpi=800)  # 增加图的宽度

bars1 =[87.8633,87.0712,87.3126,85.7658,82.1139,81.4594,85.8901,82.8115,87.3126,84.4001,84.3615,78.3631]
bars2 = [82.2135,80.4404,84.4206,83.5115,79.7907,80.7651,79.3977,80.196,80.287,77.9386,76.6242,78.5712]
yer1 = [0.53,0.44,0.57,0.27,0.58,0.51,0.69,0.54,0.46,0.56,0.29,0.81]
yer2 = [0.35,0.27,0.39,0.48,0.62,0.57,0.84,0.89,0.63,0.42,0.53,0.73]

bars3 = [79.52]*len(bars1)
yer3 = [0.39]*len(bars1)
labels = ['Degree', 'Core', 'Pagerank', 'Betweenness', 'Closeness', 'Eigenvector', 'Gravitydegree', 'Gravitycore', 'Gravitypagerank', 'Gravitybetweenness', 'Gravitycloseness', 'Gravityeigenvector']

r1 = np.arange(len(bars1))
r2 = r1 
r3 = r1 

axes[0].errorbar(bars1, r1, xerr=yer1, fmt='o', c='#FB8071', ecolor='white', markeredgecolor='black', markeredgewidth=0.5,elinewidth=1, capsize=0, label='Sampled nodes')
axes[0].errorbar(bars2, r2, xerr=yer2, fmt='o', c='#FCB364', ecolor='white', markeredgecolor='black', markeredgewidth=0.5, elinewidth=0, capsize=0, label='Top nodes')
# axes[0].errorbar(bars3, r3, xerr=yer3, fmt='o', c='#7FB1D2', ecolor='white', markeredgecolor='black', markeredgewidth=0.5, elinewidth=0, capsize=0, label='Uniform nodes')
axes[0].errorbar(bars3[0], r3[0], xerr=yer3[0], fmt='o', c='#7FB1D2', ecolor='white', 
                 markeredgecolor='black', markeredgewidth=0.5, elinewidth=0, capsize=0, label='Uniform nodes')

axes[0].set_yticks(r1 )
axes[0].set_yticklabels(labels, fontsize=6)

axes[0].set_xlabel('Area Under the Curve(\%)', fontsize=5)
# axes[0].set_ylabel('Metrics', fontsize=4)

axes[0].set_xlim((70, 100))
axes[0].set_ylim((-1, 12))
axes[0].legend(loc=[0.9,0.7], fontsize=5)
axes[0].grid (False)
axes[0].set_xticks([70,80,90,100])
axes[0].spines['top'].set_visible(False)
axes[0].spines['right'].set_visible(False)
axes[0].xaxis.set_ticks_position('bottom')
axes[0].yaxis.set_ticks_position('left')
axes[0].set_xticks([70,80,90,100], minor=True)
axes[0].set_yticks([], minor=True)
for idx in range(len(bars1)):
    
    sampled_x = bars1[idx]
    top_x = bars2[idx]
    
    x_min = min(sampled_x, top_x)
    x_max = max(sampled_x, top_x)
    
    axes[0].fill_betweenx([r1[idx]-0.16, r2[idx]+0.16], x_min, x_max, color='grey', alpha=0.3 ,edgecolor=None)

axes[0].text(0.5, 1.05, r'AUC on CA-HepTh Subgraph with 1000 nodes', transform=axes[0].transAxes, ha='center', va='center', bbox=dict(facecolor='none', edgecolor='none', boxstyle='round', alpha=0.0), fontsize=6)
axes[0].tick_params(labelsize=5)

plt.delaxes(axes[1])
plt.tight_layout()
fig.savefig('C:\\Users\\WENJIA\\Downloads\\cath_auc_1000.pdf', dpi=300)
# Out:
# C:\Users\WENJIA\AppData\Local\Temp\ipykernel_31336\3640232917.py:60: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('science')
plt.style.use('nature')

my_dpi = 96
fig, axes = plt.subplots(1, 2, figsize=(2, 2.4), gridspec_kw={'width_ratios': [2, 0.2], 'wspace': 0.3}, dpi=800)  # 增加图的宽度

bars1 = [90.2566,89.2429,89.6746,88.4484,84.5645,84.4588,88.7489,83.4099,89.6746,85.2557,87.3516,81.2948]
bars2 = [85.3442,83.4204,87.1345,86.8085,83.4636,83.7584,83.3559,83.6907,83.5967,81.5802,83.9479,81.7515]
yer1 = [0.53,0.44,0.57,0.27,0.58,0.51,0.69,0.54,0.46,0.56,0.29,0.81]
yer2 = [0.35,0.27,0.39,0.48,0.62,0.57,0.84,0.89,0.63,0.42,0.53,0.73]

bars3 = [81.52]*len(bars1)
yer3 = [0.39]*len(bars1)
labels = ['Degree', 'Core', 'Pagerank', 'Betweenness', 'Closeness', 'Eigenvector', 'Gravitydegree', 'Gravitycore', 'Gravitypagerank', 'Gravitybetweenness', 'Gravitycloseness', 'Gravityeigenvector']

r1 = np.arange(len(bars1))
r2 = r1 
r3 = r1 

axes[0].errorbar(bars1, r1, xerr=yer1, fmt='o', c='#FB8071', ecolor='white', markeredgecolor='black', markeredgewidth=0.5,elinewidth=1, capsize=0, label='Sampled nodes')
axes[0].errorbar(bars2, r2, xerr=yer2, fmt='o', c='#FCB364', ecolor='white', markeredgecolor='black', markeredgewidth=0.5, elinewidth=0, capsize=0, label='Top nodes')
# axes[0].errorbar(bars3, r3, xerr=yer3, fmt='o', c='#7FB1D2', ecolor='white', markeredgecolor='black', markeredgewidth=0.5, elinewidth=0, capsize=0, label='Uniform nodes')
axes[0].errorbar(bars3[0], r3[0], xerr=yer3[0], fmt='o', c='#7FB1D2', ecolor='white', 
                 markeredgecolor='black', markeredgewidth=0.5, elinewidth=0, capsize=0, label='Uniform nodes')
axes[0].set_yticks(r1 ) 
axes[0].set_yticklabels(labels, fontsize=6)
axes[0].set_xlabel('Area Under Precision Recall(\%)', fontsize=5)  
# axes[0].set_ylabel('Metrics', fontsize=4)
axes[0].set_xlim((75, 100))  
axes[0].set_ylim((-1, 12))
axes[0].legend(loc=[0.9,0.7], fontsize=5)
axes[0].grid (False)
axes[0].set_xticks([70,80,90,100])
axes[0].spines['top'].set_visible(False)
axes[0].spines['right'].set_visible(False)
axes[0].xaxis.set_ticks_position('bottom')
axes[0].yaxis.set_ticks_position('left')
axes[0].set_xticks([70,80,90,100], minor=True)
axes[0].set_yticks([], minor=True)
for idx in range(len(bars1)):
    
    sampled_x = bars1[idx]
    top_x = bars2[idx]
    
    x_min = min(sampled_x, top_x)
    x_max = max(sampled_x, top_x)
    axes[0].fill_betweenx([r1[idx]-0.16, r2[idx]+0.16], x_min, x_max, color='grey', alpha=0.3 ,edgecolor=None)  

axes[0].text(0.5, 1.05, r'AP on CA-HepTh Subgraph with 1000 nodes', transform=axes[0].transAxes, ha='center', va='center', bbox=dict(facecolor='none', edgecolor='none', boxstyle='round', alpha=0.0), fontsize=6)
axes[0].tick_params(labelsize=5)

plt.delaxes(axes[1])
plt.tight_layout()
fig.savefig('C:\\Users\\WENJIA\\Downloads\\cath_ap_1000.pdf', dpi=300)
# Out:
# C:\Users\WENJIA\AppData\Local\Temp\ipykernel_31336\3242989887.py:55: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %% [markdown]
# ### CA-CondMat

# %%
import numpy as np
import matplotlib.pyplot as plt
import scienceplots
plt.style.use('science')
plt.style.use('nature')

my_dpi = 96
fig, axes = plt.subplots(1, 2, figsize=(2, 2.4), gridspec_kw={'width_ratios': [2, 0.2], 'wspace': 0.3}, dpi=800)  # 增加图的宽度

bars1 =[91.671,92.6501,93.2314,89.5652,88.8446,82.1013,87.4771,89.0519,90.2829,85.1205,87.0979,79.3938]
bars2 = [88.326,84.4141,88.7892,89.0561,86.3818,84.6731,83.5472,83.1858,83.4117,83.3414,85.6457,81.6576]
yer1 = [0.53,0.44,0.57,0.27,0.58,0.51,0.69,0.54,0.46,0.56,0.29,0.81]
yer2 = [0.35,0.27,0.39,0.48,0.62,0.57,0.84,0.89,0.63,0.42,0.53,0.73]

bars3 = [89.52]*len(bars1)
yer3 = [0.39]*len(bars1)
labels = ['Degree', 'Core', 'Pagerank', 'Betweenness', 'Closeness', 'Eigenvector', 'Gravitydegree', 'Gravitycore', 'Gravitypagerank', 'Gravitybetweenness', 'Gravitycloseness', 'Gravityeigenvector']

r1 = np.arange(len(bars1))
r2 = r1 
r3 = r1 

axes[0].errorbar(bars1, r1, xerr=yer1, fmt='o', c='#FB8071', ecolor='white', markeredgecolor='black', markeredgewidth=0.5,elinewidth=1, capsize=0, label='Sampled nodes')
axes[0].errorbar(bars2, r2, xerr=yer2, fmt='o', c='#FCB364', ecolor='white', markeredgecolor='black', markeredgewidth=0.5, elinewidth=0, capsize=0, label='Top nodes')
# axes[0].errorbar(bars3, r3, xerr=yer3, fmt='o', c='#7FB1D2', ecolor='white', markeredgecolor='black', markeredgewidth=0.5, elinewidth=0, capsize=0, label='Uniform nodes')
axes[0].errorbar(bars3[0], r3[0], xerr=yer3[0], fmt='o', c='#7FB1D2', ecolor='white', 
                 markeredgecolor='black', markeredgewidth=0.5, elinewidth=0, capsize=0, label='Uniform nodes')

axes[0].set_yticks(r1 )
axes[0].set_yticklabels(labels, fontsize=6)

axes[0].set_xlabel('Area Under the Curve(\%)', fontsize=5)
# axes[0].set_ylabel('Metrics', fontsize=4)

axes[0].set_xlim((70, 100))
axes[0].set_ylim((-1, 12))
axes[0].legend(loc=[0.9,0.7], fontsize=5)
axes[0].grid (False)
axes[0].set_xticks([70,80,90,100])
axes[0].spines['top'].set_visible(False)
axes[0].spines['right'].set_visible(False)
axes[0].xaxis.set_ticks_position('bottom')
axes[0].yaxis.set_ticks_position('left')
axes[0].set_xticks([70,80,90,100], minor=True)
axes[0].set_yticks([], minor=True)
for idx in range(len(bars1)):
    
    sampled_x = bars1[idx]
    top_x = bars2[idx]
    
    x_min = min(sampled_x, top_x)
    x_max = max(sampled_x, top_x)
    
    axes[0].fill_betweenx([r1[idx]-0.16, r2[idx]+0.16], x_min, x_max, color='grey', alpha=0.3 ,edgecolor=None)

axes[0].text(0.5, 1.05, r'AUC on CA-CondMat Subgraph with 1500 nodes', transform=axes[0].transAxes, ha='center', va='center', bbox=dict(facecolor='none', edgecolor='none', boxstyle='round', alpha=0.0), fontsize=6)
axes[0].tick_params(labelsize=5)

plt.delaxes(axes[1])
plt.tight_layout()
fig.savefig('C:\\Users\\WENJIA\\Downloads\\cmat_auc_1500.pdf', dpi=800)
# Out:
# C:\Users\WENJIA\AppData\Local\Temp\ipykernel_31336\3309741634.py:60: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('science')
plt.style.use('nature')

my_dpi = 96
fig, axes = plt.subplots(1, 2, figsize=(2, 2.4), gridspec_kw={'width_ratios': [2, 0.2], 'wspace': 0.3}, dpi=800)  # 增加图的宽度

bars1 = [92.916,93.7517,94.3505,91.0292,89.7182,84.9416,89.3214,90.8428,91.8318,87.1689,88.5538,82.1116]
bars2 = [90.359,86.7675,90.2834,90.5814,88.2153,87.055,85.9914,85.5027,85.7214,85.5005,87.6235,83.871]
yer1 = [0.53,0.44,0.57,0.27,0.58,0.51,0.69,0.54,0.46,0.56,0.29,0.81]
yer2 = [0.35,0.27,0.39,0.48,0.62,0.57,0.84,0.89,0.63,0.42,0.53,0.73]

bars3 = [78.52]*len(bars1)
yer3 = [0.39]*len(bars1)
labels = ['Degree', 'Core', 'Pagerank', 'Betweenness', 'Closeness', 'Eigenvector', 'Gravitydegree', 'Gravitycore', 'Gravitypagerank', 'Gravitybetweenness', 'Gravitycloseness', 'Gravityeigenvector']

r1 = np.arange(len(bars1))
r2 = r1 
r3 = r1 

axes[0].errorbar(bars1, r1, xerr=yer1, fmt='o', c='#FB8071', ecolor='white', markeredgecolor='black', markeredgewidth=0.5,elinewidth=1, capsize=0, label='Sampled nodes')
axes[0].errorbar(bars2, r2, xerr=yer2, fmt='o', c='#FCB364', ecolor='white', markeredgecolor='black', markeredgewidth=0.5, elinewidth=0, capsize=0, label='Top nodes')
# axes[0].errorbar(bars3, r3, xerr=yer3, fmt='o', c='#7FB1D2', ecolor='white', markeredgecolor='black', markeredgewidth=0.5, elinewidth=0, capsize=0, label='Uniform nodes')
axes[0].errorbar(bars3[0], r3[0], xerr=yer3[0], fmt='o', c='#7FB1D2', ecolor='white', 
                 markeredgecolor='black', markeredgewidth=0.5, elinewidth=0, capsize=0, label='Uniform nodes')
axes[0].set_yticks(r1 ) 
axes[0].set_yticklabels(labels, fontsize=6)
axes[0].set_xlabel('Area Under Precision Recall(\%)', fontsize=5)  
# axes[0].set_ylabel('Metrics', fontsize=4)
axes[0].set_xlim((75, 100))  
axes[0].set_ylim((-1, 12))
axes[0].legend(loc=[0.9,0.7], fontsize=5)
axes[0].grid (False)
axes[0].set_xticks([70,80,90,100])
axes[0].spines['top'].set_visible(False)
axes[0].spines['right'].set_visible(False)
axes[0].xaxis.set_ticks_position('bottom')
axes[0].yaxis.set_ticks_position('left')
axes[0].set_xticks([70,80,90,100], minor=True)
axes[0].set_yticks([], minor=True)
for idx in range(len(bars1)):
    
    sampled_x = bars1[idx]
    top_x = bars2[idx]
    
    x_min = min(sampled_x, top_x)
    x_max = max(sampled_x, top_x)
    axes[0].fill_betweenx([r1[idx]-0.16, r2[idx]+0.16], x_min, x_max, color='grey', alpha=0.3 ,edgecolor=None)  

axes[0].text(0.5, 1.05, r'AP on CA-CondMat Subgraph with 1500 nodes', transform=axes[0].transAxes, ha='center', va='center', bbox=dict(facecolor='none', edgecolor='none', boxstyle='round', alpha=0.0), fontsize=6)
axes[0].tick_params(labelsize=5)

plt.delaxes(axes[1])
plt.tight_layout()
fig.savefig('C:\\Users\\WENJIA\\Downloads\\cmat_ap_1500.pdf', dpi=400)
# Out:
# C:\Users\WENJIA\AppData\Local\Temp\ipykernel_31336\3526886087.py:55: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %% [markdown]
# ## Small World 3000

# %%
import numpy as np
import matplotlib.pyplot as plt
import scienceplots
plt.style.use('science')
plt.style.use('nature')

my_dpi = 96
fig, axes = plt.subplots(1, 2, figsize=(2, 2.4), gridspec_kw={'width_ratios': [2, 0.2], 'wspace': 0.3}, dpi=800)  # 增加图的宽度

bars1 = [71.94,71.36,71.54,68.25,68.79,68.69,70.46,71.42,68.22,68.88]
bars2 = [63.81,58.92,64.27,62.33,58.4,62.64,63.28,64.08,59.86,61.03]
yer1 = [0.53,0.44,0.57,0.27,0.58,0.51,0.69,0.54,0.46,0.56]
yer2 = [0.35,0.27,0.39,0.48,0.62,0.57,0.84,0.89,0.63,0.42]

bars3 = [60.52]*len(bars1)
yer3 = [0.39]*len(bars1)
labels = ['Degree', 'Core', 'Pagerank', 'Betweenness', 'Closeness',  'Gravitydegree', 'Gravitycore', 'Gravitypagerank', 'Gravitybetweenness', 'Gravitycloseness', ]

r1 = np.arange(len(bars1))
r2 = r1 
r3 = r1 

axes[0].errorbar(bars1, r1, xerr=yer1, fmt='o', c='#FB8071', ecolor='white', markeredgecolor='black', markeredgewidth=0.5,elinewidth=1, capsize=0, label='Sampled nodes')
axes[0].errorbar(bars2, r2, xerr=yer2, fmt='o', c='#FCB364', ecolor='white', markeredgecolor='black', markeredgewidth=0.5, elinewidth=0, capsize=0, label='Top nodes')
# axes[0].errorbar(bars3, r3, xerr=yer3, fmt='o', c='#7FB1D2', ecolor='white', markeredgecolor='black', markeredgewidth=0.5, elinewidth=0, capsize=0, label='Uniform nodes')
axes[0].errorbar(bars3[0], r3[0], xerr=yer3[0], fmt='o', c='#7FB1D2', ecolor='white', 
                 markeredgecolor='black', markeredgewidth=0.5, elinewidth=0, capsize=0, label='Uniform nodes')

axes[0].set_yticks(r1 )
axes[0].set_yticklabels(labels, fontsize=6)

axes[0].set_xlabel('Area Under the Curve(\%)', fontsize=5)
# axes[0].set_ylabel('Metrics', fontsize=4)

axes[0].set_xlim((50, 90))
axes[0].set_ylim((-1, 10))
axes[0].legend(loc=[0.8,0.7], fontsize=5)
axes[0].grid (False)
axes[0].set_xticks([60,70,80,90,100])
axes[0].spines['top'].set_visible(False)
axes[0].spines['right'].set_visible(False)
axes[0].xaxis.set_ticks_position('bottom')
axes[0].yaxis.set_ticks_position('left')
axes[0].set_xticks([60,70,80,90,100], minor=True)
axes[0].set_yticks([], minor=True)
for idx in range(len(bars1)):
    
    sampled_x = bars1[idx]
    top_x = bars2[idx]
    
    x_min = min(sampled_x, top_x)
    x_max = max(sampled_x, top_x)

    
    axes[0].fill_betweenx([r1[idx]-0.16, r2[idx]+0.16], x_min, x_max, color='grey', alpha=0.3 ,edgecolor=None)

axes[0].text(0.5, 1.05, r'AUC on Small World 3000 Subgraph with 300 nodes', transform=axes[0].transAxes, ha='center', va='center', bbox=dict(facecolor='none', edgecolor='none', boxstyle='round', alpha=0.0), fontsize=6)
axes[0].tick_params(labelsize=5)

plt.delaxes(axes[1])
plt.tight_layout()
fig.savefig('C:\\Users\\WENJIA\\Downloads\\wk3k_auc_300.pdf', dpi=800)
# Out:
# C:\Users\WENJIA\AppData\Local\Temp\ipykernel_31336\3569559198.py:61: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %%
import numpy as np
import matplotlib.pyplot as plt
import scienceplots
plt.style.use('science')
plt.style.use('nature')

my_dpi = 96
fig, axes = plt.subplots(1, 2, figsize=(2, 2.4), gridspec_kw={'width_ratios': [2, 0.2], 'wspace': 0.3}, dpi=800)  # 增加图的宽度

bars1 = [75.12,74.04,74.96,70.38,71.63,71.33,72.68,71.15,70.94,71.19]
bars2 = [68.68,61.37,68.34,66.15,61.28,67.16,67.86,68.16,63.25,65.02]
yer1 = [0.53,0.44,0.57,0.27,0.58,0.51,0.69,0.54,0.46,0.56]
yer2 = [0.35,0.27,0.39,0.48,0.62,0.57,0.84,0.89,0.63,0.42]

bars3 = [61.34]*len(bars1)
yer3 = [0.39]*len(bars1)
labels = ['Degree', 'Core', 'Pagerank', 'Betweenness', 'Closeness',  'Gravitydegree', 'Gravitycore', 'Gravitypagerank', 'Gravitybetweenness', 'Gravitycloseness', ]

r1 = np.arange(len(bars1))
r2 = r1 
r3 = r1 

axes[0].errorbar(bars1, r1, xerr=yer1, fmt='o', c='#FB8071', ecolor='white', markeredgecolor='black', markeredgewidth=0.5,elinewidth=1, capsize=0, label='Sampled nodes')
axes[0].errorbar(bars2, r2, xerr=yer2, fmt='o', c='#FCB364', ecolor='white', markeredgecolor='black', markeredgewidth=0.5, elinewidth=0, capsize=0, label='Top nodes')
# axes[0].errorbar(bars3, r3, xerr=yer3, fmt='o', c='#7FB1D2', ecolor='white', markeredgecolor='black', markeredgewidth=0.5, elinewidth=0, capsize=0, label='Uniform nodes')
axes[0].errorbar(bars3[0], r3[0], xerr=yer3[0], fmt='o', c='#7FB1D2', ecolor='white', 
                 markeredgecolor='black', markeredgewidth=0.5, elinewidth=0, capsize=0, label='Uniform nodes')

axes[0].set_yticks(r1 )
axes[0].set_yticklabels(labels, fontsize=6)

axes[0].set_xlabel('Area Under the Curve(\%)', fontsize=5)
# axes[0].set_ylabel('Metrics', fontsize=4)

axes[0].set_xlim((50, 90))
axes[0].set_ylim((-1, 10))
axes[0].legend(loc=[0.8,0.7], fontsize=5)
axes[0].grid (False)
axes[0].set_xticks([60,70,80,90,100])
axes[0].spines['top'].set_visible(False)
axes[0].spines['right'].set_visible(False)
axes[0].xaxis.set_ticks_position('bottom')
axes[0].yaxis.set_ticks_position('left')
axes[0].set_xticks([60,70,80,90,100], minor=True)
axes[0].set_yticks([], minor=True)
for idx in range(len(bars1)):
    
    sampled_x = bars1[idx]
    top_x = bars2[idx]
    
    x_min = min(sampled_x, top_x)
    x_max = max(sampled_x, top_x)
    
    axes[0].fill_betweenx([r1[idx]-0.16, r2[idx]+0.16], x_min, x_max, color='grey', alpha=0.3 ,edgecolor=None)
axes[0].text(0.5, 1.05, r'AP on Small World 3000  Subgraph with 300 nodes', transform=axes[0].transAxes, ha='center', va='center', bbox=dict(facecolor='none', edgecolor='none', boxstyle='round', alpha=0.0), fontsize=6)
axes[0].tick_params(labelsize=5)

plt.delaxes(axes[1])
plt.tight_layout()
fig.savefig('C:\\Users\\WENJIA\\Downloads\\ws3k_ap_300.pdf', dpi=800)
# Out:
# C:\Users\WENJIA\AppData\Local\Temp\ipykernel_31336\3604935704.py:59: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %%
import numpy as np
import matplotlib.pyplot as plt
import scienceplots
plt.style.use('science')
plt.style.use('nature')

my_dpi = 96
fig, axes = plt.subplots(1, 2, figsize=(2, 2.4), gridspec_kw={'width_ratios': [2, 0.2], 'wspace': 0.3}, dpi=800)  # 增加图的宽度

bars1 =[75.6618,76.8242,76.0468,72.3497,73.0787,75.0161,77.2182,77.0882,70.7303,73.2708]
bars2 = [69.9727,60.7427,70.7028,66.9437,65.2053,66.6904,68.9116,66.9328,63.5692,67.2488]
yer1 = [0.53,0.44,0.57,0.27,0.58,0.51,0.69,0.54,0.46,0.56]
yer2 = [0.35,0.27,0.39,0.48,0.62,0.57,0.84,0.89,0.63,0.42]

bars3 = [67.92]*len(bars1)
yer3 = [0.39]*len(bars1)
labels = ['Degree', 'Core', 'Pagerank', 'Betweenness', 'Closeness',  'Gravitydegree', 'Gravitycore', 'Gravitypagerank', 'Gravitybetweenness', 'Gravitycloseness', ]

r1 = np.arange(len(bars1))
r2 = r1 
r3 = r1 

axes[0].errorbar(bars1, r1, xerr=yer1, fmt='o', c='#FB8071', ecolor='white', markeredgecolor='black', markeredgewidth=0.5,elinewidth=1, capsize=0, label='Sampled nodes')
axes[0].errorbar(bars2, r2, xerr=yer2, fmt='o', c='#FCB364', ecolor='white', markeredgecolor='black', markeredgewidth=0.5, elinewidth=0, capsize=0, label='Top nodes')
# axes[0].errorbar(bars3, r3, xerr=yer3, fmt='o', c='#7FB1D2', ecolor='white', markeredgecolor='black', markeredgewidth=0.5, elinewidth=0, capsize=0, label='Uniform nodes')
axes[0].errorbar(bars3[0], r3[0], xerr=yer3[0], fmt='o', c='#7FB1D2', ecolor='white', 
                 markeredgecolor='black', markeredgewidth=0.5, elinewidth=0, capsize=0, label='Uniform nodes')

axes[0].set_yticks(r1 )
axes[0].set_yticklabels(labels, fontsize=6)

axes[0].set_xlabel('Area Under the Curve(\%)', fontsize=5)
# axes[0].set_ylabel('Metrics', fontsize=4)

axes[0].set_xlim((50, 90))
axes[0].set_ylim((-1, 10))
axes[0].legend(loc=[0.8,0.7], fontsize=5)
axes[0].grid (False)
axes[0].set_xticks([60,70,80,90,100])
axes[0].spines['top'].set_visible(False)
axes[0].spines['right'].set_visible(False)
axes[0].xaxis.set_ticks_position('bottom')
axes[0].yaxis.set_ticks_position('left')
axes[0].set_xticks([60,70,80,90,100], minor=True)
axes[0].set_yticks([], minor=True)
for idx in range(len(bars1)):
    
    sampled_x = bars1[idx]
    top_x = bars2[idx]
    
    x_min = min(sampled_x, top_x)
    x_max = max(sampled_x, top_x)

    
    axes[0].fill_betweenx([r1[idx]-0.16, r2[idx]+0.16], x_min, x_max, color='grey', alpha=0.3 ,edgecolor=None)

axes[0].text(0.5, 1.05, r'AUC on Small World 10000 Subgraph with 1000 nodes', transform=axes[0].transAxes, ha='center', va='center', bbox=dict(facecolor='none', edgecolor='none', boxstyle='round', alpha=0.0), fontsize=6)
axes[0].tick_params(labelsize=5)

plt.delaxes(axes[1])
plt.tight_layout()
fig.savefig('C:\\Users\\WENJIA\\Downloads\\ws1w_auc_1000.pdf', dpi=800)
# Out:
# C:\Users\WENJIA\AppData\Local\Temp\ipykernel_31336\1490982888.py:61: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %%
import numpy as np
import matplotlib.pyplot as plt
import scienceplots
plt.style.use('science')
plt.style.use('nature')

my_dpi = 96
fig, axes = plt.subplots(1, 2, figsize=(2, 2.4), gridspec_kw={'width_ratios': [2, 0.2], 'wspace': 0.3}, dpi=800)  # 增加图的宽度

bars1 =[76.707,79.2155,78.2069,70.7157,71.7214,76.5648,78.2695,78.9046,69.4226,71.7001]
bars2 = [71.8367,63.3554,72.9418,69.4637,67.6004,67.6381,70.5929,68.3696,66.3659,70.0029]
yer1 = [0.53,0.44,0.57,0.27,0.58,0.51,0.69,0.54,0.46,0.56]
yer2 = [0.35,0.27,0.39,0.48,0.62,0.57,0.84,0.89,0.63,0.42]

bars3 = [70.34]*len(bars1)
yer3 = [0.39]*len(bars1)
labels = ['Degree', 'Core', 'Pagerank', 'Betweenness', 'Closeness',  'Gravitydegree', 'Gravitycore', 'Gravitypagerank', 'Gravitybetweenness', 'Gravitycloseness', ]

r1 = np.arange(len(bars1))
r2 = r1 
r3 = r1 

axes[0].errorbar(bars1, r1, xerr=yer1, fmt='o', c='#FB8071', ecolor='white', markeredgecolor='black', markeredgewidth=0.5,elinewidth=1, capsize=0, label='Sampled nodes')
axes[0].errorbar(bars2, r2, xerr=yer2, fmt='o', c='#FCB364', ecolor='white', markeredgecolor='black', markeredgewidth=0.5, elinewidth=0, capsize=0, label='Top nodes')
# axes[0].errorbar(bars3, r3, xerr=yer3, fmt='o', c='#7FB1D2', ecolor='white', markeredgecolor='black', markeredgewidth=0.5, elinewidth=0, capsize=0, label='Uniform nodes')
axes[0].errorbar(bars3[0], r3[0], xerr=yer3[0], fmt='o', c='#7FB1D2', ecolor='white', 
                 markeredgecolor='black', markeredgewidth=0.5, elinewidth=0, capsize=0, label='Uniform nodes')

axes[0].set_yticks(r1 )
axes[0].set_yticklabels(labels, fontsize=6)

axes[0].set_xlabel('Area Under the Curve(\%)', fontsize=5)
# axes[0].set_ylabel('Metrics', fontsize=4)

axes[0].set_xlim((50, 90))
axes[0].set_ylim((-1, 10))
axes[0].legend(loc=[0.8,0.7], fontsize=5)
axes[0].grid (False)
axes[0].set_xticks([60,70,80,90,100])
axes[0].spines['top'].set_visible(False)
axes[0].spines['right'].set_visible(False)
axes[0].xaxis.set_ticks_position('bottom')
axes[0].yaxis.set_ticks_position('left')
axes[0].set_xticks([60,70,80,90,100], minor=True)
axes[0].set_yticks([], minor=True)
for idx in range(len(bars1)):
    
    sampled_x = bars1[idx]
    top_x = bars2[idx]
    
    x_min = min(sampled_x, top_x)
    x_max = max(sampled_x, top_x)
    
    axes[0].fill_betweenx([r1[idx]-0.16, r2[idx]+0.16], x_min, x_max, color='grey', alpha=0.3 ,edgecolor=None)
axes[0].text(0.5, 1.05, r'AP on Small World 10000 Subgraph with 1000 nodes', transform=axes[0].transAxes, ha='center', va='center', bbox=dict(facecolor='none', edgecolor='none', boxstyle='round', alpha=0.0), fontsize=6)
axes[0].tick_params(labelsize=5)

plt.delaxes(axes[1])
plt.tight_layout()
fig.savefig('C:\\Users\\WENJIA\\Downloads\\wk1w_ap_1000.pdf', dpi=800)
# Out:
# C:\Users\WENJIA\AppData\Local\Temp\ipykernel_31336\3398287051.py:59: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

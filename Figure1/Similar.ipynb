# %%
import numpy as np
import matplotlib.pylab as plt
# %matplotlib inline
#%config InlineBackend.figure_format = 'eps'
import scienceplots
import pandas as pd


from mpl_toolkits.axes_grid1.inset_locator import inset_axes
from matplotlib.patches import  ConnectionPatch

# %% [markdown]
# ### cora datasets

# %%
# Samped nodes by probability

cora_degree_rn = pd.read_csv('cora/convert_similar/cora_rn_gcn_vae_degree_similar.csv')
cora_core_rn = pd.read_csv('cora/convert_similar/cora_rn_gcn_vae_core_similar.csv')
cora_betweenness_rn = pd.read_csv('cora/convert_similar/cora_rn_gcn_vae_betweenness_similar.csv')
cora_eigenvector_rn = pd.read_csv('cora/convert_similar/cora_rn_gcn_vae_eigenvector_similar.csv')
cora_pagerank_rn = pd.read_csv('cora/convert_similar/cora_rn_gcn_vae_pagerank_similar.csv')
cora_closeness_rn = pd.read_csv('cora/convert_similar/cora_rn_gcn_vae_closeness_similar.csv')

cora_gravitydegree_rn = pd.read_csv('cora/convert_similar/cora_rn_gcn_vae_gravitydegree_similar.csv')
cora_gravitypagerank_rn = pd.read_csv('cora/convert_similar/cora_rn_gcn_vae_gravitypagerank_similar.csv')
cora_gravitycore_rn = pd.read_csv('cora/convert_similar/cora_rn_gcn_vae_gravitycore_similar.csv')
cora_gravitybetweenness_rn = pd.read_csv('cora/convert_similar/cora_rn_gcn_vae_gravityeigenvector_similar.csv')
cora_gravityeigenvector_rn = pd.read_csv('cora/convert_similar/cora_rn_gcn_vae_gravityeigenvector_similar.csv')
cora_gravitycloseness_rn = pd.read_csv('cora/convert_similar/cora_rn_gcn_vae_gravitycloseness_similar.csv')
cora_uniform_un = pd.read_csv('cora/convert_similar/cora_tn_gcn_vae_degree_similar.csv')


plt.style.use('science')
plt.style.use('nature')

fig,axes = plt.subplots(figsize = (3.6,2.7),dpi=400)
x = np.linspace(0,1,54)

axes.plot(x,cora_degree_rn['mean_similar'],color ='#BC3C29FF',label = ' degree',linewidth = 0.5)
axes.plot(x,cora_core_rn['mean_similar'],color ='#20854EFF',label = 'core',linewidth = 0.5)
axes.plot(x,cora_pagerank_rn['mean_similar'],color ='#0072B5FF',label = 'pagerank',linewidth = 0.5)
axes.plot(x,cora_betweenness_rn['mean_similar'],color ='#E18727FF',label = 'betweenness',linewidth = 0.5)
axes.plot(x,cora_closeness_rn['mean_similar'],color ='#7876B1FF',label = 'closeness',linewidth = 0.5)
axes.plot(x,cora_eigenvector_rn['mean_similar'],color ='#6F99ADFF',label = ' eigenvector',linewidth = 0.5,linestyle = '-')

axes.plot(x,cora_gravitydegree_rn['mean_similar'],color ='#BC3C29FF',label = ' gravitydegree',linewidth = 0.5,linestyle = '-')
axes.plot(x,cora_gravitycore_rn['mean_similar'],color ='#20854EFF',label = 'gravitycore',linewidth = 0.5,linestyle = '--')
axes.plot(x,cora_gravitypagerank_rn['mean_similar'],color ='#0072B5FF',label = 'gravitypagerank',linewidth = 0.5,linestyle = '--')
axes.plot(x,cora_gravitybetweenness_rn['mean_similar'],color ='#E18727FF',label = 'gravitybetweenness',linewidth = 0.5,linestyle = '--')
axes.plot(x,cora_gravitycloseness_rn['mean_similar'],color ='#7876B1FF',label = 'gravitycloseness',linewidth = 0.5,linestyle = '--')
axes.plot(x,cora_gravityeigenvector_rn['mean_similar'],color ='#6F99ADFF',label = 'gravityeigenvector',linewidth = 0.5,linestyle = '--')
# axes.plot(x,cora_similar[:,12],color ='black',label = 'uniform',linewidth = 0.5,linestyle = ':')



#axes.set_title('WS Networks')
axes.set_xlabel('Sampling Ratio(%)',fontsize=6)
axes.set_ylabel('Jaccard similarity coefficient',fontsize=6)
axes.set_title('Cora',fontsize=6)
axes.tick_params(labelsize=6)
axes.legend(fontsize=4,frameon =False)
axes.set_ylim([0,1])
axes.set_xlim([-0.05,1.05])
axes.tick_params(axis='both', which='both', length=2,pad=2,width=0.6)
axes.grid(False)

# %%
# Samped nodes by probability

citeseer_degree_rn = pd.read_csv('citeseer/convert_similar/citeseer_rn_gcn_vae_degree_similar.csv')
citeseer_core_rn = pd.read_csv('citeseer/convert_similar/citeseer_rn_gcn_vae_core_similar.csv')
citeseer_betweenness_rn = pd.read_csv('citeseer/convert_similar/citeseer_rn_gcn_vae_betweenness_similar.csv')
citeseer_eigenvector_rn = pd.read_csv('citeseer/convert_similar/citeseer_rn_gcn_vae_eigenvector_similar.csv')
citeseer_pagerank_rn = pd.read_csv('citeseer/convert_similar/citeseer_rn_gcn_vae_pagerank_similar.csv')
citeseer_closeness_rn = pd.read_csv('citeseer/convert_similar/citeseer_rn_gcn_vae_closeness_similar.csv')

citeseer_gravitydegree_rn = pd.read_csv('citeseer/convert_similar/citeseer_rn_gcn_vae_gravitydegree_similar.csv')
citeseer_gravitypagerank_rn = pd.read_csv('citeseer/convert_similar/citeseer_rn_gcn_vae_gravitypagerank_similar.csv')
citeseer_gravitycore_rn = pd.read_csv('citeseer/convert_similar/citeseer_rn_gcn_vae_gravitycore_similar.csv')
citeseer_gravitybetweenness_rn = pd.read_csv('citeseer/convert_similar/citeseer_rn_gcn_vae_gravityeigenvector_similar.csv')
citeseer_gravityeigenvector_rn = pd.read_csv('citeseer/convert_similar/citeseer_rn_gcn_vae_gravityeigenvector_similar.csv')
citeseer_gravitycloseness_rn = pd.read_csv('citeseer/convert_similar/citeseer_rn_gcn_vae_gravitycloseness_similar.csv')
citeseer_uniform_un = pd.read_csv('citeseer/convert_similar/citeseer_tn_gcn_vae_degree_similar.csv')

plt.style.use('science')
plt.style.use('nature')

fig,axes = plt.subplots(figsize = (3.6,2.7),dpi=400)
x = np.linspace(0,1,66)

axes.plot(x,citeseer_degree_rn['mean_similar'],color ='#BC3C29FF',label = ' degree',linewidth = 0.5)
axes.plot(x,citeseer_core_rn['mean_similar'],color ='#20854EFF',label = 'core',linewidth = 0.5)
axes.plot(x,citeseer_pagerank_rn['mean_similar'],color ='#0072B5FF',label = 'pagerank',linewidth = 0.5)
axes.plot(x,citeseer_betweenness_rn['mean_similar'],color ='#E18727FF',label = 'betweenness',linewidth = 0.5)
axes.plot(x,citeseer_closeness_rn['mean_similar'],color ='#7876B1FF',label = 'closeness',linewidth = 0.5)
axes.plot(x,citeseer_eigenvector_rn['mean_similar'],color ='#6F99ADFF',label = ' eigenvector',linewidth = 0.5,linestyle = '-')

axes.plot(x,citeseer_gravitydegree_rn['mean_similar'],color ='#BC3C29FF',label = ' gravitydegree',linewidth = 0.5,linestyle = '-')
axes.plot(x,citeseer_gravitycore_rn['mean_similar'],color ='#20854EFF',label = 'gravitycore',linewidth = 0.5,linestyle = '--')
axes.plot(x,citeseer_gravitypagerank_rn['mean_similar'],color ='#0072B5FF',label = 'gravitypagerank',linewidth = 0.5,linestyle = '--')
axes.plot(x,citeseer_gravitybetweenness_rn['mean_similar'],color ='#E18727FF',label = 'gravitybetweenness',linewidth = 0.5,linestyle = '--')
axes.plot(x,citeseer_gravitycloseness_rn['mean_similar'],color ='#7876B1FF',label = 'gravitycloseness',linewidth = 0.5,linestyle = '--')
axes.plot(x,citeseer_gravityeigenvector_rn['mean_similar'],color ='#6F99ADFF',label = 'gravityeigenvector',linewidth = 0.5,linestyle = '--')
# axes.plot(x,citeseer_similar[:,12],color ='black',label = 'uniform',linewidth = 0.5,linestyle = ':')


#axes.set_title('WS Networks')
axes.set_xlabel('Sampling Ratio(%)',fontsize=6)
axes.set_ylabel('Jaccard similarity coefficient',fontsize=6)
axes.set_title('citeseer',fontsize=6)
axes.tick_params(labelsize=6)
axes.legend(fontsize=4,frameon =False)
axes.set_ylim([0,1])
axes.set_xlim([-0.05,1.05])
axes.tick_params(axis='both', which='both', length=2,pad=2,width=0.6)
axes.grid(False)

# %%
# Samped nodes by probability

ws3k_degree_rn = pd.read_csv('ws3k/convert_similar/ws3k_rn_gcn_vae_degree_similar.csv')
ws3k_core_rn = pd.read_csv('ws3k/convert_similar/ws3k_rn_gcn_vae_core_similar.csv')
ws3k_betweenness_rn = pd.read_csv('ws3k/convert_similar/ws3k_rn_gcn_vae_betweenness_similar.csv')
# ws3k_eigenvector_rn = pd.read_csv('ws3k/convert_similar/ws3k_rn_gcn_vae_eigenvector_similar.csv')
ws3k_pagerank_rn = pd.read_csv('ws3k/convert_similar/ws3k_rn_gcn_vae_pagerank_similar.csv')
ws3k_closeness_rn = pd.read_csv('ws3k/convert_similar/ws3k_rn_gcn_vae_closeness_similar.csv')

ws3k_gravitydegree_rn = pd.read_csv('ws3k/convert_similar/ws3k_rn_gcn_vae_gravitydegree_similar.csv')
ws3k_gravitypagerank_rn = pd.read_csv('ws3k/convert_similar/ws3k_rn_gcn_vae_gravitypagerank_similar.csv')
ws3k_gravitycore_rn = pd.read_csv('ws3k/convert_similar/ws3k_rn_gcn_vae_gravitycore_similar.csv')
ws3k_gravitybetweenness_rn = pd.read_csv('ws3k/convert_similar/ws3k_rn_gcn_vae_gravitybetweenness_similar.csv')
# ws3k_gravityeigenvector_rn = pd.read_csv('ws3k/convert_similar/ws3k_rn_gcn_vae_gravityeigenvector_similar.csv')
ws3k_gravitycloseness_rn = pd.read_csv('ws3k/convert_similar/ws3k_rn_gcn_vae_gravitycloseness_similar.csv')
# ws3k_uniform_un = pd.read_csv('ws3k/convert_similar/ws3k_tn_gcn_vae_degree_similar.csv')

plt.style.use('science')
plt.style.use('nature')

fig,axes = plt.subplots(figsize = (3.6,2.7),dpi=400)
x = np.linspace(0,1,30)

axes.plot(x,ws3k_degree_rn['mean_similar'],color ='#BC3C29FF',label = ' degree',linewidth = 0.5)
axes.plot(x,ws3k_core_rn['mean_similar'],color ='#20854EFF',label = 'core',linewidth = 0.5)
axes.plot(x,ws3k_pagerank_rn['mean_similar'],color ='#0072B5FF',label = 'pagerank',linewidth = 0.5)
axes.plot(x,ws3k_betweenness_rn['mean_similar'],color ='#E18727FF',label = 'betweenness',linewidth = 0.5)
axes.plot(x,ws3k_closeness_rn['mean_similar'],color ='#7876B1FF',label = 'closeness',linewidth = 0.5)
# axes.plot(x,ws3k_eigenvector_rn['mean_similar'],color ='#6F99ADFF',label = ' eigenvector',linewidth = 0.5,linestyle = '-')

axes.plot(x,ws3k_gravitydegree_rn['mean_similar'],color ='#BC3C29FF',label = ' gravitydegree',linewidth = 0.5,linestyle = '-')
axes.plot(x,ws3k_gravitycore_rn['mean_similar'],color ='#20854EFF',label = 'gravitycore',linewidth = 0.5,linestyle = '--')
axes.plot(x,ws3k_gravitypagerank_rn['mean_similar'],color ='#0072B5FF',label = 'gravitypagerank',linewidth = 0.5,linestyle = '--')
axes.plot(x,ws3k_gravitybetweenness_rn['mean_similar'],color ='#E18727FF',label = 'gravitybetweenness',linewidth = 0.5,linestyle = '--')
axes.plot(x,ws3k_gravitycloseness_rn['mean_similar'],color ='#7876B1FF',label = 'gravitycloseness',linewidth = 0.5,linestyle = '--')
# axes.plot(x,ws3k_gravityeigenvector_rn['mean_similar'],color ='#6F99ADFF',label = 'gravityeigenvector',linewidth = 0.5,linestyle = '--')
# axes.plot(x,ws3k_similar[:,12],color ='black',label = 'uniform',linewidth = 0.5,linestyle = ':')


#axes.set_title('WS Networks')
axes.set_xlabel('Sampling Ratio(%)',fontsize=6)
axes.set_ylabel('Jaccard similarity coefficient',fontsize=6)
axes.set_title('ws3k',fontsize=6)
axes.tick_params(labelsize=6)
axes.legend(fontsize=4,frameon =False)
axes.set_ylim([0,1])
axes.set_xlim([-0.05,1.05])
axes.tick_params(axis='both', which='both', length=2,pad=2,width=0.6)
axes.grid(False)



axins = axes.inset_axes([0.1,0.55,0.3,0.42])
axins.plot(x[14:20],ws3k_degree_rn['mean_similar'][14:20],color ='#BC3C29FF',label = 'proba degree',linewidth=0.5)
axins.plot(x[14:20],ws3k_core_rn['mean_similar'][14:20],color ='#20854EFF',label = 'proba core',linewidth=0.5)
axins.plot(x[14:20],ws3k_pagerank_rn['mean_similar'][14:20],color ='#0072B5FF',label = 'proba gravitycore',linewidth=0.5)
axins.plot(x[14:20],ws3k_betweenness_rn['mean_similar'][14:20],color ='#E18727FF',label = 'proba pagerank',linewidth=0.5)
axins.plot(x[14:20],ws3k_closeness_rn['mean_similar'][14:20],color ='#7876B1FF',label = 'proba gravitydegree',linewidth=0.5)


axins.plot(x[14:20],ws3k_gravitydegree_rn['mean_similar'][14:20],color ='#BC3C29FF',label = 'proba degree',linewidth=0.5,linestyle = '--')
axins.plot(x[14:20],ws3k_gravitycore_rn['mean_similar'][14:20],color ='#20854EFF',label = 'proba core',linewidth=0.5,linestyle = '--')
axins.plot(x[14:20],ws3k_gravitypagerank_rn['mean_similar'][14:20],color ='#0072B5FF',label = 'proba gravitycore',linewidth=0.5,linestyle = '--')
axins.plot(x[14:20],ws3k_gravitybetweenness_rn['mean_similar'][14:20],color ='#E18727FF',label = 'proba pagerank',linewidth=0.5,linestyle = '--')
axins.plot(x[14:20],ws3k_gravitycloseness_rn['mean_similar'][14:20],color ='#7876B1FF',label = 'proba gravitydegree',linewidth=0.5,linestyle = '--')



# axins.plot(x[24:34],ws3k_similar[24:34,5],color ='#BC3C29FF',label = 'proba degree',linewidth=0.5,linestyle = '--')
# axins.plot(x[24:34],ws3k_similar[24:34,6],color ='#20854EFF',label = 'proba core',linewidth=0.5,linestyle = '--')
# axins.plot(x[24:34],ws3k_similar[24:34,7],color ='#0072B5FF',label = 'proba gravitycore',linewidth=0.5,linestyle = '--')
# axins.plot(x[24:34],ws3k_similar[24:34,8],color ='#E18727FF',label = 'proba pagerank',linewidth=0.5,linestyle = '--')
# axins.plot(x[24:34],ws3k_similar[24:34,9],color ='#7876B1FF',label = 'proba gravitydegree',linewidth=0.5,linestyle = '--')
# #axins.plot(x[40:45],ws_similar[15:45,5],color ='#FFDC91FF',label = 'proba gravitypagerank',linewidth=0.5)
# axins.plot(x[24:34],ws3k_similar[24:34,10],color ='black',linestyle = ':', label = 'uniform',linewidth=0.5)
axins.set_xticks([], minor=True)
axins.set_yticks([], minor=True)
axes.grid(False)
axes.plot([0.23,0.3],[0.42,0.67],linestyle = '--',color = 'black',linewidth = 0.25)
axes.plot([0.34,0.39],[0.42,0.57],linestyle = '--',color = 'black',linewidth = 0.25)
axins.tick_params(axis='both', which='both', length=1.0)
axins.tick_params(labelsize=5)
axins.grid(False)
tx0 = 0.23
tx1 = 0.34
ty0 = 0.12
ty1  = 0.42
sx = [tx0,tx1,tx1,tx0,tx0]
sy = [ty0,ty0,ty1,ty1,ty0]
axes.plot(sx,sy,'black',linestyle = '--',linewidth=0.25)

# %%
fig,axes = plt.subplots(1,3,figsize=(1.5, 0.45),dpi=400)
x = np.linspace(0,1,54)

axes[0].plot(x,cora_degree_rn['mean_similar'],color ='#BC3C29FF',label = ' degree',linewidth = 0.3)
axes[0].plot(x,cora_core_rn['mean_similar'],color ='#20854EFF',label = 'core',linewidth = 0.3)
axes[0].plot(x,cora_pagerank_rn['mean_similar'],color ='#0072B5FF',label = 'pagerank',linewidth = 0.3)
axes[0].plot(x,cora_betweenness_rn['mean_similar'],color ='#E18727FF',label = 'betweenness',linewidth = 0.3)
axes[0].plot(x,cora_closeness_rn['mean_similar'],color ='#7876B1FF',label = 'closeness',linewidth = 0.3)
axes[0].plot(x,cora_eigenvector_rn['mean_similar'],color ='#6F99ADFF',label = ' eigenvector',linewidth = 0.3,linestyle = '-')

axes[0].plot(x,cora_gravitydegree_rn['mean_similar'],color ='#BC3C29FF',label = ' gravitydegree',linewidth = 0.3,linestyle = '-')
axes[0].plot(x,cora_gravitycore_rn['mean_similar'],color ='#20854EFF',label = 'gravitycore',linewidth = 0.3,linestyle = '--')
axes[0].plot(x,cora_gravitypagerank_rn['mean_similar'],color ='#0072B5FF',label = 'gravitypagerank',linewidth = 0.3,linestyle = '--')
axes[0].plot(x,cora_gravitybetweenness_rn['mean_similar'],color ='#E18727FF',label = 'gravitybetweenness',linewidth = 0.3,linestyle = '--')
axes[0].plot(x,cora_gravitycloseness_rn['mean_similar'],color ='#7876B1FF',label = 'gravitycloseness',linewidth = 0.3,linestyle = '--')
axes[0].plot(x,cora_gravityeigenvector_rn['mean_similar'],color ='#6F99ADFF',label = 'gravityeigenvector',linewidth = 0.3,linestyle = '--')
# axes.plot(x,cora_similar[:,12],color ='black',label = 'uniform',linewidth = 0.3,linestyle = ':')


x = np.linspace(0,1,66)
axes[1].plot(x,citeseer_degree_rn['mean_similar'],color ='#BC3C29FF',label = ' degree',linewidth = 0.3)
axes[1].plot(x,citeseer_core_rn['mean_similar'],color ='#20854EFF',label = 'core',linewidth = 0.3)
axes[1].plot(x,citeseer_pagerank_rn['mean_similar'],color ='#0072B5FF',label = 'pagerank',linewidth = 0.3)
axes[1].plot(x,citeseer_betweenness_rn['mean_similar'],color ='#E18727FF',label = 'betweenness',linewidth = 0.3)
axes[1].plot(x,citeseer_closeness_rn['mean_similar'],color ='#7876B1FF',label = 'closeness',linewidth = 0.3)
axes[1].plot(x,citeseer_eigenvector_rn['mean_similar'],color ='#6F99ADFF',label = ' eigenvector',linewidth = 0.3,linestyle = '-')

axes[1].plot(x,citeseer_gravitydegree_rn['mean_similar'],color ='#BC3C29FF',label = ' gravitydegree',linewidth = 0.3,linestyle = '-')
axes[1].plot(x,citeseer_gravitycore_rn['mean_similar'],color ='#20854EFF',label = 'gravitycore',linewidth = 0.3,linestyle = '--')
axes[1].plot(x,citeseer_gravitypagerank_rn['mean_similar'],color ='#0072B5FF',label = 'gravitypagerank',linewidth = 0.3,linestyle = '--')
axes[1].plot(x,citeseer_gravitybetweenness_rn['mean_similar'],color ='#E18727FF',label = 'gravitybetweenness',linewidth = 0.3,linestyle = '--')
axes[1].plot(x,citeseer_gravitycloseness_rn['mean_similar'],color ='#7876B1FF',label = 'gravitycloseness',linewidth = 0.3,linestyle = '--')
axes[1].plot(x,citeseer_gravityeigenvector_rn['mean_similar'],color ='#6F99ADFF',label = 'gravityeigenvector',linewidth = 0.3,linestyle = '--')



x = np.linspace(0,1,30)
axes[2].plot(x,ws3k_degree_rn['mean_similar'],color ='#BC3C29FF',label = ' degree',linewidth = 0.3)
axes[2].plot(x,ws3k_core_rn['mean_similar'],color ='#20854EFF',label = 'core',linewidth = 0.3)
axes[2].plot(x,ws3k_pagerank_rn['mean_similar'],color ='#0072B5FF',label = 'pagerank',linewidth = 0.3)
axes[2].plot(x,ws3k_betweenness_rn['mean_similar'],color ='#E18727FF',label = 'betweenness',linewidth = 0.3)
axes[2].plot(x,ws3k_closeness_rn['mean_similar'],color ='#7876B1FF',label = 'closeness',linewidth = 0.3)

axes[2].plot(x,ws3k_gravitydegree_rn['mean_similar'],color ='#BC3C29FF',label = ' gravitydegree',linewidth = 0.3,linestyle = '-')
axes[2].plot(x,ws3k_gravitycore_rn['mean_similar'],color ='#20854EFF',label = 'gravitycore',linewidth = 0.3,linestyle = '--')
axes[2].plot(x,ws3k_gravitypagerank_rn['mean_similar'],color ='#0072B5FF',label = 'gravitypagerank',linewidth = 0.3,linestyle = '--')
axes[2].plot(x,ws3k_gravitybetweenness_rn['mean_similar'],color ='#E18727FF',label = 'gravitybetweenness',linewidth = 0.3,linestyle = '--')
axes[2].plot(x,ws3k_gravitycloseness_rn['mean_similar'],color ='#7876B1FF',label = 'gravitycloseness',linewidth = 0.3,linestyle = '--')

axins = axes[2].inset_axes([0.1,0.35,0.3,0.42])
axins.plot(x[14:20],ws3k_degree_rn['mean_similar'][14:20],color ='#BC3C29FF',label = 'proba degree',linewidth=0.3)
axins.plot(x[14:20],ws3k_core_rn['mean_similar'][14:20],color ='#20854EFF',label = 'proba core',linewidth=0.3)
axins.plot(x[14:20],ws3k_pagerank_rn['mean_similar'][14:20],color ='#0072B5FF',label = 'proba gravitycore',linewidth=0.3)
axins.plot(x[14:20],ws3k_betweenness_rn['mean_similar'][14:20],color ='#E18727FF',label = 'proba pagerank',linewidth=0.3)
axins.plot(x[14:20],ws3k_closeness_rn['mean_similar'][14:20],color ='#7876B1FF',label = 'proba gravitydegree',linewidth=0.3)


axins.plot(x[14:20],ws3k_gravitydegree_rn['mean_similar'][14:20],color ='#BC3C29FF',label = 'proba degree',linewidth=0.3,linestyle = '--')
axins.plot(x[14:20],ws3k_gravitycore_rn['mean_similar'][14:20],color ='#20854EFF',label = 'proba core',linewidth=0.3,linestyle = '--')
axins.plot(x[14:20],ws3k_gravitypagerank_rn['mean_similar'][14:20],color ='#0072B5FF',label = 'proba gravitycore',linewidth=0.3,linestyle = '--')
axins.plot(x[14:20],ws3k_gravitybetweenness_rn['mean_similar'][14:20],color ='#E18727FF',label = 'proba pagerank',linewidth=0.3,linestyle = '--')
axins.plot(x[14:20],ws3k_gravitycloseness_rn['mean_similar'][14:20],color ='#7876B1FF',label = 'proba gravitydegree',linewidth=0.3,linestyle = '--')





axes[0].set_ylabel(r'Similarity Coefficient $\tau$',fontsize=2,labelpad=2)

axes[0].set_title('Cora',fontsize=2)
axes[1].set_title('Citeseer',fontsize=2)
axes[2].set_title('WS 3000',fontsize=2)


for ax in axes.flat:

    ax.set_xlabel('Sampling Ratio (\%)',fontsize=2,labelpad=2)
    ax.tick_params(labelsize=6)
    # axes[0].legend(fontsize=4,frameon =False)
    ax.set_ylim([0,1])
    ax.set_xlim([-0.05,1.05])
    ax.tick_params(axis='both', which='both', length=2,pad=2,width=0.6)
    ax.tick_params(labelsize=2)
    ax.grid(False)

plt.tight_layout()

# %%
plt.style.use('nature')

fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(4, 1), dpi=1200)


x = np.linspace(0,1,54)

axes[0].plot(x,cora_degree_rn['mean_similar'],color ='#BC3C29FF',label = ' degree',linewidth = 0.3)
axes[0].plot(x,cora_core_rn['mean_similar'],color ='#20854EFF',label = 'core',linewidth = 0.3)
axes[0].plot(x,cora_pagerank_rn['mean_similar'],color ='#0072B5FF',label = 'pagerank',linewidth = 0.3)
axes[0].plot(x,cora_betweenness_rn['mean_similar'],color ='#E18727FF',label = 'betweenness',linewidth = 0.3)
axes[0].plot(x,cora_closeness_rn['mean_similar'],color ='#7876B1FF',label = 'closeness',linewidth = 0.3)
axes[0].plot(x,cora_eigenvector_rn['mean_similar'],color ='#6F99ADFF',label = ' eigenvector',linewidth = 0.3)

axes[0].plot(x,cora_gravitydegree_rn['mean_similar'],color ='#BC3C29FF',label = ' gravitydegree',linewidth = 0.3,linestyle = '--')
axes[0].plot(x,cora_gravitycore_rn['mean_similar'],color ='#20854EFF',label = 'gravitycore',linewidth = 0.3,linestyle = '--')
axes[0].plot(x,cora_gravitypagerank_rn['mean_similar'],color ='#0072B5FF',label = 'gravitypagerank',linewidth = 0.3,linestyle = '--')
axes[0].plot(x,cora_gravitybetweenness_rn['mean_similar'],color ='#E18727FF',label = 'gravitybetweenness',linewidth = 0.3,linestyle = '--')
axes[0].plot(x,cora_gravitycloseness_rn['mean_similar'],color ='#7876B1FF',label = 'gravitycloseness',linewidth = 0.3,linestyle = '--')
axes[0].plot(x,cora_gravityeigenvector_rn['mean_similar'],color ='#6F99ADFF',label = 'gravityeigenvector',linewidth = 0.3,linestyle = '--')
axes[0].set_xlabel('Sampling Ratio (\%)',fontsize=2,labelpad=2)
axes[0].set_ylabel(r'Similarity Coefficient $\tau$',fontsize=2,labelpad=2)
#axes[0].set_title(,fontsize=3,bbox_to_anchor=(0.5, 0.95))
axes[0].text(0.5, 1.05, 'Cora', transform=axes[0].transAxes, ha='center', va='center', bbox=dict(facecolor='none', edgecolor='none', boxstyle='round', alpha=0.0), fontsize=2.5)

axes[0].tick_params(labelsize=6)
#axes[0].legend(fontsize=4)
axes[0].grid(False)

x = np.linspace(0,1,66)
axes[1].plot(x,citeseer_degree_rn['mean_similar'],color ='#BC3C29FF',label = ' degree',linewidth = 0.3)
axes[1].plot(x,citeseer_core_rn['mean_similar'],color ='#20854EFF',label = 'core',linewidth = 0.3)
axes[1].plot(x,citeseer_pagerank_rn['mean_similar'],color ='#0072B5FF',label = 'pagerank',linewidth = 0.3)
axes[1].plot(x,citeseer_betweenness_rn['mean_similar'],color ='#E18727FF',label = 'betweenness',linewidth = 0.3)
axes[1].plot(x,citeseer_closeness_rn['mean_similar'],color ='#7876B1FF',label = 'closeness',linewidth = 0.3)
axes[1].plot(x,citeseer_eigenvector_rn['mean_similar'],color ='#6F99ADFF',label = ' eigenvector',linewidth = 0.3,linestyle = '-')

axes[1].plot(x,citeseer_gravitydegree_rn['mean_similar'],color ='#BC3C29FF',label = ' gravitydegree',linewidth = 0.3,linestyle = '--')
axes[1].plot(x,citeseer_gravitycore_rn['mean_similar'],color ='#20854EFF',label = 'gravitycore',linewidth = 0.3,linestyle = '--')
axes[1].plot(x,citeseer_gravitypagerank_rn['mean_similar'],color ='#0072B5FF',label = 'gravitypagerank',linewidth = 0.3,linestyle = '--')
axes[1].plot(x,citeseer_gravitybetweenness_rn['mean_similar'],color ='#E18727FF',label = 'gravitybetweenness',linewidth = 0.3,linestyle = '--')
axes[1].plot(x,citeseer_gravitycloseness_rn['mean_similar'],color ='#7876B1FF',label = 'gravitycloseness',linewidth = 0.3,linestyle = '--')
axes[1].plot(x,citeseer_gravityeigenvector_rn['mean_similar'],color ='#6F99ADFF',label = 'gravityeigenvector',linewidth = 0.3,linestyle = '--')

axes[1].set_xlabel('Sampling Ratio (\%)',fontsize=2,labelpad=2)
axes[1].text(0.5, 1.05,'Citeseer', transform=axes[1].transAxes, ha='center', va='center', bbox=dict(facecolor='none', edgecolor='none', boxstyle='round', alpha=0.0), fontsize=2.5)


#axes[1].set_ylabel('Mutual Information',fontsize=6)
#
axes[1].tick_params(labelsize=2)
#axes[1].legend(fontsize=4)
axes[1].grid(False)




x = np.linspace(0,1,30)
axes[2].plot(x,ws3k_degree_rn['mean_similar'],color ='#BC3C29FF',label = ' degree',linewidth = 0.3)
axes[2].plot(x,ws3k_core_rn['mean_similar'],color ='#20854EFF',label = 'core',linewidth = 0.3)
axes[2].plot(x,ws3k_pagerank_rn['mean_similar'],color ='#0072B5FF',label = 'pagerank',linewidth = 0.3)
axes[2].plot(x,ws3k_betweenness_rn['mean_similar'],color ='#E18727FF',label = 'betweenness',linewidth = 0.3)
axes[2].plot(x,ws3k_closeness_rn['mean_similar'],color ='#7876B1FF',label = 'closeness',linewidth = 0.3)

axes[2].plot(x,ws3k_gravitydegree_rn['mean_similar'],color ='#BC3C29FF',label = ' gravitydegree',linewidth = 0.3,linestyle = '--')
axes[2].plot(x,ws3k_gravitycore_rn['mean_similar'],color ='#20854EFF',label = 'gravitycore',linewidth = 0.3,linestyle = '--')
axes[2].plot(x,ws3k_gravitypagerank_rn['mean_similar'],color ='#0072B5FF',label = 'gravitypagerank',linewidth = 0.3,linestyle = '--')
axes[2].plot(x,ws3k_gravitybetweenness_rn['mean_similar'],color ='#E18727FF',label = 'gravitybetweenness',linewidth = 0.3,linestyle = '--')
axes[2].plot(x,ws3k_gravitycloseness_rn['mean_similar'],color ='#7876B1FF',label = 'gravitycloseness',linewidth = 0.3,linestyle = '--')


#axes.set_title('WS Networks')
axes[2].set_xlabel('Sampling Ratio(\%)',fontsize=2,labelpad=2)
axes[2].tick_params(labelsize=10)


axins = axes[2].inset_axes([0.17,0.55,0.3,0.42])
axins.plot(x[14:20],ws3k_degree_rn['mean_similar'][14:20],color ='#BC3C29FF',label = 'proba degree',linewidth=0.3)
axins.plot(x[14:20],ws3k_core_rn['mean_similar'][14:20],color ='#20854EFF',label = 'proba core',linewidth=0.3)
axins.plot(x[14:20],ws3k_pagerank_rn['mean_similar'][14:20],color ='#0072B5FF',label = 'proba gravitycore',linewidth=0.3)
axins.plot(x[14:20],ws3k_betweenness_rn['mean_similar'][14:20],color ='#E18727FF',label = 'proba pagerank',linewidth=0.3)
axins.plot(x[14:20],ws3k_closeness_rn['mean_similar'][14:20],color ='#7876B1FF',label = 'proba gravitydegree',linewidth=0.3)


axins.plot(x[14:20],ws3k_gravitydegree_rn['mean_similar'][14:20],color ='#BC3C29FF',label = 'proba degree',linewidth=0.3,linestyle = '--')
axins.plot(x[14:20],ws3k_gravitycore_rn['mean_similar'][14:20],color ='#20854EFF',label = 'proba core',linewidth=0.3,linestyle = '--')
axins.plot(x[14:20],ws3k_gravitypagerank_rn['mean_similar'][14:20],color ='#0072B5FF',label = 'proba gravitycore',linewidth=0.3,linestyle = '--')
axins.plot(x[14:20],ws3k_gravitybetweenness_rn['mean_similar'][14:20],color ='#E18727FF',label = 'proba pagerank',linewidth=0.3,linestyle = '--')
axins.plot(x[14:20],ws3k_gravitycloseness_rn['mean_similar'][14:20],color ='#7876B1FF',label = 'proba gravitydegree',linewidth=0.3,linestyle = '--')

axes[2].text(0.5, 1.05,'WS 3000', transform=axes[2].transAxes, ha='center', va='center', bbox=dict(facecolor='none', edgecolor='none', boxstyle='round', alpha=0.0), fontsize=2.5)

axins.set_xticks([], minor=True)
axins.set_yticks([], minor=True)
axes[2].grid(False)
# axes[2].plot([0.23,0.2],[0.42,0.57],linestyle = '--',color = 'black',linewidth = 0.12)
# axes[2].plot([0.34,0.47],[0.42,0.57],linestyle = '--',color = 'black',linewidth = 0.12)
axins.tick_params(axis='both', which='both', length=0.3,pad=0.5,width=0.1)

axins.spines['left'].set_linewidth(0.1)
axins.spines['bottom'].set_linewidth(0.1)
axins.spines['top'].set_linewidth(0.1)
axins.spines['right'].set_linewidth(0.1)
axins.tick_params(labelsize=1.5)
axins.grid(False)
tx0 = 0.46
tx1 = 0.64
ty0 = 0.28
ty1  = 0.52
sx = [tx0,tx1,tx1,tx0,tx0]
sy = [ty0,ty0,ty1,ty1,ty0]
axes[2].plot(sx,sy,'black',linestyle = '--',linewidth=0.18)





lines1, labels1 = axes[0].get_legend_handles_labels()
lines2, labels2 = axes[1].get_legend_handles_labels()
lines3, labels3 = axes[2].get_legend_handles_labels()
lines = lines1 + lines2 + lines3 
labels = labels1 + labels2 + labels3




for i,ax in enumerate(axes.flat):
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.tick_params(labelsize=2, which='both', length=1,  top=False,right=False)
    ax.spines['left'].set_linewidth(0.3)
    ax.spines['bottom'].set_linewidth(0.3)
    ax.spines['top'].set_linewidth(0.3)
    ax.spines['right'].set_linewidth(0.3)
    #ax.xaxis.set_ticks_position('bottom')
    #ax.yaxis.set_ticks_position('left')

    # Set common ticks and labels for the first 12 subplots
    if i < 4:
        ax.set_yticks([0, 0.2, 0.4, 0.6,0.8,1])
        ax.set_xticks(np.linspace(0, 1, 6))
        ax.set_xticklabels(np.array([0, 0.2, 0.4, 0.6,0.8,1]).astype(float))
        ax.set_xticks([], minor=True)
        ax.set_yticks([], minor=True)
        ax.set_ylim(0,1)
        ax.tick_params(axis='both', which='both', length=1,labelsize=3,pad=1,width=0.2)

fig.legend(lines1, labels1, fontsize=1.6, loc='lower center', bbox_to_anchor=(1.0,0.025),ncol=1)
plt.subplots_adjust(wspace=0.2)
eps_fig = plt.gcf() # 'get current figure'
eps_fig.savefig('C:\\Users\\WENJIA\\Downloads\\rn_similar.pdf', dpi=600)
# eps_fig.savefig('papers/citation.png', dpi=1200)
# plt.show()

# %%
# Samped nodes by probability

cath_degree_rn = pd.read_csv('cath/convert_similar/cath_rn_gcn_vae_degree_similar.csv')
cath_core_rn = pd.read_csv('cath/convert_similar/cath_rn_gcn_vae_core_similar.csv')
cath_betweenness_rn = pd.read_csv('cath/convert_similar/cath_rn_gcn_vae_betweenness_similar.csv')
cath_eigenvector_rn = pd.read_csv('cath/convert_similar/cath_rn_gcn_vae_eigenvector_similar.csv')
cath_pagerank_rn = pd.read_csv('cath/convert_similar/cath_rn_gcn_vae_pagerank_similar.csv')
cath_closeness_rn = pd.read_csv('cath/convert_similar/cath_rn_gcn_vae_closeness_similar.csv')

cath_gravitydegree_rn = pd.read_csv('cath/convert_similar/cath_rn_gcn_vae_gravitydegree_similar.csv')
cath_gravitypagerank_rn = pd.read_csv('cath/convert_similar/cath_rn_gcn_vae_gravitypagerank_similar.csv')
cath_gravitycore_rn = pd.read_csv('cath/convert_similar/cath_rn_gcn_vae_gravitycore_similar.csv')
cath_gravitybetweenness_rn = pd.read_csv('cath/convert_similar/cath_rn_gcn_vae_gravityeigenvector_similar.csv')
cath_gravityeigenvector_rn = pd.read_csv('cath/convert_similar/cath_rn_gcn_vae_gravityeigenvector_similar.csv')
cath_gravitycloseness_rn = pd.read_csv('cath/convert_similar/cath_rn_gcn_vae_gravitycloseness_similar.csv')
cath_uniform_un = pd.read_csv('cath/convert_similar/cath_tn_gcn_vae_degree_similar.csv')


plt.style.use('science')
plt.style.use('nature')

fig,axes = plt.subplots(figsize = (3.6,2.7),dpi=400)
x = np.linspace(0,1,54)

axes.plot(x,cath_degree_rn['mean_similar'],color ='#BC3C29FF',label = ' degree',linewidth = 0.5)
axes.plot(x,cath_core_rn['mean_similar'],color ='#20854EFF',label = 'core',linewidth = 0.5)
axes.plot(x,cath_pagerank_rn['mean_similar'],color ='#0072B5FF',label = 'pagerank',linewidth = 0.5)
axes.plot(x,cath_betweenness_rn['mean_similar'],color ='#E18727FF',label = 'betweenness',linewidth = 0.5)
axes.plot(x,cath_closeness_rn['mean_similar'],color ='#7876B1FF',label = 'closeness',linewidth = 0.5)
axes.plot(x,cath_eigenvector_rn['mean_similar'],color ='#6F99ADFF',label = ' eigenvector',linewidth = 0.5,linestyle = '-')

axes.plot(x,cath_gravitydegree_rn['mean_similar'],color ='#BC3C29FF',label = ' gravitydegree',linewidth = 0.5,linestyle = '-')
axes.plot(x,cath_gravitycore_rn['mean_similar'],color ='#20854EFF',label = 'gravitycore',linewidth = 0.5,linestyle = '--')
axes.plot(x,cath_gravitypagerank_rn['mean_similar'],color ='#0072B5FF',label = 'gravitypagerank',linewidth = 0.5,linestyle = '--')
axes.plot(x,cath_gravitybetweenness_rn['mean_similar'],color ='#E18727FF',label = 'gravitybetweenness',linewidth = 0.5,linestyle = '--')
axes.plot(x,cath_gravitycloseness_rn['mean_similar'],color ='#7876B1FF',label = 'gravitycloseness',linewidth = 0.5,linestyle = '--')
axes.plot(x,cath_gravityeigenvector_rn['mean_similar'],color ='#6F99ADFF',label = 'gravityeigenvector',linewidth = 0.5,linestyle = '--')
# axes.plot(x,cath_similar[:,12],color ='black',label = 'uniform',linewidth = 0.5,linestyle = ':')



#axes.set_title('WS Networks')
axes.set_xlabel('Sampling Ratio(%)',fontsize=6)
axes.set_ylabel('Jaccard similarity coefficient',fontsize=6)
axes.set_title('cath',fontsize=6)
axes.tick_params(labelsize=6)
axes.legend(fontsize=4,frameon =False)
axes.set_ylim([0,1])
axes.set_xlim([-0.05,1.05])
axes.tick_params(axis='both', which='both', length=2,pad=2,width=0.6)
axes.grid(False)
